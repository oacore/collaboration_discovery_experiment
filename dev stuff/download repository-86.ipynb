# %%
from urllib2 import urlopen
from urllib import urlencode
from urllib import quote_plus
# import urllib.parse
import json
import pprint

class CoreApiRequestor:

    def __init__(self, endpoint, api_key):
        self.endpoint = endpoint
        self.api_key = api_key
        #defaults
        self.pagesize = 100
        self.page = 1

    def parse_response(self, decoded):
        res = []
        for item in decoded['data']:
            doi = None
            if 'identifiers' in item:
                for identifier in item['identifiers']:
                    if identifier and identifier.startswith('doi:'):
                        doi = identifier
                        break
            res.append([item['title'], doi])
        return res

    def request_url(self, url):
        print(url)
        response = urlopen(url)
        html = response.read()
        return html

    def get_method_query_request_url(self,method,query,fullText,page):
        if (fullText):
            fullText = 'true'
        else:
            fullText = 'false'
        params = {
            'apiKey':self.api_key,
            'page':page,
            'pageSize':self.pagesize,
            'fulltext':fullText
        }
        return self.endpoint + method + '/' + quote_plus(query) + '?' + urlencode(params)

    def get_up_to_20_pages_of_query(self,method,query,fulltext):
        url = self.get_method_query_request_url(method,query,fulltext,1)
        all_articles=[]
        resp = self.request_url(url)
        result = json.loads(resp.decode('utf-8'))
        all_articles.append(result)
        if (result['totalHits']>100):
            numOfPages = int(result['totalHits']/self.pagesize)  #rounds down
            if (numOfPages>20):
                numOfPages=20
            for i in range(2,numOfPages):
                url = self.get_method_query_request_url(method,query,False,i)
                print(url)
                resp =self.request_url(url)
                all_articles.append(json.loads(resp.decode('utf-8')))
        return all_articles
    
    def get_repository_articles_fulltext_as_dict(self,repository_id):
        return ""
    
    def get_search_repository_request_url(self,repoQuery,page=1,pageSize=10):
        params={
            'apiKey':self.api_key,
            'page':page,
            'pageSize':pageSize
        }
        return self.endpoint + "/repositories/search/"+quote_plus(repoQuery)+'?'+urlencode(params)
    
    def search_repository_ids_by_name(self,repoName):
        discoverRepoUrl = self.get_search_repository_request_url(repoName)
        resp = self.request_url(discoverRepoUrl)
        result = json.loads(resp.decode('utf-8'))
        for item in result['data']:
            if 'name' in item:
                name = item['name']
            if 'id' in item:
                id = item['id']
            repos[id]=name
        return repos
    
    def get_count_articles_of_repository_url(self,repoId,withFullText):
        ft = 'false'
        if(withFullText):
            ft = 'true'
                
        params = {
            'apiKey':self.api_key,
            'fulltext':ft
        }    
        return self.endpoint + "/articles/search/repositories.id:"+repoId+'?'+urlencode(params)
    
    def count_articles_of_repository(self,repoId,withFullText=False):
        countArticlesOfRepoUrl = self.get_count_articles_of_repository_url(repoId,withFullText)
        print(countArticlesOfRepoUrl)
        resp = self.request_url(countArticlesOfRepoUrl)
        result = json.loads(resp.decode('utf-8'))
        return result['totalHits']
    
    def get_url_of_download_articles_of_repository(self,repoId,fullText,page,pageSize):
        params={
            'apiKey':self.api_key,
            'page':page,
            'pageSize':pageSize,
            'fulltext':fullText
               }
        return self.endpoint + "/articles/search/repositories.id:"+str(repoId)+'?'+urlencode(params)
    
    def download_articles_of_repository(self, repoId, fulltext=True, page=1, pageSize=100):
        url = self.get_url_of_download_articles_of_repository(repoId,fulltext,page,pageSize)
        all_articles=[]
        resp = self.request_url(url)
        result = json.loads(resp.decode('utf-8'))
        if (result['totalHits']>100):
            numOfPages = int(result['totalHits']/self.pagesize)  #rounds down
            if (numOfPages>5):
                numOfPages=5
            for i in range(2,numOfPages):
                url = self.get_url_of_download_articles_of_repository(repoId,fulltext,page,pageSize)
                print(url)
                resp =self.request_url(url)
                all_articles.append(json.loads(resp.decode('utf-8')))
        return all_articles

# %%
'''
Initialise parameters
'''
# init 
endpoint = 'https://core.ac.uk/api-v2'

'''
********************************************
Add your own api key below
'''
api_key =""
# or get it from a config file
file = open("api_key.secret","r") 
api_key=file.read()
'''
********************************************
'''
'''
Create your api object
'''
api = CoreApiRequestor(endpoint,api_key)

# %%
api.get_url_of_download_articles_of_repository(39,True,1,100)
# Out:
# 'https://core.ac.uk/api-v2/articles/search/repositories.id:39?fulltext=True&apiKey=20hIsS1F5j4D2C2iXrg4Wxf7VTp4Xt1j&page=1&pageSize=100'

# %%
url = api.get_url_of_download_articles_of_repository(1,True,39,12)

# %%
import pickle

# %%
repoId=86
'''
Use page size 50 
-
store as pickle every 200 articles (4 pages)
in the end you will have in the cwd files:
all_articles_on1_1.pkl
all_articles_on1_2.pkl
all_articles_on1_3.pkl
...

'''
all_articles=[]
for i in range(1,60):
    url = api.get_url_of_download_articles_of_repository(repoId,True,i,50)
    response = urlopen(url)
    resp = response.read()
    result = json.loads(resp.decode('utf-8'))
    all_articles.append(result)
    if (i%4==0):
        pickle.dump(all_articles,open('all_articles_on'+str(repoId)+'_'+str(i/4)+'.pkl','wb'),pickle.HIGHEST_PROTOCOL)
        all_articles=[]

# %%
try:
    articles = pickle.load(open('all_articles_on86_1.pkl','rb'))
except (OSError,IOError) as e:
    print(e)

# %%
articles[0]['data'][0]
# Out:
# {u'authors': [u'Mootien, Namasoondrum P.',
#   u'Warren, James P.',
#   u'Morris, Dick',
#   u'Enoch, Marcus P.'],
#  u'contributors': [],
#  u'datePublished': u'2013',
#  u'description': u'Aviation globally is characterised by significant change and consequently the future of the sector has always been difficult to predict. This study adopts a systemic approach based on findings from exploratory interviews with UK aviation academics to: determine the roles of stakeholders in the air transport system; report the current issues facing the sector; explore how these issues interact and impact on the stakeholders in the system; and speculate on the future implications. Six core stakeholders are identified: airlines, airports, consumers, manufacturers, governing institutions and interest groups. Nine core issues are reported, namely: local environment, climate change, peak oil, the state of the economy, social norms, demographics, disruptive events, national (or international) regulations and capacity. A matrix of interactions and their impacts and implications for managing the aviation system is then presented',
#  u'fullText': u'Open Research Online\nThe Open University\u2019s repository of research publications\nand other research outputs\nMapping expert perspectives of the aviation sector\nJournal Article\nHow to cite:\nMootien, Namasoondrum P.; Warren, James P.; Morris, Dick and Enoch, Marcus P. (2012). Mapping\nexpert perspectives of the aviation sector. International Journal of Environmental Technology and Manage-\nment (In press).\nFor guidance on citations see FAQs.\nc\xa9 Inderscience\nVersion: Accepted Manuscript\nLink(s) to article on publisher\u2019s website:\nhttp://www.inderscience.com/browse/index.php?journalID=11\nCopyright and Moral Rights for the articles on this site are retained by the individual authors and/or other copy-\nright owners. For more information on Open Research Online\u2019s data policy on reuse of materials please consult\nthe policies page.\noro.open.ac.uk\nInternational Journal of Environmental Technology & Management, 2012, pp. 1-21.  1 \nMapping Expert Perspectives of the Aviation Sector \n \nNamasoondrum P Mootien a, James P Warren (*corresponding author) b,  Dick Morrisc, and \nMarcus P Enoch d   \n \nABSTRACT \nAviation globally is characterised by significant change and consequently the future of the \nsector has always been difficult to predict. This study adopts a systemic approach based on \nfindings from exploratory interviews with UK aviation academics to: determine the roles of \nstakeholders in the air transport system; report the current issues facing the sector; explore \nhow these issues interact and impact on the stakeholders in the system; and speculate on the \nfuture implications. Six core stakeholders are identified: airlines, airports, consumers, \nmanufacturers, governing institutions and interest groups. Nine core issues are reported, \nnamely: local environment, climate change, peak oil, the state of the economy, social norms, \ndemographics, disruptive events, national (or international) regulations and capacity. A \nmatrix of interactions and their impacts and implications for managing the aviation system is \nthen presented.  \nKeywords: aviation issues; air transport; future scenarios; stakeholders; expert perspectives; \nsoft systems methodology (SSM); airlines; airports; exploratory interviews \n \n1 INTRODUCTION  \nIn recent decades the aviation sector across the world has undergone a period of significant \nchange and seems at times according to some to be facing a more uncertain future McKelvey \n(2002). The sector has always been engaged in attempts to model its own trajectory in terms \nof overall growth both in the short and medium term. Some (e.g. Kivits et al (2010) and \nSigourdis et al (2010)) suggest that currently the entire sector is \u2018locked-in\u2019 to a deep aviation \nparadigm which relies heavily on a space and time rich landscape due to the requirements of \nthe highly complex technological regime in which aviation craft, manufacturers and airports \nfunction. This paper argues that due to high investments in research and development that \nlong periods of time are required to reach profitability. These slow processes of \u2018product \nlifetimes\u2019 ranging from 30-40 years require long times for change. Airports similarly require \nlarge spaces to operate to disperse not only craft (on the ground and in airspace) but to also \nreduce negative externalities such as noise, visual intrusion and local air quality issues.  \n                                                 \n \na\n School of Sustainable Development and Tourism (SSDT), University of Technology, Mauritius, La Tour \nKoenig, Pointe-aux-Sables, Mauritius \nb\n The Design Group (Department of Design, Development, Environment & Materials), The Open University, \nMilton Keynes, MK7 6AA, UK * james.warren@open.ac.uk \nc\n Visiting Fellow of Department of Communications & Systems, The Open University, Milton Keynes, MK7 \n6AA, UK \nd\n Transport Studies Group, School of Civil and Building E ...
#  u'fulltextIdentifier': u'https://core.ac.uk/download/pdf/2832385.pdf',
#  u'id': u'2832385',
#  u'identifiers': [u'oai:open.ac.uk.OAI2:33619', None],
#  u'language': {u'code': u'en', u'id': 9, u'name': u'English'},
#  u'oai': u'oai:open.ac.uk.OAI2:33619',
#  u'relations': [],
#  u'repositories': [{u'citationCount': 0,
#    u'citationDoiCount': 0,
#    u'citationFilesDb': 0,
#    u'citationWithDocCount': 0,
#    u'crawlingLimit': 0,
#    u'databaseDeletedPdfCount': 0,
#    u'databaseDeletedRecordCount': 0,
#    u'databaseIndexCount': 0,
#    u'databasePdfCount': 0,
#    u'databasePdfLinkCount': 0,
#    u'databaseRecordCount': 0,
#    u'databaseTextCount': 0,
#    u'databaseTextNotDeletedCount': 0,
#    u'description': None,
#    u'disabled': False,
#    u'documentDoiCount': 0,
#    u'documentDoiWithFulltextCount': 0,
#    u'hardDriveCitationFiles': 0,
#    u'hardDriveDeletedPdfCount': 0,
#    u'hardDriveDeletedTextCount': 0,
#    u'hardDrivePdfCount': 0,
#    u'hardDrivePdfSize': 0,
#    u'hardDriveTextCount': 0,
#    u'id': u'86',
#    u'indexJournalCount': 0,
#    u'indexRecordCount': 0,
#    u'indexTextCount': 0,
#    u'indexTextCountDB': 0,
#    u'indexTextNotDeletedCount': 0,
#    u'indexedDisabledDB': 0,
#    u'indexedPdfDB': 0,
#    u'journal': None,
#    u'journalMetadataAge': None,
#    u'journalMetadataExtractionDate': None,
#    u'journalMetadataSize': 0,
#    u'lastUpdateTime': None,
#    u'metadataAge': None,
#    u'metadataAlloweInIndexCount': 0,
#    u'metadataDeletedInIndexCount': 0,
#    u'metadataDeletedRecordCount': 0,
#    u'metadataDisabledInIndexCount': 0,
#    u'metadataExtractionDate': None,
#    u'metadataFormat': None,
#    u'metadataInIndexCount': 0,
#    u'metadataLinkCount': 0,
#    u'metadataOnlyIndex': 0,
#    u'metadataRecordCount': 0,
#    u'metadataSize': 0,
#    u'name': u'Open Research Online',
#    u'nrUpdates': 0,
#    u'openDoarId': 0,
#    u'pdfStatus': None,
#    u'physicalName': u'noname',
#    u'repositoryLocation': None,
#    u'software': None,
#    u'source': None,
#    u'uri': None,
#    u'uriJournals': None}],
#  u'subjects': [],
#  u'title': u'Mapping expert perspectives of the aviation sector',
#  u'topics': [],
#  u'types': [],
#  u'year': 2013}

# %%
text = articles[0]['data'][0]['fullText']

# %%
import re
match = re.findall(r'[\w\.-]+@[\w\.-]+', text)

# %%
match
# Out:
# [u'james.warren@open.ac.uk']

# %%
import re
all_emails = []
for page_pickle in range(1,10):
    try:
        articles = pickle.load(open('all_articles_on39_'+str(page_pickle)+'.pkl','rb'))
        for page in range(0,len(articles)):
            for item in articles[page]['data']:
                text = item['fullText']
                match = re.findall(r'[\w\.-]+@[\w\.-]+', text)
                print(match)
                all_emails.append(match)
    except (OSError,IOError) as e:
        print(e)
# Out:
# [u'j.k.knox@sms.ed.ac.uk', u'MOOCs@Edinburgh', u'78233395@N02', u'MOOCs@Edinburgh']
# [u'crfr@ed.ac.uk']
# [u'sarah.macpherson@ed.ac.uk']
# []
# [u'crfr@ed.ac.uk']
# [u'ibethune@epcc.ed.ac.uk', u'ibethune@epcc.ed.ac.uk']
# []
# [u'crfr@ed.ac.uk']
# []
# [u'h.lam@ed.ac.uk']
# []
# [u'g.pennetta@ed.ac.uk', u'journals.permission@oup.com']
# []
# []
# [u'crfr@ed.ac.uk']
# [u'crfr@ed.ac.uk']
# [u'thomas.bak@ed.ac.uk']
# [u'crfr@ed.ac.uk']
# []
# [u'e-Learning@Ed']
# [u'h.lam@ed.ac.uk']
# [u'crfr@ed.ac.uk']
# [u'h.lam@ed.ac.uk']
# [u'crfr@ed.ac.uk']
# []
# [u'j.gales@ed.ac.uk', u'c.maluk@ed.ac.uk', u'luke.bisby@ed.ac.uk']
# [u'h.lam@ed.ac.uk']
# []
# [u'crfr@ed.ac.uk']
# [u'ibethune@epcc.ed.ac.uk']
# [u'crfr@ed.ac.uk']
# [u'helpdesk@hector.ac.uk.']
# [u'd.ahiaga-dagbui@ed.ac.uk', u'simon.smith@ed.ac.uk']
# [u'Giovanni.terrasi@empa.ch', u'c.maluk@ed.ac.uk', u'luke.bisby@ed.ac.uk', u'erich.hugi@empa.ch', u'kanik@sacac.ch']
# []
# []
# []
# [u's1135017@sms.ed.ac.uk', u's.abrahams@ed.ac.uk', u's1135017@sms.ed.ac.uk', u's.abrahams@ed.ac.uk']
# [u'Martine.Manuel@ed.ac.uk', u't.pratt@ed.ac.uk', u'mmltarn@yahoo.com.cn', u'g.jeffery@ucl.ac.uk', u'David.Price@ed.ac.uk']
# [u'bundy@ed.ac.uk.', u'gordon@uk.ac.ed.aisb.']
# []
# [u'chris.burton@ed.ac.uk', u'J.Knoop@nkcv.umcn.nl', u'nikola.popovic@ed.ac.uk', u'michael.sharpe@ed.ac.uk', u'G.Bleijenberg@nkcv.umcn.nl']
# [u'caroline.lovelock@clneuro.ox.ac.uk']
# []
# [u'fausto@irst.itc.it.', u'A.Bundy@ed.ac.uk.', u'rseba@mrg.dist.unige.it.', u'toby@irst.itc.it.', u'...@C', u'...@C', u'X@Y', u'x@yVx', u'x@y', u'x@z.', u'x@y', u'x@y', u'x@z', u'x@y', u'x@y', u'x@y', u'X@Y', u'x@y', u'x@y', u'x@y', u'l-x@y', u'then.r@y', u'Art@icitr', u'Art@cial', u'Art@xz', u'Ar@cial']
# [u'Mark.Bastin@ed.ac.uk', u'Mark.Bastin@ed.ac.uk']
# [u'r.c.vipperla@sms.ed.ac.uk']
# [u'raj.bhopal@ed.ac.uk']
# [u'Joanna.Wardlaw@ed.ac.uk.']
# [u'bartosz@karaszewski.org', u'ralph.thomas@nhs.net', u'francesca.chappell@ed.ac.uk', u'paul.armitage@ed.ac.uk', u'trevor.carpenter@ed.ac.uk', u'katherine.lymer@ed.ac.uk', u'martin.dennis@ed.ac.uk', u'ian.marshall@ed.ac.uk', u'Joanna.Wardlaw@ed.ac.uk', u'bartosz@karaszewski.org']
# [u'reingu@gmail.com']
# [u'ibethune@epcc.ed.ac.uk']
# []
# [u'Joanna.wardlaw@ed.ac.uk']
# [u'jwessnit@inf.ed.ac.uk']
# []
# []
# [u'a.buck@ed.ac.uk.']
# []
# [u'mwester@inf.ed.ac.uk']
# [u'vijendrag@nmsu.edu', u'pucher@ftw.at', u'jyamagis@inf.ed.ac.uk']
# []
# []
# [u'c.c.towell@sms.ed.ac.uk']
# [u'renatag@ime.usp.br', u'r.wallace@4c.ucc.ie', u'naz2001@yahoo.com', u'apease@articulatesoftware.com', u'jlehmann@inf.ed.ac.uk', u'bundy@inf.ed.ac.uk', u'mchan@inf.ed.ac.uk', u'fanizzi@di.uniba.it', u'ivarzinczak@csir.co.za', u'M.Chan@ed.ac.uk', u'JLehmann@inf.ed.ac.uk', u'A.Bundy@ed.ac.uk']
# []
# [u'adrian.haith@ed.ac.uk', u'c.p.jackson.1@bham.ac.uk', u'r.c.miall@bham.ac.uk', u'sethu.vijayakumar@ed.ac.uk']
# []
# [u'hannes.saal@ed.ac.uk', u'jting@acm.org', u'svijayak@inf.ed.ac.uk']
# []
# [u'pucher@ftw.at', u'schabus@ftw.at', u'jyamagis@inf.ed.ac.uk']
# [u'dlfelps@cse.tamu.edu', u'cgeng@ling.ed.ac.uk', u'm.a.berger@sms.ed.ac.uk', u'korin@cstr.ed.ac.uk', u'rgutier@cse.tamu.edu']
# [u'crfr@ed.ac.uk']
# [u'r.mitchell@clinmed.gla.ac.uk']
# [u'Tom.Freeman@roslin.ed.ac.uk']
# [u'O.S.Watts@sms.ed.ac.uk', u'jyamagis@inf.ed.ac.uk', u'Simon.King@ed.ac.uk']
# []
# [u'A.Correia-Semiao@ed.ac.uk', u'Andrea.Schaefer@ed.ac.uk']
# [u'gqta13@udcf.gla.ac.uk.']
# []
# [u'G.J.McNeill-2@sms.ed.ac.uk', u'sethu.vijayakumar@ed.ac.uk']
# [u'kgeorgila@ict.usc.edu', u'maria.wolters@ed.ac.uk', u'J.Moore@ed.ac.uk']
# []
# [u'crfr@ed.ac.uk']
# [u'jting@acm.org', u'adsouza@google.com', u'sethu.vijayakumar@ed.ac.uk', u'sschaal@usc.edu']
# [u'g.netto@hw.ac.uk', u'journals.permissions@oxfordjournals.org']
# []
# [u'h.saal@sms.ed.ac.uk']
# [u'sschaalg@usc.edu']
# [u'crfr@ed.ac.uk']
# [u'raj.bhopal@ed.ac.uk']
# [u'npb28@cl.cam.ac.uk', u'c.fensch@ed.ac.uk', u'swm11@cl.cam.ac.uk']
# []
# [u'J.S.Andersson@sms.ed.ac.uk']
# [u'matthew.howard@ed.ac.uk.']
# [u'moakristin.johansson@univr.it', u'a.bundyg@ed.ac.uk']
# [u'd.mitrovic@ed.ac.uk', u's.klanke@ed.ac.uk', u'sethu.vijayakumar@ed.ac.uk', u'sho-n@is.naist.jp', u'takam-m@is.naist.jp']
# [u'n.u.edakunni@sms.ed.ac.uk', u'sschaal@usc.edu', u'sethu.vijayakumar@ed.ac.uk']
# [u'javier.tejedor@uam.es', u'dwang2@inf.e-', u'joe@cstr.ed.ac.uk', u'Simon.King@ed.ac.uk', u'jose.colas@uam.es']
# [u'mtoussai@inf.ed.ac.uk', u'sethu.vijayakumar@ed.ac.uk']
# [u'sethu.vijayakumar@ed.ac.uk', u'adsouza@usc.edu', u'sschaal@usc.edu']
# [u'evelyne.sernagor@ncl.ac.uk', u'guenther.zeck@nmi.de', u'pjliang@sjtu.edu.cn', u'zeck@neuro.mpg.de', u'leibig@biochem.mpg.de']
# [u'Andrea.Schaefer@ed.ac.uk']
# [u'matthew.howard@ed.ac.uk', u'michael.gienger@honda-ri.de']
# []
# [u'maria.wolters@ed.ac.uk']
# [u'javier.tejedor@uam.es']
# [u'pubs-permissions@ieee.org.', u'pubs-permissions@ieee.org.', u'Dong.Wang@ed.ac.uk', u'Simon.King@ed.ac.uk', u'joe@cstr.ed.ac.uk', u'pubs-permissions@ieee.org.', u'pubs-permissions@ieee.org.', u'pubs-permissions@ieee.org.', u'pubs-permissions@ieee.org.', u'pubs-permissions@ieee.org.', u'pubs-permissions@ieee.org.', u'pubs-permissions@ieee.org.', u'pubs-permissions@ieee.org.', u'pubs-permissions@ieee.org.', u'pubs-permissions@ieee.org.']
# [u'vfotaki@ed.ac.uk', u'david.price@ed.ac.uk', u'john.mason@ed.ac.uk']
# []
# [u'A.Law@ed.ac.uk', u'M.Gillie@ed.ac.uk']
# [u'pucher@ftw.at', u'friedrich.neubarth@ofai.at', u'vstrom@inf.ed.ac.uk']
# [u'adsouza@usc.edu', u'sethu.vijayakumar@ed.ac.uk', u'sschaal@usc.edu']
# [u'sethu.vijayakumar@ed.ac.uk']
# [u'h.saal@sms.ed.ac.uk']
# [u'h.saal@sms.ed.ac.uk.']
# [u'licensing@oqps.gov.uk']
# []
# [u'g.petkos@sms.ed.ac.uk', u'sethu.vijayakumar@ed.ac.uk']
# [u'aferreir@udec.cl', u'J.Moore@ed.ac.uk', u'cmellish@csd.abdn.ac.uk']
# [u'r.begh@bham.ac.uk', u'p.n.aveyard@bham.ac.uk', u'p.upton@worc.ac.uk', u'raj.bhopal@ed.ac.uk', u'martin.white@newcastle.ac.uk', u'amanda.amos@ed.ac.uk', u'robin.prescott@ed.ac.uk', u'raman.bedi@kcl.ac.uk', u'p.m.barton@bham.ac.uk', u'm.fletcher@educationforhealth.org.uk', u'p.s.gill@bham.ac.uk', u'zaidiq@bhf.org.uk', u'aziz.sheikh@ed.ac.uk']
# [u'Deborah.Ritchie@ed.ac.uk', u'amanda.amos@ed.ac.uk', u'Richard.Phillips@ed.ac.uk', u'scburley@staffmail.ed.ac.uk', u'C.Martin@scotcen.org.uk']
# [u'ggrov@staffmail.ed.ac.uk', u'bundy@staffmail.ed.ac.uk', u'cliff.jones@ncl.ac.uk', u'A.Ireland@hw.ac.uk']
# [u'mwester@inf.ed.ac.uk']
# []
# [u'bsshrikant@yahoo.com', u'Fiona.Mackenzie@northglasgow.scot.nhs.uk', u'j.norrie@abdn.ac.uk', u'stavros.petrou@npeu.ox.ac.uk', u'm.e.reid@clinmed.gla.ac.uk', u'i.a.greer@clinmed.gla.ac.uk', u'InassOsman@aol.com', u'j.e.norman@clinmed.gla.ac.uk']
# [u'matthew.howard@ed.ac.uk.']
# [u'G.J.McNeill-2@sms.ed.ac.uk', u'sethu.vijayakumar@ed.ac.uk']
# [u't.hospedales@ed.ac.uk', u'j.j.cartwright@sms.ed.ac.uk', u'sethu.vijayakumar@ed.ac.uk']
# [u'S.KLANKE@ED.AC.UK', u'SETHU.VIJAYAKUMAR@ED.AC.UK', u'SSCHAAL@USC.EDU']
# [u'graham.mcneill@ed.ac.uk', u'sethu.vijayakumar@ed.ac.uk']
# [u'vincent.lorant@uclouvain.be']
# [u'pawel.m@ed.ac.uk']
# []
# []
# []
# [u'mwester@inf.ed.ac.uk']
# [u'm.heal@ed.ac.uk']
# [u'friedrich.neubarth@ofai.at', u'vstrom@inf.ed.ac.uk', u'sylvia.moosmueller@oeaw.ac.at', u'gregor.hofer@ed.ac.uk']
# [u'support@jstor.org.']
# [u'zhling@ustc.edu', u'korin@cstr.ed.ac.uk', u'jyamagis@inf.ed.ac.uk']
# []
# [u'vieno.massimo@gmail.com']
# []
# [u'G.J.McNeill-2@sms.ed.ac.uk', u'sethu.vijayakumar@ed.ac.uk']
# [u'korin@cstr.ed.ac.uk', u'robert@cstr.ed.ac.uk', u'Q@U_o']
# [u'm.heal@ed.ac.uk']
# [u'crfr@ed.ac.uk']
# []
# []
# [u'm.heal@ed.ac.uk']
# []
# []
# [u's.renals@ed.ac.uk']
# [u'crfr@ed.ac.uk']
# []
# [u'jyamagis@inf.ed.ac.uk', u'takao.kobayashi@ip.titech.ac.jp']
# []
# []
# []
# [u'j.e.norman@clinmed.gla.ac.uk', u'bsshrikant@yahoo.com', u'my12g@clinmed.gla.ac.uk', u's.nelson@clinmed.gla.ac.uk']
# [u'gqta13@udcf.gla.ac.uk.']
# [u'mmarina@inf.ed.ac.uk', u'rajiveg@cs.ucla.edu']
# [u'kgeorgila@ict.usc.edu', u'maria.wolters@ed.ac.uk', u'J.Moore@ed.ac.uk']
# [u'd.mitrovic@ed.ac.uk', u's.klanke@ed.ac.uk', u'sethu.vijayakumar@ed.ac.uk']
# [u't.hospedales@ed.ac.uk']
# []
# []
# [u'licensing@oqps.gov.uk']
# [u'jnc@ceh.ac.uk']
# [u's.bitzer@ed.ac.uk']
# [u's.bitzer@ed.ac.uk', u'sethu.vijayakumar@ed.ac.uk']
# [u'mwester@inf.ed.ac.uk']
# []
# [u'O.S.Watts@sms.ed.ac.uk', u'jyamagis@inf.ed.ac.uk', u'Simon.King@ed.ac.uk']
# [u'jyamagis@inf.ed.ac.uk']
# []
# []
# [u'crfr@ed.ac.uk']
# [u'ibethune@epcc.ed.ac.uk']
# [u'mwolters@inf.ed.ac.uk', u'permissions@acm.org.']
# [u'paul@inf.ed.ac.uk.computational']
# [u'G.Rein@ed.ac.uk']
# [u'Find@JRUL']
# [u'e.e.k.cooper@sms.ed.ac.uk', u'wadler@inf.ed.ac.uk']
# [u'adrian.haith@ed.ac.uk']
# []
# [u'jehnes@inf.ed.ac.uk']
# []
# [u'Mikko.Kurimo@tkk.fi']
# [u'crfr@ed.ac.uk']
# []
# [u'jyamagis@inf.ed.ac.uk']
# [u'ghofer@inf.ed.ac.uk', u'korin@inf.ed.ac.uk']
# [u'sugi@cs.titech.ac.jp', u'H.Hachiya@sms.ed.ac.uk', u'C.C.Towell@sms.ed.ac.uk', u'sethu.vijayakumar@ed.ac.uk']
# [u'l.dixon@ed.ac.uk']
# []
# [u'liangxiu.han@ed.ac.uk', u'lhan@nesc.ac.uk']
# []
# []
# []
# []
# []
# [u'jehnes@inf.ed.ac.uk']
# [u'h.mcqueen@ed.ac.uk', u'michael.clinton@roslin.ed.ac.uk']
# [u'Polly.Arnold@ed.ac.uk']
# [u'neil.pollock@ed.ac.uk', u'neil.pollock@edinburgh.ac.uk']
# [u'ummels@logic.rwth-aachen.de', u'd.k.wojtczak@cwi.nl']
# []
# [u'john.dines@idiap.ch', u'jyamagis@inf.ed.ac.uk', u'simon.king@ed.ac.uk']
# [u'recs.admin@scotland.gsi.gov.uk']
# [u'J.S.Andersson@sms.ed.ac.uk', u'jscabral@inf.ed.ac.uk', u'l.badino@sms.ed.ac.uk']
# []
# [u's.f.huang@ed.ac.uk', u'zhou@us.ibm.com']
# [u'javier.tejedor@uam.es', u'dwang2@inf.ed.ac.uk']
# [u'neeraj.bhala@ctsu.ox.ac.uk']
# [u'luis.martinez-uribe@oerc.ox.ac.uk', u'stuart.macdonald@ed.ac.uk']
# []
# []
# []
# [u'martin.donnelly@ed.ac.uk', u's.jones@hatii.arts.gla.ac.uk']
# []
# [u'matthewa@inf.ed.ac.uk']
# []
# [u'mtietze@inf.ed.ac.uk', u'A.Winterboer@ed.ac.uk', u'J.Moore@ed.ac.uk']
# [u'hts-users@sp.nitech.ac.jp']
# [u'recs.admin@scotland.gsi.gov.uk']
# [u'jmoore@inf.ed.ac.uk']
# [u'stuart.macdonald@ed.ac.uk']
# [u'info@dcc.ac.uk']
# [u'crfr@ed.ac.uk']
# []
# [u'Aziz.sheikh@ed.ac.uk']
# [u'galvarez@anatom.uni-tuebingen.de.']
# [u'jehnes@inf.ed.ac.uk']
# [u'veljko@cs.ucsb.edu', u'ebelding@cs.ucsb.edu', u'mmarina@inf.ed.ac.uk']
# [u'cwaiswa@vetmed.mak.ac.ug', u'znsadha@vetmed.mak.ac.ug', u'Eric.Fevre@ed.ac.uk', u'cssikasunge@unza.zm', u'awi@life.ku.dk', u'cwaiswa@vetmed.mak.ac.ug']
# [u'stephen.osborne@ed.ac.uk']
# [u'G.Rein@ed.ac.uk', u'G.Rein@ed.ac.uk.']
# [u'D.Hammett@ed.ac.uk', u'lynn.staeheli@ed.ac.uk']
# [u'recs.admin@scotland.gsi.gov.uk']
# [u'S.B.Rafnsson@ed.ac.uk']
# []
# [u'steiner@coli.uni-saarland.de', u'korin@cstr.ed.ac.uk']
# []
# [u'S.B.Rafnsson@ed.ac.uk']
# [u'recs.admin@scotland.gsi.gov.uk']
# [u'denis.headon@roslin.ed.ac.uk']
# []
# [u'dbyron@ccs.neu.edu', u'koller@mmci.uni-saarland.de', u'striegnk@union.edu', u'justine@northwestern.edu', u'Robert.Dale@mq.edu.au', u'J.Moore@ed.ac.uk', u'J.Oberlander@ed.ac.uk']
# [u'jscabral@inf.ed.ac.uk', u's.renals@ed.ac.uk', u'korin@cstr.ed.ac.uk', u'jyamagis@inf.ed.ac.uk']
# [u'm.hennig@ed.ac.uk.']
# [u'jyamagis@inf.ed.ac.uk']
# [u'doris.jermann@eawag.ch']
# [u'jnc@ceh.ac.uk']
# [u'korin@cstr.ed.ac.uk']
# [u'sara_dolnicar@uow.edu.au', u'Andrea.Schaefer@ed.ac.uk']
# [u'crfr@ed.ac.uk']
# [u'crfr@ed.ac.uk']
# [u'Robin.Williams@ed.ac.uk', u'Neil.Pollock@ed.ac.uk']
# []
# []
# [u'abs@.nsf']
# []
# [u'G.Rein@ed.ac.uk']
# [u'm.heal@ed.ac.uk']
# [u'G.Wickler@ed.ac.uk', u'G.Beckett@ed.ac.uk', u'liangxiu.han@ed.ac.uk', u'S.Koo@ed.ac.uk', u'S.Potter@ed.ac.uk', u'G.Pringle@ed.ac.uk', u'A.Tate@ed.ac.uk']
# [u'korin@cstr.ed.ac.uk', u'robert@cstr.ed.ac.uk', u'i@_ea', u'I@_ea']
# [u'O.S.Watts@sms.ed.ac.uk', u'jyamagis@inf.ed.ac.uk', u'Simon.King@ed.ac.uk', u'kay@berkling.com']
# []
# []
# [u'jnc@ceh.ac.uk']
# []
# []
# [u'jehnes@inf.ed.ac.uk']
# [u'dwang2@inf.ed.ac.uk', u'Simon.King@ed.ac.uk', u'joe@cstr.ed.ac.uk', u'Peter.Bell@ed.ac.uk']
# []
# []
# []
# []
# [u'NCDDPsupportteam@isd.csa.scot.nhs.ukDigital', u'McKinstry@ed.ac.uk']
# [u'dwang2@inf.ed.ac.uk', u'Simon.King@ed.ac.uk', u'joe@cstr.ed.ac.uk']
# [u'B.S.Richards@hw.ac.uk']
# []
# [u'm.heal@ed.ac.uk']
# [u'jane.jacobs@ed.ac.uk']
# [u'Andrea.Schaefer@ed.ac.uk']
# [u'opb@inf.ed.ac.uk', u'jcheney@inf.ed.ac.uk', u'wctan@cs.ucsc.edu', u'stijn.vansummeren@uhasselt.be']
# []
# [u'joe@cstr.ed.ac.uk', u'dwang2@inf.ed.ac.uk', u'Simon.King@ed.ac.uk']
# [u'j.torero@ed.ac.uk']
# [u'kousha@inf.ed.ac.uk', u'D.K.Wojtczak@sms.ed.ac.uk', u'mihalis@cs.columbia.edu']
# [u'cgmontes@ujaen.es']
# []
# [u'g.hofer@sms.ed.ac.uk']
# []
# []
# []
# []
# []
# [u's.potter@ed.ac.uk', u'g.wickler@ed.ac.uk']
# [u'matthewa@cereproc.com', u'jyamagis@inf.ed.ac.uk']
# []
# []
# [u'ane@ed.ac.uk.']
# [u'ferpello@me.berkeley.edu']
# []
# [u'w.jahn@ed.ac.uk', u'g.rein@ed.ac.uk', u'j.torero@ed.ac.uk']
# [u'kgeorgil@inf.ed.ac.uk', u'mwolters@inf.ed.ac.uk']
# []
# [u'mtietze@inf.ed.ac.uk', u'v.demberg@ed.ac.uk', u'j.moore@ed.ac.uk']
# []
# [u'vstrom@inf.ed.ac.uk']
# []
# [u'giles.hardingham@ed.ac.uk.']
# []
# []
# [u'NewellMorgan@yahoo.co.uk', u'mcgeemr@dcs.gla.ac.uk', u'nhine@computing.dundee.ac.uk', u'jarnott@computing.dundee.ac.uk', u'cjmartin@computing.dundee.ac.uk', u'jsc@cs.stir.ac.uk', u'mwolters@inf.ed.ac.uk']
# [u'dwang2@inf.ed.ac.uk', u'i.himawan@qut.edu.au', u'joe@cstr.ed.ac.uk', u'Simon.King@ed.ac.uk']
# [u'curation.manual@dcc.ac.uk.', u'mbaca@getty.edu']
# [u'recs.admin@scotland.gsi.gov.uk']
# [u'b.partridge@derby.ac.uk']
# [u'pedro.reszka@ed.ac.uk']
# [u'bjorner@gmail.com']
# [u'carmen-enquiries@ncl.ac.uk']
# [u'matthewa@cereproc.com']
# [u'jyamagis@inf.ed.ac.uk']
# [u'Eric.laurier@ed.ac.uk']
# [u'tkocjancic@qmu.ac.uk']
# [u'O.S.Watts@sms.ed.ac.uk', u'jyamagis@inf.ed.ac.uk', u'kay@berkling.com', u'Simon.King@ed.ac.uk']
# [u's.f.huang@ed.ac.uk', u's.renals@ed.ac.uk']
# []
# [u'ingmar.steiner@ed.ac.uk', u'korin@cstr.ed.ac.uk']
# [u'Eric.laurier@ed.ac.uk']
# [u'jane.jacobs@ed.ac.uk', u'stephen.cairns@ed.ac.uk']
# [u'ladan@psych.ucla.edu']
# [u'Simon.King@ed.ac.uk']
# [u'g.garau@ed.ac.uk', u's.renals@ed.ac.uk']
# []
# []
# []
# [u'crfr@ed.ac.uk']
# [u'n@d']
# []
# [u'RSALAKHU@CS.TORONTO.EDU', u'MURRAY@CS.TORONTO.EDU']
# []
# [u'crfr@ed.ac.uk']
# [u'g.bernardi@sms.ed.ac.uk', u'opb@inf.ed.ac.uk', u'mmarina@inf.ed.ac.uk']
# []
# []
# [u'l.badino@sms.ed.ac.uk']
# [u'matthewa@inf.ed.ac.uk']
# [u'hazel.christie@ed.ac.uk', u'susanj.smith@durham.ac.uk', u'moira.munro@socsci.gla.ac.uk']
# []
# [u'curation.manual@dcc.ac.uk.']
# [u'I.A.Currie@sms.ed.ac.uk', u'mmarina@inf.ed.ac.uk']
# []
# [u'jyamagis@inf.ed.ac.uk', u'zhling@ustc.edu', u'Simon.King@ed.ac.uk']
# []
# [u'crfr@ed.ac.uk']
# [u'p.hsueh@ed.ac.uk', u'J.Moore@ed.ac.uk']
# [u'Jean-Louis.Consalvi@polytech.univ-mrs.fr']
# []
# []
# [u'jyamagis@inf.ed.ac.uk', u'takao.kobayashi@ip.titech.ac.jp', u's.renals@ed.ac.uk', u'simon.king@ed.ac.uk', u'zen@sp.nitech.ac.jp', u'tomoki@is.naist.jp', u'tokuda@nitech.ac.jp']
# [u'mmackinnon@kilifi.kemri-wellcome.org']
# [u'Colin.Fischbacher@isd.csa.scot.nh', u'Raj.Bhopal@ed.ac.uk', u'Chris.Povey@isd.csa.scot.nhs.uk', u'm.steiner@abdn.ac.uk', u'jim.chalmers@isd.csa.scot.nhs.uk', u'Ganka.Mueller@gro-scotland.gsi.gov.uk', u'Joan.Jamieson@isd.csa.scot.nhs.uk', u'david.knowles@isd.csa.scot.nhs.uk']
# [u'g.wickler@ed.ac.uk', u'a.tate@ed.ac.uk', u's.potter@ed.ac.uk']
# []
# []
# []
# []
# [u'korin@cstr.ed.ac.uk']
# []
# []
# []
# []
# [u'business.edinburgh@blackwell.co.uk']
# [u'andres.fuentes@lcd.ensma.fr']
# [u'A.Bundy@ed.ac.uk']
# []
# []
# [u'gabriel.murray@ed.ac.uk', u's.renals@ed.ac.uk']
# [u'j.d.barry@bio.gla.ac.uk']
# []
# [u'Katrina.Grech@moredun.ac.uk', u's0126761@sms.ed.ac.uk', u'Andrew.Read@ed.ac.uk']
# [u'A.Richmond@ed.ac.uk']
# [u's.potter@ed.ac.uk', u'y.kalfoglou@ecs.soton.ac.uk']
# [u'liz.bondi@ed.ac.uk']
# []
# [u's.welch@ed.ac.uk']
# []
# []
# [u'business.edinburgh@blackwell.co.uk']
# []
# [u'hazel.christie@ed.ac.uk']
# [u'matthew.thomas@csiro.au']
# []
# []
# [u'Sasha.Calhoun@ed.ac.uk']
# [u'dave.laurensong@ed.ac.uk']
# []
# [u'g.hofer@sms.ed.ac.uk', u'h.shimodaira@ed.ac.uk', u'v1jyamag@inf.ed.ac.uk']
# [u'A.Winterboer@ed.ac.uk', u'J.Moore@ed.ac.uk']
# []
# []
# [u'sions@acm.org.']
# [u'j.toribio@ed.ac.uk.']
# [u'jurafskyg@stanford.edu', u'Sasha.Calhoun@ed.ac.uk']
# [u'S.Welch@ed.ac.uk']
# [u'S.Welch@ed.ac.uk']
# []
# []
# []
# []
# []
# []
# [u'g.hofer@sms.ed.ac.uk', u'h.shimodaira@ed.ac.uk']
# [u'S.Welch@ed.ac.uk']
# [u'G.Rein@ed.ac.uk', u'J.Torero@ed.ac.uk', u'ferpello@me.berkeley.edu']
# [u'jyh@uctm.edu', u'jordan.hristov@mail.bg.', u'hristovmeister@gmail.com']
# []
# []
# []
# [u'v.wan@dcs.shef.ac.uk']
# [u'joe@cstr.ed.ac.uk']
# []
# [u'sarah.glynn@ed.ac.uk']
# [u'boon.low@ed.ac.uk', u'dfmac@nesc.ac.uk', u'john.maccoll@ed.ac.uk']
# [u'andres.fuentes@lcd.ensma.fr']
# []
# [u'leew@landcareresearch.co.nz']
# [u'Simon.King@ed.ac.uk']
# [u'jscabral@inf.ed.ac.uk', u's.renals@ed.ac.uk', u'korin@cstr.ed.ac.uk', u'jyamagis@inf.ed.ac.uk']
# [u'korin@cstr.ed.ac.uk']
# [u'curation.manual@dcc.ac.uk.']
# []
# []
# [u'awargo@u.washington.edu']
# []
# []
# [u'aisbq@aisb.org.uk', u'aisbq@aisb.org.uk', u'd.r.myatt@reading.ac.uk', u'nrj@soton.ac.uk', u'a.tate@ed.ac.uk', u'arielpro@gmail.com10', u'aisb08@aisb.org.uk', u'chair@aisb.org.uk', u'vicechair@aisb.org.uk', u'louise.dennis@aisb.org.uk', u'treasurer@aisb.org.uk', u'travel@aisb.org.uk', u'membership@aisb.org.uk', u'publications@aisb.org.uk', u'aisbj@aisb.org.uk', u'aisbq@aisb.org.uk', u't.blackwell@gold.ac.uk', u'publicrelations@aisb.org.uk', u'f.j.mcneill@ed.ac.uk', u'aisb07@aisb.org.uk', u'aisb08@aisb.org.uk', u's.j.nasuto@reading.ac.uk', u'secretary@aisb.org.uk', u'secretary@aisb.org.uk']
# []
# [u'joe@cstr.ed.ac.uk']
# []
# []
# [u'Karen.Chapman@ed.ac.uk']
# [u'lars.raberg@zooekol.lu.se']
# [u'm.heal@ed.ac.uk']
# [u'a.tate@ed.ac.uk', u'Jeff.Hansberger@je.jfcom.mil']
# []
# []
# []
# [u'zena.mulligan@ed.ac.uk']
# [u'a.tate@ed.ac.uk', u'semsch@labe.felk.cvut.cz']
# [u'jyamagis@inf.ed.ac.uk', u'zen@sp.nitech.ac.jp', u'tomoki@is.naist.jp', u'tokuda@nitech.ac.jp']
# []
# []
# [u'joe@cstr.ed.ac.uk']
# [u'stephen.cairns@ed.ac.uk', u'jane.jacobs@ed.ac.uk']
# []
# []
# [u'curation.manual@dcc.ac.uk.']
# [u'Eric.laurier@ed.ac.uk', u'barry@dcs.gla.ac.uk']
# [u'a.tate@ed.ac.uk']
# [u'andy@indiana.edu']
# [u'matt.davies@ed.ac.uk', u'colin.legg@ed.ac.uk', u'asmith@gct.org.uk', u'ajmacdonald@treeline3m.freeserve.co.uk']
# []
# [u'comms@esrc.ac.uk']
# [u'asif.usmani@ed.ac.uk', u'G.R.Flint@ed.ac.uk', u'C.C.Roben@sms.ed.ac.uk', u'LS.Johnston@sms.ed.ac.uk', u'A.I.Jowsey@ed.ac.uk']
# [u'pedro.reszka@ed.ac.uk', u'jltorero@staffmail.ed.ac.uk']
# [u'andrea.nightingale@ed.ac.uk']
# []
# []
# []
# [u'a.read@ed.ac.uk']
# []
# [u'Modest_Witness@Second_Millennium.']
# []
# []
# [u'Bill.Pollard@ed.ac.uk']
# []
# [u'Era.Admin@ed.ac.uk']
# [u'curation.manual@dcc.ac.uk.', u'firstname.lastname@enron.com.']
# []
# []
# [u'Modest_Witness@Second_Millennium.']
# []
# []
# [u'curation.manual@dcc.ac.uk.']
# [u'anightin@geo.ed.ac.uk']
# []
# []
# [u'O.Chaudhry@sms.ed.ac.uk', u'William.mackaness@ed.ac.uk', u'O.Chaudhry@sms.ed.ac.uk', u'William.mackaness@ed.ac.uk']
# [u'lesley.gallacher@ed.ac.uk']
# [u'femke.reitsma@ed.ac.uk', u'jochen@hunter.cuny.edu']
# [u'a.amundarain@ed.ac.uk', u'j.torero@ed.ac.uk', u'a.usmani@ed.ac.uk', u'ahmad@powerwall.co.uk']
# []
# [u'euan.adie@ed.ac.uk', u'journals.permissions@oxfordjournals.org']
# []
# [u'ubpub@uni-potsdam.de', u'James@cs.rochester.edu', u'mdstone@cs.rutgers.edu', u'elena.karagjosova@ilos.uio.no', u'kavita.e.thomas@gmail.com', u'claire.beyssade@ehess.fr', u'marandin@linguist.jussieu.fr', u'yhara@ling.bun.kyoto-u.ac.jp', u'krifka@rz.hu-berlin.de', u'krifka@zas.gwz-berlin.de', u'alex@inf.ed.ac.uk', u'Matthew.Stone@rutgers.edu', u'andre@informatik.uni-augsburg.de', u'gj@dfki.de', u'john.kelleher@comp.dit.ie', u'alfred.kranstedt@googlemail.com', u'philip.diderichsen@lucs.lu.se', u'zoran.macura@kcl.ac.uk', u'jonathan.ginzburg@kcl.ac.uk', u'gj@dcs.qmul.ac.uk', u'ph@dcs.qmul.ac.uk', u'schegloff@soc.ucla.edu', u'Sylvie.Saget@enssat.fr', u'Marc.Guyomard@enssat.fr', u'David.DeVault@rutgers.edu', u'Matthew.Stone@rutgers.edu', u'ruth.kempson@kcl.ac.uk', u'ronnie@ling.ed.ac.uk', u'tenbrink@tzi.de', u'shi@tzi.de', u'kerstinf@uni-bremen.de', u'lilia.mironovschi@hu-berlin.de', u'knoeferle@coli.uni-sb.de', u'monic@coli.uni-sb.de', u'brownsch@uiuc.edu', u'gunlog@ling.rochester.edu', u'mlouwers@memphis.edu', u'hua@cs.pitt.edu', u'foster@in.tum.de', u'xliu4@inf.ed.ac.uk', u'carl@appliedreactivity.com', u'jessica@ling.gu.se', u'sl@ling.gu.se', u'jhulstijn@feweb.vu.nl', u'kirschner@inf.unibz.it', u'tantan@human.mie-u.ac.jp', u'judith.holler@manchester.ac.uk', u'olemon@inf.ed.ac.uk']
# [u'Christine.Love-Rodgers@ed.ac.uk', u'Rowena.Stewart@ed.ac.uk']
# [u'O.Chaudhry@sms.ed.ac.uk', u'William.mackaness@ed.ac.uk', u'O.Chaudhry@sms.ed.ac.uk', u'William.mackaness@ed.ac.uk']
# [u'lars.raberg@zooekol.lu.se', u'jaapderoode@hotmail.com', u'andrew.bell@ed.ac.uk', u'panagiota.stamou@joslin.harvard.edu', u'd.gray@ed.ac.uk', u'a.read@ed.ac.uk']
# []
# [u'curation.manual@dcc.ac.uk.']
# [u'rbose@inf.ed.ac.uk', u'femke.reitsma@ed.ac.uk', u'rbose@inf.ed.ac.uk', u'femke.reitsma@ed.ac.uk']
# [u'Eric.Laurier@ed.ac.uk', u'cphilo@ges.gla.ac.uk']
# [u'student@myu.ac.uk', u'student@myu.ac.uk']
# []
# [u'p.polydoratou@imperial.ac.uk']
# [u'eric.laurier@ed.ac.ukthattherewasno']
# []
# []
# [u'femke.reitsma@ed.ac.uk', u'jochen@hunter.cuny.edu', u'femke.reitsma@ed.ac.uk', u'jochen@hunter.cuny.edu']
# [u'jane.jacobs@ed.ac.uk', u'Stephen.cairns@ed.ac.uk', u'ignaz.strebel@ed.ac.uk']
# [u'anightin@geo.ed.ac.uk']
# []
# [u'rgm@roe.ac.uk', u'wkmr@roe.ac.uk', u'jkd@roe.ac.uk', u'jb@roe.ac.uk', u'R.deGrijs@sheffield.ac.uk']
# []
# [u'H.Halpin@ed.ac.uk', u'J.Moore@ed.ac.uk']
# []
# []
# [u'andrea.nightingale@ed.ac.uk', u'Modest_Witness@Second_Millennium.']
# [u'H.Liang@ed.ac.uk', u'S.Welch@ed.ac.uk']
# [u'ferpello@me.berkeley.edu']
# []
# []
# []
# [u'andy.clark@ed.ac.uk']
# [u'Eric.laurier@ed.ac.uk', u'cphilo@ges.geog.gla.ac.uk']
# [u'a.guadamuz@ed.ac.uk.']
# [u'a.ranicki@ed.ac.uk']
# [u'capotej@unican.es', u'alveard@unican.es', u'lazarom@unican.es', u'espinap@unican.es', u'ian.fletcher@ed.ac.uk', u's.welch@ed.ac.uk', u'j.torero@.ed.ac.uk']
# []
# []
# [u'sarah.glynn@ed.ac.uk']
# []
# [u'g.wickler@ed.ac.uk', u'a.tate@ed.ac.uk', u's.potter@ed.ac.uk']
# []
# [u'Era.Admin@ed.ac.uk', u'Z.huang-2@sms.ed.ac.uk', u'qqs@aber.ac.uk']
# []
# []
# [u's.potter@ed.ac.uk', u'a.tate@ed.ac.uk', u'g.wickler@ed.ac.uk']
# [u'andy.clark@ed.ac.uk']
# []
# [u'dreitter@inf.ed.ac.uk']
# [u'curation.manual@dcc.ac.uk.']
# [u'sara_dolnicar@uow.edu.au', u'Andrea.Schaefer@ed.ac.uk']
# [u'ferpello@me.berkeley.edu']
# []
# [u'sarah.glynn@ed.ac.uk']
# [u'a.tate@ed.ac.uk']
# [u'grainne.long@ed.ac.uk']
# [u'ian.fletcher@ed.ac.uk', u's.welch@ed.ac.uk']
# [u'Richard.jones@ub.uib.no', u'theo.andrew@ed.ac.uk']
# [u'j.torero@ed.ac.uk']
# []
# [u'Era.Admin@ed.ac.uk']
# [u'ferpello@me.berkeley.edu.']
# [u'm.heal@ed.ac.uk']
# [u'crfr@ed.ac.uk']
# []
# [u'Era.Admin@ed.ac.uk', u'm.heal@ed.ac.uk']
# []
# []
# [u'extremepricecuts@extremepricecuts.net', u'no-one@microsoft.com']
# [u'Era.Admin@ed.ac.uk', u'm.heal@ed.ac.uk']
# [u'Schaefer@uow.edu.au']
# []
# [u'y.gotohg@dcs.shef.ac.uk', u'srenals@inf.ed.ac.uk']
# [u'j-goldman@northwestern.edu', u's.renals@ed.ac.uk', u'sb@ldc.upenn.edu', u'fdejong@ewi.utwente.nl', u'federico@itc.it', u'cfle@loc.gov', u'mark@mail.matrix.msu.edu', u'lamel@limsi.fr', u'oard@umd.edu', u'claire-stewart@northwestern.edu', u'richard.wright@bbc.co.uk']
# [u'alexander.gutkin@ed.ac.uk', u'dave.gay@unb.ca']
# [u'm.heal@ed.ac.uk']
# [u'curation.manual@dcc.ac.uk.']
# [u'schaefer@uow.edu.au', u'andreasb@uow.edu.au', u'bryce.richards@anu.edu.au']
# []
# [u'g.hutchison@hrsu.mrc.ac.uk', u'da.brown@napier.ac.uk', u'leon.hibbs@ed.ac.uk', u'm.heal@ed.ac.uk', u'ken.donaldson@ed.ac.uk', u'robert.maynard@doh.gsi.gov.uk', u'm.monaghan@napier.ac.uk', u'andy.nicholl@iomhq.org.uk', u'v.stone@napier.ac.uk']
# []
# [u'legros@lcd.ensma.fr1']
# []
# [u'michael.spearpoint@canterbury.ac.nz']
# []
# [u'Era.Admin@ed.ac.uk', u'Meng.Li@ed.ac.uk']
# [u'james.laidlaw@ed.ac.uk', u'charlie.mansfield@ed.ac.uk']
# []
# []
# [u's.renalsg@ed.ac.uk']
# [u'frank.laturnus@ituf.liu.se']
# []
# []
# [u'Sasha.Calhoun@ed.ac.uk', u'jbrenier@colorado.edu']
# [u'Gareth.Harrison@ed.ac.uk']
# [u'charlie.mansfield@ed.ac.uk']
# []
# [u'elaurier@geog.gla.ac.uk']
# []
# [u'catherin@ling.ed.ac.uk', u'turk@ling.ed.ac.uk']
# [u'lo35@cornell.edu']
# []
# []
# [u'inga.neumann@biologie.uni-regensburg.de.']
# []
# []
# [u'Era.Admin@ed.ac.uk']
# [u'v.wan@dcs.shef.ac.uk', u's.renals@ed.ac.uk']
# [u'dominika@coli.uni-sb.de', u'robert@cstr.ed.ac.uk']
# [u'jeffrey.ketland@ed.ac.uk']
# []
# [u'publication@source']
# []
# [u'curation.manual@dcc.ac.uk.']
# []
# []
# [u'catherin@ling.ed.ac.uk']
# [u'm.j.siegert@bristol.ac.uk']
# [u'c.k.i.williams@ed.ac.uk', u'john.quinn@ed.ac.uk', u'neil.mcintosh@ed.ac.uk']
# [u'a.e.l.brown@sms.ed.ac.uk.']
# [u'Era.Admin@ed.ac.uk', u'ed@ed']
# []
# [u'Era.Admin@ed.ac.uk', u'Z.huang-2@sms.ed.ac.uk', u'qqs@aber.ac.uk']
# [u'shawn@tellme.com', u'ter@inf.ed.ac.uk', u'steveng@savant-garde.net', u'shawn@tellme.com', u'mwester@inf.ed.ac.uk', u'steveng@savant-garde.net']
# [u'doug.dyer@activecomputing.org', u'steve.cross@gtri.gatech.edu', u'knoblock@isi.edu', u'minton@fetch.com']
# [u'Era.Admin@ed.ac.uk', u'k.c.molloy@bath.ac.uk', u'ed@ed', u'ed@ed']
# []
# []
# [u'koumpis@ftw.at', u's.renals@ed.ac.uk']
# [u'Era.Admin@ed.ac.uk', u'meg.pollock@sac.ac.uk']
# [u'seb.rouvreau@tele2.fr']
# []
# []
# []
# [u'andy.clark@ed.ac.uk']
# [u'jessicac@inf.ed.ac.uk']
# []
# []
# []
# [u'alex@ai-center.com', u'e.freuder@4c.ucc.ie.', u'4er@iems.northwestern.edu.', u'giunchiglia@unige.it.', u'rpgoldman@sift.info.', u'kautz@cs.washington.edu.', u'rintanen@informatik.uni-freiburg.de.', u'a.tate@ed.ac.uk.']
# [u'hazel.christie@ed.ac.uk']
# [u'liz.bondi@ed.ac.uk']
# [u'Era.Admin@ed.ac.uk']
# [u'euan.adie@ed.ac.uk', u'richard.adams@ed.ac.uk', u'kathy.evans@ed.ac.uk', u'david.porteous@ed.ac.uk', u'ben.pickard@ed.ac.uk']
# []
# []
# [u'c.siebra@ed.ac.uk']
# [u'ricky@tunnelfiresafety.co.uk']
# [u'business.edinburgh@blackwell.co.uk']
# []
# []
# []
# []
# [u'graeme.laurie@ed.ac.uk']
# []
# []
# [u'L.Hurtado@ed.ac.uk']
# []
# [u'crfr@ed.ac.uk']
# []
# [u'A.Schaefer@uow.edu.au', u'andritso@cperi.certh.gr', u'karabaj@cperi.certh.gr', u'hoek@engr.ucr.edu', u'schneide@icb.usp.br', u'marianne.nystrom@lut.fi']
# []
# [u's.renals@ed.ac.uk']
# [u'femke@geog.umd.edu', u'engeljs@umd.edu']
# []
# [u'ira.ojala@glg.ed.ac.uk']
# []
# []
# []
# [u'Schaefer@uow.edu.au', u'agentno2@web.de', u'B.Richards@unsw.edu.au']
# [u'l.edwards@ed.ac.uk.']
# [u'c.k.i.williams@ed.ac.uk', u'M.Titsias@sms.ed.ac.uk']
# []
# []
# []
# [u'Sasha.Calhoun@ed.ac.uk']
# [u'jjk32@cam.ac.uk']
# [u'J.Torero@ed.ac.uk']
# []
# [u'sara.dorman@ed.ac.uk']
# []
# []
# [u'stephenp@inf.ed.ac.uk']
# []
# [u'recs.admin@scotland.gsi.gov.uk', u'marion.flett@highland.gov.uk']
# [u'yoshi@cstr.ed.ac.uk']
# []
# [u'terasima@biz.ryukoku.ac.jp', u'john.dawson@ed.ac.uk.']
# [u'ichambers@ed.ac.uk', u'austin.smith@ed.ac.uk']
# []
# []
# [u'elaurier@geog.gla.ac.uk']
# []
# [u'y.gotohg@dcs.shef.ac.uk', u's.renals@ed.ac.uk']
# []
# [u'Era.Admin@ed.ac.uk', u'Meng.Li@ed.ac.uk']
# []
# []
# []
# []
# []
# [u'terasima@biz.ryukoku.ac.jp', u'john.dawson@ed.ac.uk.']
# []
# [u'm.heal@ed.ac.uk']
# [u'yoshi@cstr.ed.ac.uk']
# [u'l.edwards@ed.ac.uk.', u'E-L@w', u'L@w']
# [u'skhan@uow.edu.au', u'a.schafer@uow.edu.au', u'paul.sherman@epa.qld.gov.au']
# []
# []
# [u'tgma@wam.umd.edu']
# [u'Raj.Bhopal@ed.ac.uk']
# [u'Era.Admin@ed.ac.uk']
# [u'simonkg@cstr.ed.ac.uk']
# [u'yoshi@cstr.ed.ac.uk']
# [u'auszok@ihmc.us.', u'jbradshaw@ihmc.us.', u'rjeffers@ihmc.us.', u'mjohnson@ihmc.us.', u'a.tate@ed.ac.uk.', u'jeff@inf.ed.ac.uk.']
# [u'Natasha.Queiroz@ed.ac.uk']
# []
# [u'D.Waite@unsw.edu.au']
# [u'Era.Admin@ed.ac.uk']
# [u'M.Mackinnon@ed.ac.uk']
# [u'Era.Admin@ed.ac.uk']
# [u'Alexander.Gutkin@ed.ac.uk']
# []
# [u'jessicac@inf.ed.ac.uk']
# []
# [u'skhan@uow.edu.au', u'wintgens@ivt.rwth-aachen.de', u'Paul.Sherman@epa.qld.gov.au', u'Jan.Zaricky@env.qld.gov.au', u'a.schaefer@uow.edu.au']
# [u'Era.Admin@ed.ac.uk']
# [u'Alexander.Gutkin@ed.ac.uk']
# [u'long.nghiem@yale.edu', u'A.Schaefer@uow.edu.au']
# []
# [u'Era.Admin@ed.ac.uk']
# [u'Era.Admin@ed.ac.uk', u'Z.huang-2@sms', u'qiangs@inf']
# [u's.renalsg@ed.ac.uk']
# []
# [u'alexander.gutkin@ed.ac.uk', u'mwester@inf.ed.ac.uk', u'goldfarb@unb.ca', u'dave.gay@unb.ca']
# []
# []
# [u'A.Schaefer@uow.edu.au']
# []
# []
# []
# [u'permissions@emeraldinsight.com']
# [u'L@w']
# [u'stephen.elphick@glg.ed.ac.uk', u'ian.main@glg.', u'bryne.ngwenya@glg.ed.ac.uk', u'ira.ojala@glg.ed.ac.uk']
# [u'gdp@dcs.ed.ac.uk.One']
# [u'femke@geog.umd.edu', u'thomas.bittner@ifomis.uni-leipzig.de']
# [u'dl37@le.ac.uk.']
# []
# [u'a.tate@ed.ac.uk']
# [u'a.tate@ed.ac.uk', u'pbeautement@qinetiq.com']
# []
# []
# [u'C.v.Bael@let.kun.nl', u'Simon.King@ed.ac.uk']
# []
# [u'sara.dorman@ed.ac.uk']
# [u'mf@dcs.ed.ac.uk', u'gdp@dcs.ed.ac.uk', u'ajp@dcs.ed.ac.uk', u'DO@0', u'DO@0', u'O@0', u'O@0', u'O@0', u'O@0', u'O@0']
# [u'M.Hyland@dpmms.cam.ac.uk', u'gdp@dcs.ed.ac.uk', u'ajp@dcs.ed.ac.uk.', u'V@1', u'V@1', u'V@1']
# []
# []
# [u'b.richards@unsw.edu.au', u'b.richards@unsw.edu.au']
# [u'A.Schaefer@unsw.edu.au']
# []
# [u's.flitsch@ed.ac.uk.']
# [u'dt@dcs.ed.ac.uk', u'gdp@dcs.ed.ac.uk']
# []
# [u'stu.west@ed.ac.uk']
# [u's.renals@dcs.shef.ac.uk', u'dpwe@ee.columbia.edu']
# [u'm.wester@let.kun.nl.variation']
# [u'mitg@jaist.ac.jp', u'takashi2.sudo@toshiba.co.jp', u'sagayama@hil.t.u-tokyo.ac.jp']
# [u'robert@cstr.ed.ac.uk']
# [u'elaurier@geog.gla.ac.uk', u'cphilo@geog.gla.ac.uk']
# []
# []
# [u'sarah.reece@ed.ac.uk']
# [u'j.torero@ed.ac.uk']
# []
# []
# [u'j.j.ketland@leeds.ac.uk']
# []
# []
# [u'dirk@bioss.ac.uk.']
# [u'gdp@dcs.ed.ac.uk.Then']
# []
# [u'rvg@cs.stanford.edu', u'gdp@dcs.ed.ac.uk']
# [u'simon.bains@ed.ac.uk', u'r.d.jones@ed.ac.uk']
# []
# []
# [u'olga@cstr.ed.ac.uk']
# []
# []
# []
# [u'jgalag@mit.edu', u'bwb@genome.wi.mit.edu']
# []
# [u'korin@cstr.ed.ac.uk']
# []
# [u'types@theory.lcs.mit.edu']
# [u'Era.Admin@ed.ac.uk']
# []
# [u'Era.Admin@ed.ac.uk', u'm.heal@ed.ac.uk']
# [u'brabec@ibp.cz.', u'P.J.Sadler@ed.ac.uk.']
# [u'gwilym_davies@yahoo.co.uk']
# []
# []
# [u'anightin@geo.ed.ac.uk']
# []
# [u'crfr@ed.ac.uk']
# [u'Gareth.Harrison@ed.ac.uk']
# [u'p.j.sadler@ed.ac.uk.']
# [u'm.heal@ed.ac.uk.']
# []
# []
# []
# [u'andy@twinearth.wustl.edu']
# []
# [u'E-L@w']
# []
# []
# [u'catherin@ling.ed.ac.uk', u'turk@ling.ed.ac.uk']
# []
# [u'Era.Admin@ed.ac.uk', u'Z.huang-2@sms.ed.ac.uk', u'qiangs@dai.ed.ac.uk']
# [u'P.J.Sadler@ed.ac.uk']
# [u'jnc@ceh.ac.uk.']
# [u'jtoribio@indiana.edu']
# []
# []
# []
# [u'E-L@w']
# []
# [u'Simon.King@ed.ac.uk']
# [u's.u.egelhaaf@ed.ac.uk.', u'1nj@h']
# [u'Era.Admin@ed.ac.uk', u'C.R.Pulham@ed.ac.uk']
# [u'freitsma@uwm.edu']
# []
# []
# []
# []
# [u'sean.nee@ed.ac.uk']
# [u's.e.armitage@hw.ac.uk1']
# [u'b.richards@unsw.edu.au', u'a.schaefer@unsw.edu.au']
# [u'Ercan.Balaban@ed.ac.uk', u'abayar@cankaya.edu.tr', u'Robert.Faff@BusEco.monash.edu.au1']
# []
# [u'Rustam.Al-Shahi@ed.ac.uk']
# []
# []
# [u'Elaurier@geog.gla.ac.uk', u'e.laurier@virgin.net']
# []
# [u'mark.woolhouse@ed.ac.uk']
# [u'stu.west@ed.ac.uk']
# []
# [u'tandrew@glg.ed.ac.']
# []
# [u'pepat@cogs.susx.ac.uk.']
# []
# [u'Era.Admin@ed.ac.uk']
# [u'jtoribio@indiana.edu']
# [u'ketland@ketland.fsnet.co.uk']
# [u'D.Waite@unsw.edu.au', u'D.Waite@unsw.edu.au']
# [u'rick.maizels@ed.ac.uk']
# [u'Era.Admin@ed.ac.uk']
# [u'D.Waite@unsw.edu.au', u'D.Waite@unsw.edu.au']
# []
# [u'crfr@ed.ac.uk']
# [u'rick.maizels@ed.ac.uk']
# [u'andycl@cogs.susx.ac.uk']
# [u'pepat@cogs.susx.ac.uk', u'pepat@cogs.susx.ac.uk']
# [u'a.tate@ed.ac.uk', u'j.Dalton@ed.ac.uk', u'j.stader@ed.ac.uk']
# [u'crfr@ed.ac.uk', u'Sarah.Nelson@ed.ac.uk']
# [u'd.allsopp@signal.QinetiQ.com.', u'Patrick.Beautement@signal.QinetiQ.com.', u'durfee@umich.edu.', u'm.kirton@signal.QinetiQ.com.', u'knoblock@isi.edu.', u'nsuri@ai.uwf.edu.', u'thompson@objs.com.']
# [u'mclark@glg.ed.ac.']
# [u'andy@twinearth.wustl.edu']
# [u'jtoribio@indiana.edu']
# [u'A..Schaefer@unsw.edu.au', u'maibritt@student.unsw.edu.au', u'studingbixen@hotmail.com']
# [u'jamie@mccarthy.vg']
# [u'jessicac@aiai.ed.ac.uk', u'a.tate@ed.ac.uk', u'dr@dai.ed.ac.uk']
# []
# [u'A.Schaefer@unsw.edu.au']
# [u'Ercan.Balaban@ed.ac.uk']
# [u'andycl@cogs.susx.ac.uk']
# [u'stu.west@ed.ac.uk']
# [u'ajr@softsound.com']
# []
# []
# []
# [u'andy@twinearth.wustl.edu']
# [u'J.Torero@ed.ac.uk']
# [u'V@1', u'V@1', u'V@1', u'V@1']
# [u'A.Schaefer@unsw.edu.au', u'D.Waite@unsw.edu.au', u'T.Fane@unsw.edu.au']
# []
# [u'M.Wester@let.kun.nl']
# []
# [u'sim@jaist.ac.jp', u'knoma@jaist.ac.jp', u'mit@jaist.ac.jp', u'sagayama@hil.t.u-tokyo.ac.jp']
# [u'm.nudds@bbk.ac.uk']
# []
# [u'e.laurier@mail.qmced.ac.uk', u'e.laurier@virgin.net']
# []
# [u'rick.maizels@ed.ac.uk']
# [u'Graeme.Laurie@ed.ac.uk62']
# [u'c.watts@dundee.ac.uk']
# [u'niwa@rtc.riken.go.jp.']
# [u'rick.maizels@ed.ac.uk']
# []
# [u'dallsopp@signal.dera.gov.uk', u'PBeautement@dera.gov.uk', u'jbradshaw@ai.uwf.edu', u'jcarson@signal.dera.gov.uk', u'kirton@signal.dera.gov.uk', u'nsuri@ai.uwf.edu', u'a.tate@ed.ac.uk', u'dallsopp@signal.dera.gov.uk', u'PBeautement@dera.gov.uk', u'jbradshaw@ai.uwf.edu', u'jcarson@signal.dera.gov.uk', u'kirton@signal.dera.gov.uk', u'nsuri@ai.uwf.edu', u'a.tate@ed.ac.uk']
# [u'crfr@ed.ac.uk']
# [u'r.maizels@ed.ac.uk']
# []
# [u'S.E.Armitage@hw.ac.uk1']
# [u'N.Ashbolt@unsw.edu.au']
# [u'K.N.Paudyal@Durham.ac.uk.EXPLAINING']
# [u'andycl@cogs.susx.ac.uk']
# [u'j.allen@ed.ac.uk']
# [u'm.wilkinson@glg.ed.ac.uk']
# [u'A.Schaefer@unsw.edu.au']
# [u'r.maizels@ed.ac']
# []
# [u'gweiblen@pilot.msu.edu']
# []
# []
# [u'vrossum@brandeis.edu']
# [u'I.Deary@ed.ac.uk']
# []
# [u'vrossum@swallow.bio.brandeis.edu']
# [u'milke@eng.umd.edu']
# []
# [u'andycl@cogs.susx.ac.uk']
# []
# [u's.renals@dcs.shef.ac.uk', u'dca@softsound.com']
# [u'sagayamag@jaist.ac.jp', u'sagayama@hil.t.u-tokyo.ac.jp']
# [u'nj@glg.ed.ac.uk']
# [u'dtsg@dcs.ed.ac.uk', u'rdt@cs.queensu.ca']
# []
# []
# []
# [u's.armitage@ed.ac.uk.1']
# [u'A.Fane@unsw.edu.au']
# [u'jltorero@eng.umd.edu']
# []
# [u'stu.west@ed.ac.uk']
# []
# [u'jeffrey.ketland@kcl.ac.uk']
# []
# [u'A.Schaefer@unsw.edu.au', u'A.Fane@unsw.edu.au', u'D.Waite@unsw.edu.au']
# [u'hisarm@dai.ed.ac.uk', u'g.d.ritchie@ed.ac.uk', u'ht@cogsci.ed.ac.uk', u'A@2', u'A@2', u'I@1', u'I@2.2']
# [u'jessicac@aiai.ed.ac.uk', u'jussi.stader@aiai.ed.ac.uk', u'dr@dai.ed.ac.uk']
# []
# []
# [u'C.A.Rusbridge@warwick.ac.uk']
# [u'hisarm@dai.ed.ac.uk', u'g.d.ritchie@ed.ac.uk', u'ht@cogsci.ed.ac.uk', u'A@2', u'A@2', u'I@1', u'I@2.2']
# [u'jessicac@dai.ed.ac.uk', u'dr@dai.ed.ac.uk', u'jussi.stader@aiai.ed.ac.uk']
# [u'cps@dcs.ed.ac.uk']
# []
# [u'Jeffrey.Ketland@nottingham.ac.uk']
# [u'cappell@cims.nyu.edu', u'aar@maths.ed.ac.uk', u'jmr@math.umd.eduC.']
# []
# [u'g.d.ritchie@ed.ac.uk']
# []
# [u'David.Aspinall@dcs.ed.ac.uk', u'anonymous@ftp.dcs.ed.ac.uk']
# [u'makemoney@yahoo.com', u'nospam@spam-domain.com', u'Lilian.Edwards@ed.ac.uk', u'eusl01@law.srv0.ed.ac.uk.', u'L.Edwards@ed.ac.uk.']
# [u'marta@dcs.ed.ac.uk', u'roni@dcs.ed.ac.uk']
# []
# []
# [u'j.j.ketland@lse.ac.uk']
# [u'Era.Admin@ed.ac.uk']
# [u'marta@dcs.ed.ac.uk', u'roni@dcs.ed.ac.uk']
# [u'bundyg@dai.ed.ac.uk', u'toby.walsh@cs.york.ac.uk']
# []
# [u'aar@maths.ed.ac.uk']
# [u'andy@twinearth.wustl.edu']
# []
# [u'toks.sangowawa@email.']
# []
# [u'Simon.King@ed.ac.uk']
# []
# [u'Is@t', u'Amst@RdAm', u't@rYx', u'Amst@RdAm', u'dEl@f', u'Amst@dAm']
# [u'andy@twinearth.wustl.edu']
# [u'bridget@dai.ed.ac.uk2']
# [u'J.Torero@ed.ac.uk']
# [u'J.Leeg@ed.ac.uk']
# []
# [u'g@dcs.shef.ac.uk', u'dpwe@ICSI.Berkeley.EDU', u'ajr@softsound.com']
# [u'Era.Admin@ed.ac.uk']
# []
# []
# [u'Era.Admin@ed.ac.uk']
# []
# [u'andy@twinearth.wustl.edu']
# [u'elaurier@geog.gla.ac.uk', u'cphilo@geog.gla.ac.uk']
# []
# [u'paul.cunningham@ed.ac.uk']
# [u'andy@twinearth.wustl.edu6']
# []
# [u'g.d.ritchie@ed.ac.uk']
# [u'poesio@cogsci.ed.ac.uk']
# [u'andy@twinearth.wustl.edu']
# [u'louised@dcs.gla.ac.uk', u'dream@dai.ed.ac.uk.26']
# [u'Raj.Bhopal@ed.', u'jdwilson@dunham.']
# []
# [u'andy@twinearth.wustl.edu']
# []
# []
# [u'oplan@ed.ac.uk.']
# []
# []
# []
# [u'Is@t']
# []
# [u'a.bundy@ed.ac.uk', u'julian.richardson@ed.ac.uk']
# [u'kurt@cstr.ed.ac.uk']
# []
# [u'L@l', u'z@l', u'sl@1', u'd3r@e', u'd3r@m221', u'm@1', u't@1', u't@1', u't8@1', u'ut2t8u@1', u'L@l.', u'l@1.', u'dt8e2t2t8@MB', u't@1', u't@1', u'CS@1', u'ttr@1', u'df@e2f22e22f1e26f', u'm@1', u'm@1', u'dt8@MB', u'm@1.', u'dt8@MB', u'dt8@MB', u'dt@21112', u'R@l', u'1G@I2', u'uMuL@1', u'5@sinh', u'dz@z21', u'r0@L', u'3@Lin', u'EEdzdz8@Lint', u'52h4@2', u'5h4@2', u'r0@L.', u'2@q', u'D@x5', u'r0@L', u'r0@L', u'exp@g0', u'Lx@Lz', u'Ly@Lz', u'exp@xsa2Fcon', u'sa@1', u'sa@1.', u'2@2', u'r0@L', u'5@p22k22nt', u'5@l']
# []
# [u'pepa@twinearth.wustl.edu']
# [u'Simon.King@ed.ac.uk']
# [u'pepa@twinearth.wustl.edu']
# [u't@r', u'dEl@ft']
# []
# []
# []
# [u'pepa@twinearth.wustl.edu']
# []
# []
# []
# []
# []
# [u'andy@twinearth.wustl.edu']
# [u'andy@twinearth.wustl.edu']
# [u'mitg@jaist.ac.jp']
# [u'wester@let.kun.nl']
# []
# [u'A.Schaefer@unsw.edu.au', u'A.Fane@unsw.edu.au', u'D.Waite@unsw.edu.au']
# [u'P.Moles@ed.ac.uk']
# [u'andy@twinearth.wustl.edu']
# [u'pepa@twinearth.wustl.edu']
# [u'S.ARMITAGE@ED.AC.UK1']
# [u'vrossum@retina.anatomy.upenn.edu']
# []
# [u'andy@twinearth.wustl.edu', u'chalmers@arizona.edu']
# []
# [u'pepa@twinearth.wustl.edu']
# [u'asc3@le.ac.uk']
# [u'austin.smith@ed.ac.uk']
# []
# []
# []
# []
# []
# []
# [u'awb@cstr.ed.ac.uk', u'Paul.Taylor@ed.ac.uk']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'pepa@twinearth.wustl.edu']
# [u'sue@cstr.ed.ac.uk']
# []
# [u'tn-calint@essex.ac.uk', u'tn-calint@essex.ac.uk']
# [u'pepa@twinearth.wustl.edu']
# []
# []
# [u'awb@cstr.ed.ac.uk', u'Paul.Taylor@ed.ac.uk']
# [u'robert@cstr.ed.ac.uk']
# [u'catherin@ling.ed.ac.uk', u'matthewa@cogsci.ed.ac.uk', u'bob@ling.ed.ac.uk']
# [u'briony@cstr.ed.ac.uk']
# []
# [u'andy@twinearth.wustl.edu']
# [u'Meteordc@ca']
# []
# [u'andy@twinearth.wustl.edu']
# [u'sue@cstr.ed.ac.uk']
# []
# [u'briony@cstr.ed.ac.uk']
# [u'pdg@dcs.ed.ac.uk', u'honsell@dimi.uniud.it', u'gdp@dcs.ed.ac.uk']
# [u'pault@cogsci.ed.ac.uk']
# []
# [u'aaw@cstr.ed.ac.uk']
# []
# []
# []
# []
# []
# [u'andy@twinearth.wustl.edu', u'pepa@twinearth.wustl.edu']
# [u'mf@dcs.ed.ac.uk', u'gdp@dcs.ed.ac.uk']
# []
# []
# []
# []
# [u'paul@itl.atr.co.jp']
# []
# []
# []
# []
# []
# []
# [u'pepa@twinearth.wustl.edu']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'cathie.sudlow@ed.ac.uk']
# [u'-@3A', u'-@3A']
# []
# []
# []
# []
# [u'1553@p.', u'1555@p.', u'1555@p.', u'1555@p.', u'1555@p.', u'1555@p.', u'1555@p.', u'1555@p.', u'1555@p.', u'1555@p.', u'1551@p.17', u'1551@p.10', u'1551@p.18-19', u'1553@p.', u'1553@p.', u'1613@p.', u'1553@p.', u'1553@p.', u'1553@p.', u'1553@p.', u'1553@p.', u'1553@p.', u'1553@p.', u'1553@p.', u'1553@p.', u'1553@p.', u'1553@p.', u'1553@p.', u'1553@p.', u'1553@p.365', u'1553@p.', u'1553@p.', u'1553@p.', u'1553@p.', u'1553@p.', u'1613@p.', u'1613@p.', u'1554@p.', u'1555@p.', u'1555@p.', u'1555@p.', u'1554@p.', u'1554@p.', u'1554@p.', u'1554@p.', u'1554@p.', u'1555@p.', u'1555@p.', u'1555@p.', u'1555@p.', u'1554@p.144', u'1546@p.', u'1554@p.109']
# []
# []
# []
# []
# [u'L@a']
# []
# []
# []
# []
# []
# []
# [u'A.whyte@ed.ac.uk']
# []
# [u'liz.bondi@ed.ac.uk']
# []
# []
# []
# [u'O.Chaudhry@sms.ed.ac.uk', u'William.mackaness@ed.ac.uk', u'William.mackaness@ed.ac.uk']
# [u'C.N.Abrahams@sms.ed.ac.uk']
# []
# []
# []
# []
# []
# []
# []
# []
# [u'R.Rice@ed.ac.uk']
# [u'aar@maths.ed.ac.uk']
# []
# [u'pb@dcs.ed.ac.uk']
# [u'Charlotte.Waelde@ed.ac.uk']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'gaya.n@ed.ac.uk', u'gaya.n@ed.ac.uk', u'gaya.n@ed.ac.uk']
# [u'olive7402@gmail.com', u'olive7402@gmail.com']
# []
# [u'L.D.Oliver@sms.ed.ac.uk', u'D.C.Rogers@sms.ed.ac.uk', u'L.D.Oliver@sms.ed.ac.uk', u'D.C.Rogers@dmd.ed.ac.uk']
# []
# []
# []
# []
# []
# []
# []
# []
# [u'c.adachi@sms.ed.ac.uk.', u'c.adachi@sms.ed.ac.uk.']
# []
# []
# [u'Dominic.Campopiano@ed.ac.uk', u'Michael.Greaney@ed.ac.uk', u'juan.mareque@ed.ac.uk.']
# []
# []
# []
# []
# []
# [u'nI@D', u'sEk@t', u't@r', u't@r', u'E@P6v', u'wI@d', u'noU@meIzIz', u'fEl@U', u'6n@z', u'j@z', u'D@2D', u'rm@r', u'k@n', u'aS@nIN', u'aS@nIN', u'mId@lzbr', u'mId@lzb', u'mId@lzb', u'mId@lzbrIS', u'mId@lzb', u'r@r', u't@nIk', u'pIst@n', u'pIst@n', u'pIst@n', u'sIst@rn', u'IdI@P', u'IdI@t', u's6n@P', u's6n@t', u'b@nA']
# []
# []
# [u's1055988@sms.ed.ac.uk', u's1055988@sms.ed.ac.uk', u's1055988@sms.ed.ac.uk', u'm.e.l.beveridge@sms.ed.ac.uk', u'rcs@inf.ed.ac.uk']
# []
# [u'fsemple@hgu.mrc.ac.uk', u'fsemple@hgu.mrc.ac.uk', u'donald.davidson@ed.ac.uk', u'ase.bjorstad@rheuma.gu.se.']
# []
# []
# []
# []
# [u'simon@ling.ed.ac.uk.', u'simon@ling.ed.ac.uk', u'rights@benjamins.nl']
# []
# []
# []
# [u's1026816@sms.ed.ac.uk']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'i@t', u'praat-users@yahoogroups.co.uk']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'vesna.miletic@gmail.com', u'ariosantini@hotmail.com', u'ariosantini@hotmail.com', u'vesna.miletic@gmail.com']
# []
# []
# []
# []
# []
# [u'marjorie.harding@ed.ac.uk', u'm.walkinshaw@ed.ac.uk']
# []
# []
# []
# [u'a@q', u'Am@Af']
# []
# []
# []
# []
# [u'C.Du@ed.ac.uk', u'John.Thompson@ed.ac.uk', u'Y.R.Petillot@hw.ac.uk', u'C.Du@ed.ac.uk', u'John.Thompson@ed.ac.uk', u'Y.R.Petillot@hw.ac.uk', u'Y.R.Petillot@hw.ac.uk', u'Y.R.Petillot@hw.ac.uk', u'C.Du@ed.ac.uk']
# [u'.@.']
# [u'A.Gemmell-2@sms.ed.ac.uk', u'jfoley@ed.ac.uk']
# []
# [u'v.plows@sms.ed.ac.uk']
# []
# []
# [u'Elaine.Love@glacomen.scot.nhs.uk']
# [u'Mhairi.Williams@nhs.net', u'Mhairi.Williams@nhs.net']
# [u's.michlewska@sms.ed.ac.uk', u'A.G.Rossi@ed.ac.uk', u'eld@ed.ac.uk']
# []
# []
# []
# []
# []
# []
# [u'Modest_Witness@Second_Millennium.FemaleMan']
# [u'763.46@cid35.00', u'767.04@cid35.00']
# []
# []
# [u'm1z1@m2z2...']
# []
# []
# []
# []
# []
# [u'yi@v', u'0@x', u'yd@d', u'y@d0', u'dpasx@dinupdated']
# []
# [u'alison.campbell5@nhs.net', u'alison.campbell5@nhs.net', u'alison.campbell5@nhs.net']
# []
# [u'.@.']
# []
# [u'www-tag@w3.org', u'www-tag@w3.org.', u'www-tag@w3.org.', u'www-rdf-comments@w3.org.', u'www-rdf-comments@w3.org.', u'www-rdf-comments@w3.org.']
# []
# [u'mhch@bgs.ac.uk']
# []
# []
# [u'c.r.hall@ed.sac.ac.uk', u'c.r.hall@ed.sac.ac.uk']
# []
# [u'Nick.Johnson@ed.ac.uk', u'garcia@agilent.com', u'garcia@agilent.com', u'garcia@agilent.com']
# []
# []
# []
# []
# [u'yT@w', u'yl@g', u'ym@ym', u'yl@k']
# []
# []
# []
# []
# [u'D.Leach@ed.ac.uk']
# [u'em@w3.org', u'em@w3.org']
# []
# []
# []
# [u'adel.heenan@gmail.com']
# []
# []
# []
# []
# []
# [u'a.d.rankin@ed.ac.uk']
# []
# []
# []
# [u'i.r.poxton@ed.ac.uk']
# []
# []
# []
# []
# []
# [u'eld@ed.ac.uk', u'eld@ed.ac.uk']
# []
# []
# []
# []
# []
# []
# []
# [u'David.Leigh@ed.ac.uk', u'david.leigh@ed.ac.uk', u'aucagne@cnrs-orleans.fr', u'sebastien.papot@univ-poitiers.fr']
# []
# []
# []
# []
# [u'stephane.dalle@chu-lyon.fr', u'm.zamiri@clinmed.gla.ac.uk']
# []
# [u'David.Leigh@ed.ac.uk', u'david.leigh@ed.ac.uk', u'david.leigh@ed.ac.uk', u'david.leigh@ed.ac.uk']
# [u'Fab@Home', u'Fab@home']
# [u'A.Law@ed.ac.uk', u'M.Gillie@ed.ac.uk']
# []
# []
# []
# []
# []
# [u'yaghoobi@ieee.org', u'mike.davies@ed.ac.uk', u'daudet@lam.jussieu.fr', u'laurent.daudet@espci.fr']
# []
# []
# []
# []
# []
# []
# [u'Psychology@ed.ac.uk', u's.abrahams@ed.ac.uk', u's.abrahams@ed.ac.uk', u'Psychology@ed.ac.uk', u's.abrahams@ed.ac.uk', u's.abrahams@ed.ac.uk']
# []
# []
# []
# []
# []
# [u'mark.bradley@ed.ac.uk.']
# []
# []
# []
# [u'clean@0s']
# [u'S.Nagappa@ed.ac.uk', u'James.Hopgood@ed.ac.uk', u'S.Nagappa@ed.ac.uk', u'James.Hopgood@ed.ac.uk']
# []
# []
# []
# []
# []
# []
# [u'jscotla2@staffmail.ed.ac.uk', u'jscotla2@staffmail.ed.ac.uk']
# []
# []
# []
# []
# []
# [u'mjpower@staffmail.ed.ac.uk', u'Shona.Haining@northtyneside-pct.nhs.uk', u'Alex.Moores@ncumbria.nhs.uk', u'catherine.nesbitt@nhs.net', u'catherine.nesbitt@nhs.net']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'bi@k']
# [u'H.Du@ed.ac.uk', u'P.Chung@ed.ac.uk', u'H.Du@ed.ac.uk', u'P.Chung@ed.ac.uk', u'B.Mulgrew@ed.ac.uk', u'P.Chung@ed.ac.uk', u'H.Du@ed.ac.uk', u'J.Gondzio@ed.ac.uk']
# []
# [u'M.M.Gilek@sms.ed.ac.uk', u'a.finucane@ed.ac.uk', u'elizabeth.austin@ed.ac.uk', u'M.M.Gilek@sms.ed.ac.uk']
# []
# [u'h.haas@ed.ac.uk', u'auer@docomolab-euro.com', u's.videv@jacobs-alumni.de', u'auer@docomolab-euro.com', u'auer@docomolab-euro.com', u'auer@docomolab-euro.com', u'h.haas@ed.ac.uk', u's.videv@jacobs-university.de', u'auer@docomolab-euro.com', u'auer@docomolab-euro.com']
# [u'j@L']
# []
# [u'v.s.munoz@sms.ed.ac.uk', u'v.s.munoz@sms.ed.ac.uk']
# []
# []
# []
# []
# []
# [u'a.read@psu.edu']
# []
# [u'xxx@gmail.com.', u'xxx@gmail.com.', u'xxx@gmail.com.']
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Stewart.Smith@ed.ac.uk', u'Stewart.Smith@ed.ac.uk']
# [u'unzarec@zamtel.zm']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'c.evers@ed.ac.uk', u'c.evers@ed.ac.uk']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'S.J.Rhynas@sms.ed.ac.uk', u'S.J.Rhynas@sms.ed.ac.uk', u'S.J.Rhynas@sms.ed.ac.uk', u'S.J.Rhynas@sms.ed.ac.uk', u'S.J.Rhynas@sms.ed.ac.uk']
# [u'CB@MAMI', u'CB@MAMI']
# []
# [u'nosres@nhs.net', u'referencegroup@nationalres.org.uk', u'nosres@nhs.net', u'nosres@nhs.net', u'jackie.fraser@haht.scot.nhs.ukAppendix', u'alexis.patterson@nhs.netWorking']
# []
# []
# []
# []
# []
# [u'david.dryden@ed.ac.uk', u'david.dryden@ed.ac.uk.']
# []
# []
# []
# []
# []
# []
# [u's.j.palmer@sms.ed.ac.uk']
# [u's.r.shave@sms.ed.ac.uk', u'p.taylor@ed.ac.uk', u'm.walkinshaw@ed.ac.uk', u'l.smith@ed.ac.uk', u'j.hardy@ed.ac.uk', u'a.trew@ed.ac.uk', u'm.walkinshaw@ed.ac.uk']
# [u'K.R.Lohse@sms.ed.ac.uk', u'konrad.lohse@gmail.com', u'K.R.Lohse@sms.ed.ac.uk.']
# []
# []
# []
# []
# []
# []
# []
# [u'Y@Z', u't@Y', u'T@L', u'Y@Z', u'Y@Z', u't@Y', u'Y@Z', u't@Y', u'Y@Z', u't@Y']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'Science@Nasa']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'S@miz', u'S@val', u's@mEn', u'k@mis', u's@mI', u's@mI', u's@mI', u'arbr@s', u'sendr@APPENDIX', u'ktjS@O', u's@mI', u'ts@mi', u'S@miz', u'k@mY', u'k@mis', u'tS@vo', u'S@val', u'k@val', u'simetjEr@APPENDIX', u'kutr@330', u'Uf@l', u'f@O', u'Z@n', u'gr@nul', u'gar@tjEr', u'Zub@n', u'oraZ@336', u'p@s', u's@me', u's@mE', u's@me', u's@mEn', u's@m', u'vak@340', u'remco@ling.ed.ac.uk']
# []
# []
# []
# [u'j.i.mason@ed.ac.uk']
# []
# [u'marker@markersoftware.com']
# []
# []
# []
# []
# [u'g.jenkins@nhs.net', u'help@b-eat.co.uk', u'g.jenkins@nhs.net', u'Jill.lobbestael@dmkep.unimaas.nl']
# []
# []
# []
# []
# [u'home@antongeist.com.']
# [u'Vf@60s', u'Prediction@60s', u'Vf@150s', u'Vf@180s', u'Vf@210s', u'Vf@240s', u'Vf@270s', u'lp@90s', u'lf@90s', u'lp@210s', u'lf@210s', u'fit@60s', u'fit@90s', u'fit@120s', u'fit@150s', u'fit@180s', u'fit@210s', u'fit@240s', u'fit@270s', u'fit@300s', u'fit@60s', u'fit@90s', u'fit@120s', u'fit@150s', u'fit@180s', u'fit@210s', u'fit@330s', u'fit@360s', u'fit@390s', u'fit@420s', u'fit@450s', u'fit@480s', u'fit@510s', u'fit@540s', u'fit@570s', u'fit@600s', u'atrouve@umd.edu.']
# []
# []
# [u'mcuzi@hanmail.net']
# []
# []
# [u'e.foutekova@ed.ac.uk', u'pagyapong@jacobs-alumni.de', u'e.foutekova@iu-bremen.de', u'cevers@world.iu-bremen.de', u'h.haas@iu-bremen.de']
# [u'h.sutherland@hgu.mrc.ac.uk']
# []
# []
# []
# []
# [u'ben.williams@ed.ac.uk', u'ben.williams@ed.ac.uk']
# []
# []
# []
# []
# []
# []
# [u'alex.horsley@ed.ac.uk', u'kenny.macleod@ed.ac.uk']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'jtodman@nhs.net', u'margaret.somerville@chss.org.']
# []
# []
# [u'paul.skehel@ed.ac.uk', u'journals.permissions@oxfordjournals.org']
# []
# [u'Justin.Goodrich@ed.ac.uk', u'Daniel.Schubert@uni-']
# []
# []
# []
# [u'g@b']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'mcsot@yahoo.com', u'Z.Xie@sms.ed.ac.uk', u'INTER@CTiVE']
# []
# []
# []
# []
# [u'R.C.Stenhouse@sms.ed.ac.uk']
# []
# []
# [u'Andreas.Hofmann@ed.ac.uk', u'a.hofmann@griffith.edu.au', u'a.hofmann@griffith.edu.au']
# []
# []
# []
# []
# [u'Bruce.Rae@ed.ac.uk', u'David.Li@ed.ac.uk', u'jonathan.mckendry@strath.ac.uk', u'Bruce.Rae@ed.ac.uk', u'pubs-permissions@ieee.org.', u'David.Li@ed.ac.uk', u'zheng.gong@strath.ac.uk', u'David.Li@ed.ac.uk', u'e.y.m.bonnist@sms.ed.ac.uk', u'Y.Li@ed.ac.uk', u'Bruce.Rae@ed.ac.uk', u'Y.Li@ed.ac.uk', u'Bruce.Rae@ed.ac.uk', u'Robert.Henderson@ed.ac.uk', u'Robert.Henderson@ed.ac.uk', u'Edoardo.Charbon@epfl.ch']
# [u'constant.@The']
# []
# []
# []
# []
# []
# []
# [u'l@qup', u'lMPq@l', u'lMPq@l', u'WRstU@dG', u'WRstU@dG']
# []
# []
# []
# []
# [u'SETI@home', u'SETI@home']
# [u'h.lam@ed.ac.uk', u'h.lam@ed.ac.uk', u'deposit@ccdc.cam.ac.uk', u'deposit@ccdc.cam.ac.uk']
# []
# []
# []
# [u'rmsbysetting@qi']
# []
# []
# [u'f@g']
# [u'P.Collard@sms.ed.ac.uk']
# []
# []
# [u'h.lam@ed.ac.uk']
# []
# []
# [u'n.golledge@bgs.ac.uk', u'n.golledge@bgs.ac.uk', u'n.golledge@bgs.ac.uk', u'n.golledge@bgs.ac.uk', u'n.golledge@bgs.ac.uk', u'n.golledge@bgs.ac.uk', u'n.golledge@bgs.ac.uk', u'n.golledge@bgs.ac.uk', u'n.golledge@bgs.ac.uk']
# []
# []
# []
# [u'ed@ed', u'ed@ed', u'ed@ed20']
# []
# []
# []
# []
# []
# [u'SETI@home', u'SETI@home']
# []
# []
# []
# []
# []
# []
# []
# []
# [u'neil.robertson@ed.ac.uk', u'neil.robertson@ed.ac.uk']
# []
# []
# []
# []
# []
# [u'Paul.Gaston@ed.ac.uk', u'richard.burnett@wlt.scot.nhs.ukChapter']
# []
# [u'sim.bamford@ed.ac.uk', u'sim.bamford@ed.ac.uk']
# []
# []
# []
# []
# []
# [u'stefan@ling.ed.ac.uk', u'stefan@ling.ed.ac.uk', u'andrew@ling.ed.ac.uk', u'stefan@ling.ed.ac.uk', u'andrew@ling.ed.ac.uk']
# [u'z.lu@hrsu.mrc.ac.uk.', u'karger@karger.ch', u'k.morgan@hrsu.mrc.ac.uk']
# []
# []
# []
# []
# [u'xavier.donadeu@ed.ac.uk']
# []
# [u'rowena.arshad@ed.ac.uk']
# [u'David.Leigh@ed.ac.uk', u'Francesco.Zerbetto@unibo.it', u'David.Leigh@ed.ac.uk']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'x@y', u'x@z', u'y@x', u'y@z', u'z@x', u'z@y']
# []
# []
# []
# []
# []
# []
# []
# [u'andrew.macdonald@ed.ac.uk', u'andrew.macdonald@ed.ac.uk']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'g.ferguson@abdn.ac.uk']
# []
# []
# []
# []
# [u'David.Leigh@ed.ac.uk', u'David.Leigh@ed.ac.uk', u'david.leigh@ed.ac.uk', u'David.Leigh@ed.ac.uk', u'david.leigh@ed.ac.uk', u'paul.dyson@epfl.ch.']
# [u'L.Paternoster@sms.ed.ac.uk']
# []
# []
# []
# [u's0460205@sms.ed.ac.uk', u'stephen@milker.org.uk']
# [u'vcb11@psu.edu', u'victoria.barclay@ed.ac.uk', u'4nlm@queensu.ca.']
# []
# [u'serena.margadonna@ed.ac.uk']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'h.v.senn@sms.ed.ac.uk']
# []
# []
# []
# [u'a.h.hill@ed.ac.uk.', u'wzhou@st-andrews.ac.uk', u'p.g.bruce@st-andrews.ac.uk', u'g.bruce@st-and.ac.uk', u'pgb1@st-andrews.ac.uk']
# []
# [u'c.trevethan@nhs.net', u'c.trevethan@nhs.net']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [u'ess@skull.dcn.ed.ac.uk', u'ess@skull.dcn.ed.ac.uk', u'ess@skull.dcn.ed.ac.uk', u'caroline.jackson@ed.ac.uk']
# []
# []
# []
# []
# []
# []
# []
# []

# %%
len(all_emails)
# Out:
# 200

# %%
type(all_emails)
# Out:
# list
