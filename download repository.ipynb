# %%
from urllib2 import urlopen
from urllib import urlencode
from urllib import quote_plus
# import urllib.parse
import json
import pprint

class CoreApiRequestor:

    def __init__(self, endpoint, api_key):
        self.endpoint = endpoint
        self.api_key = api_key
        #defaults
        self.pagesize = 100
        self.page = 1

    def parse_response(self, decoded):
        res = []
        for item in decoded['data']:
            doi = None
            if 'identifiers' in item:
                for identifier in item['identifiers']:
                    if identifier and identifier.startswith('doi:'):
                        doi = identifier
                        break
            res.append([item['title'], doi])
        return res

    def request_url(self, url):
        print(url)
        response = urlopen(url)
        html = response.read()
        return html

    def get_method_query_request_url(self,method,query,fullText,page):
        if (fullText):
            fullText = 'true'
        else:
            fullText = 'false'
        params = {
            'apiKey':self.api_key,
            'page':page,
            'pageSize':self.pagesize,
            'fulltext':fullText
        }
        return self.endpoint + method + '/' + quote_plus(query) + '?' + urlencode(params)

    def get_up_to_20_pages_of_query(self,method,query,fulltext):
        url = self.get_method_query_request_url(method,query,fulltext,1)
        all_articles=[]
        resp = self.request_url(url)
        result = json.loads(resp.decode('utf-8'))
        all_articles.append(result)
        if (result['totalHits']>100):
            numOfPages = int(result['totalHits']/self.pagesize)  #rounds down
            if (numOfPages>20):
                numOfPages=20
            for i in range(2,numOfPages):
                url = self.get_method_query_request_url(method,query,False,i)
                print(url)
                resp =self.request_url(url)
                all_articles.append(json.loads(resp.decode('utf-8')))
        return all_articles
    
    def get_repository_articles_fulltext_as_dict(self,repository_id):
        return ""
    
    def get_search_repository_request_url(self,repoQuery,page=1,pageSize=10):
        params={
            'apiKey':self.api_key,
            'page':page,
            'pageSize':pageSize
        }
        return self.endpoint + "/repositories/search/"+quote_plus(repoQuery)+'?'+urlencode(params)
    
    def search_repository_ids_by_name(self,repoName):
        discoverRepoUrl = self.get_search_repository_request_url(repoName)
        resp = self.request_url(discoverRepoUrl)
        result = json.loads(resp.decode('utf-8'))
        for item in result['data']:
            if 'name' in item:
                name = item['name']
            if 'id' in item:
                id = item['id']
            repos[id]=name
        return repos
    
    def get_count_articles_of_repository_url(self,repoId,withFullText):
        ft = 'false'
        if(withFullText):
            ft = 'true'
                
        params = {
            'apiKey':self.api_key,
            'fulltext':ft
        }    
        return self.endpoint + "/articles/search/repositories.id:"+repoId+'?'+urlencode(params)
    
    def count_articles_of_repository(self,repoId,withFullText=False):
        countArticlesOfRepoUrl = self.get_count_articles_of_repository_url(repoId,withFullText)
        print(countArticlesOfRepoUrl)
        resp = self.request_url(countArticlesOfRepoUrl)
        result = json.loads(resp.decode('utf-8'))
        return result['totalHits']
    
    def get_url_of_download_articles_of_repository(self,repoId,fullText,page,pageSize):
        params={
            'apiKey':self.api_key,
            'page':page,
            'pageSize':pageSize,
            'fulltext':fullText
               }
        return self.endpoint + "/articles/search/repositories.id:"+str(repoId)+'?'+urlencode(params)
    
    def download_articles_of_repository(self, repoId, fulltext=True, page=1, pageSize=100):
        url = self.get_url_of_download_articles_of_repository(repoId,fulltext,page,pageSize)
        all_articles=[]
        resp = self.request_url(url)
        result = json.loads(resp.decode('utf-8'))
        if (result['totalHits']>100):
            numOfPages = int(result['totalHits']/self.pagesize)  #rounds down
            if (numOfPages>5):
                numOfPages=5
            for i in range(2,numOfPages):
                url = self.get_url_of_download_articles_of_repository(repoId,fulltext,page,pageSize)
                print(url)
                resp =self.request_url(url)
                all_articles.append(json.loads(resp.decode('utf-8')))
        return all_articles

# %%
'''
Initialise parameters
'''
# init 
endpoint = 'https://core.ac.uk/api-v2'

'''
********************************************
Add your own api key below
'''
api_key =""
# or get it from a config file
file = open("api_key.secret","r") 
api_key=file.read()
'''
********************************************
'''
'''
Create your api object
'''
api = CoreApiRequestor(endpoint,api_key)

# %%
api.get_url_of_download_articles_of_repository(1,True,1,100)
# Out:
# 'https://core.ac.uk/api-v2/articles/search/repositories.id:1?fulltext=True&apiKey=nTo627BU8jPNth4EbsrDue9IXWzAfZiY&page=1&pageSize=100'

# %%
url = api.get_url_of_download_articles_of_repository(1,True,1,12)

# %%
import pickle

# %%
repoId=1
'''
Use page size 50 
-
store as pickle every 200 articles (4 pages)
in the end you will have in the cwd files:
all_articles_on1_1.pkl
all_articles_on1_2.pkl
all_articles_on1_3.pkl
...

'''
all_articles=[]
for i in range(1,40):
    url = api.get_url_of_download_articles_of_repository(repoId,True,i,50)
    response = urlopen(url)
    resp = response.read()
    result = json.loads(resp.decode('utf-8'))
    all_articles.append(result)
    if (i%4==0):
        pickle.dump(all_articles,open('all_articles_on'+str(repoId)+'_'+str(i/4)+'.pkl','wb'),pickle.HIGHEST_PROTOCOL)
        all_articles=[]

# %%
try:
    articles = pickle.load(open('all_articles_on1_1.pkl','rb'))
except (OSError,IOError) as e:
    print(e)

# %%
articles[0]['data'][0]
# Out:
# {u'authors': [u'Lenartowicz, Malgorzata',
#   u'Kennedy, Christine',
#   u'Hayes, Helen',
#   u'McArdle, Harry J'],
#  u'contributors': [u'University of Aberdeen, Medicine, Medical Sciences & Nutrition, RINH'],
#  u'datePublished': u'2015-02',
#  u'description': u'Acknowledgments The authors\u2019 work is supported by Scottish Government (Rural and Environmental Scientific and Analytical Services). We are grateful to Ms Val Stevens for analytical and technical assistance and to the Biological Resource Facility staff for husbandry and maintenance of the experimental animals. The authors declare no conflicts of interest. Open Access This article is distributed under the terms of the Creative Commons Attribution License which permits any use, distribution, and reproduction in any medium, provided the original author(s) and the source are credited.Peer reviewedPublisher PD',
#  u'doi': u'10.1007/s10534-014-9802-z',
#  u'fullText': u'Transcriptional regulation of copper metabolism genes\nin the liver of fetal and neonatal control and iron-deficient\nrats\nMalgorzata Lenartowicz \u2022 Christine Kennedy \u2022\nHelen Hayes \u2022 Harry J. McArdle\nReceived: 13 October 2014 / Accepted: 16 October 2014 / Published online: 28 October 2014\n\x02 The Author(s) 2014. This article is published with open access at Springerlink.com\nAbstract Copper and iron metabolism have been\nknown to interact for many years. We have previously\nshown, during pregnancy, that copper levels in the\nmaternal liver rise as a consequence of iron deficiency,\nbut that levels in the fetal liver decrease. In this paper,\nwe measure expression of genes involved in copper\nmetabolism in fetal and postnatal liver, to test whether\nalterations can explain this observation. Additionally,\nwe study the extent to which gene expression changes\nin the latter stages of pregnancy and in the perinatal\nperiod. Ctr1 expression levels dropped to term, rising\nagain thereafter. There was no difference in gene\nexpression between control and iron deficient animals.\nAtox1 expression remained approximately stable until\nterm, and then there was a rise to a maximum at about\nDay 8. Atp7a expression levels remained constant,\nexcept for a brief drop at term. Atp7b levels, in contrast,\ndecreased from a maximum early in gestation to low\nlevels in the term and post-natal livers. Ceruloplasmin\nexpression appeared to be diametrically opposite to\nAtp7b. The other two metallochaperones showed the\nsame pattern of expression as Atox1, with a decrease to\nterm, a rise at Day 1, or a rise after birth followed by a\nbrief decrease at about Day 3. None of the genes were\nsignificantly affected by iron deficiency, suggesting\nthat changes in expression cannot explain the altered\ncopper levels in the fetal and neonatal liver.\nKeywords Copper-iron interactions \x02 Perinatal\ndevelopment \x02 Metallochaperones \x02 ATP7A \x02 ATP7B \x02\nCopper metabolism \x02 Hooded Lister rats\nIntroduction\nCopper is a micronutrient, essential for normal growth\nand development. It is a cofactor for enzymes that\ncatalyze reactions used in fundamental metabolic\nprocesses, including respiratory oxidation, neurotrans-\nmitter synthesis, iron uptake regulation, and connec-\ntive tissue formation (Lutsenko et al. 2007). However,\nan excess of copper has the potential to be toxic, as the\nions are potent generators of free radicals, which could\nlead to oxidative damage of proteins, lipids and nucleic\nacids (Lutsenko et al. 2007; Van den Berghe and\nKlomp 2010; Velthuis et al. 2009). Consequently,\norganisms have developed complex and genetically\nregulated control mechanisms for maintaining the\nbalance between essential and toxic copper levels.\nIn mammals, copper is absorbed mainly in the\nstomach and duodenum and is transported in plasma to\nM. Lenartowicz\nDepartment of Genetics and Evolution, Institute of\nZoology, Jagiellonian University, Gronostajowa 9,\n30-387 Krako\xb4w, Poland\nC. Kennedy \x02 H. Hayes \x02 H. J. McArdle (&)\nRowett Institute of Nutrition and Health, University of\nAberdeen, Greenburn Road, Bucksburn,\nAberdeen AB21 9SB, UK\ne-mail: h.mcardle@abdn.ac.uk\n123\nBiometals (2015) 28:51\u201359\nDOI 10.1007/s10534-014-9802-z\nthe liver (Van den Berghe and Klomp 2010), the main\norgan responsible for copper homeostasis. The copper\nis stored primarily as a copper-metallothionein com-\nplex (Bauerly et al. 2005; Czachor et al. 2002; Davis\nand Cousins 2000) and is excreted through bile\n(Huster et al. 2006; Wijmenga and Klomp 2004).\nCopper uptake by hepatocytes is mediated by the\nhigh affinity copper transporter 1 (CTR1) (Kuo et al.\n2001, 2006). In the cell the copper is bound to\nmetallochaperones, and transported to the different\ncompartments of the cell (O\u2019Halloran and Cizewski\nCulotta 2000). Different chaperones deliver the copper\nto different enzymes. The copper chaperone of\nsu ...
#  u'fulltextIdentifier': u'https://core.ac.uk/download/pdf/29151098.pdf',
#  u'id': u'29151098',
#  u'identifiers': [u'oai:aura.abdn.ac.uk:2164/4203',
#   u'10.1007/s10534-014-9802-z'],
#  u'journals': [{u'identifiers': [u'0966-0844', u'issn:0966-0844'],
#    u'title': None}],
#  u'oai': u'oai:aura.abdn.ac.uk:2164/4203',
#  u'relations': [],
#  u'repositories': [{u'citationCount': 0,
#    u'citationDoiCount': 0,
#    u'citationFilesDb': 0,
#    u'citationWithDocCount': 0,
#    u'crawlingLimit': 0,
#    u'databaseDeletedPdfCount': 0,
#    u'databaseDeletedRecordCount': 0,
#    u'databaseIndexCount': 0,
#    u'databasePdfCount': 0,
#    u'databasePdfLinkCount': 0,
#    u'databaseRecordCount': 0,
#    u'databaseTextCount': 0,
#    u'databaseTextNotDeletedCount': 0,
#    u'description': None,
#    u'disabled': False,
#    u'documentDoiCount': 0,
#    u'documentDoiWithFulltextCount': 0,
#    u'hardDriveCitationFiles': 0,
#    u'hardDriveDeletedPdfCount': 0,
#    u'hardDriveDeletedTextCount': 0,
#    u'hardDrivePdfCount': 0,
#    u'hardDrivePdfSize': 0,
#    u'hardDriveTextCount': 0,
#    u'id': u'1',
#    u'indexJournalCount': 0,
#    u'indexRecordCount': 0,
#    u'indexTextCount': 0,
#    u'indexTextCountDB': 0,
#    u'indexTextNotDeletedCount': 0,
#    u'indexedDisabledDB': 0,
#    u'indexedPdfDB': 0,
#    u'journal': None,
#    u'journalMetadataAge': None,
#    u'journalMetadataExtractionDate': None,
#    u'journalMetadataSize': 0,
#    u'lastUpdateTime': None,
#    u'metadataAge': None,
#    u'metadataAlloweInIndexCount': 0,
#    u'metadataDeletedInIndexCount': 0,
#    u'metadataDeletedRecordCount': 0,
#    u'metadataDisabledInIndexCount': 0,
#    u'metadataExtractionDate': None,
#    u'metadataFormat': None,
#    u'metadataInIndexCount': 0,
#    u'metadataLinkCount': 0,
#    u'metadataOnlyIndex': 0,
#    u'metadataRecordCount': 0,
#    u'metadataSize': 0,
#    u'name': u'Aberdeen University Research Archive',
#    u'nrUpdates': 0,
#    u'openDoarId': 0,
#    u'pdfStatus': None,
#    u'physicalName': u'noname',
#    u'repositoryLocation': None,
#    u'software': None,
#    u'source': None,
#    u'uri': None,
#    u'uriJournals': None}],
#  u'subjects': [u'Journal article'],
#  u'title': u'Transcriptional regulation of copper metabolism genes in the liver of fetal and neonatal control and iron-deficient rats',
#  u'topics': [u'copper-iron interactions',
#   u'perinatal development',
#   u'metallochaperones',
#   u'ATP7A',
#   u'ATP7B',
#   u'copper metabolism',
#   u'Hooded Lister rats',
#   u'QP Physiology',
#   u'QP'],
#  u'types': [],
#  u'year': 2015}

# %%
text = articles[0]['data'][0]['fullText']

# %%
import re
match = re.findall(r'[\w\.-]+@[\w\.-]+', text)

# %%
match
# Out:
# [u'L.V.Burgin@leeds.ac.uk',
#  u'Lorna.ramsay@education.gsi.gov.uk',
#  u'r.aspden@abdn.ac.uk']

# %%
import pickle 
import re
def get_all_emails_of_repository(repoId):
    all_emails = []
    for page_pickle in range(1,13):
        try:
            articles = pickle.load(open('all_articles_on'+str(repoId)+'_'+str(page_pickle)+'.pkl','rb'))
            for page in range(0,len(articles)):
                for item in articles[page]['data']:
                    text = item['fullText']
                    match = re.findall(r'[\w\.-]+@[\w\.-]+', text)
#                     print(match)
                    all_emails.append(match)
        except (OSError,IOError) as e:
            print(e)
    return all_emails

# %%
email_of_1 = get_all_emails_of_repository(1)
# Out:
# [Errno 2] No such file or directory: 'all_articles_on1_10.pkl'
# [Errno 2] No such file or directory: 'all_articles_on1_11.pkl'
# [Errno 2] No such file or directory: 'all_articles_on1_12.pkl'

# %%
email_of_39 = get_all_emails_of_repository(39)

# %%
email_of_86 = get_all_emails_of_repository(86)

# %%
len(all_emails)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-fefea9708111> in <module>()
# ----> 1 len(all_emails)
#
# NameError: name 'all_emails' is not defined

# %%
def flatten_list(unevenList):
    flat_list=[]
    for sublist in unevenList:
        for item in sublist:
            flat_list.append(item)
    return flat_list

# %%
email_of_1_flat = flatten_list(email_of_1)
len(email_of_1_flat)
# Out:
# 2936

# %%
email_of_39_flat = flatten_list(email_of_39)
email_of_86_flat = flatten_list(email_of_86)

# %%
#how many authors from aberdeen's articles are from aberdeen?
abdn_ctn=0
for i in email_of_1_flat:
    if i.endswith("abdn.ac.uk"):
        abdn_ctn +=1
print(abdn_ctn,len(email_of_1_flat))
# Out:
# (1132, 2936)

# %%
import pandas as pd

# %%
world_domains = pd.read_json('world_universities_and_domains.json')

# %%
world_domains.head()
# Out:
#   alpha_two_code        country          domain  \
# 0             US  United States  calbaptist.edu
# 1             US  United States   stevenson.edu
# 2             US  United States         mbl.edu
# 3             US  United States   maryville.edu
# 4             US  United States         aii.edu
#
#                             name                    web_page
# 0  California Baptist University  http://www.calbaptist.edu/
# 1           Stevenson University   http://www.stevenson.edu/
# 2   Marine Biological Laboratory         http://www.mbl.edu/
# 3           Maryville University   http://www.maryville.edu/
# 4             The Art Institutes         http://www.aii.edu/

# %%
world_domains.tail()
# Out:
#      alpha_two_code        country                domain  \
# 9450             US  United States            ewc.wy.edu
# 9451             US  United States           lccc.wy.edu
# 9452             US  United States  northwestcollege.edu
# 9453             US  United States          sheridan.edu
# 9454             US  United States           wwcc.wy.edu
#
#                                    name                         web_page
# 9450            Eastern Wyoming College                http://ewc.wy.edu
# 9451   Laramie County Community College           http://www.lccc.wy.edu
# 9452                  Northwest College  http://www.northwestcollege.edu
# 9453                   Sheridan College          http://www.sheridan.edu
# 9454  Western Wyoming Community College           http://www.wwcc.wy.edu

# %%
emails_df = pd.DataFrame.from_records({'email':email_of_1_flat+email_of_39_flat+email_of_86_flat})

# %%
emails_df
# Out:
#                                    email
# 0                 L.V.Burgin@leeds.ac.uk
# 1      Lorna.ramsay@education.gsi.gov.uk
# 2                    r.aspden@abdn.ac.uk
# 3                david.mcghee@abdn.ac.uk
# 4                    j.mercer@abdn.ac.uk
# 5             michelle.murphy@abdn.ac.uk
# 6            Sarah.Harris@igmm.ed.ac.uk.
# 7               T.Gillingwater@ed.ac.uk.
# 8                   jiabao.he@abdn.ac.uk
# 9                s.schwarzkopf@gmail.com
# 10        marie.castellazzi@hutton.ac.uk
# 11            diana.feliciano@abdn.ac.uk
# 12               iain.brown@hutton.ac.uk
# 13             Jill.Francis.1@city.ac.uk
# 14            jukka.corander@helsinki.fi
# 15            s.k.sheppard@swansea.ac.uk
# 16                    a.price@abdn.ac.uk
# 17              a.r.akisanya@abdn.ac.uk.
# 18                  j.hussein@abdn.ac.uk
# 19                    c.hesse@abdn.ac.uk
# 20                     y.hopf@abdn.ac.uk
# 21            clare.allely@glasgow.ac.uk
# 22                 n.r.velaga@iitb.ac.in
# 23              a.r.akisanya@abdn.ac.uk.
# 24                   x.lambin@abdn.ac.uk
# 25             m.olson@beatson.gla.ac.uk
# 26                l.n.kanguru@abdn.ac.uk
# 27              sally.wyke@glasgow.ac.uk
# 28                  jane.reid@abdn.ac.uk
# 29                  wmoncur@dundee.ac.uk
# ...                                  ...
# 9034                 j.f.hellings@hva.nl
# 9035  mwoodruff@myknowledgenetwork.co.uk
# 9036           hwalker@brighttribe.og.uk
# 9037             Michael.Webb@jisc.ac.uk
# 9038     Sandeep.Jayaprakash1@marist.edu
# 9039                 ggilbert@unicon.net
# 9040               Shady.Shehata@d2l.com
# 9041                 t.nixon@memphis.edu
# 9042                n.dowell@memphis.edu
# 9043                t.ullmann@open.ac.uk
# 9044              David.Bevan@open.ac.uk
# 9045              csaba.szabo@open.ac.uk
# 9046                  n.smith@open.ac.uk
# 9047    helen.caldwell@northampton.ac.uk
# 9048               m.richards@open.ac.uk
# 9049          vanni.moggicecchi@unifi.it
# 9050           palgrave@macmillan.com.au
# 9051                 orders@palgrave.com
# 9052         alistair.willis@open.ac.uk.
# 9053               ali@humanshuddle.com.
# 9054                            il23@st-
# 9055               T.Currie@exeter.ac.uk
# 9056            Sharon.mallon@open.ac.uk
# 9057                  k.galway@qub.ac.uk
# 9058               ann.grand@uwa.edu.au.
# 9059         Richard.Holliman@open.ac.uk
# 9060          Trevor.Collins@open.ac.uk.
# 9061              Anne.Adams@open.ac.uk.
# 9062          jacky.bourgeois@open.ac.uk
# 9063          candice.bedford@open.ac.uk
#
# [9064 rows x 1 columns]

# %%
def extract_domain(email):
    return email.split("@")[1]

# %%
extract_domain("mackenzie@abdn.ac.uk")
# Out:
# 'abdn.ac.uk'

# %%
emails_df['domain']=emails_df.apply(lambda row: extract_domain(row['email']),axis=1)
emails_df
# Out:
#                                    email                    domain
# 0                 L.V.Burgin@leeds.ac.uk               leeds.ac.uk
# 1      Lorna.ramsay@education.gsi.gov.uk      education.gsi.gov.uk
# 2                    r.aspden@abdn.ac.uk                abdn.ac.uk
# 3                david.mcghee@abdn.ac.uk                abdn.ac.uk
# 4                    j.mercer@abdn.ac.uk                abdn.ac.uk
# 5             michelle.murphy@abdn.ac.uk                abdn.ac.uk
# 6            Sarah.Harris@igmm.ed.ac.uk.            igmm.ed.ac.uk.
# 7               T.Gillingwater@ed.ac.uk.                 ed.ac.uk.
# 8                   jiabao.he@abdn.ac.uk                abdn.ac.uk
# 9                s.schwarzkopf@gmail.com                 gmail.com
# 10        marie.castellazzi@hutton.ac.uk              hutton.ac.uk
# 11            diana.feliciano@abdn.ac.uk                abdn.ac.uk
# 12               iain.brown@hutton.ac.uk              hutton.ac.uk
# 13             Jill.Francis.1@city.ac.uk                city.ac.uk
# 14            jukka.corander@helsinki.fi               helsinki.fi
# 15            s.k.sheppard@swansea.ac.uk             swansea.ac.uk
# 16                    a.price@abdn.ac.uk                abdn.ac.uk
# 17              a.r.akisanya@abdn.ac.uk.               abdn.ac.uk.
# 18                  j.hussein@abdn.ac.uk                abdn.ac.uk
# 19                    c.hesse@abdn.ac.uk                abdn.ac.uk
# 20                     y.hopf@abdn.ac.uk                abdn.ac.uk
# 21            clare.allely@glasgow.ac.uk             glasgow.ac.uk
# 22                 n.r.velaga@iitb.ac.in                iitb.ac.in
# 23              a.r.akisanya@abdn.ac.uk.               abdn.ac.uk.
# 24                   x.lambin@abdn.ac.uk                abdn.ac.uk
# 25             m.olson@beatson.gla.ac.uk         beatson.gla.ac.uk
# 26                l.n.kanguru@abdn.ac.uk                abdn.ac.uk
# 27              sally.wyke@glasgow.ac.uk             glasgow.ac.uk
# 28                  jane.reid@abdn.ac.uk                abdn.ac.uk
# 29                  wmoncur@dundee.ac.uk              dundee.ac.uk
# ...                                  ...                       ...
# 9034                 j.f.hellings@hva.nl                    hva.nl
# 9035  mwoodruff@myknowledgenetwork.co.uk  myknowledgenetwork.co.uk
# 9036           hwalker@brighttribe.og.uk         brighttribe.og.uk
# 9037             Michael.Webb@jisc.ac.uk                jisc.ac.uk
# 9038     Sandeep.Jayaprakash1@marist.edu                marist.edu
# 9039                 ggilbert@unicon.net                unicon.net
# 9040               Shady.Shehata@d2l.com                   d2l.com
# 9041                 t.nixon@memphis.edu               memphis.edu
# 9042                n.dowell@memphis.edu               memphis.edu
# 9043                t.ullmann@open.ac.uk                open.ac.uk
# 9044              David.Bevan@open.ac.uk                open.ac.uk
# 9045              csaba.szabo@open.ac.uk                open.ac.uk
# 9046                  n.smith@open.ac.uk                open.ac.uk
# 9047    helen.caldwell@northampton.ac.uk         northampton.ac.uk
# 9048               m.richards@open.ac.uk                open.ac.uk
# 9049          vanni.moggicecchi@unifi.it                  unifi.it
# 9050           palgrave@macmillan.com.au          macmillan.com.au
# 9051                 orders@palgrave.com              palgrave.com
# 9052         alistair.willis@open.ac.uk.               open.ac.uk.
# 9053               ali@humanshuddle.com.         humanshuddle.com.
# 9054                            il23@st-                       st-
# 9055               T.Currie@exeter.ac.uk              exeter.ac.uk
# 9056            Sharon.mallon@open.ac.uk                open.ac.uk
# 9057                  k.galway@qub.ac.uk                 qub.ac.uk
# 9058               ann.grand@uwa.edu.au.               uwa.edu.au.
# 9059         Richard.Holliman@open.ac.uk                open.ac.uk
# 9060          Trevor.Collins@open.ac.uk.               open.ac.uk.
# 9061              Anne.Adams@open.ac.uk.               open.ac.uk.
# 9062          jacky.bourgeois@open.ac.uk                open.ac.uk
# 9063          candice.bedford@open.ac.uk                open.ac.uk
#
# [9064 rows x 2 columns]

# %%
merged_domains = pd.merge(emails_df,world_domains , left_on='domain',right_on="domain")

# %%
merged_domains
# Out:
#                                  email             domain alpha_two_code  \
# 0               L.V.Burgin@leeds.ac.uk        leeds.ac.uk             GB
# 1              T.R.A.Ensor@leeds.ac.uk        leeds.ac.uk             GB
# 2              T.R.A.Ensor@leeds.ac.uk        leeds.ac.uk             GB
# 3                  n.alwan@leeds.ac.uk        leeds.ac.uk             GB
# 4               j.d.walley@leeds.ac.uk        leeds.ac.uk             GB
# 5               r.m.wilkie@leeds.ac.uk        leeds.ac.uk             GB
# 6                 d.miller@leeds.ac.uk        leeds.ac.uk             GB
# 7                  pscplab@leeds.ac.uk        leeds.ac.uk             GB
# 8            s.r.kingsbury@leeds.ac.uk        leeds.ac.uk             GB
# 9                d.g.jayne@leeds.ac.uk        leeds.ac.uk             GB
# 10             j.j.ketland@leeds.ac.uk        leeds.ac.uk             GB
# 11                 eng2m2p@leeds.ac.uk        leeds.ac.uk             GB
# 12               a.j.baird@leeds.ac.uk        leeds.ac.uk             GB
# 13               a.j.baird@leeds.ac.uk        leeds.ac.uk             GB
# 14               a.j.baird@leeds.ac.uk        leeds.ac.uk             GB
# 15                i.jowers@leeds.ac.uk        leeds.ac.uk             GB
# 16                 a.mckay@leeds.ac.uk        leeds.ac.uk             GB
# 17                i.jowers@leeds.ac.uk        leeds.ac.uk             GB
# 18                 r.aspden@abdn.ac.uk         abdn.ac.uk             GB
# 19             david.mcghee@abdn.ac.uk         abdn.ac.uk             GB
# 20                 j.mercer@abdn.ac.uk         abdn.ac.uk             GB
# 21          michelle.murphy@abdn.ac.uk         abdn.ac.uk             GB
# 22                jiabao.he@abdn.ac.uk         abdn.ac.uk             GB
# 23          diana.feliciano@abdn.ac.uk         abdn.ac.uk             GB
# 24                  a.price@abdn.ac.uk         abdn.ac.uk             GB
# 25                j.hussein@abdn.ac.uk         abdn.ac.uk             GB
# 26                  c.hesse@abdn.ac.uk         abdn.ac.uk             GB
# 27                   y.hopf@abdn.ac.uk         abdn.ac.uk             GB
# 28                 x.lambin@abdn.ac.uk         abdn.ac.uk             GB
# 29              l.n.kanguru@abdn.ac.uk         abdn.ac.uk             GB
# ...                                ...                ...            ...
# 3996      susanna.sancassani@polimi.it          polimi.it             IT
# 3997             paola.corti@polimi.it          polimi.it             IT
# 3998      federica.brambilla@polimi.it          polimi.it             IT
# 3999              NTikhomirova@mesi.ru            mesi.ru             RU
# 4000                 ISmirnova@mesi.ru            mesi.ru             RU
# 4001              NTikhomirova@mesi.ru            mesi.ru             RU
# 4002                 ISmirnova@mesi.ru            mesi.ru             RU
# 4003           gkurubac@anadolu.edu.tr     anadolu.edu.tr             TR
# 4004             vyuzer@anadolu.edu.tr     anadolu.edu.tr             TR
# 4005           gkurubac@anadolu.edu.tr     anadolu.edu.tr             TR
# 4006             vyuzer@anadolu.edu.tr     anadolu.edu.tr             TR
# 4007    Jean-Pierre.Berthet@ec-lyon.fr         ec-lyon.fr             FR
# 4008    Jean-Pierre.Berthet@ec-lyon.fr         ec-lyon.fr             FR
# 4009             m.hoffmann@gatech.edu         gatech.edu             US
# 4010              goran.falkman@his.se             his.se             SE
# 4011              mariegus@chalmers.se        chalmers.se             SE
# 4012                 oloft@chalmers.se        chalmers.se             SE
# 4013                jlee@brookes.ac.uk      brookes.ac.uk             GB
# 4014           helen.farley@usq.edu.au         usq.edu.au             AU
# 4015             kilian.gericke@uni.lu             uni.lu             LU
# 4016             kilian.gericke@uni.lu             uni.lu             LU
# 4017         a.cano-basave@aston.ac.uk        aston.ac.uk             GB
# 4018         rilla.khaled@concordia.ca       concordia.ca             CA
# 4019          adrian.hopgood@ulg.ac.be          ulg.ac.be             BE
# 4020             Josh.Baron@marist.edu         marist.edu             US
# 4021   Sandeep.Jayaprakash1@marist.edu         marist.edu             US
# 4022   Sandeep.Jayaprakash1@marist.edu         marist.edu             US
# 4023                      lou@ncsu.edu           ncsu.edu             US
# 4024               j.f.hellings@hva.nl             hva.nl             NL
# 4025  helen.caldwell@northampton.ac.uk  northampton.ac.uk             GB
#
#                  country                                               name  \
# 0         United Kingdom                                University of Leeds
# 1         United Kingdom                                University of Leeds
# 2         United Kingdom                                University of Leeds
# 3         United Kingdom                                University of Leeds
# 4         United Kingdom                                University of Leeds
# 5         United Kingdom                                University of Leeds
# 6         United Kingdom                                University of Leeds
# 7         United Kingdom                                University of Leeds
# 8         United Kingdom                                University of Leeds
# 9         United Kingdom                                University of Leeds
# 10        United Kingdom                                University of Leeds
# 11        United Kingdom                                University of Leeds
# 12        United Kingdom                                University of Leeds
# 13        United Kingdom                                University of Leeds
# 14        United Kingdom                                University of Leeds
# 15        United Kingdom                                University of Leeds
# 16        United Kingdom                                University of Leeds
# 17        United Kingdom                                University of Leeds
# 18        United Kingdom                             University of Aberdeen
# 19        United Kingdom                             University of Aberdeen
# 20        United Kingdom                             University of Aberdeen
# 21        United Kingdom                             University of Aberdeen
# 22        United Kingdom                             University of Aberdeen
# 23        United Kingdom                             University of Aberdeen
# 24        United Kingdom                             University of Aberdeen
# 25        United Kingdom                             University of Aberdeen
# 26        United Kingdom                             University of Aberdeen
# 27        United Kingdom                             University of Aberdeen
# 28        United Kingdom                             University of Aberdeen
# 29        United Kingdom                             University of Aberdeen
# ...                  ...                                                ...
# 3996               Italy                     Polytechnic Institute of Milan
# 3997               Italy                     Polytechnic Institute of Milan
# 3998               Italy                     Polytechnic Institute of Milan
# 3999  Russian Federation  Moscow State University of Economics, Statisti...
# 4000  Russian Federation  Moscow State University of Economics, Statisti...
# 4001  Russian Federation  Moscow State University of Economics, Statisti...
# 4002  Russian Federation  Moscow State University of Economics, Statisti...
# 4003              Turkey                                 Anadolu University
# 4004              Turkey                                 Anadolu University
# 4005              Turkey                                 Anadolu University
# 4006              Turkey                                 Anadolu University
# 4007              France                             Ecole Centrale de Lyon
# 4008              France                             Ecole Centrale de Lyon
# 4009       United States                    Georgia Institute of Technology
# 4010              Sweden                       University College of Skövde
# 4011              Sweden                  Chalmers University of Technology
# 4012              Sweden                  Chalmers University of Technology
# 4013      United Kingdom                          Oxford Brookes University
# 4014           Australia                  University of Southern Queensland
# 4015          Luxembourg                            University of Luxemburg
# 4016          Luxembourg                            University of Luxemburg
# 4017      United Kingdom                                   Aston University
# 4018              Canada                               Concordia University
# 4019             Belgium                                Université de Liège
# 4020       United States                                     Marist College
# 4021       United States                                     Marist College
# 4022       United States                                     Marist College
# 4023       United States                    North Carolina State University
# 4024         Netherlands                           Hogeschool van Amsterdam
# 4025      United Kingdom                          University of Northampton
#
#                            web_page
# 0           http://www.leeds.ac.uk/
# 1           http://www.leeds.ac.uk/
# 2           http://www.leeds.ac.uk/
# 3           http://www.leeds.ac.uk/
# 4           http://www.leeds.ac.uk/
# 5           http://www.leeds.ac.uk/
# 6           http://www.leeds.ac.uk/
# 7           http://www.leeds.ac.uk/
# 8           http://www.leeds.ac.uk/
# 9           http://www.leeds.ac.uk/
# 10          http://www.leeds.ac.uk/
# 11          http://www.leeds.ac.uk/
# 12          http://www.leeds.ac.uk/
# 13          http://www.leeds.ac.uk/
# 14          http://www.leeds.ac.uk/
# 15          http://www.leeds.ac.uk/
# 16          http://www.leeds.ac.uk/
# 17          http://www.leeds.ac.uk/
# 18           http://www.abdn.ac.uk/
# 19           http://www.abdn.ac.uk/
# 20           http://www.abdn.ac.uk/
# 21           http://www.abdn.ac.uk/
# 22           http://www.abdn.ac.uk/
# 23           http://www.abdn.ac.uk/
# 24           http://www.abdn.ac.uk/
# 25           http://www.abdn.ac.uk/
# 26           http://www.abdn.ac.uk/
# 27           http://www.abdn.ac.uk/
# 28           http://www.abdn.ac.uk/
# 29           http://www.abdn.ac.uk/
# ...                             ...
# 3996          http://www.polimi.it/
# 3997          http://www.polimi.it/
# 3998          http://www.polimi.it/
# 3999            http://www.mesi.ru/
# 4000            http://www.mesi.ru/
# 4001            http://www.mesi.ru/
# 4002            http://www.mesi.ru/
# 4003     http://www.anadolu.edu.tr/
# 4004     http://www.anadolu.edu.tr/
# 4005     http://www.anadolu.edu.tr/
# 4006     http://www.anadolu.edu.tr/
# 4007         http://www.ec-lyon.fr/
# 4008         http://www.ec-lyon.fr/
# 4009         http://www.gatech.edu/
# 4010             http://www.his.se/
# 4011        http://www.chalmers.se/
# 4012        http://www.chalmers.se/
# 4013      http://www.brookes.ac.uk/
# 4014         http://www.usq.edu.au/
# 4015             http://www.uni.lu/
# 4016             http://www.uni.lu/
# 4017        http://www.aston.ac.uk/
# 4018       http://www.concordia.ca/
# 4019          http://www.ulg.ac.be/
# 4020         http://www.marist.edu/
# 4021         http://www.marist.edu/
# 4022         http://www.marist.edu/
# 4023           http://www.ncsu.edu/
# 4024             http://www.hva.nl/
# 4025  http://www.northampton.ac.uk/
#
# [4026 rows x 6 columns]

# %%
# merged_domains.groupby(['domain']).agg(['count']).reset_index('count').sort_values(['count'], ascending=False)
merged_domains.groupby(['domain']).count().sort(['email'],ascending=False)#.reset_index('count').sort_values(['count'], ascending=False)
# Out:
#                    email  alpha_two_code  country  name  web_page
# domain
# abdn.ac.uk          1126            1126     1126  1126      1126
# open.ac.uk          1108            1108     1108  1108      1108
# ed.ac.uk             685             685      685   685       685
# ncl.ac.uk             69              69       69    69        69
# nottingham.ac.uk      39              39       39    39        39
# unsw.edu.au           26              26       26    26        26
# cam.ac.uk             24              24       24    24        24
# dundee.ac.uk          24              24       24    24        24
# ucl.ac.uk             23              23       23    23        23
# kcl.ac.uk             21              21       21    21        21
# bham.ac.uk            20              20       20    20        20
# soton.ac.uk           19              19       19    19        19
# leeds.ac.uk           18              18       18    18        18
# lshtm.ac.uk           17              17       17    17        17
# ou.nl                 17              17       17    17        17
# hw.ac.uk              16              16       16    16        16
# uow.edu.au            16              16       16    16        16
# unifi.it              14              14       14    14        14
# ioe.ac.uk             14              14       14    14        14
# strath.ac.uk          14              14       14    14        14
# utoronto.ca           12              12       12    12        12
# rgu.ac.uk             12              12       12    12        12
# rutgers.edu           12              12       12    12        12
# lboro.ac.uk           12              12       12    12        12
# stir.ac.uk            10              10       10    10        10
# mcmaster.ca           10              10       10    10        10
# du.se                 10              10       10    10        10
# ugr.es                10              10       10    10        10
# bath.ac.uk            10              10       10    10        10
# warwick.ac.uk         10              10       10    10        10
# ...                  ...             ...      ...   ...       ...
# uci.edu                1               1        1     1         1
# ucmerced.edu           1               1        1     1         1
# uctm.edu               1               1        1     1         1
# squ.edu.om             1               1        1     1         1
# sjtu.edu.cn            1               1        1     1         1
# lut.fi                 1               1        1     1         1
# ntnu.no                1               1        1     1         1
# mans.edu.eg            1               1        1     1         1
# missouri.edu           1               1        1     1         1
# mq.edu.au              1               1        1     1         1
# mtholyoke.edu          1               1        1     1         1
# ncsu.edu               1               1        1     1         1
# newcastle.edu.au       1               1        1     1         1
# njau.edu.cn            1               1        1     1         1
# nmsu.edu               1               1        1     1         1
# northampton.ac.uk      1               1        1     1         1
# nottingham.edu.my      1               1        1     1         1
# nus.edu.sg             1               1        1     1         1
# sghms.ac.uk            1               1        1     1         1
# osu.edu                1               1        1     1         1
# p.lodz.pl              1               1        1     1         1
# pi.ac.ae               1               1        1     1         1
# pitt.edu               1               1        1     1         1
# poliba.it              1               1        1     1         1
# princeton.edu          1               1        1     1         1
# pucrs.br               1               1        1     1         1
# purdue.edu             1               1        1     1         1
# qut.edu.au             1               1        1     1         1
# salford.ac.uk          1               1        1     1         1
# queensu.ca             1               1        1     1         1
#
# [319 rows x 5 columns]

# %%
import textrazor
#pip install textrazor
file = open("article_19787393.txt","r") 
testarticle=file.read()

textrazor.api_key = "eba9d80209aaad9627277d21437d2e0f56ef9c1e6e16332f221af063"

client = textrazor.TextRazor(extractors=["entities", "topics"])
response = client.analyze(testarticle)

for entity in response.entities():
    print entity.id, entity.relevance_score, entity.confidence_score, entity.freebase_types
# Out:
# Species 0.3804 2.214 [u'/biology/organism_classification', u'/biology/organism_classification_rank']
# Regeneration (biology) 0.5071 1.426 []
# Natural environment 0.5846 1.335 [u'/book/book_subject', u'/law/legal_subject', u'/organization/organization_sector']
# Pascal (unit) 0.3716 7.744 [u'/time_series/unit', u'/type/unit', u'/symbols/namesake', u'/measurement_unit/pressure_unit']
# Pascal (unit) 0.3716 7.744 [u'/time_series/unit', u'/type/unit', u'/symbols/namesake', u'/measurement_unit/pressure_unit']
# Pascal (unit) 0.3716 7.744 [u'/time_series/unit', u'/type/unit', u'/symbols/namesake', u'/measurement_unit/pressure_unit']
# Pascal (unit) 0.3716 7.744 [u'/time_series/unit', u'/type/unit', u'/symbols/namesake', u'/measurement_unit/pressure_unit']
# Pascal (unit) 0.3716 7.744 [u'/time_series/unit', u'/type/unit', u'/symbols/namesake', u'/measurement_unit/pressure_unit']
# Pascal (unit) 0.3716 7.744 [u'/time_series/unit', u'/type/unit', u'/symbols/namesake', u'/measurement_unit/pressure_unit']
# Pascal (unit) 0.3716 7.744 [u'/time_series/unit', u'/type/unit', u'/symbols/namesake', u'/measurement_unit/pressure_unit']
# Pascal (unit) 0.3716 7.744 [u'/time_series/unit', u'/type/unit', u'/symbols/namesake', u'/measurement_unit/pressure_unit']
# Pascal (unit) 0.3716 7.744 [u'/time_series/unit', u'/type/unit', u'/symbols/namesake', u'/measurement_unit/pressure_unit']
# Pascal (unit) 0.3716 7.744 [u'/time_series/unit', u'/type/unit', u'/symbols/namesake', u'/measurement_unit/pressure_unit']
# 3.20000000000000000004 0 0.5 []
# Pascal (unit) 0.3716 7.744 [u'/time_series/unit', u'/type/unit', u'/symbols/namesake', u'/measurement_unit/pressure_unit']
# Pascal (unit) 0.3716 7.744 [u'/time_series/unit', u'/type/unit', u'/symbols/namesake', u'/measurement_unit/pressure_unit']
# Pascal (unit) 0.3716 7.744 [u'/time_series/unit', u'/type/unit', u'/symbols/namesake', u'/measurement_unit/pressure_unit']
# Pascal (unit) 0.3716 7.744 [u'/time_series/unit', u'/type/unit', u'/symbols/namesake', u'/measurement_unit/pressure_unit']
# 11.1000000000000000003 0 0.5 []
# 2 0 0.5 []
# 2.90000000000000000009 0 0.5 []
# 24 0 0.5 []
# 70.9000000000000000014 0 0.5 []
# 13 0 0.5 []
# 2 0 0.5 []
# 1 0 0.5 []
# 9.30000000000000000017 0 0.5 []
# 1.10000000000000000002 0 0.5 []
# 9.5 0 0.5 []
# 5.40000000000000000009 0 0.5 []
# Femoral head 0.3432 7.431 [u'/medicine/anatomical_structure']
# Metacarpal bones 0.1056 2.639 [u'/medicine/bone', u'/medicine/anatomical_structure']
# Femoral head 0.3432 7.431 [u'/medicine/anatomical_structure']
# Pascal (unit) 0.3716 7.744 [u'/time_series/unit', u'/type/unit', u'/symbols/namesake', u'/measurement_unit/pressure_unit']
# 0.409999999999999999997 0 0.5 []
# Pascal (unit) 0.3716 7.744 [u'/time_series/unit', u'/type/unit', u'/symbols/namesake', u'/measurement_unit/pressure_unit']
# Pascal (unit) 0.3716 7.744 [u'/time_series/unit', u'/type/unit', u'/symbols/namesake', u'/measurement_unit/pressure_unit']
# In vivo 0.247 9.651 []
# Femoral head 0.3432 7.431 [u'/medicine/anatomical_structure']
# 0.300000000000000000011 0 0.5 []
# 0.409999999999999999997 0 0.5 []
# Femoral head 0.3432 7.431 [u'/medicine/anatomical_structure']
# Correlation and dependence 0.4213 4.846 [u'/book/book_subject']
# Femoral head 0.3432 7.431 [u'/medicine/anatomical_structure']
# 0.409999999999999999997 0 0.5 []
# Energy 0.5782 14.52 [u'/organization/organization_sector', u'/book/book_subject', u'/measurement_unit/dimension', u'/measurement_unit/common_dimension', u'/business/industry']
# Femoral head 0.3432 7.431 [u'/medicine/anatomical_structure']
# Pascal (unit) 0.3716 7.744 [u'/time_series/unit', u'/type/unit', u'/symbols/namesake', u'/measurement_unit/pressure_unit']
# Pascal (unit) 0.3716 7.744 [u'/time_series/unit', u'/type/unit', u'/symbols/namesake', u'/measurement_unit/pressure_unit']
# Pascal (unit) 0.3716 7.744 [u'/time_series/unit', u'/type/unit', u'/symbols/namesake', u'/measurement_unit/pressure_unit']
# 45 0 0.5 []
# Femoral head 0.3432 7.431 [u'/medicine/anatomical_structure']
# Pascal (unit) 0.3716 7.744 [u'/time_series/unit', u'/type/unit', u'/symbols/namesake', u'/measurement_unit/pressure_unit']
# Pascal (unit) 0.3716 7.744 [u'/time_series/unit', u'/type/unit', u'/symbols/namesake', u'/measurement_unit/pressure_unit']
# Femoral head 0.3432 7.431 [u'/medicine/anatomical_structure']
# Tissue (biology) 0.1598 11.92 [u'/medicine/anatomical_structure']
# Analytical chemistry 0.22 13.39 [u'/book/book_subject', u'/organization/organization_sector', u'/education/field_of_study']
# Chemistry 0.2634 17.5 [u'/people/professional_field', u'/education/field_of_study', u'/media_common/media_genre', u'/award/award_discipline', u'/media_common/literary_genre', u'/organization/organization_sector', u'/business/industry', u'/book/periodical_subject', u'/book/book_subject']
# Chondrocyte 0.1836 12.34 [u'/medicine/anatomical_structure']
# Percentage 0.2599 2.746 [u'/time_series/unit', u'/type/unit']
# Collagen 0.4493 14.43 [u'/chemistry/chemical_classification', u'/business/product_ingredient']
# Methodology 0.02648 2.463 [u'/book/book_subject']
# Connective tissue 0.152 6.053 [u'/medicine/anatomical_structure']
# Tissue (biology) 0.1598 10.46 [u'/medicine/anatomical_structure']
# Collagen 0.4493 14.43 [u'/chemistry/chemical_classification', u'/business/product_ingredient']
# Glycosaminoglycan 0.3364 13.97 []
# Collagen 0.4493 14.43 [u'/chemistry/chemical_classification', u'/business/product_ingredient']
# Collagen 0.4493 14.43 [u'/chemistry/chemical_classification', u'/business/product_ingredient']
# Collagen 0.4493 14.43 [u'/chemistry/chemical_classification', u'/business/product_ingredient']
# Collagen 0.4493 14.43 [u'/chemistry/chemical_classification', u'/business/product_ingredient']
# 68 0 0.5 []
# 0.439999999999999999998 0 0.5 []
# 17.2999999999999999993 0 0.5 []
# -0.330000000000000000012 0 0.5 []
# 1.77999999999999999997 0 0.5 []
# 0.000999999999999999999958 0 0.5 []
# 0.930000000000000000007 0 0.5 []
# 0.0370000000000000000011 0 0.5 []
# -0.430000000000000000007 0 0.5 []
# 0.0190000000000000000008 0 0.5 []
# 4 0 0.5 []
# 0.000999999999999999999958 0 0.5 []
# 51.9000000000000000014 0 0.5 []
# 0.920000000000000000015 0 0.5 []
# 11.8000000000000000002 0 0.5 []
# 2.6400000000000000001 0 0.5 []
# 2.05999999999999999995 0 0.5 []
# 0.0119999999999999999999 0 0.5 []
# 0.27000000000000000001 0 0.5 []
# 0.00199999999999999999992 0 0.5 []
# 2.3900000000000000001 0 0.5 []
# 1.36000000000000000001 0 0.5 []
# 0.100000000000000000001 0 0.5 []
# 0.800000000000000000011 0 0.5 []
# Collagen 0.4493 14.43 [u'/chemistry/chemical_classification', u'/business/product_ingredient']
# Bone 0.8196 12.55 [u'/medicine/anatomical_structure']
# 44 0 0.5 []
# 47 0 0.5 []
# Collagen 0.4493 14.43 [u'/chemistry/chemical_classification', u'/business/product_ingredient']
# Collagen 0.4493 14.43 [u'/chemistry/chemical_classification', u'/business/product_ingredient']
# Collagen 0.4493 14.43 [u'/chemistry/chemical_classification', u'/business/product_ingredient']
# Chondrocyte 0.1937 12.34 [u'/medicine/anatomical_structure']
# -4 0 0.5 []
# Collagen 0.4493 14.43 [u'/chemistry/chemical_classification', u'/business/product_ingredient']
# Biomechanics 0.3042 4.213 [u'/education/field_of_study', u'/book/book_subject']
# Collagen 0.4493 14.43 [u'/chemistry/chemical_classification', u'/business/product_ingredient']
# -4 0 0.5 []
# Chemistry 0.2623 17.5 [u'/people/professional_field', u'/education/field_of_study', u'/media_common/media_genre', u'/award/award_discipline', u'/media_common/literary_genre', u'/organization/organization_sector', u'/business/industry', u'/book/periodical_subject', u'/book/book_subject']
# Collagen 0.4493 14.43 [u'/chemistry/chemical_classification', u'/business/product_ingredient']
# Finlay JB 0 0.5 [u'/people/person']
# Collagen 0.4493 14.43 [u'/chemistry/chemical_classification', u'/business/product_ingredient']
# Kempson GE 0 0.5 [u'/people/person']
# Collagen 0.4493 14.43 [u'/chemistry/chemical_classification', u'/business/product_ingredient']
# Collagen 0.4493 14.43 [u'/chemistry/chemical_classification', u'/business/product_ingredient']
# Collagen 0.4493 14.43 [u'/chemistry/chemical_classification', u'/business/product_ingredient']
# Chondroitin sulfate 0.5538 7.206 [u'/chemistry/chemical_compound']
# Data 0.2285 5.448 [u'/internet/website_category']
# Collagen 0.4493 14.43 [u'/chemistry/chemical_classification', u'/business/product_ingredient']
# Collagen 0.4493 14.43 [u'/chemistry/chemical_classification', u'/business/product_ingredient']
# 150 0 0.5 []
# Proteoglycan 0.2513 17.76 [u'/biology/protein']
# Proteoglycan 0.2513 17.76 [u'/biology/protein']
# Analysis of variance 0.3267 14.05 []
# Restitution 0.03971 1.062 []
# Tissue (biology) 0.1598 11.92 [u'/medicine/anatomical_structure']
# Tissue (biology) 0.1598 11.92 [u'/medicine/anatomical_structure']
# Tissue (biology) 0.1598 11.92 [u'/medicine/anatomical_structure']
# Microtiter plate 0.2207 1.116 []
# gentle blotting 0 0.5 [u'/organization/organization']
# Zeiss Ltd 0 0.5 [u'/people/person']
# Seedhom 0 0.5 [u'/organization/organization']
# Zeiss Stemi-2000 0 0.5 [u'/organization/organization']
# Local Research Ethics Committee 0 0.5 [u'/organization/organization']
# MPa for 0 0.5 [u'/organization/organization']
# Absolute value 0.06632 4.613 []
# Absolute value 0.06632 4.613 []
# Absolute value 0.06632 4.613 []
# Senescence 0.3093 5.84 [u'/medicine/risk_factor']
# 24 0 0.5 []
# R.M. Aspden 0 0.5 [u'/people/person']
# Cartilage 0.9913 14.11 [u'/medicine/anatomical_structure']
# 1.08000000000000000004 0 0.5 []
# Matrix (mathematics) 0.1801 8.561 [u'/book/book_subject', u'/film/film_subject']
# Matrix (mathematics) 0.1801 8.561 [u'/book/book_subject', u'/film/film_subject']
# -84 0 0.5 []
# 24 0 0.5 []
# United Kingdom 0.226 4.922 [u'/sports/sport_country', u'/organization/contact_category', u'/food/beer_country_region', u'/government/governmental_jurisdiction', u'/location/uk_statistical_location', u'/business/employer', u'/location/dated_location', u'/organization/organization_scope', u'/royalty/kingdom', u'/organization/organization_member', u'/sports/sports_team_location', u'/media_common/netflix_genre', u'/book/periodical_subject', u'/military/military_combatant', u'/location/location', u'/location/statistical_region', u'/location/administrative_division', u'/biology/breed_origin', u'/symbols/flag_referent', u'/fictional_universe/fictional_setting', u'/tv/tv_location', u'/film/film_location', u'/organization/organization_founder', u'/periodicals/newspaper_circulation_area', u'/location/country', u'/business/business_location', u'/olympics/olympic_participating_country', u'/cvg/computer_game_region', u'/law/court_jurisdiction_area', u'/book/book_subject']
# Spearman 0 0.5 [u'/people/person']
# Matrix (mathematics) 0.1801 8.561 [u'/book/book_subject', u'/film/film_subject']
# 10.8000000000000000002 0 0.5 []
# Cartilage 0.9913 14.11 [u'/medicine/anatomical_structure']
# Cartilage 0.9913 14.11 [u'/medicine/anatomical_structure']
# 1.60000000000000000002 0 0.5 []
# Synovial joint 0.2448 1.159 [u'/medicine/anatomical_structure']
# 1.60000000000000000002 0 0.5 []
# Cartilage 0.9913 14.11 [u'/medicine/anatomical_structure']
# Cartilage 0.9913 14.11 [u'/medicine/anatomical_structure']
# Matrix (mathematics) 0.1801 8.561 [u'/book/book_subject', u'/film/film_subject']
# Cartilage 0.9913 14.11 [u'/medicine/anatomical_structure']
# Matrix (mathematics) 0.1801 8.561 [u'/book/book_subject', u'/film/film_subject']
# Cartilage 0.9913 14.11 [u'/medicine/anatomical_structure']
# Pascal (unit) 0.1224 5.892 [u'/time_series/unit', u'/type/unit', u'/symbols/namesake', u'/measurement_unit/pressure_unit']
# 1.34000000000000000003 0 0.5 []
# Logarithm 0.6002 3.686 [u'/book/book_subject', u'/law/invention']
# United Kingdom 0.226 4.922 [u'/sports/sport_country', u'/organization/contact_category', u'/food/beer_country_region', u'/government/governmental_jurisdiction', u'/location/uk_statistical_location', u'/business/employer', u'/location/dated_location', u'/organization/organization_scope', u'/royalty/kingdom', u'/organization/organization_member', u'/sports/sports_team_location', u'/media_common/netflix_genre', u'/book/periodical_subject', u'/military/military_combatant', u'/location/location', u'/location/statistical_region', u'/location/administrative_division', u'/biology/breed_origin', u'/symbols/flag_referent', u'/fictional_universe/fictional_setting', u'/tv/tv_location', u'/film/film_location', u'/organization/organization_founder', u'/periodicals/newspaper_circulation_area', u'/location/country', u'/business/business_location', u'/olympics/olympic_participating_country', u'/cvg/computer_game_region', u'/law/court_jurisdiction_area', u'/book/book_subject']
# 2.22000000000000000003 0 0.5 []
# 20 0 0.5 []
# Sample (statistics) 0.07271 2.157 []
# Sample (statistics) 0.07271 2.157 []
# Sample (statistics) 0.07271 2.157 []
# 3 0 0.5 []
# Sample (statistics) 0.07271 2.157 []
# Ficus 0.2225 1.052 [u'/food/food', u'/food/ingredient', u'/biology/organism_classification']
# Software 0.1304 5.475 [u'/education/school_category', u'/broadcast/genre', u'/media_common/quotation_subject', u'/business/consumer_product', u'/business/product_category', u'/organization/organization_sector', u'/computer/software_genre', u'/business/industry', u'/internet/website_category', u'/media_common/media_genre', u'/business/competitive_space', u'/book/book_subject', u'/organization/organization']
# Sample (statistics) 0.07271 2.157 []
# Sample (statistics) 0.07271 2.157 []
# Sample (statistics) 0.07271 2.157 []
# Sample (statistics) 0.07271 2.157 []
# PBS 0.1233 4.229 [u'/book/author', u'/broadcast/producer', u'/tv/tv_network', u'/media_common/netflix_genre', u'/tv/tv_producer', u'/book/book_subject', u'/business/business_operation', u'/tv/tv_program_creator', u'/business/employer', u'/award/award_winner', u'/organization/non_profit_organization', u'/film/production_company', u'/book/interviewer', u'/organization/organization', u'/film/director', u'/film/film_distributor', u'/award/award_nominee', u'/people/person', u'/film/producer']
# Sample (statistics) 0.07271 2.157 []
# Water 0.2854 2.891 [u'/exhibitions/exhibition_subject', u'/chemistry/molecular_entity', u'/food/nutrient', u'/cvg/computer_game_subject', u'/food/ingredient', u'/visual_art/visual_art_medium', u'/chemistry/chemical_compound', u'/book/book_subject', u'/medicine/drug_ingredient']
# Sample (statistics) 0.07271 2.157 []
# Sample (statistics) 0.07271 2.157 []
# Sample (statistics) 0.07271 2.157 []
# Ficus 0.2225 1.052 [u'/food/food', u'/food/ingredient', u'/biology/organism_classification']
# Sample (statistics) 0.07271 2.157 []
# Sample (statistics) 0.07271 2.157 []
# Sample (statistics) 0.07271 2.157 []
# Diameter 0.08553 5.066 []
# Diameter 0.08553 5.066 []
# Dynamic modulus 0.1694 3.756 []
# Dynamic modulus 0.1694 3.756 []
# Dynamic modulus 0.1694 3.756 []
# Impact event 0.3023 1.615 [u'/film/film_subject', u'/event/disaster_type', u'/book/book_subject']
# Dynamic modulus 0.1694 3.756 []
# 1000-01-01T00:00:00.000-05:17:32 0 0.5 []
# Impact event 0.3023 1.615 [u'/film/film_subject', u'/event/disaster_type', u'/book/book_subject']
# Impact event 0.3023 1.615 [u'/film/film_subject', u'/event/disaster_type', u'/book/book_subject']
# Dynamic modulus 0.1694 3.756 []
# Dynamic modulus 0.1694 3.756 []
# Dynamic modulus 0.1694 3.756 []
# Dynamic modulus 0.1694 3.756 []
# Tissue (biology) 0.2199 11.92 [u'/medicine/anatomical_structure']
# Neck 0.1438 1.872 [u'/medicine/anatomical_structure']
# Anatomical terms of location 0.2577 1.387 []
# Absolute value 0.06632 4.613 []
# Absolute value 0.06632 4.613 []
# Absolute value 0.06632 4.613 []
# Absolute value 0.06632 4.613 []
# Absolute value 0.06632 4.613 []
# Articular bone 0.1268 0.9689 []
# Cartilage 0.629 11.81 [u'/medicine/anatomical_structure']
# 17 0 0.5 []
# 2.5 0 0.5 []
# 2.56999999999999999994 0 0.5 []
# 0.419999999999999999988 0 0.5 []
# 150 0 0.5 []
# 25 0 0.5 []
# 31 0 0.5 []
# 16 0 0.5 []
# 30 0 0.5 []
# 2 0 0.5 []
# 0.100000000000000000001 0 0.5 []
# Impact event 0.3023 1.615 [u'/film/film_subject', u'/event/disaster_type', u'/book/book_subject']
# Stress (mechanics) 0.1957 5.661 []
# Synovial fluid 0.5062 12.1 [u'/medicine/biofluid']
# Fluid 0.2003 5.782 []
# Soft tissue 0.5367 9.894 []
# Tissue (biology) 0.2178 11.92 [u'/medicine/anatomical_structure']
# Cartilage 0.5039 10.47 [u'/medicine/anatomical_structure']
# Femur 0.4992 5.282 [u'/medicine/bone', u'/medicine/anatomical_structure']
# Femoral head 0.3432 7.081 [u'/medicine/anatomical_structure']
# Biosynthesis 0.2202 6.705 [u'/chemistry/chemical_compound']
# Friction 0.5823 18.69 [u'/medicine/disease_cause']
# Strength of materials 0.6699 2.471 [u'/education/field_of_study']
# Normal distribution 0.5643 6.162 [u'/book/book_subject']
# Regression analysis 0.6357 6.579 []
# Friction 0.5823 18.69 [u'/medicine/disease_cause']
# Standard deviation 0.8098 12.24 []
# Standard deviation 0.8098 12.24 []
# Histology 0.3352 18.26 [u'/book/book_subject', u'/education/field_of_study']
# Torzilli PA. 0 0.5 [u'/people/person']
# Species 0.1201 2.174 [u'/biology/organism_classification', u'/biology/organism_classification_rank']
# In vitro 0.2754 8.204 []
# Stoke Mandeville 0 2.989 [u'/location/citytown', u'/location/location', u'/location/administrative_division', u'/location/dated_location', u'/location/uk_civil_parish', u'/location/statistical_region']
# Femoral head 0.3432 7.431 [u'/medicine/anatomical_structure']
# Femoral head 0.3432 7.431 [u'/medicine/anatomical_structure']
# Pascal (unit) 0.3716 7.744 [u'/time_series/unit', u'/type/unit', u'/symbols/namesake', u'/measurement_unit/pressure_unit']
# Biochemistry 0.1946 45.18 [u'/organization/organization_sector', u'/award/award_discipline', u'/education/field_of_study', u'/book/book_subject']
# Pathology 0.26 1.088 [u'/medicine/medical_specialty', u'/book/book_subject', u'/education/field_of_study']
# Proteoglycan 0.2513 17.76 [u'/biology/protein']
# Kolmogorov–Smirnov test 0.6616 4.71 [u'/symbols/namesake']
# 0.200000000000000000003 0 0.5 []
# 2.59999999999999999991 0 0.5 []
# Cartilage 0.9913 14.11 [u'/medicine/anatomical_structure']
# Correlation and dependence 0.5975 4.424 [u'/book/book_subject']
# Cartilage 0.9913 14.11 [u'/medicine/anatomical_structure']
# 0 0 0.5 []
# 0.0500000000000000000007 0 0.5 []
# Correlation and dependence 0.383 4.846 [u'/book/book_subject']
# Tissue (biology) 0.1458 11.92 [u'/medicine/anatomical_structure']
# 2.59999999999999999991 0 0.5 []
# Correlation and dependence 0.5975 4.424 [u'/book/book_subject']
# Cartilage 0.9913 14.11 [u'/medicine/anatomical_structure']
# 0.100000000000000000001 0 0.5 []
# Cartilage 0.9913 14.11 [u'/medicine/anatomical_structure']
# 0.25 0 0.5 []
# 0.100000000000000000001 0 0.5 []
# Correlation and dependence 0.5975 4.424 [u'/book/book_subject']
# Cartilage 0.9913 14.11 [u'/medicine/anatomical_structure']
# 0.119999999999999999998 0 0.5 []
# 0.150000000000000000005 0 0.5 []
# Tissue (biology) 0.1458 11.92 [u'/medicine/anatomical_structure']
# Correlation and dependence 0.383 4.846 [u'/book/book_subject']
# Tissue (biology) 0.1458 11.92 [u'/medicine/anatomical_structure']
# Correlation and dependence 0.383 4.846 [u'/book/book_subject']
# 2 0 0.5 []
# Correlation and dependence 0.383 4.846 [u'/book/book_subject']
# 2.59999999999999999991 0 0.5 []
# 0.100000000000000000001 0 0.5 []
# 0.330000000000000000012 0 0.5 []
# Tissue (biology) 0.1458 11.92 [u'/medicine/anatomical_structure']
# Experiment 0.553 1.77 [u'/book/book_subject', u'/tv/tv_subject']
# Hydrostatics 0.193 13.8 [u'/education/field_of_study']
# Pressure 0.317 12.01 [u'/measurement_unit/dimension', u'/medicine/disease_cause', u'/measurement_unit/common_dimension']
# Mass 0.3817 11.09 [u'/measurement_unit/common_dimension', u'/measurement_unit/dimension']
# Cartilage 0.4944 10.57 [u'/medicine/anatomical_structure']
# Biological engineering 0.4353 3.114 [u'/education/field_of_study', u'/media_common/quotation_subject', u'/book/book_subject']
# Medicine 0.3462 16.7 [u'/media_common/quotation_subject', u'/book/periodical_subject', u'/book/book_subject', u'/business/employer', u'/medicine/medical_specialty', u'/media_common/literary_genre', u'/film/film_subject', u'/business/industry', u'/people/profession', u'/organization/organization_sector', u'/radio/radio_subject', u'/book/magazine_genre', u'/internet/website_category', u'/education/field_of_study', u'/award/award_discipline', u'/media_common/media_genre', u'/broadcast/genre']
# Tissue (biology) 0.1458 11.92 [u'/medicine/anatomical_structure']
# Tissue (biology) 0.1458 11.92 [u'/medicine/anatomical_structure']
# Tissue (biology) 0.1458 11.92 [u'/medicine/anatomical_structure']
# Tissue (biology) 0.1458 11.92 [u'/medicine/anatomical_structure']
# Tissue (biology) 0.1458 11.92 [u'/medicine/anatomical_structure']
# Tissue (biology) 0.1458 11.92 [u'/medicine/anatomical_structure']
# Tissue (biology) 0.1458 11.92 [u'/medicine/anatomical_structure']
# Tissue (biology) 0.1458 11.92 [u'/medicine/anatomical_structure']
# Molecule 0.3115 18.94 []
# 58.9000000000000000014 0 0.5 []
# 2.03999999999999999997 0 0.5 []
# 12.6999999999999999998 0 0.5 []
# 2.20000000000000000004 0 0.5 []
# Medicine 0.3301 16.7 [u'/media_common/quotation_subject', u'/book/periodical_subject', u'/book/book_subject', u'/business/employer', u'/medicine/medical_specialty', u'/media_common/literary_genre', u'/film/film_subject', u'/business/industry', u'/people/profession', u'/organization/organization_sector', u'/radio/radio_subject', u'/book/magazine_genre', u'/internet/website_category', u'/education/field_of_study', u'/award/award_discipline', u'/media_common/media_genre', u'/broadcast/genre']
# University of Leeds 0.3214 9.872 [u'/location/location', u'/award/ranked_item', u'/organization/organization_founder', u'/organization/endowed_organization', u'/education/educational_institution_campus', u'/organization/organization', u'/business/employer', u'/architecture/architectural_structure_owner', u'/education/educational_institution', u'/education/university']
# Medicine 0.3228 16.7 [u'/media_common/quotation_subject', u'/book/periodical_subject', u'/book/book_subject', u'/business/employer', u'/medicine/medical_specialty', u'/media_common/literary_genre', u'/film/film_subject', u'/business/industry', u'/people/profession', u'/organization/organization_sector', u'/radio/radio_subject', u'/book/magazine_genre', u'/internet/website_category', u'/education/field_of_study', u'/award/award_discipline', u'/media_common/media_genre', u'/broadcast/genre']
# 3.20000000000000000004 0 0.5 []
# 0.330000000000000000012 0 0.5 []
# 3 0 0.5 []
# 0.800000000000000000011 0 0.5 []
# 70.1999999999999999972 0 0.5 []
# -0.230000000000000000004 0 0.5 []
# 2.09999999999999999991 0 0.5 []
# 8.19999999999999999983 0 0.5 []
# 3.40000000000000000009 0 0.5 []
# 0.490000000000000000009 0 0.5 []
# 14 0 0.5 []
# 12.1000000000000000003 0 0.5 []
# 3.59999999999999999991 0 0.5 []
# 11.1999999999999999998 0 0.5 []
# 5.80000000000000000017 0 0.5 []
# -0.349999999999999999995 0 0.5 []
# 5 0 0.5 []
# 3 0 0.5 []
# 73.4000000000000000014 0 0.5 []
# 3 0 0.5 []
# 1.20000000000000000004 0 0.5 []
# 72.0999999999999999986 0 0.5 []
# 72.9000000000000000014 0 0.5 []
# 2.59999999999999999991 0 0.5 []
# 1.5 0 0.5 []
# 2.79999999999999999996 0 0.5 []
# Pascal (unit) 0.3716 7.744 [u'/time_series/unit', u'/type/unit', u'/symbols/namesake', u'/measurement_unit/pressure_unit']
# 3 0 0.5 []
# Femoral head 0.3432 7.431 [u'/medicine/anatomical_structure']
# Medical school 0.3321 2.107 [u'/fictional_universe/school_in_fiction', u'/education/school_category', u'/organization/organization_type']
# L.V.Burgin@leeds.ac.uk 0 0.5 []
# Dynamic 0 0.5 [u'/organization/organization']
# Eberhardt 0 0.5 [u'/people/person']
# Edyn 0 0.5 [u'/location/location']
# Curiously 0 0.5 [u'/location/location']
# hyaluronon 0 0.5 [u'/location/location']
# fixed-charge 0 0.5 [u'/organization/organization']
# GAG 0 0.5 [u'/organization/organization']
# Grant 0 0.5 [u'/people/person']
# 0.000999999999999999999958 0 0.5 []
# Sample (statistics) 0.07271 2.157 []
# Femoral head 0.3432 7.081 [u'/medicine/anatomical_structure']
# 1 0 0.5 []
# 1 0 0.5 []
# 0.000999999999999999999958 0 0.5 []
# Articular bone 0.1053 1.056 []
# Ratcliffe A 0 0.5 [u'/people/person']
# 0.000999999999999999999958 0 0.5 []
# Burgin LV 0 0.5 [u'/people/person']
# GAG 0 0.5 [u'/organization/organization']
# GAG 0 0.5 [u'/organization/organization']
# Femoral head 0.3432 7.081 [u'/medicine/anatomical_structure']
# 2.09999999999999999991 0 0.5 []
# Milentijevic D 0 0.5 [u'/organization/organization']
# 0.000999999999999999999958 0 0.5 []
# Femur 0.3952 9.706 [u'/medicine/bone', u'/medicine/anatomical_structure']
# Femoral head 0.3432 7.081 [u'/medicine/anatomical_structure']
# GAG 0 0.5 [u'/organization/organization']
# 2.09999999999999999991 0 0.5 []
# 78.5 0 0.5 []
# GAG 0 0.5 [u'/organization/organization']
# 78.5 0 0.5 []
# 1 0 0.5 []
# 1 0 0.5 []
# Burgin LV 0 0.5 [u'/people/person']
# Femur 0.3952 9.706 [u'/medicine/bone', u'/medicine/anatomical_structure']
# 2.09999999999999999991 0 0.5 []
# Burgin LV 0 0.5 [u'/people/person']
# 0.000999999999999999999958 0 0.5 []
# Linear regression 0.4809 19.94 []
# Regression analysis 0.6357 6.579 []
# 1990-01-01T00:00:00.000-05:00 0 0.5 []
# Upper extremity of humerus 0.1272 2.039 [u'/medicine/anatomical_structure']
# Carl Zeiss AG 0.257 1.838 [u'/digicams/digital_camera_manufacturer', u'/business/employer', u'/business/business_operation', u'/award/award_winner', u'/organization/organization']
# Energy 0.2601 14.52 [u'/organization/organization_sector', u'/book/book_subject', u'/measurement_unit/dimension', u'/measurement_unit/common_dimension', u'/business/industry']
# Energy 0.2601 14.52 [u'/organization/organization_sector', u'/book/book_subject', u'/measurement_unit/dimension', u'/measurement_unit/common_dimension', u'/business/industry']
# Energy 0.2601 14.52 [u'/organization/organization_sector', u'/book/book_subject', u'/measurement_unit/dimension', u'/measurement_unit/common_dimension', u'/business/industry']
# Femoral head 0.3432 7.431 [u'/medicine/anatomical_structure']
# Energy 0.2601 14.52 [u'/organization/organization_sector', u'/book/book_subject', u'/measurement_unit/dimension', u'/measurement_unit/common_dimension', u'/business/industry']
# Energy 0.2601 14.52 [u'/organization/organization_sector', u'/book/book_subject', u'/measurement_unit/dimension', u'/measurement_unit/common_dimension', u'/business/industry']
# Energy 0.2601 14.52 [u'/organization/organization_sector', u'/book/book_subject', u'/measurement_unit/dimension', u'/measurement_unit/common_dimension', u'/business/industry']
# Energy 0.2601 14.52 [u'/organization/organization_sector', u'/book/book_subject', u'/measurement_unit/dimension', u'/measurement_unit/common_dimension', u'/business/industry']
# Energy 0.2601 14.52 [u'/organization/organization_sector', u'/book/book_subject', u'/measurement_unit/dimension', u'/measurement_unit/common_dimension', u'/business/industry']
# Energy 0.2601 14.52 [u'/organization/organization_sector', u'/book/book_subject', u'/measurement_unit/dimension', u'/measurement_unit/common_dimension', u'/business/industry']
# Energy 0.2601 14.52 [u'/organization/organization_sector', u'/book/book_subject', u'/measurement_unit/dimension', u'/measurement_unit/common_dimension', u'/business/industry']
# Energy 0.2601 14.52 [u'/organization/organization_sector', u'/book/book_subject', u'/measurement_unit/dimension', u'/measurement_unit/common_dimension', u'/business/industry']
# Water 0.2392 2.891 [u'/exhibitions/exhibition_subject', u'/chemistry/molecular_entity', u'/food/nutrient', u'/cvg/computer_game_subject', u'/food/ingredient', u'/visual_art/visual_art_medium', u'/chemistry/chemical_compound', u'/book/book_subject', u'/medicine/drug_ingredient']
# Fracture 0.5052 1.18 [u'/medicine/disease_cause']
# Force 0.6412 1.982 [u'/fictional_universe/fictional_character', u'/book/book_subject', u'/measurement_unit/dimension', u'/media_common/quotation_subject', u'/measurement_unit/common_dimension']
# Osteoarthritis 0.5538 13.06 [u'/medicine/risk_factor', u'/medicine/disease_cause', u'/medicine/disease']
# Rheum 0.009604 1.774 []
# Dzida FJ 0 0.5 [u'/location/location']
# -0.769999999999999999983 0 0.5 []
# Aspden RM 0 0.5 [u'/people/person']
# 1.79999999999999999996 0 0.5 []
# 0.0659999999999999999983 0 0.5 []
# 2 0 0.5 []
# 0.779999999999999999974 0 0.5 []
# Aspden RM 0 0.5 [u'/people/person']
# 0.569999999999999999993 0 0.5 []
# 75.5 0 0.5 []
# 78.5 0 0.5 []
# Aspden RM 0 0.5 [u'/people/person']
# Aspden RM 0 0.5 [u'/people/person']
# Aspden RM 0 0.5 [u'/people/person']
# Aspden RM 0 0.5 [u'/people/person']
# Aspden RM 0 0.5 [u'/people/person']
# 0.349999999999999999995 0 0.5 []
# 5.80000000000000000017 0 0.5 []
# Aspden RM 0 0.5 [u'/people/person']
# Aspden RM 0 0.5 [u'/people/person']
# Aspden RM 0 0.5 [u'/people/person']
# Accelerometer 0.6725 9.551 [u'/computer/computer_peripheral', u'/measurement_unit/measuring_instrument', u'/business/consumer_product']
# 12 0 0.5 []
# 0.300000000000000000011 0 0.5 []
# Aspden RM 0 0.5 [u'/people/person']
# 0.501999999999999999987 0 0.5 []
# Elastic modulus 0.3765 3.316 []
# Coefficient 0.02286 0.9862 []
# Coefficient of restitution 0.648 7.211 []
# Restitution 0.03971 1.062 []
# Pressure 0.4116 11.67 [u'/measurement_unit/dimension', u'/medicine/disease_cause', u'/measurement_unit/common_dimension']
# Knee 0.422 1.394 [u'/medicine/anatomical_structure']
# Joint 0.4164 17.92 [u'/book/book_subject', u'/medicine/anatomical_structure']
# Deformation (engineering) 0.4642 3.733 []
# Etiology 0.01849 3.718 [u'/book/book_subject']
# Multiple comparisons problem 0.4755 3.692 []
# 0.460000000000000000008 0 0.5 []
# 2.32999999999999999993 0 0.5 []
# 16.1000000000000000003 0 0.5 []
# 1.72000000000000000003 0 0.5 []
# 54.2000000000000000007 0 0.5 []
# 0.469999999999999999999 0 0.5 []
# 0.219999999999999999999 0 0.5 []
# 7.90000000000000000009 0 0.5 []
# 2.47000000000000000003 0 0.5 []
# 68.0999999999999999986 0 0.5 []
# 0.850000000000000000022 0 0.5 []
# 1.24000000000000000001 0 0.5 []
# 0.47999999999999999999 0 0.5 []
# 2.26999999999999999998 0 0.5 []
# 2.3599999999999999999 0 0.5 []
# University of Cambridge 0.1645 6.884 [u'/business/business_location', u'/business/customer', u'/award/ranked_item', u'/education/university', u'/award/award_presenting_organization', u'/computer/processor_manufacturer', u'/organization/endowed_organization', u'/projects/project_participant', u'/education/educational_institution', u'/education/educational_institution_campus', u'/business/employer', u'/education/academic_institution', u'/location/location', u'/organization/organization', u'/fictional_universe/school_in_fiction', u'/architecture/architectural_structure_owner', u'/organization/organization_member', u'/business/business_operation']
# Viscoelasticity 0.8744 18.06 []
# Platen 0.1366 2.007 []
# Pendulum 0.2801 4.224 []
# Tissue (biology) 0.1458 11.92 [u'/medicine/anatomical_structure']
# Stress (mechanics) 0.6966 2.061 []
# Normal distribution 0.636 1.816 [u'/book/book_subject']
# Phase (waves) 0.2108 1.123 []
# Hypothesis 0.3102 5.371 []
# Dynamic modulus 0.1694 3.756 []
# Elastic modulus 0.3335 3.255 []
# Acceleration 0.5092 4.444 [u'/measurement_unit/dimension', u'/film/film_subject', u'/measurement_unit/common_dimension']
# Restitution 0.09829 1.127 []
# Correlation and dependence 0.786 4.846 [u'/book/book_subject']
# 0.5 0 0.5 []
# Absolute value 0.06632 4.613 []
# Measurement 0.2001 1.22 []
# Cartilage 0.6153 10.67 [u'/medicine/anatomical_structure']
# Tissue remodeling 0.04535 1.073 []
# Osteoarthritis 0.696 1.448 [u'/medicine/risk_factor', u'/medicine/disease_cause', u'/medicine/disease']
# In vivo 0.247 9.651 []
# 1998-01-01T00:00:00.000-05:00 0 0.5 []
# 2003-01-01T00:00:00.000-05:00 0 0.5 []
# 50 0 0.5 []
# 1.37 0 0.5 []
# 1.98 0 0.5 []
# 1854-01-01T00:00:00.000-05:17:32 0 0.5 []
# 1994-01-01T00:00:00.000-05:00 0 0.5 []
# 1985-01-01T00:00:00.000-05:00 0 0.5 []
# 2006-01-01T00:00:00.000-05:00 0 0.5 []
# 2007-01-01T00:00:00.000-05:00 0 0.5 []
# 2013-01-01T00:00:00.000-05:00 0 0.5 []
# 2005-01-01T00:00:00.000-05:00 0 0.5 []
# 2006-01-01T00:00:00.000-05:00 0 0.5 []
# 2002-01-01T00:00:00.000-05:00 0 0.5 []
# 2011-01-01T00:00:00.000-05:00 0 0.5 []
# 2002-01-01T00:00:00.000-05:00 0 0.5 []
# 2004-01-01T00:00:00.000-05:00 0 0.5 []
# 16 0 0.5 []
# 25 0 0.5 []
# 80 0 0.5 []
# 12.6 0 0.5 []
# 2.98 0 0.5 []
# Sample (statistics) 0.0449 2.157 []
# Sulfate 0.1905 4.41 [u'/medicine/drug_ingredient', u'/chemistry/chemical_compound', u'/medicine/drug']
# 53.5999999999999999986 0 0.5 []
# Biomechanics 0.486 1.076 [u'/education/field_of_study', u'/book/book_subject']
# Physiology 0.1911 10.63 [u'/education/field_of_study', u'/book/book_subject', u'/award/award_discipline']
# Biology 0.5386 16.93 [u'/people/professional_field', u'/book/book_subject', u'/education/department', u'/media_common/literary_genre', u'/internet/website_category', u'/book/periodical_subject', u'/media_common/media_genre', u'/award/award_discipline', u'/education/field_of_study']
# Hip 0.4323 0.9568 [u'/people/measured_body_part', u'/medicine/anatomical_structure']
# Natoli 0 0.5 [u'/organization/organization']
# Repo 0 0.5 [u'/organization/organization']
# Athanasiou 0 0.5 [u'/people/person']
# 23 0 0.5 []
# 1 0 0.5 []
# 12 0 0.5 []
# 5 0 0.5 []
# 5 0 0.5 []
# 79 0 0.5 []
# 9 0 0.5 []
# 1.60000000000000000002 0 0.5 []
# 5 0 0.5 []
# 12.79 0 0.5 []
# 25 0 0.5 []
# 300 0 0.5 []
# 20 0 0.5 []
# 22 0 0.5 []
# 4 0 0.5 []
# 20 0 0.5 []
# 5 0 0.5 []
# 25 0 0.5 []
# 5 0 0.5 []
# 19 0 0.5 []
# 1 0 0.5 []
# 21 0 0.5 []
# 20 0 0.5 []
# 2000-01-01T00:00:00.000-05:00 0 0.5 []
# 15 0 0.5 []
# 60 0 0.5 []
# 20 0 0.5 []
# 1976-01-01T00:00:00.000-05:00 0 0.5 []
# 1994-01-01T00:00:00.000-05:00 0 0.5 []
# 2007-01-01T00:00:00.000-05:00 0 0.5 []
# 1995-01-01T00:00:00.000-05:00 0 0.5 []
# 1983-01-01T00:00:00.000-05:00 0 0.5 []
# 2007-01-01T00:00:00.000-05:00 0 0.5 []
# 1992-01-01T00:00:00.000-05:00 0 0.5 []
# 2009-01-01T00:00:00.000-05:00 0 0.5 []
# 1977-01-01T00:00:00.000-05:00 0 0.5 []
# 2017-06-23T13:47:00.000-04:00 0 0.5 []
# 1978-01-01T00:00:00.000-05:00 0 0.5 []
# 2017-06-23T17:29:00.000-04:00 0 0.5 []
# 1970-01-01T00:00:00.000-05:00 0 0.5 []
# 1970-01-01T00:00:00.000-05:00 0 0.5 []
# 2008-01-01T00:00:00.000-05:00 0 0.5 []
# 2005-01-01T00:00:00.000-05:00 0 0.5 []
# Displacement (vector) 0.1516 2.435 []
# 30 0 0.5 []
# Femoral head 0.3432 7.431 [u'/medicine/anatomical_structure']
# Femoral head 0.3432 7.431 [u'/medicine/anatomical_structure']
# Acetabulum 0.2485 6.06 [u'/medicine/anatomical_structure', u'/medicine/bone']
# Anatomical terms of location 0.355 1.387 []
# Pascal (unit) 0.1224 5.892 [u'/time_series/unit', u'/type/unit', u'/symbols/namesake', u'/measurement_unit/pressure_unit']
# Measurement 0.2546 1.43 []
# Behavior 0.3229 1.02 [u'/media_common/quotation_subject', u'/book/book_subject', u'/education/field_of_study']
# Energy 0.2601 14.52 [u'/organization/organization_sector', u'/book/book_subject', u'/measurement_unit/dimension', u'/measurement_unit/common_dimension', u'/business/industry']
# Aspect ratio 0.1533 3.623 []
# 0.0500000000000000000007 0 0.5 []
# 2.5 0 0.5 []
# Hydroxyproline 0.1769 7.65 [u'/chemistry/chemical_compound', u'/medicine/drug', u'/medicine/drug_ingredient', u'/food/nutrient']
# 1.52999999999999999997 0 0.5 []
# 5 0 0.5 []
# Transducer 0.1854 9.194 []
# 2.5 0 0.5 []
# Glycosaminoglycan 0.2951 13.35 []
# Stress (mechanics) 0.1957 5.661 []
# 0.360000000000000000013 0 0.5 []
# Glycosaminoglycan 0.2951 13.35 []
# 0.0500000000000000000007 0 0.5 []
# Biochemistry 0.1946 45.18 [u'/organization/organization_sector', u'/award/award_discipline', u'/education/field_of_study', u'/book/book_subject']
# Hydroxyproline 0.1769 7.65 [u'/chemistry/chemical_compound', u'/medicine/drug', u'/medicine/drug_ingredient', u'/food/nutrient']
# Biomechanics 0.8443 9.815 [u'/education/field_of_study', u'/book/book_subject']
# 2.5 0 0.5 []
# 2.5 0 0.5 []
# Percentage 0.1735 1.842 [u'/time_series/unit', u'/type/unit']
# 2.5 0 0.5 []
# 0.519999999999999999983 0 0.5 []
# 10 0 0.5 []
# Statistics 0.5781 13.42 [u'/media_common/quotation_subject', u'/book/book_subject', u'/book/periodical_subject', u'/computer/software_genre', u'/award/award_discipline', u'/education/school_category', u'/education/field_of_study']
# Hyaline cartilage 0.3609 10.72 [u'/medicine/anatomical_structure']
# Hyaline cartilage 0.3609 10.72 [u'/medicine/anatomical_structure']
# 0 0 0.5 []
# Hyaline cartilage 0.3609 10.72 [u'/medicine/anatomical_structure']
# Hyaline cartilage 0.3609 10.72 [u'/medicine/anatomical_structure']
# Hyaline cartilage 0.3609 10.72 [u'/medicine/anatomical_structure']
# Hyaline cartilage 0.3609 10.72 [u'/medicine/anatomical_structure']
# Hyaline cartilage 0.3609 10.72 [u'/medicine/anatomical_structure']
# Hyaline cartilage 0.3609 10.72 [u'/medicine/anatomical_structure']
# Hyaline cartilage 0.3609 10.72 [u'/medicine/anatomical_structure']
# Hyaline cartilage 0.3609 10.72 [u'/medicine/anatomical_structure']
# Hyaline cartilage 0.3609 10.72 [u'/medicine/anatomical_structure']
# Joint 0.4164 17.92 [u'/book/book_subject', u'/medicine/anatomical_structure']
# Rheumatology 0.1483 4.099 [u'/education/field_of_study', u'/book/book_subject', u'/medicine/medical_specialty']
# Hyaline cartilage 0.3609 10.72 [u'/medicine/anatomical_structure']
# Hyaline cartilage 0.3609 10.72 [u'/medicine/anatomical_structure']
# Paul IL 0 0.5 [u'/people/person']
# 5.40000000000000000009 0 0.5 []
# Hyaline cartilage 0.3609 10.72 [u'/medicine/anatomical_structure']
# Hyaline cartilage 0.3609 10.72 [u'/medicine/anatomical_structure']
# Hyaline cartilage 0.3609 10.72 [u'/medicine/anatomical_structure']
# Hyaline cartilage 0.3609 10.72 [u'/medicine/anatomical_structure']
# 3.09999999999999999991 0 0.5 []
# 1 0 0.5 []
# 2 0 0.5 []
# 91.6999999999999999972 0 0.5 []
# 0.0549999999999999999997 0 0.5 []
# 0.680000000000000000007 0 0.5 []
# -0.490000000000000000009 0 0.5 []
# 22.5 0 0.5 []
# 0.119999999999999999998 0 0.5 []
# Correlation and dependence 0.1398 4.846 [u'/book/book_subject']
# Correlation and dependence 0.1398 4.846 [u'/book/book_subject']
# Correlation and dependence 0.1398 4.846 [u'/book/book_subject']
# Correlation and dependence 0.383 4.846 [u'/book/book_subject']
# 0.27000000000000000001 0 0.5 []
# Stress–strain curve 0.9242 8.854 []
# Curve 0.253 2.844 []
# Ficus 0.2225 1.052 [u'/food/food', u'/food/ingredient', u'/biology/organism_classification']
# Ultrasound 0.3361 8.435 [u'/education/field_of_study', u'/organization/organization_sector', u'/business/industry']
# Measurement 0.2045 1.198 []
# Femur 0.4992 5.282 [u'/medicine/bone', u'/medicine/anatomical_structure']
# GAG 0 0.5 [u'/organization/organization']
# Fracture 0.1703 2.757 [u'/medicine/disease_cause']
# GAG 0 0.5 [u'/organization/organization']
# 1.90999999999999999997 0 0.5 []
# GAG 0 0.5 [u'/organization/organization']
# GAG 0 0.5 [u'/organization/organization']
# GAG 0 0.5 [u'/organization/organization']
# Elastic modulus 0.5681 3.565 []
# Mean 0.5608 1.654 []
# Articular bone 0.1268 0.9689 []
# Cartilage 0.629 11.42 [u'/medicine/anatomical_structure']
# Elasticity (physics) 0.3899 6.958 [u'/fictional_universe/character_powers']
# Elastic collision 0.3275 8.899 []
# Collision 0.5978 1.642 [u'/event/disaster_type', u'/people/cause_of_death']
# Interaction 0.1491 1.577 []
# Biopsy 0.3402 6.643 [u'/medicine/diagnostic_test']
# Soft matter 0.2018 2.701 []
# Measurement 0.3431 1.343 []
# Email 0.2119 3.866 [u'/organization/organization_sector', u'/internet/website_category', u'/organization/contact_category', u'/film/film_subject', u'/computer/software_genre', u'/book/book_subject', u'/law/invention']
# Biochem Biophys 0 0.5 [u'/organization/organization']
# Gregory DW 0 0.5 [u'/people/person']
# 9 0 0.5 []
# 22 0 0.5 []
# 6 0 0.5 []
# 10 0 0.5 []
# -92 0 0.5 []
# 13 0 0.5 []
# 11 0 0.5 []
# 5 0 0.5 []
# -200 0 0.5 []
# -91 0 0.5 []
# 12 0 0.5 []
# 7 0 0.5 []
# 8 0 0.5 []
# 2 0 0.5 []
# -20 0 0.5 []
# Measurement 0.225 1.83 []
# 0.889999999999999999987 0 0.5 []
# 22.2000000000000000007 0 0.5 []
# 65.8000000000000000028 0 0.5 []
# 1.34000000000000000003 0 0.5 []
# 0.379999999999999999996 0 0.5 []
# 2.49000000000000000001 0 0.5 []
# Ratio 0.1965 3.238 [u'/measurement_unit/dimension']
# Human musculoskeletal system 0.3436 3.173 [u'/medicine/anatomical_structure', u'/book/book_subject']
# Cartilage 0.9913 14.11 [u'/medicine/anatomical_structure']
# Cartilage 0.9913 14.11 [u'/medicine/anatomical_structure']
# Velocity 0.2138 7.353 [u'/measurement_unit/dimension']
# Cartilage 0.9913 14.11 [u'/medicine/anatomical_structure']
# Medical school 0.3321 2.107 [u'/fictional_universe/school_in_fiction', u'/education/school_category', u'/organization/organization_type']
# Cartilage 0.9913 14.11 [u'/medicine/anatomical_structure']
# Velocity 0.2138 7.353 [u'/measurement_unit/dimension']
# Cartilage 0.9913 14.11 [u'/medicine/anatomical_structure']
# 37 0 0.5 []
# Velocity 0.2138 7.353 [u'/measurement_unit/dimension']
# Cartilage 0.9913 14.11 [u'/medicine/anatomical_structure']
# Parameter 0.3999 2.882 []
# Measurement 0.3431 1.83 []
# 0.100000000000000000001 0 0.5 []
# 0.100000000000000000001 0 0.5 []
# 0.100000000000000000001 0 0.5 []
# Curve 0.1163 2.49 []
# Curve 0.1163 2.49 []
# Curve 0.1163 2.49 []
# 0.100000000000000000001 0 0.5 []
# 0.100000000000000000001 0 0.5 []
# 0.150000000000000000005 0 0.5 []
# 0.100000000000000000001 0 0.5 []
# Curve 0.1163 2.49 []
# Curve 0.1163 2.49 []
# Curve 0.1163 2.49 []
# Absolute value 0.06632 4.613 []
# Absolute value 0.06632 4.613 []
# Absolute value 0.06632 4.613 []
# Deformation (mechanics) 0.1767 4.402 []
# Deformation (mechanics) 0.1767 4.402 []
# Deformation (mechanics) 0.1767 4.402 []
# Absolute value 0.06632 4.613 []
# Absolute value 0.06632 4.613 []
# Absolute value 0.06632 4.613 []
# Deformation (mechanics) 0.1767 4.402 []
# Absolute value 0.06632 4.613 []
# Absolute value 0.06632 4.613 []
# Deformation (mechanics) 0.1767 4.402 []
# Absolute value 0.06632 4.613 []
# Absolute value 0.06632 4.613 []
# Absolute value 0.06632 4.613 []
# Absolute value 0.06632 4.613 []
# Absolute value 0.06632 4.613 []
# Absolute value 0.06632 4.613 []
# Absolute value 0.06632 4.613 []
# Absolute value 0.06632 4.613 []
# Absolute value 0.06632 4.613 []
# Absolute value 0.06632 4.613 []
# Absolute value 0.06632 4.613 []
# Absolute value 0.06632 4.613 []
# Absolute value 0.06632 4.613 []
# Absolute value 0.06632 4.613 []
# Musculoskeletal Research Programme 0 0.5 [u'/organization/organization']
# L. Edelsten2 0 0.5 [u'/people/person']
# 1990-01-01T00:00:00.000-05:00 0 0.5 []
# University of 0 0.5 [u'/organization/organization']
# Cartilage 0.9913 14.11 [u'/medicine/anatomical_structure']
# Femoral head 0.3432 7.431 [u'/medicine/anatomical_structure']
# Femoral head 0.3432 7.431 [u'/medicine/anatomical_structure']
# Femoral head 0.3432 7.431 [u'/medicine/anatomical_structure']
# Hyaline cartilage 0.3609 10.72 [u'/medicine/anatomical_structure']
# Software 0.1304 5.475 [u'/education/school_category', u'/broadcast/genre', u'/media_common/quotation_subject', u'/business/consumer_product', u'/business/product_category', u'/organization/organization_sector', u'/computer/software_genre', u'/business/industry', u'/internet/website_category', u'/media_common/media_genre', u'/business/competitive_space', u'/book/book_subject', u'/organization/organization']
# Linear regression 0.4809 19.94 []
# R.M. Aspden 0 0.5 [u'/people/person']
# United Kingdom 0.226 4.922 [u'/sports/sport_country', u'/organization/contact_category', u'/food/beer_country_region', u'/government/governmental_jurisdiction', u'/location/uk_statistical_location', u'/business/employer', u'/location/dated_location', u'/organization/organization_scope', u'/royalty/kingdom', u'/organization/organization_member', u'/sports/sports_team_location', u'/media_common/netflix_genre', u'/book/periodical_subject', u'/military/military_combatant', u'/location/location', u'/location/statistical_region', u'/location/administrative_division', u'/biology/breed_origin', u'/symbols/flag_referent', u'/fictional_universe/fictional_setting', u'/tv/tv_location', u'/film/film_location', u'/organization/organization_founder', u'/periodicals/newspaper_circulation_area', u'/location/country', u'/business/business_location', u'/olympics/olympic_participating_country', u'/cvg/computer_game_region', u'/law/court_jurisdiction_area', u'/book/book_subject']
# Fiber 0.199 3.741 []
# Freeze-drying 0.2061 4.538 []
# Pascal (unit) 0.4051 21.57 [u'/time_series/unit', u'/type/unit', u'/symbols/namesake', u'/measurement_unit/pressure_unit']
# Stress (mechanics) 0.4905 5.349 []
# Stress–strain curve 0.522 3.643 []
# Deformation (engineering) 0.5855 3.733 []
# Cartilage 0.4546 10.84 [u'/medicine/anatomical_structure']
# Mecha 0.0633 1.691 [u'/media_common/media_genre', u'/comic_books/comic_book_genre', u'/media_common/literary_genre', u'/tv/tv_genre', u'/film/film_genre', u'/book/book_subject', u'/cvg/computer_game_subject']
# Microscope 0.3439 7.55 [u'/law/invention']
# Histology 0.3352 18.26 [u'/book/book_subject', u'/education/field_of_study']
# Cartilage 0.4902 10.49 [u'/medicine/anatomical_structure']
# 70.4000000000000000014 0 0.5 []
# 10.3000000000000000002 0 0.5 []
# 0.600000000000000000022 0 0.5 []
# Gradient 0.2657 6.637 []
# Drop tower 0.07116 2.009 [u'/amusement_parks/ride_type']
# Seedhom BB 0 0.5 [u'/people/person']
# Reserved word 0.1663 1.006 []
# Articular bone 0.1053 1.056 []
# Anatomical terms of location 0.2577 1.387 []
# Hyaline cartilage 0.3609 10.72 [u'/medicine/anatomical_structure']
# Seedhom BB 0 0.5 [u'/people/person']
# Cartilage 0.9913 13.55 [u'/medicine/anatomical_structure']
# Anatomical terms of location 0.2577 1.387 []
# 5.5 0 0.5 []
# Seedhom BB 0 0.5 [u'/people/person']
# 0.490000000000000000009 0 0.5 []
# 2.79999999999999999996 0 0.5 []
# Absolute value 0.06632 4.613 []
# Cartilage 0.5039 11.32 [u'/medicine/anatomical_structure']
# Matrix (mathematics) 0.1801 8.561 [u'/book/book_subject', u'/film/film_subject']
# Vithoontien V. An 0 0.5 [u'/people/person']
# Barker MK 0 0.5 [u'/people/person']
# Odgaard A 0 0.5 [u'/organization/organization']
# Linde F. 0 0.5 [u'/organization/organization']
# Shepherd DE 0 0.5 [u'/people/person']
# Eberhardt AW 0 0.5 [u'/people/person']
# Swanson SA 0 0.5 [u'/people/person']
# Athanasiou KA 0 0.5 [u'/people/person']
# Dzida FJ 0 0.5 [u'/location/location']
# Constantinides G 0 0.5 [u'/location/location']
# Spivey CJ 0 0.5 [u'/people/person']
# Seedhom BB 0 0.5 [u'/people/person']
# Muffoletto A 0 0.5 [u'/people/person']
# Lewis JL 0 0.5 [u'/people/person']
# limb 0 0.5 [u'/organization/organization']
# Aspden RM 0 0.5 [u'/people/person']
# Agarwal 0 0.5 [u'/people/person']
# Keer LM 0 0.5 [u'/people/person']
# Freeman MA 0 0.5 [u'/people/person']
# 2.40000000000000000009 0 0.5 []
# 8 0 0.5 []
# 0 0 0.5 []
# 1 0 0.5 []
# 0.0167000000000000000007 0 0.5 []
# 26 0 0.5 []
# 7 0 0.5 []
# 2 0 0.5 []
# 15 0 0.5 []
# 24 0 0.5 []
# 80 0 0.5 []
# 100 0 0.5 []
# 25 0 0.5 []
# 24 0 0.5 []
# 10 0 0.5 []
# 5564 0 0.5 []
# 30 0 0.5 []
# Restitution 0.1837 1.118 []
# Ball bearing 0.3674 4.396 [u'/law/invention']
# Bearing (mechanical) 0.3986 1.055 [u'/law/invention']
# English language 0.1161 1.492 [u'/book/school_or_movement', u'/language/human_language', u'/organization/organization_sector', u'/organization/contact_category', u'/dataworld/information_source', u'/language/languoid', u'/book/book_subject', u'/education/school_category', u'/symbols/namesake', u'/education/field_of_study', u'/fictional_universe/fictional_language']
# Visual inspection 0.1346 1.489 []
# Chemistry 0.2623 17.5 [u'/people/professional_field', u'/education/field_of_study', u'/media_common/media_genre', u'/award/award_discipline', u'/media_common/literary_genre', u'/organization/organization_sector', u'/business/industry', u'/book/periodical_subject', u'/book/book_subject']
# Chemical composition 0.05944 2.389 []
# Mean 0.4185 1.199 []
# Schematic 0.08197 2.356 []
# Diagram 0.123 2.625 []
# Chondrocyte 0.1937 12.34 [u'/medicine/anatomical_structure']
# Bone 0.3455 11.36 [u'/medicine/anatomical_structure']
# Chondrocyte 0.1937 12.34 [u'/medicine/anatomical_structure']
# Chondrocyte 0.1937 12.34 [u'/medicine/anatomical_structure']
# Stress–strain curve 0.9242 8.854 []
# Stress–strain curve 0.9242 8.854 []
# Stress–strain curve 0.9242 8.854 []
# Biomechanics 0.3042 4.213 [u'/education/field_of_study', u'/book/book_subject']
# Bone 0.3455 11.36 [u'/medicine/anatomical_structure']
# Stress (mechanics) 0.4905 5.661 []
# 0.800000000000000000011 0 0.5 []
# Stress (mechanics) 0.4905 5.661 []
# Stress (mechanics) 0.4905 5.661 []
# Stress (mechanics) 0.4905 5.661 []
# Stress (mechanics) 0.4905 5.661 []
# Deformation (mechanics) 0.5757 4.278 []
# Deformation (mechanics) 0.3335 3.667 []
# Deformation (mechanics) 0.3335 3.667 []
# Deformation (mechanics) 0.3335 3.667 []
# Deformation (mechanics) 0.3335 3.667 []
# Drop tower 0.07116 2.009 [u'/amusement_parks/ride_type']
# Deformation (mechanics) 0.5757 4.278 []
# Drop tower 0.07116 2.009 [u'/amusement_parks/ride_type']
# Drop tower 0.07116 2.009 [u'/amusement_parks/ride_type']
# 80 0 0.5 []
# Deformation (mechanics) 0.5757 4.278 []
# ...
# Proc R Soc Lond B-Biol Sci 0 0.5 [u'/organization/organization']
# Data 0.2285 5.448 [u'/internet/website_category']
# Femur 0.3952 9.706 [u'/medicine/bone', u'/medicine/anatomical_structure']
# Femoral head 0.1738 6.858 [u'/medicine/anatomical_structure']
# Mean 0.5608 1.654 []
# Standard deviation 0.8098 12.24 []
# PHY (chip) 0.0174 1.905 []
# SSL International 0.08134 2.682 [u'/business/issuer', u'/business/employer', u'/business/business_operation', u'/business/consumer_company', u'/business/defunct_company', u'/organization/organization']
# Collagen 0.4493 14.43 [u'/chemistry/chemical_classification', u'/business/product_ingredient']
# Correlation and dependence 0.5975 4.424 [u'/book/book_subject']
# Water 0.3579 2.891 [u'/exhibitions/exhibition_subject', u'/chemistry/molecular_entity', u'/food/nutrient', u'/cvg/computer_game_subject', u'/food/ingredient', u'/visual_art/visual_art_medium', u'/chemistry/chemical_compound', u'/book/book_subject', u'/medicine/drug_ingredient']
# Surgery 0.281 9.341 [u'/book/book_subject', u'/medicine/medical_treatment', u'/medicine/risk_factor', u'/people/cause_of_death', u'/visual_art/art_subject', u'/tv/tv_subject', u'/education/field_of_study', u'/medicine/medical_specialty']
# Biomechanics 0.486 1.076 [u'/education/field_of_study', u'/book/book_subject']
# Biomech Eng 0 0.5 [u'/organization/organization']
# Biomech Eng 0 0.5 [u'/organization/organization']
# Biomechanics 0.486 1.076 [u'/education/field_of_study', u'/book/book_subject']
# Absolute value 0.06632 4.613 []
# Tissue (biology) 0.2199 11.4 [u'/medicine/anatomical_structure']
# Cartilage 0.2146 8.841 [u'/medicine/anatomical_structure']
# Collision 0.5978 1.642 [u'/event/disaster_type', u'/people/cause_of_death']
# Kinetic energy 0.3291 29.89 []
# Energy 0.3355 14.52 [u'/organization/organization_sector', u'/book/book_subject', u'/measurement_unit/dimension', u'/measurement_unit/common_dimension', u'/business/industry']
# Stiffness 0.4224 3.09 [u'/medicine/symptom']
# Absolute value 0.3232 4.83 []
# SPSS 0.2157 10.24 [u'/book/book_subject', u'/computer/software']
# United Kingdom 0.1837 4.551 [u'/sports/sport_country', u'/organization/contact_category', u'/food/beer_country_region', u'/government/governmental_jurisdiction', u'/location/uk_statistical_location', u'/business/employer', u'/location/dated_location', u'/organization/organization_scope', u'/royalty/kingdom', u'/organization/organization_member', u'/sports/sports_team_location', u'/media_common/netflix_genre', u'/book/periodical_subject', u'/military/military_combatant', u'/location/location', u'/location/statistical_region', u'/location/administrative_division', u'/biology/breed_origin', u'/symbols/flag_referent', u'/fictional_universe/fictional_setting', u'/tv/tv_location', u'/film/film_location', u'/organization/organization_founder', u'/periodicals/newspaper_circulation_area', u'/location/country', u'/business/business_location', u'/olympics/olympic_participating_country', u'/cvg/computer_game_region', u'/law/court_jurisdiction_area', u'/book/book_subject']
# Articular bone 0.1268 0.9689 []
# Cartilage 0.629 11.53 [u'/medicine/anatomical_structure']
# Energy 0.2601 14.52 [u'/organization/organization_sector', u'/book/book_subject', u'/measurement_unit/dimension', u'/measurement_unit/common_dimension', u'/business/industry']
# Joint 0.4164 17.92 [u'/book/book_subject', u'/medicine/anatomical_structure']
# Energy 0.2601 14.52 [u'/organization/organization_sector', u'/book/book_subject', u'/measurement_unit/dimension', u'/measurement_unit/common_dimension', u'/business/industry']
# Stress (mechanics) 0.1957 5.661 []
# Joint 0.4164 17.92 [u'/book/book_subject', u'/medicine/anatomical_structure']
# Stress (mechanics) 0.1957 5.661 []
# Energy 0.2601 14.52 [u'/organization/organization_sector', u'/book/book_subject', u'/measurement_unit/dimension', u'/measurement_unit/common_dimension', u'/business/industry']
# Joint 0.4164 17.92 [u'/book/book_subject', u'/medicine/anatomical_structure']
# Energy 0.2601 14.52 [u'/organization/organization_sector', u'/book/book_subject', u'/measurement_unit/dimension', u'/measurement_unit/common_dimension', u'/business/industry']
# Stress (mechanics) 0.1957 5.661 []
# Energy 0.2601 14.52 [u'/organization/organization_sector', u'/book/book_subject', u'/measurement_unit/dimension', u'/measurement_unit/common_dimension', u'/business/industry']
# Joint 0.4164 17.92 [u'/book/book_subject', u'/medicine/anatomical_structure']
# Articular bone 0.1268 0.9689 []
# Cartilage 0.629 11.47 [u'/medicine/anatomical_structure']
# Biorheology 0.1333 2.214 []
# Articular bone 0.1268 0.9689 []
# Cartilage 0.629 11.43 [u'/medicine/anatomical_structure']
# Medicine 0.3228 16.7 [u'/media_common/quotation_subject', u'/book/periodical_subject', u'/book/book_subject', u'/business/employer', u'/medicine/medical_specialty', u'/media_common/literary_genre', u'/film/film_subject', u'/business/industry', u'/people/profession', u'/organization/organization_sector', u'/radio/radio_subject', u'/book/magazine_genre', u'/internet/website_category', u'/education/field_of_study', u'/award/award_discipline', u'/media_common/media_genre', u'/broadcast/genre']
# Innovation 0.3986 2.672 [u'/book/book_subject', u'/education/field_of_study', u'/media_common/quotation_subject', u'/film/film_subject', u'/award/award_discipline', u'/book/book_subject']
# Acceleration 0.5092 4.4 [u'/measurement_unit/dimension', u'/film/film_subject', u'/measurement_unit/common_dimension']
# Gravity of Earth 0.353 2.308 []
# Gravity 0.4657 12.49 [u'/book/book_subject', u'/physics/fundamental_interaction']
# Structural load 0.4886 0.9586 []
# Pascal (unit) 0.4255 7.871 [u'/time_series/unit', u'/type/unit', u'/symbols/namesake', u'/measurement_unit/pressure_unit']
# Polynomial 0.05516 8.514 [u'/book/book_subject']
# Biopsy 0.2942 6.365 [u'/medicine/diagnostic_test']
# Tissue (biology) 0.1319 5.592 [u'/medicine/anatomical_structure']
# Hydrogen 0.1091 18.37 [u'/medicine/drug_ingredient', u'/chemistry/chemical_element']
# Tissue (biology) 0.1319 5.592 [u'/medicine/anatomical_structure']
# Stress (mechanics) 0.4905 5.661 []
# In vitro 0.2754 8.204 []
# Hydrogen 0.1091 18.37 [u'/medicine/drug_ingredient', u'/chemistry/chemical_element']
# Bearing (mechanical) 0.3521 1.035 [u'/law/invention']
# Nonlinear system 0.1612 1.204 []
# 1.70000000000000000004 0 0.5 []
# Variance 0.4085 10.23 [u'/book/book_subject']
# Variance 0.4085 10.23 [u'/book/book_subject']
# 1.70000000000000000004 0 0.5 []
# 0.0659999999999999999983 0 0.5 []
# 25 0 0.5 []
# 0.980000000000000000017 0 0.5 []
# In vitro 0.2754 8.204 []
# 1.10000000000000000002 0 0.5 []
# Bearing surface 0.0781 1.348 []
# Venn MF 0 0.5 [u'/people/person']
# Standard deviation 0.6679 12.24 []
# Variance 0.4085 10.23 [u'/book/book_subject']
# 0.501999999999999999987 0 0.5 []
# 25 0 0.5 []
# In vitro 0.2754 8.204 []
# Tissue (biology) 0.1458 11.92 [u'/medicine/anatomical_structure']
# Tissue (biology) 0.1458 11.92 [u'/medicine/anatomical_structure']
# Tissue (biology) 0.1458 11.92 [u'/medicine/anatomical_structure']
# Tissue (biology) 0.1458 11.92 [u'/medicine/anatomical_structure']
# Tissue (biology) 0.1458 11.92 [u'/medicine/anatomical_structure']
# Tissue (biology) 0.1458 11.92 [u'/medicine/anatomical_structure']
# Tissue (biology) 0.1458 11.92 [u'/medicine/anatomical_structure']
# Tissue (biology) 0.1458 11.92 [u'/medicine/anatomical_structure']
# Tissue (biology) 0.1458 11.92 [u'/medicine/anatomical_structure']
# Tissue (biology) 0.1458 11.92 [u'/medicine/anatomical_structure']
# Tissue (biology) 0.1458 11.92 [u'/medicine/anatomical_structure']
# Tissue (biology) 0.1458 11.92 [u'/medicine/anatomical_structure']
# Tissue (biology) 0.1458 11.92 [u'/medicine/anatomical_structure']
# Tissue (biology) 0.1458 11.92 [u'/medicine/anatomical_structure']
# Cell damage 0.5443 1.112 [u'/medicine/disease']
# Tissue (biology) 0.1458 11.92 [u'/medicine/anatomical_structure']
# Tissue (biology) 0.1458 11.92 [u'/medicine/anatomical_structure']
# Tissue (biology) 0.1458 11.92 [u'/medicine/anatomical_structure']
# Tissue (biology) 0.1458 11.92 [u'/medicine/anatomical_structure']
# Tissue (biology) 0.1458 11.92 [u'/medicine/anatomical_structure']
# Tissue (biology) 0.1458 11.92 [u'/medicine/anatomical_structure']
# Tissue (biology) 0.1458 11.92 [u'/medicine/anatomical_structure']
# Tissue (biology) 0.1458 11.92 [u'/medicine/anatomical_structure']
# Tissue (biology) 0.1458 11.92 [u'/medicine/anatomical_structure']
# Tissue (biology) 0.1458 11.92 [u'/medicine/anatomical_structure']
# Absorption (electromagnetic radiation) 0.1499 2.812 []
# Chemical equilibrium 0.4804 1.15 []
# Load cell 0.3825 2.923 []
# Percentile 0.4426 3.721 []
# 0.340000000000000000003 0 0.5 []
# Fiber 0.1085 3.783 []
# Analysis of variance 0.7138 16.01 []
# ANOVA on ranks 0.4361 1.52 []
# 0.0099999999999999999998 0 0.5 []
# 6.09999999999999999991 0 0.5 []
# Biomaterial 0.6277 5.938 []
# Stress (mechanics) 0.1957 5.661 []
# Mass 0.3817 11.09 [u'/measurement_unit/common_dimension', u'/measurement_unit/dimension']
# Fluid 0.3238 6.426 []
# Mass 0.3817 11.09 [u'/measurement_unit/common_dimension', u'/measurement_unit/dimension']
# Mass 0.3817 11.09 [u'/measurement_unit/common_dimension', u'/measurement_unit/dimension']
# Mass 0.3817 11.09 [u'/measurement_unit/common_dimension', u'/measurement_unit/dimension']
# Mass 0.3817 11.09 [u'/measurement_unit/common_dimension', u'/measurement_unit/dimension']
# Mass 0.3817 11.09 [u'/measurement_unit/common_dimension', u'/measurement_unit/dimension']
# Eslow 0 0.5 [u'/location/location']
# Mass 0.3817 11.09 [u'/measurement_unit/common_dimension', u'/measurement_unit/dimension']
# Mass 0.3817 11.09 [u'/measurement_unit/common_dimension', u'/measurement_unit/dimension']
# 2.20000000000000000004 0 0.5 []
# 2.29999999999999999996 0 0.5 []
# Mass 0.3817 11.09 [u'/measurement_unit/common_dimension', u'/measurement_unit/dimension']
# Fluid 0.3238 6.426 []
# Eslow 0 0.5 [u'/location/location']
# Eslow 0 0.5 [u'/location/location']
# Eslow 0 0.5 [u'/location/location']
# Mass 0.3817 11.09 [u'/measurement_unit/common_dimension', u'/measurement_unit/dimension']
# Fluid 0.3238 6.426 []
# Mass 0.3817 11.09 [u'/measurement_unit/common_dimension', u'/measurement_unit/dimension']
# Mass 0.3817 11.09 [u'/measurement_unit/common_dimension', u'/measurement_unit/dimension']
# Eslow 0 0.5 [u'/location/location']
# Machine 0.379 2.181 [u'/visual_art/art_subject', u'/business/product_category']
# 0.100000000000000000001 0 0.5 []
# Instruments Ltd. 0 0.5 [u'/organization/organization']
# Alton 0 0.5 [u'/location/location']
# sulphated glycosaminoglycans 0 0.5 [u'/organization/organization']
# Sulphated 0 0.5 [u'/organization/organization']
# Kistler Instruments Ltd. 0 0.5 [u'/organization/organization']
# Kistler 0 0.5 [u'/people/person']
# Data 0.2285 5.448 [u'/internet/website_category']
# Data 0.2285 5.448 [u'/internet/website_category']
# Data 0.2285 5.448 [u'/internet/website_category']
# Data 0.2285 5.448 [u'/internet/website_category']
# Data 0.2285 5.448 [u'/internet/website_category']
# Data 0.2285 5.448 [u'/internet/website_category']
# Data 0.2285 5.448 [u'/internet/website_category']
# Data 0.2285 5.448 [u'/internet/website_category']
# Data 0.2285 5.448 [u'/internet/website_category']
# Data 0.2285 5.448 [u'/internet/website_category']
# Data 0.2285 5.448 [u'/internet/website_category']
# Data 0.2285 5.448 [u'/internet/website_category']
# Data 0.2285 5.448 [u'/internet/website_category']
# Papain 0.1184 4.472 [u'/chemistry/chemical_compound', u'/medicine/drug_ingredient']
# Solution 0.1842 7.498 [u'/book/book_subject', u'/medicine/drug_dosage_form']
# Femoral head 0.1738 6.858 [u'/medicine/anatomical_structure']
# Cartilage 0.4902 10.78 [u'/medicine/anatomical_structure']
# mJ mm-3 0 0.5 [u'/organization/organization']
# 100 0 0.5 []
# 6 0 0.5 []
# 30 0 0.5 []
# 13 0 0.5 []
# 27 0 0.5 []
# 28 0 0.5 []
# 2.02999999999999999997 0 0.5 []
# 2.28999999999999999997 0 0.5 []
# 0.589999999999999999976 0 0.5 []
# 1.41999999999999999996 0 0.5 []
# 65 0 0.5 []
# 113 0 0.5 []
# 6 0 0.5 []
# 29 0 0.5 []
# 9 0 0.5 []
# 135 0 0.5 []
# 24 0 0.5 []
# Knee 0.3333 1.24 [u'/medicine/anatomical_structure']
# Ankle 0.1306 3.08 [u'/medicine/anatomical_structure']
# Aberdeen AB25 0 0.5 [u'/location/location']
# Cartilage 0.9913 14.11 [u'/medicine/anatomical_structure']
# Cartilage 0.9913 14.11 [u'/medicine/anatomical_structure']
# Cartilage 0.9913 14.11 [u'/medicine/anatomical_structure']
# Cartilage 0.9913 14.11 [u'/medicine/anatomical_structure']
# Cartilage 0.9913 14.11 [u'/medicine/anatomical_structure']
# Cartilage 0.9913 14.11 [u'/medicine/anatomical_structure']
# Cartilage 0.9913 14.11 [u'/medicine/anatomical_structure']
# Cartilage 0.9913 14.11 [u'/medicine/anatomical_structure']
# Cartilage 0.9913 14.11 [u'/medicine/anatomical_structure']
# Cartilage 0.9913 14.11 [u'/medicine/anatomical_structure']
# Cartilage 0.9913 14.11 [u'/medicine/anatomical_structure']
# Cartilage 0.9913 14.11 [u'/medicine/anatomical_structure']
# Cartilage 0.9913 14.11 [u'/medicine/anatomical_structure']
# Energy 0.2601 14.52 [u'/organization/organization_sector', u'/book/book_subject', u'/measurement_unit/dimension', u'/measurement_unit/common_dimension', u'/business/industry']
# Cartilage 0.9913 14.11 [u'/medicine/anatomical_structure']
# Stress (mechanics) 0.1957 5.661 []
# Cartilage 0.9913 14.11 [u'/medicine/anatomical_structure']
# Cartilage 0.9913 14.11 [u'/medicine/anatomical_structure']
# Energy 0.2601 14.52 [u'/organization/organization_sector', u'/book/book_subject', u'/measurement_unit/dimension', u'/measurement_unit/common_dimension', u'/business/industry']
# Stress (mechanics) 0.1957 5.661 []
# Cartilage 0.9913 14.11 [u'/medicine/anatomical_structure']
# Cartilage 0.9913 14.11 [u'/medicine/anatomical_structure']
# Cartilage 0.9913 14.11 [u'/medicine/anatomical_structure']
# Cartilage 0.9913 14.11 [u'/medicine/anatomical_structure']
# Cartilage 0.9913 14.11 [u'/medicine/anatomical_structure']
# Stress (mechanics) 0.1957 5.661 []
# Cartilage 0.9913 14.11 [u'/medicine/anatomical_structure']
# Cartilage 0.9913 14.11 [u'/medicine/anatomical_structure']
# Cartilage 0.9913 14.11 [u'/medicine/anatomical_structure']
# Restitution 0.08742 1.111 []
# Load profile 0.3253 1.442 []
# Structural load 0.4886 0.9586 []
# Matrix (biology) 0.5905 1.609 []
# The Matrix 0.2432 1.454 [u'/award/ranked_item', u'/media_common/netflix_title', u'/film/film', u'/award/award_nominated_work', u'/fictional_universe/work_of_fiction', u'/award/award_winning_work']
# Cartilage 0.5359 10.88 [u'/medicine/anatomical_structure']
# Knutsford 0.09835 3.794 [u'/location/uk_civil_parish', u'/location/citytown', u'/location/location', u'/location/dated_location', u'/location/administrative_division', u'/location/statistical_region']
# Coefficient 0.04405 1.08 []
# Restitution 0.0613 1.071 []
# Biology 0.5386 16.93 [u'/people/professional_field', u'/book/book_subject', u'/education/department', u'/media_common/literary_genre', u'/internet/website_category', u'/book/periodical_subject', u'/media_common/media_genre', u'/award/award_discipline', u'/education/field_of_study']
# Deformation (mechanics) 0.1767 4.402 []
# Anatomical terms of location 0.2682 1.387 []
# Deformation (mechanics) 0.1767 4.402 []
# Biology 0.5386 16.93 [u'/people/professional_field', u'/book/book_subject', u'/education/department', u'/media_common/literary_genre', u'/internet/website_category', u'/book/periodical_subject', u'/media_common/media_genre', u'/award/award_discipline', u'/education/field_of_study']
# Behavior 0.3229 1.02 [u'/media_common/quotation_subject', u'/book/book_subject', u'/education/field_of_study']
# 0.00199999999999999999992 0 0.5 []
# Deformation (mechanics) 0.1767 4.402 []
# Behavior 0.3229 1.02 [u'/media_common/quotation_subject', u'/book/book_subject', u'/education/field_of_study']
# Behavior 0.3229 1.02 [u'/media_common/quotation_subject', u'/book/book_subject', u'/education/field_of_study']
# Tide 0.5446 1.104 [u'/book/book_subject']
# Histology 0.2172 9.089 [u'/book/book_subject', u'/education/field_of_study']
# John Tukey 0.2377 5.156 [u'/people/person', u'/book/author', u'/symbols/name_source', u'/award/award_winner', u'/people/deceased_person', u'/influence/influence_node', u'/education/academic']
# Cartilage 0.6715 10.63 [u'/medicine/anatomical_structure']
