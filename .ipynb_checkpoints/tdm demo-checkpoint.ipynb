# %% [markdown]
# # How to use CORE API as your data provider in common TDM tasks

# %% [markdown]
# # A small CORE API client
#
# Nothing like a full CORE API client like the one for java that covers all the functionalities of CORE API (https://github.com/oacore/oacore4j). Yet, is a simple wrapper, essentially a class that crafts URLs and with the use of urllib fetches the content of that URL

# %% [markdown]
# Keep an eye in http://github.com/oacore more clients / modules / bundles for other programming languages coming up.

# %%
from urllib2 import urlopen
from urllib import urlencode
from urllib import quote_plus
from urllib import quote
# import urllib.parse
import json
import pprint

class CoreApiClient:

    def __init__(self, endpoint, api_key):
        self.endpoint = endpoint
        self.api_key = api_key
        #defaults
        self.pagesize = 100
        self.page = 1

    def parse_response(self, decoded):
        res = []
        for item in decoded['data']:
            doi = None
            if 'identifiers' in item:
                for identifier in item['identifiers']:
                    if identifier and identifier.startswith('doi:'):
                        doi = identifier
                        break
            res.append([item['title'], doi])
        return res

    def request_url(self, url):
        response = urlopen(url)
        html = response.read()
        return html

    def get_method_query_request_url(self,method,query,fullText,page):
        if (fullText):
            fullText = 'true'
        else:
            fullText = 'false'
        params = {
            'apiKey':self.api_key,
            'page':page,
            'pageSize':self.pagesize,
            'fulltext':fullText
        }
        return self.endpoint + method + '/' + quote_plus(query) + '?' + urlencode(params)

    def get_up_to_20_pages_of_query(self,method,query,fulltext):
        url = self.get_method_query_request_url(method,query,fulltext,1)
        all_articles=[]
        resp = self.request_url(url)
        result = json.loads(resp.decode('utf-8'))
        all_articles.append(result)
        if (result['totalHits']>100):
            numOfPages = int(result['totalHits']/self.pagesize)  #rounds down
            if (numOfPages>20):
                numOfPages=20
            for i in range(2,numOfPages):
                url = self.get_method_query_request_url(method,query,False,i)
                print(url)
                resp =self.request_url(url)
                all_articles.append(json.loads(resp.decode('utf-8')))
        return all_articles
    
    def get_repository_articles_fulltext_as_dict(self,repository_id):
        return ""
    
    def get_search_repository_request_url(self,repoQuery,page=1,pageSize=10):
        params={
            'apiKey':self.api_key,
            'page':page,
            'pageSize':pageSize
        }
        return self.endpoint + "/repositories/search/"+quote_plus(repoQuery)+'?'+urlencode(params)
    
    def search_repository_ids_by_name(self,repoName):
        discoverRepoUrl = self.get_search_repository_request_url(repoName)
        resp = self.request_url(discoverRepoUrl)
        result = json.loads(resp.decode('utf-8'))
        for item in result['data']:
            if 'name' in item:
                name = item['name']
            if 'id' in item:
                id = item['id']
            repos[id]=name
        return repos
    
    def get_count_articles_of_repository_url(self,repoId,withFullText):
        ft = 'false'
        if(withFullText):
            ft = 'true'
                
        params = {
            'apiKey':self.api_key,
            'fulltext':ft
        }    
        return self.endpoint + "/articles/search/repositories.id:"+repoId+'?'+urlencode(params)
    
    def count_articles_of_repository(self,repoId,withFullText=False):
        countArticlesOfRepoUrl = self.get_count_articles_of_repository_url(repoId,withFullText)
        print(countArticlesOfRepoUrl)
        resp = self.request_url(countArticlesOfRepoUrl)
        result = json.loads(resp.decode('utf-8'))
        return result['totalHits']
    
    def get_url_of_download_articles_of_repository(self,repoId,fullText,page,pageSize):
        params={
            'apiKey':self.api_key,
            'page':page,
            'pageSize':pageSize,
            'fulltext':fullText
               }
        return self.endpoint + "/articles/search/repositories.id:"+str(repoId)+'?'+urlencode(params)
    
    def download_articles_of_repository(self, repoId, fulltext=True, page=1, pageSize=100):
        url = self.get_url_of_download_articles_of_repository(repoId,fulltext,page,pageSize)
        all_articles=[]
        resp = self.request_url(url)
        result = json.loads(resp.decode('utf-8'))
        if (result['totalHits']>100):
            numOfPages = int(result['totalHits']/self.pagesize)  #rounds down
            if (numOfPages>5):
                numOfPages=5
            for i in range(2,numOfPages):
                url = self.get_url_of_download_articles_of_repository(repoId,fulltext,page,pageSize)
                print(url)
                resp =self.request_url(url)
                all_articles.append(json.loads(resp.decode('utf-8')))
        return all_articles
    
    def get_core_article_by_id(self,core_id,fulltext=False):
        ft='false'
        if (fulltext):
            ft='true'
        params={
            'apiKey':self.api_key,
            'fulltext':ft
        }
        url = self.endpoint + '/articles/get/'+str(core_id)+'?'+urlencode(params)
        print(url)
        resp = self.request_url(url)
        result = json.loads(resp.decode('utf-8'))
        if (result['data']):
            return result['data']
        else:
            return ""
        return ""
    
    def get_core_article_by_doi(self,doi,fulltext=False):
        ft='false'
        if (fulltext):
            ft='true'
        query = "\""+doi+"\""
        params={
            'apiKey':self.api_key,
            'fulltext':ft
        }
        url = self.endpoint + '/articles/search/doi:'+quote(query)+'?'+urlencode(params)
        resp = self.request_url(url)
        result = json.loads(resp.decode('utf-8'))
        if (result['totalHits']>=1):
            return result['data'][0]
        else:
            return ""

# %% [markdown]
# ## Register your api key

# %% [markdown]
# Here: https://core.ac.uk/api-keys/register
#
# It takes literally 2 min
#
# .. and that if you are slow

# %% [markdown]
# ## Explore CORE API
#
# https://core.ac.uk/services#api
#
# Play with the live console (swagger/openAPI)
#
# https://core.ac.uk/docs/

# %% [markdown]
# ### Play with CORE API from this notebook

# %%
'''
Initialise parameters
'''
# init 
endpoint = 'https://core.ac.uk/api-v2'

'''
********************************************
Add your own api key below
'''
api_key =""
# or get it from a config file
file = open("api_key.secret","r") 
api_key=file.read()
api_key=api_key.strip()
'''
********************************************
'''
'''
Create your api object
'''
api = CoreApiClient(endpoint,api_key)

# %%
print (api.get_core_article_by_id(42,True))
# Out:
# https://core.ac.uk/api-v2/articles/get/42?fulltext=true&apiKey=btYj73TKGQahoUzL41yHANnJVeClvPIX
# ---------------------------------------------------------------------------
# BadStatusLine                             Traceback (most recent call last)
# <ipython-input-31-350c92d089bb> in <module>()
# ----> 1 print (api.get_core_article_by_id(42,True))
#
# <ipython-input-14-848c31ed6e2b> in get_core_article_by_id(self, core_id, fulltext)
#     139         url = self.endpoint + '/articles/get/'+str(core_id)+'?'+urlencode(params)
#     140         print(url)
# --> 141         resp = self.request_url(url)
#     142         result = json.loads(resp.decode('utf-8'))
#     143         if (result['data']):
#
# <ipython-input-14-848c31ed6e2b> in request_url(self, url)
#      29
#      30     def request_url(self, url):
# ---> 31         response = urlopen(url)
#      32         html = response.read()
#      33         return html
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/urllib2.pyc in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     152     else:
#     153         opener = _opener
# --> 154     return opener.open(url, data, timeout)
#     155
#     156 def install_opener(opener):
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/urllib2.pyc in open(self, fullurl, data, timeout)
#     429             req = meth(req)
#     430
# --> 431         response = self._open(req, data)
#     432
#     433         # post-process response
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/urllib2.pyc in _open(self, req, data)
#     447         protocol = req.get_type()
#     448         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 449                                   '_open', req)
#     450         if result:
#     451             return result
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/urllib2.pyc in _call_chain(self, chain, kind, meth_name, *args)
#     407             func = getattr(handler, meth_name)
#     408
# --> 409             result = func(*args)
#     410             if result is not None:
#     411                 return result
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/urllib2.pyc in https_open(self, req)
#    1238         def https_open(self, req):
#    1239             return self.do_open(httplib.HTTPSConnection, req,
# -> 1240                 context=self._context)
#    1241
#    1242         https_request = AbstractHTTPHandler.do_request_
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/urllib2.pyc in do_open(self, http_class, req, **http_conn_args)
#    1192
#    1193         try:
# -> 1194             h.request(req.get_method(), req.get_selector(), req.data, headers)
#    1195         except socket.error, err: # XXX what error?
#    1196             h.close()
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/httplib.pyc in request(self, method, url, body, headers)
#    1051     def request(self, method, url, body=None, headers={}):
#    1052         """Send a complete request to the server."""
# -> 1053         self._send_request(method, url, body, headers)
#    1054
#    1055     def _set_content_length(self, body, method):
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/httplib.pyc in _send_request(self, method, url, body, headers)
#    1091         for hdr, value in headers.iteritems():
#    1092             self.putheader(hdr, value)
# -> 1093         self.endheaders(body)
#    1094
#    1095     def getresponse(self, buffering=False):
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/httplib.pyc in endheaders(self, message_body)
#    1047         else:
#    1048             raise CannotSendHeader()
# -> 1049         self._send_output(message_body)
#    1050
#    1051     def request(self, method, url, body=None, headers={}):
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/httplib.pyc in _send_output(self, message_body)
#     891             msg += message_body
#     892             message_body = None
# --> 893         self.send(msg)
#     894         if message_body is not None:
#     895             #message_body was not a string (i.e. it is a file) and
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/httplib.pyc in send(self, data)
#     853         if self.sock is None:
#     854             if self.auto_open:
# --> 855                 self.connect()
#     856             else:
#     857                 raise NotConnected()
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/httplib.pyc in connect(self)
#    1264             "Connect to a host on a given (SSL) port."
#    1265
# -> 1266             HTTPConnection.connect(self)
#    1267
#    1268             if self._tunnel_host:
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/httplib.pyc in connect(self)
#     833
#     834         if self._tunnel_host:
# --> 835             self._tunnel()
#     836
#     837     def close(self):
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/httplib.pyc in _tunnel(self)
#     810         response = self.response_class(self.sock, strict = self.strict,
#     811                                        method = self._method)
# --> 812         (version, code, message) = response._read_status()
#     813
#     814         if code != 200:
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/httplib.pyc in _read_status(self)
#     415             # Presumably, the server closed the connection before
#     416             # sending a valid response.
# --> 417             raise BadStatusLine(line)
#     418         try:
#     419             [version, status, reason] = line.split(None, 2)
#
# BadStatusLine: ''

# %%
'''
Fetch an article by DOI
'''

doi="10.1016/j.nuclphysb.2015.11.012"
print(api.get_core_article_by_doi(doi,True))
# Out:
# ---------------------------------------------------------------------------
# BadStatusLine                             Traceback (most recent call last)
# <ipython-input-19-94e655f00491> in <module>()
#       4
#       5 doi="10.1016/j.nuclphysb.2015.11.012"
# ----> 6 print(api.get_core_article_by_doi(doi,True))
#
# <ipython-input-14-848c31ed6e2b> in get_core_article_by_doi(self, doi, fulltext)
#     157         }
#     158         url = self.endpoint + '/articles/search/doi:'+quote(query)+'?'+urlencode(params)
# --> 159         resp = self.request_url(url)
#     160         result = json.loads(resp.decode('utf-8'))
#     161         if (result['totalHits']>=1):
#
# <ipython-input-14-848c31ed6e2b> in request_url(self, url)
#      29
#      30     def request_url(self, url):
# ---> 31         response = urlopen(url)
#      32         html = response.read()
#      33         return html
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/urllib2.pyc in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     152     else:
#     153         opener = _opener
# --> 154     return opener.open(url, data, timeout)
#     155
#     156 def install_opener(opener):
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/urllib2.pyc in open(self, fullurl, data, timeout)
#     429             req = meth(req)
#     430
# --> 431         response = self._open(req, data)
#     432
#     433         # post-process response
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/urllib2.pyc in _open(self, req, data)
#     447         protocol = req.get_type()
#     448         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 449                                   '_open', req)
#     450         if result:
#     451             return result
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/urllib2.pyc in _call_chain(self, chain, kind, meth_name, *args)
#     407             func = getattr(handler, meth_name)
#     408
# --> 409             result = func(*args)
#     410             if result is not None:
#     411                 return result
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/urllib2.pyc in https_open(self, req)
#    1238         def https_open(self, req):
#    1239             return self.do_open(httplib.HTTPSConnection, req,
# -> 1240                 context=self._context)
#    1241
#    1242         https_request = AbstractHTTPHandler.do_request_
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/urllib2.pyc in do_open(self, http_class, req, **http_conn_args)
#    1192
#    1193         try:
# -> 1194             h.request(req.get_method(), req.get_selector(), req.data, headers)
#    1195         except socket.error, err: # XXX what error?
#    1196             h.close()
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/httplib.pyc in request(self, method, url, body, headers)
#    1051     def request(self, method, url, body=None, headers={}):
#    1052         """Send a complete request to the server."""
# -> 1053         self._send_request(method, url, body, headers)
#    1054
#    1055     def _set_content_length(self, body, method):
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/httplib.pyc in _send_request(self, method, url, body, headers)
#    1091         for hdr, value in headers.iteritems():
#    1092             self.putheader(hdr, value)
# -> 1093         self.endheaders(body)
#    1094
#    1095     def getresponse(self, buffering=False):
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/httplib.pyc in endheaders(self, message_body)
#    1047         else:
#    1048             raise CannotSendHeader()
# -> 1049         self._send_output(message_body)
#    1050
#    1051     def request(self, method, url, body=None, headers={}):
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/httplib.pyc in _send_output(self, message_body)
#     891             msg += message_body
#     892             message_body = None
# --> 893         self.send(msg)
#     894         if message_body is not None:
#     895             #message_body was not a string (i.e. it is a file) and
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/httplib.pyc in send(self, data)
#     853         if self.sock is None:
#     854             if self.auto_open:
# --> 855                 self.connect()
#     856             else:
#     857                 raise NotConnected()
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/httplib.pyc in connect(self)
#    1264             "Connect to a host on a given (SSL) port."
#    1265
# -> 1266             HTTPConnection.connect(self)
#    1267
#    1268             if self._tunnel_host:
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/httplib.pyc in connect(self)
#     833
#     834         if self._tunnel_host:
# --> 835             self._tunnel()
#     836
#     837     def close(self):
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/httplib.pyc in _tunnel(self)
#     810         response = self.response_class(self.sock, strict = self.strict,
#     811                                        method = self._method)
# --> 812         (version, code, message) = response._read_status()
#     813
#     814         if code != 200:
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/httplib.pyc in _read_status(self)
#     415             # Presumably, the server closed the connection before
#     416             # sending a valid response.
# --> 417             raise BadStatusLine(line)
#     418         try:
#     419             [version, status, reason] = line.split(None, 2)
#
# BadStatusLine: ''

# %%
doi="10.1016/j.nuclphysb.2015.11.111111111"
print(api.get_core_article_by_doi(doi))

# %%
'''
Fetch an article by core ID
'''
id=42
#just metadata
api.get_core_article_by_id(id)
# Out:
# https://core.ac.uk/api-v2/articles/get/42?fulltext=false&apiKey=20hIsS1F5j4D2C2iXrg4Wxf7VTp4Xt1j
# {u'authors': [u'Bell, Simon', u'Christina, Ann'],
#  u'contributors': [],
#  u'datePublished': u'2006-02',
#  u'description': u'This paper sets out some observations arising from on-going research into the use of systemic methods in the planning of complex projects within the National Health Service (NHS) in Staffordshire and Shropshire in the UK. This brief paper sets out the main reasons for the application of systemic approaches, the nature of the methodologies put in place and some of the outcomes and reflections of those involved in the various workshops. Whilst not attempting to be definitive in our conclusions, the authors believe that the results of the application of systemic methods by Health and Care professionals show a range of strengths going forward',
#  u'fulltextIdentifier': u'https://core.ac.uk/download/pdf/42.pdf',
#  u'id': u'42',
#  u'identifiers': [u'oai:open.ac.uk.OAI2:108', None],
#  u'language': {u'code': u'en', u'id': 9, u'name': u'English'},
#  u'oai': u'oai:open.ac.uk.OAI2:108',
#  u'relations': [],
#  u'repositories': [{u'citationCount': 0,
#    u'citationDoiCount': 0,
#    u'citationFilesDb': 0,
#    u'citationWithDocCount': 0,
#    u'crawlingLimit': 0,
#    u'databaseDeletedPdfCount': 0,
#    u'databaseDeletedRecordCount': 0,
#    u'databaseIndexCount': 0,
#    u'databasePdfCount': 0,
#    u'databasePdfLinkCount': 0,
#    u'databaseRecordCount': 0,
#    u'databaseTextCount': 0,
#    u'databaseTextNotDeletedCount': 0,
#    u'description': None,
#    u'disabled': False,
#    u'documentDoiCount': 0,
#    u'documentDoiWithFulltextCount': 0,
#    u'hardDriveCitationFiles': 0,
#    u'hardDriveDeletedPdfCount': 0,
#    u'hardDriveDeletedTextCount': 0,
#    u'hardDrivePdfCount': 0,
#    u'hardDrivePdfSize': 0,
#    u'hardDriveTextCount': 0,
#    u'id': u'86',
#    u'indexJournalCount': 0,
#    u'indexRecordCount': 0,
#    u'indexTextCount': 0,
#    u'indexTextCountDB': 0,
#    u'indexTextNotDeletedCount': 0,
#    u'indexedDisabledDB': 0,
#    u'indexedPdfDB': 0,
#    u'journal': None,
#    u'journalMetadataAge': None,
#    u'journalMetadataExtractionDate': None,
#    u'journalMetadataSize': 0,
#    u'lastUpdateTime': None,
#    u'metadataAge': None,
#    u'metadataAlloweInIndexCount': 0,
#    u'metadataDeletedInIndexCount': 0,
#    u'metadataDeletedRecordCount': 0,
#    u'metadataDisabledInIndexCount': 0,
#    u'metadataExtractionDate': None,
#    u'metadataFormat': None,
#    u'metadataInIndexCount': 0,
#    u'metadataLinkCount': 0,
#    u'metadataOnlyIndex': 0,
#    u'metadataRecordCount': 0,
#    u'metadataSize': 0,
#    u'name': u'Open Research Online',
#    u'nrUpdates': 0,
#    u'openDoarId': 0,
#    u'pdfStatus': None,
#    u'physicalName': u'noname',
#    u'repositoryLocation': None,
#    u'software': None,
#    u'source': None,
#    u'uri': None,
#    u'uriJournals': None}],
#  u'subjects': [],
#  u'title': u'Applying Systemic Project Management Approaches for the UK National Health Service',
#  u'topics': [],
#  u'types': [],
#  u'year': 2006}

# %%
#with full text
api.get_core_article_by_id(id,True)
# Out:
# https://core.ac.uk/api-v2/articles/get/42?fulltext=true&apiKey=20hIsS1F5j4D2C2iXrg4Wxf7VTp4Xt1j
# {u'authors': [u'Bell, Simon', u'Christina, Ann'],
#  u'contributors': [],
#  u'datePublished': u'2006-02',
#  u'description': u'This paper sets out some observations arising from on-going research into the use of systemic methods in the planning of complex projects within the National Health Service (NHS) in Staffordshire and Shropshire in the UK. This brief paper sets out the main reasons for the application of systemic approaches, the nature of the methodologies put in place and some of the outcomes and reflections of those involved in the various workshops. Whilst not attempting to be definitive in our conclusions, the authors believe that the results of the application of systemic methods by Health and Care professionals show a range of strengths going forward',
#  u'fullText': u'Open Research Online\nThe Open University\u2019s repository of research publications\nand other research outputs\nApplying Systemic Project Management Approaches\nfor the UK National Health Service\nJournal Article\nHow to cite:\nBell, Simon and Christina, Ann (2006). Applying Systemic Project Management Approaches for the\nUK National Health Service. Systemic Practice and Action Research, 19(1), pp. 27\u201343.\nFor guidance on citations see FAQs.\nc\xa9 [not recorded]\nVersion: [not recorded]\nLink(s) to article on publisher\u2019s website:\nhttp://dx.doi.org/doi:10.1007/s11213-005-9002-4\nCopyright and Moral Rights for the articles on this site are retained by the individual authors and/or other copy-\nright owners. For more information on Open Research Online\u2019s data policy on reuse of materials please consult\nthe policies page.\noro.open.ac.uk\n 1\nApplying Systemic Project Management Approaches for the \nUK National Health Service1 \n \nDr. Simon Bell Ann Christina \nOpen Systems Research Group Head of Professional Development for \nSocial Care \nSystems Discipline Kent County Council.  \nOpen University Brenchley House, BH-2 Training \nMilton Keynes 123 - 135 Week Street \nMK7 6AA Maidstone ME14 1RF \ns.g.bell@open.ac.uk Ann.christina@kent.gov.uk  \n \n \nAbstract \nThis paper sets out some observations arising from on-going research into the use of \nsystemic methods in the planning of complex projects within the National Health \nService (NHS) in Staffordshire and Shropshire in the UK.  \nThis brief paper sets out the main reasons for the application of systemic approaches, \nthe nature of the methodologies put in place and some of the outcomes and reflections \nof those involved in the various workshops. \nWhilst not attempting to be definitive in our conclusions, the authors believe that the \nresults of the application of systemic methods by Health and Care professionals show \na range of strengths going forward.  \n \nKeywords: \nSystemic, planning, project management.  \n \n \nAccepted for Systemic Practice and Action Research 2006, Vol. 19 \n                                              \n1 Published with the kind permission of Staffordshire and Shropshire Workforce Development \nDirectorate. \n 2\nContextual Background to the Study \nThe background to the study described in this paper is the modernisation of the health \nand social care workforces (numerously documented but see: McNulty and Ferlie \n2002). More specifically, this paper arises from the experiences of the application of \nsystemic approaches to workforce re-modelling following the establishment of the \nnew role of Associate Director Workforce Development (ADWD) (Health and Social \nCare Integration) for the Shropshire and Staffordshire Workforce Development \nConfederation. The post was funded by the NHS but the host employer was one of the \nfour Local Authority Social Services Departments within the boundaries of the \nShropshire and Staffordshire Strategic Health Authority. The paper sets out \npractitioner and client notes on the selection and use of systemic methods applied to \nassist care professionals meet their evolving needs to manage complexity in their \nworking environment. In this paper the reflections of the commissioning client and \nthe main consultant/ researcher are included, both in order to provide an accurate \naccount of the training/ induction process for systems methods, and also as a means to \nprovide the reader with a sense of the practical issues which arise from such \nsituations.  \n \nThe care workforce is in a climate of continuous change, invoking wide scale \nrethinking on almost all aspects of its use and development (for a comprehensive \ndiscussion of key issues see: Davies 2003). The NHS workforce for the Staffordshire \nand Shropshire area (the focus of this paper) is 35,000 and the social care workforce is \nestimated to be nearly as great but largely employed outside the Social Servi ...
#  u'fulltextIdentifier': u'https://core.ac.uk/download/pdf/42.pdf',
#  u'id': u'42',
#  u'identifiers': [u'oai:open.ac.uk.OAI2:108', None],
#  u'language': {u'code': u'en', u'id': 9, u'name': u'English'},
#  u'oai': u'oai:open.ac.uk.OAI2:108',
#  u'relations': [],
#  u'repositories': [{u'citationCount': 0,
#    u'citationDoiCount': 0,
#    u'citationFilesDb': 0,
#    u'citationWithDocCount': 0,
#    u'crawlingLimit': 0,
#    u'databaseDeletedPdfCount': 0,
#    u'databaseDeletedRecordCount': 0,
#    u'databaseIndexCount': 0,
#    u'databasePdfCount': 0,
#    u'databasePdfLinkCount': 0,
#    u'databaseRecordCount': 0,
#    u'databaseTextCount': 0,
#    u'databaseTextNotDeletedCount': 0,
#    u'description': None,
#    u'disabled': False,
#    u'documentDoiCount': 0,
#    u'documentDoiWithFulltextCount': 0,
#    u'hardDriveCitationFiles': 0,
#    u'hardDriveDeletedPdfCount': 0,
#    u'hardDriveDeletedTextCount': 0,
#    u'hardDrivePdfCount': 0,
#    u'hardDrivePdfSize': 0,
#    u'hardDriveTextCount': 0,
#    u'id': u'86',
#    u'indexJournalCount': 0,
#    u'indexRecordCount': 0,
#    u'indexTextCount': 0,
#    u'indexTextCountDB': 0,
#    u'indexTextNotDeletedCount': 0,
#    u'indexedDisabledDB': 0,
#    u'indexedPdfDB': 0,
#    u'journal': None,
#    u'journalMetadataAge': None,
#    u'journalMetadataExtractionDate': None,
#    u'journalMetadataSize': 0,
#    u'lastUpdateTime': None,
#    u'metadataAge': None,
#    u'metadataAlloweInIndexCount': 0,
#    u'metadataDeletedInIndexCount': 0,
#    u'metadataDeletedRecordCount': 0,
#    u'metadataDisabledInIndexCount': 0,
#    u'metadataExtractionDate': None,
#    u'metadataFormat': None,
#    u'metadataInIndexCount': 0,
#    u'metadataLinkCount': 0,
#    u'metadataOnlyIndex': 0,
#    u'metadataRecordCount': 0,
#    u'metadataSize': 0,
#    u'name': u'Open Research Online',
#    u'nrUpdates': 0,
#    u'openDoarId': 0,
#    u'pdfStatus': None,
#    u'physicalName': u'noname',
#    u'repositoryLocation': None,
#    u'software': None,
#    u'source': None,
#    u'uri': None,
#    u'uriJournals': None}],
#  u'subjects': [],
#  u'title': u'Applying Systemic Project Management Approaches for the UK National Health Service',
#  u'topics': [],
#  u'types': [],
#  u'year': 2006}

# %% [markdown]
# # Now, let's do some NLP

# %%
import nltk
nltk.download("punkt")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-14-cfab64fb3fb3> in <module>()
# ----> 1 import nltk
#       2 nltk.download("punkt")
#
# ImportError: No module named nltk

# %%
'''
In case you don;t have nltk - uncomment and run
'''
# !pip install nltk
import nltk
# Out:
# Collecting nltk
#   Using cached nltk-3.2.4.tar.gz
# Requirement already satisfied: six in /Library/Python/2.7/site-packages (from nltk)
# Building wheels for collected packages: nltk
# done
#   Stored in directory: /Users/mc26486/Library/Caches/pip/wheels/79/8b/2a/b2da7fce57a1fd9b20b08fa8800c83b6fde62af9e880722e29
# Successfully built nltk
# Installing collected packages: nltk
# Successfully installed nltk-3.2.4

# %%
from nltk.probability import FreqDist
from nltk.corpus import treebank
'''
in case any of the above complains, you need to download the corresponding corpora by executing:
nltk.download()
'''
# Out:
# '\nin case any of the above complains, you need to download the corresponding corpora by executing:\nnltk.download()\n'

# %%
articleText = api.get_core_article_by_id(42,True)['fullText']
articleText
# Out:
# https://core.ac.uk/api-v2/articles/get/42?fulltext=true&apiKey=btYj73TKGQahoUzL41yHANnJVeClvPIX
# u'Open Research Online\nThe Open University\u2019s repository of research publications\nand other research outputs\nApplying Systemic Project Management Approaches\nfor the UK National Health Service\nJournal Article\nHow to cite:\nBell, Simon and Christina, Ann (2006). Applying Systemic Project Management Approaches for the\nUK National Health Service. Systemic Practice and Action Research, 19(1), pp. 27\u201343.\nFor guidance on citations see FAQs.\nc\xa9 [not recorded]\nVersion: [not recorded]\nLink(s) to article on publisher\u2019s website:\nhttp://dx.doi.org/doi:10.1007/s11213-005-9002-4\nCopyright and Moral Rights for the articles on this site are retained by the individual authors and/or other copy-\nright owners. For more information on Open Research Online\u2019s data policy on reuse of materials please consult\nthe policies page.\noro.open.ac.uk\n 1\nApplying Systemic Project Management Approaches for the \nUK National Health Service1 \n \nDr. Simon Bell Ann Christina \nOpen Systems Research Group Head of Professional Development for \nSocial Care \nSystems Discipline Kent County Council.  \nOpen University Brenchley House, BH-2 Training \nMilton Keynes 123 - 135 Week Street \nMK7 6AA Maidstone ME14 1RF \ns.g.bell@open.ac.uk Ann.christina@kent.gov.uk  \n \n \nAbstract \nThis paper sets out some observations arising from on-going research into the use of \nsystemic methods in the planning of complex projects within the National Health \nService (NHS) in Staffordshire and Shropshire in the UK.  \nThis brief paper sets out the main reasons for the application of systemic approaches, \nthe nature of the methodologies put in place and some of the outcomes and reflections \nof those involved in the various workshops. \nWhilst not attempting to be definitive in our conclusions, the authors believe that the \nresults of the application of systemic methods by Health and Care professionals show \na range of strengths going forward.  \n \nKeywords: \nSystemic, planning, project management.  \n \n \nAccepted for Systemic Practice and Action Research 2006, Vol. 19 \n                                              \n1 Published with the kind permission of Staffordshire and Shropshire Workforce Development \nDirectorate. \n 2\nContextual Background to the Study \nThe background to the study described in this paper is the modernisation of the health \nand social care workforces (numerously documented but see: McNulty and Ferlie \n2002). More specifically, this paper arises from the experiences of the application of \nsystemic approaches to workforce re-modelling following the establishment of the \nnew role of Associate Director Workforce Development (ADWD) (Health and Social \nCare Integration) for the Shropshire and Staffordshire Workforce Development \nConfederation. The post was funded by the NHS but the host employer was one of the \nfour Local Authority Social Services Departments within the boundaries of the \nShropshire and Staffordshire Strategic Health Authority. The paper sets out \npractitioner and client notes on the selection and use of systemic methods applied to \nassist care professionals meet their evolving needs to manage complexity in their \nworking environment. In this paper the reflections of the commissioning client and \nthe main consultant/ researcher are included, both in order to provide an accurate \naccount of the training/ induction process for systems methods, and also as a means to \nprovide the reader with a sense of the practical issues which arise from such \nsituations.  \n \nThe care workforce is in a climate of continuous change, invoking wide scale \nrethinking on almost all aspects of its use and development (for a comprehensive \ndiscussion of key issues see: Davies 2003). The NHS workforce for the Staffordshire \nand Shropshire area (the focus of this paper) is 35,000 and the social care workforce is \nestimated to be nearly as great but largely employed outside the Social Services \nDepartme ...

# %% [markdown]
# ## Sentence segmentation

# %%
'''
Let's split the text into sentences:
'''
sentences = nltk.sent_tokenize(articleText)
sentences
# Out:
# [u'Open Research Online\nThe Open University\u2019s repository of research publications\nand other research outputs\nApplying Systemic Project Management Approaches\nfor the UK National Health Service\nJournal Article\nHow to cite:\nBell, Simon and Christina, Ann (2006).',
#  u'Applying Systemic Project Management Approaches for the\nUK National Health Service.',
#  u'Systemic Practice and Action Research, 19(1), pp.',
#  u'27\u201343.',
#  u'For guidance on citations see FAQs.',
#  u'c\xa9 [not recorded]\nVersion: [not recorded]\nLink(s) to article on publisher\u2019s website:\nhttp://dx.doi.org/doi:10.1007/s11213-005-9002-4\nCopyright and Moral Rights for the articles on this site are retained by the individual authors and/or other copy-\nright owners.',
#  u'For more information on Open Research Online\u2019s data policy on reuse of materials please consult\nthe policies page.',
#  u'oro.open.ac.uk\n 1\nApplying Systemic Project Management Approaches for the \nUK National Health Service1 \n \nDr. Simon Bell Ann Christina \nOpen Systems Research Group Head of Professional Development for \nSocial Care \nSystems Discipline Kent County Council.',
#  u'Open University Brenchley House, BH-2 Training \nMilton Keynes 123 - 135 Week Street \nMK7 6AA Maidstone ME14 1RF \ns.g.bell@open.ac.uk Ann.christina@kent.gov.uk  \n \n \nAbstract \nThis paper sets out some observations arising from on-going research into the use of \nsystemic methods in the planning of complex projects within the National Health \nService (NHS) in Staffordshire and Shropshire in the UK.',
#  u'This brief paper sets out the main reasons for the application of systemic approaches, \nthe nature of the methodologies put in place and some of the outcomes and reflections \nof those involved in the various workshops.',
#  u'Whilst not attempting to be definitive in our conclusions, the authors believe that the \nresults of the application of systemic methods by Health and Care professionals show \na range of strengths going forward.',
#  u'Keywords: \nSystemic, planning, project management.',
#  u'Accepted for Systemic Practice and Action Research 2006, Vol.',
#  u'19 \n                                              \n1 Published with the kind permission of Staffordshire and Shropshire Workforce Development \nDirectorate.',
#  u'2\nContextual Background to the Study \nThe background to the study described in this paper is the modernisation of the health \nand social care workforces (numerously documented but see: McNulty and Ferlie \n2002).',
#  u'More specifically, this paper arises from the experiences of the application of \nsystemic approaches to workforce re-modelling following the establishment of the \nnew role of Associate Director Workforce Development (ADWD) (Health and Social \nCare Integration) for the Shropshire and Staffordshire Workforce Development \nConfederation.',
#  u'The post was funded by the NHS but the host employer was one of the \nfour Local Authority Social Services Departments within the boundaries of the \nShropshire and Staffordshire Strategic Health Authority.',
#  u'The paper sets out \npractitioner and client notes on the selection and use of systemic methods applied to \nassist care professionals meet their evolving needs to manage complexity in their \nworking environment.',
#  u'In this paper the reflections of the commissioning client and \nthe main consultant/ researcher are included, both in order to provide an accurate \naccount of the training/ induction process for systems methods, and also as a means to \nprovide the reader with a sense of the practical issues which arise from such \nsituations.',
#  u'The care workforce is in a climate of continuous change, invoking wide scale \nrethinking on almost all aspects of its use and development (for a comprehensive \ndiscussion of key issues see: Davies 2003).',
#  u'The NHS workforce for the Staffordshire \nand Shropshire area (the focus of this paper) is 35,000 and the social care workforce is \nestimated to be nearly as great but largely employed outside the Social Services \nDepartments.',
#  u'Rather, it is supplied by hundreds of different private and charitable \nbusiness employers (these organisations face their own, related challenges, see: \nHarris, Cairns et al.',
#  u'2004).',
#  u'The ADWD post was expected to work at the interface \nbetween the NHS and the social care sector on workforce development issues.',
#  u'Shropshire and Staffordshire Workforce Development Confederation was established \nin April 2001 to take forward local strategies in support of the national plan for \nmodernisation of the health and social care workforce.',
#  u'Its formation was part of the \nNHS restructuring of Regional Authorities which devolved budgets and \ncommissioning power to these confederations across the country.',
#  u'In 2004 the \n 3\nWorkforce Development Confederations in England were integrated into each of the \n28 Strategic Health Authorities adding another dimension to the latter\u2019s performance \nmanagement role which had been constantly expanding since they had been brought \ninto being in 2002.',
#  u'In the Shropshire and Staffordshire area this meant that the Confederation was now to \nbecome the Workforce Development Directorate (or WDD) of the Shropshire and \nStaffordshire Strategic Health Authority alongside Directorates for Service \nImprovement, Health Strategy, and Performance and Finance.',
#  u'The WDD was tasked \nwith ensuring the local implementation of national policy.',
#  u'Further, and developing \nfrom this role, there is an expectation that the WDD is also performance managing \nHuman Resource (HR) improvement aspects of the work of the Health Trusts in line \nwith Department of Health (DoH) requirements.',
#  u'This is alongside the continuing \nmulti-million pound commissioning role for university provision of health \nprofessional programmes and funding of secondment to these.',
#  u'Problem issues abound for the WDD to manage.',
#  u'Problems of data shortage on vital \nteams within the NHS are well documented (see, for example: Stubbings and Scott \n200; Editorial 2004), the development of decentralised teams working at local level \nseems patchy at best (Deeming 2004), and leadership training and effectiveness \nremains critical (e.g.',
#  u'see: Hewison and Griffiths 2004; Kristina 2004), yet the goal of \nflexible workforces, responding to need flexible and autonomous ways remains the \nphilosophers stone (For a wider discussion on this see: Huselid, Becker et al.',
#  u'2005) \n \nIn the case of Staffordshire and Shropshire, the WDD had a specific need in the \ndevelopment of capacity in the use of a range of management techniques.',
#  u'The \nadvertisement for the post of ADWD implies as much:  \n\u201cyou will play a key role in modernising service delivery through the effective \nintegration of social care and health workforce development strategies, initiatives and \nprocesses.',
#  u'The task is both enormous and multi-faceted.',
#  u'What we\u2019re working to \nachieve is not only an understanding of functional processes and the skills \ndemonstrated by the current workforce to deliver services, but a specification of the \nskill sets required to deliver evolving, emerging and future service models.\u201d \n(Guardian newspaper, June 2001) \n 4\nThe need for the application of systemic processes and methods in the further \ndevelopment of the WDD remit was also clear:  \n\u201cIn describing you as the Social Care guru in the WDC, we need to make one point \nabsolutely clear: this is not the time or place for professional advocacy.',
#  u'The whole \npoint is to get away from old pitfalls  - demarcation, adversarial budgeting, territorial \nthinking \u2013 and build on the essential elements in the make up of multi-skilled teams\u201d \nThis systemic quality is further emphasised in following sections, including:  \n \n\u201cTo take forward the integration of modernisation of the Health and Social Care \nworkforce through the development of integrated workforce planning and \ndevelopment between the NHS and Social Care; scoping the potential for reducing \ndemarcation, changing working practices and roles and initiating projects to produce \nchange; initiating joint reforms in health and social care education and development at \npre and post qualification levels.\u201d   \n(Guardian newspaper, June 2001) \n \nFollowing her appointment, the remit for multi-skilled teams initiating projects, \navoiding old demarcations and adversarial/ territorial thinking was recognised by Ann \nas demonstrating an implicit need for systemic processes.',
#  u'Such processes impose \nresponsibilities and rigours on the organisation.',
#  u'As Charlotte Roberts and Jennifer \nKemeny have argued:  \n"You can\'t redesign your system .. by dividing it into parts; everyone must look at the \nwhole together.',
#  u"Thus you can't practice systems thinking as an individual - not \nbecause the discipline itself is difficult, but because good results in a complex system \ndepend on bringing in as many perspectives as possible.",
#  u'As you put together a team, \nmake sure all necessary functions are represented, and gain clearance from top \nmanagement to propose cross-functional solutions, regardless of sensitivities and \npolitics" \n(Senge, Ross et al.',
#  u'1994 pages 91 - 92)  \n \n 5\n \nFigure 1.',
#  u'Members of the WDD using Soft Systems Methodology \n \nApproaching the Systemic Intervention \nOn appointment, Ann reflected on the progress being made towards team building \ngoals.',
#  u'In an early reflective email to a colleague she said:  \n\u201cIt is vital to have vision and big picture thinking ability; promoting a whole systems \napproach while breaking down the steps to change into something manageable and \nnot too threatening.\u201d \n(Private email from ADWD to a colleague in the WDD) \n \nIn a separate email Ann developed her thinking as follows: \n"I said that I thought my workplan would mean being a programme manager for a \nrange of projects where I would bring stakeholders together and be a catalyst for them \nto achieve something that they were wanting to do but didn\u2019t know how.',
#  u'Two years \nlater that is exactly what I have been doing."',
#  u'(Private email from ADWD to a colleague in the WDD) \n \nIn order to provide such a catalyst, Ann approached Simon, to develop a structured, \nsystemic intervention in the form of training need support and private mentoring.',
#  u'At \nthis time the needs of the WDD were clearly stated to be focused on six key items in \nthe terms of engagement: \n 6\n1.',
#  u'A series of training events on systemic approaches to project scoping, planning and \nmanagement.',
#  u'2.',
#  u'Actual project work to be used as the basis for all training \n3.',
#  u'A Team based approach to be applied to all training \n4.',
#  u'The workshop process to be completed 1st October 2003.',
#  u'5.',
#  u'That there be a tailored half day for the Executive team.',
#  u'6.',
#  u'That on-going support via email be provided.',
#  u'The nature of the approach to be adopted had been agreed to be systemic, \nparticipatory methods.',
#  u'Ann had gained some first hand experience of systemic/ \nparticipative approaches at a range of workshops run in London and Rugby and was \nconvinced that they could meet the needs of Professionals in Staffordshire and \nShropshire.',
#  u'In her own words:  \n"To be able to advise on the scope for integrated workforce planning and development \nand the methods by which that may be achieved could itself only be achieved through \nwide consultation with stakeholders.',
#  u'Harvesting these stakeholders\u2019 ideas whilst \ngaining an understanding of their opinions, their perspectives and their assumptions \nwould be an important task en route".',
#  u'The main requirement from the WDD was to provide Health and Care Professionals \nwith transferable skills to aid in the planning, management and development of \nprojects across the region.',
#  u'It was judged that systemic methods, focused on problem \nsolving, would be most likely to meet this need.',
#  u'Again, in Ann\'s words: \n"To be able to advise on reforms in working practices and on new roles which may be \nachievable and provide up to date intelligence on key workforce issues in health and \nsocial care I would need to create the kind of mini-environments that would enable \nme to qualitatively research through using \u201cparticipative inquiry\u201d and health and care \npathway and process analysis a shared understanding with those involved across \ndiffering cultures of the current working practices and roles being applied by the NHS \nand Social Care organisations" \n \nIt had further been agreed between Ann and Simon that all training involve real \nprojects in the pipeline.',
#  u'This would help to concentrate participants minds and \n 7\nprovide an acid test for the methods - they would need to be seen to be delivering real \nresults during the learning process.',
#  u'Teams were engaged in the work.',
#  u'Again this was intended to allow cooperating \ncolleagues to learn common methods and provide strength in depth to on-going use of \nthe methods.',
#  u"No one person should be seen as being the team 'expert', all should \ncontribute and participate.",
#  u'Ann notes on this point: \n"The notion of \u201creleasing\u201d ideas about the transformations needed and the way to \nachieve them to bring about the required modernisation from different people in all \nparts of the affected workforce has been very motivating".',
#  u'The original completion date was September 2003.',
#  u'This was subsequently shifted to \nOctober and then later to early 2004.',
#  u'The executive team would also be introduced to the method.',
#  u'This was a crucial plus \nfor the research as it meant that the WDD would gain understanding of the methods \nacross the organisational hierarchy.',
#  u'This is rare in the experience of the authors and \nthe lack of such senior buy-in often means that initiatives lack senior champions later \nin the process.',
#  u'Finally, it was agreed that the process would be supported by email and phone support \nduring the project run-time.',
#  u'This would mean that professionals working on specific, \ncomplex issues could have access to support in the development of their proposals.',
#  u'Methodologies applied \nThe Systems Department at the Open University has been teaching and researching \nwith systemic approaches for over three decades.',
#  u'Although approaches have changed \nand developed over time, one main methodology, applied across undergraduate and \npostgraduate teaching, has been Soft Systems Methodology or SSM.',
#  u'This approach - \nfirst advocated and subsequently developed by Checkland et al (Checkland 1981; \nCheckland and Scholes 1990; Checkland 1994; Checkland 2001) has been included in \nOpen University courses and developed into a distance learning format (Open \nUniversity 1987; Open University 2000).',
#  u'There has been much discussion about the \nuse of SSM (Stowell, Holland et al.',
#  u"1990; Haynes 1995; Jayaratna 1997; Probert \n1998; Flood 2001; Holwell 2001) and it has been applied in a wide variety of contexts \n 8\n- most recently the main author's have turned to the complex field of information \nsystems (Checkland and Holwell 1998).",
#  u'SSM has a range of strengths to advocate its use in the development of project \nplanning and can be seen as an aid to other systemic approaches in encouraging \nimaginative problem solving (see for example: Brookfield 1991; Issacs 1999; Wenger \n1999).',
#  u'From the perspective of the present authors these can be listed as: \n1. a capacity to make use of SSM at a very basic level very quickly - it can be \nadopted rapidly \n2.',
#  u'SSM can be applied in such a way as to provide three outcomes essential for a \nproject: a rich picture of what is, a root definition of what could be and an \nactivity plan or conceptual model of how to get there.',
#  u'3.',
#  u'SSM is best used in a participatory manner by mixed teams of stakeholders.',
#  u'4.',
#  u'SSM is a problem solving approach, it is designed to focus on the kinds of \nsoft, intangible problems which beset organisations like the UK NHS \n5.',
#  u'SSM links well as the front end to more formal methods.',
#  u'This allows user \ngroups to begin their planning with SSM and then move on to more formal \ntechniques.',
#  u'All of these factors keyed in well with the requirements of the WDD as set out in the \nterms of engagement - most specifically for project scoping and early planning.',
#  u'In further developing the project plan, and taking it up to implementation, monitoring \nand evaluation, the Logical Framework Approach or LFA has been applied in a \nvariety of contexts (Coleman 1987; Bell 1998; Baccarini 1999; Kumar and Corbridge \n2002; Biggs and Smith 2003; Crawford 2003; Crawford 2003; Dale 2003) and, as \nwith SSM, has found its way into Open University Systems teaching (Open \nUniversity 1997; Open University 2000; Open University 2004).',
#  u'LFA involves the \ndevelopment of a four by four matrix, containing the main story or the project (the \nnarrative summary), the main assumptions or risks (a key item - often noted as being \nabsent or under-represented in project planning (British Computer Society and Royal \nAcademy of Engineering 2004)) and the means of measuring success in terms of \nperformance, impact, sustainability and strategy \u2013 see Table 1.',
#  u'The LFA can provide a \nsystemic, if highly structured, means to capture the outcomes of SSM.',
#  u'9\nTable 1.',
#  u'The Logical Framework \nNarrative summary \ncolumn \n \nThe Goal of the \npurposeful human \nactivity.',
#  u'Always \nbeyond the project \npurpose.',
#  u'Aspirational \nVerifiable \nindicators \n \nThe goal is \nmeasured by \nqualitative and \nquantitative \nstrategic indicators \nor ST Is \nMeans of \nverification \n \nIndicators can be \nmeasured in by \ndata or by means of \nfocus group/ \nquestionnaire \nAssumptions or \nrisks \n \nThe risks that \nwould mean that \nthe goal was \nunachievable \nThe purpose of the \npurposeful activity: \nincluding details of \nbeneficiaries, \nimplementers, \ntransformation, \nassumption, owners \nand constraints \nThe purpose is \nmeasured by \nqualitative and \nquantitative \nsustainability  \nindicators or SIs \nIndicators can be \nmeasured in by \ndata or by means of \nfocus group/ \nquestionnaire \nThe risks and \nassumptions that \nwould render the \ngoal unrealisable or \nunachievable even \nif this purpose was \nachieved \nThe outputs of the \npurposeful activity:  \nOutput is measured \n\u2013 usually \nquantitatively \u2013 by \nimpact indicators - \nIIs \nIndicators are \nusually measured \nby data or \nquestionnaire \nThe risks and \nassumptions that \nwould render the \npurpose \nunrealisable or \nunachievable even \nif these outputs \nwere achieved \nThe key activities \nfor the purposeful \nactivity \nActivity is \nmeasured \nquantitatively by \nperformance \nindicators \u2013 PIs \nIndicators are \nmeasured by data \nor questionnaire \nThe risks and \nassumptions that \nwould render the \noutputs \nunrealisable or \nunachievable even \nif these activities  \nwere successful  \n \nIn an earlier paper Bell applied this - specifically as a means to explore the outcomes \nof SSM analysis (Bell 2000).',
#  u'Although it is not without numerous critics - and it can \ncertainly be applied in a non-participatory and top-down manner (Gasper 1997; \nGasper 2000), it remains a commonly used method in many difficult and complex \ncontexts.',
#  u'Key to the virtues of LFA are: \n1.',
#  u'It can be applied in context and rapidly \n2.',
#  u'It lends itself to participatory workshops \n3.',
#  u'It can be revised readily \n4. it does not require software or IT solutions.',
#  u'10\n5. it links in to other, even more formal project planning methods if necessary.',
#  u'Again, these five factors all have resonances with the needs of the Directorate.',
#  u'Research Question, Workshops outcomes and participant reflections \nIn May 2003 Ann took a proposal in the form of a discussion paper to the WDD \nExecutive team meeting.',
#  u'They had already approved an experimental day with some \nmembers of the team and Simon Bell to explore the possibilities of the methodologies \nhe could introduce.',
#  u'A key question was, could systemic tools and techniques \neffectively develop the various work streams of the WDD?',
#  u'A recently completed review of the Confederation\u2019s Organisational Structure and \nProcesses had recommended that it needed to build up its project management \napproach.',
#  u"Ann's paper proposed adopting the use of the Logical Framework model for \nproject planning and agreeing other suitable systems for scoping, monitoring, \nreviewing and reporting on all of the project based work being undertaken.",
#  u"On Ann's agenda was the plan to help facilitate these developments for the work \nwhich other members of the Confederation team were responsible for while at the \nsame time helping to ensure that social care and health interface issues were \nprioritised for urgent development using these methods.",
#  u'So, at the instigation of the WDD, a training package for project planning and \ndevelopment was put together which was based upon user-focused variations of SSM \nand LFA.',
#  u'Over a period of eleven months - from April 2003 - May 2004 more than a \ndozen training events took place.',
#  u'Most of the events were either focused on SSM or LFA or, if time allowed - made use \nof both.',
#  u'The user need was paramount and if certain teams needed help with scoping \ntheir specific project, as opposed to planning the detail, then elements of SSM would \nbe applied.',
#  u'It was also notable that, as time progressed, teams began making use of \nkey elements of either methodology, out of sequence, if they thought it would be \nvaluable to them.',
#  u'Following the workshops a random sample of Participants was asked to comment on \nthe value of the various aspects applied.',
#  u'Concerning the overall use of SSM: \n \n 11\nWayne Coombe, Head of Human Resources, Staffordshire Social Care and Health \nmade the following observations:  \n"My experience of Logframe/Soft Systems to date has been very positive \u2026I have \nfound it a useful (yet ultimately simple) technique for pulling together groups of \nindividuals from different organisations (or sub sections of the same organisation).',
#  u'I \nfind that it helps groups who sometimes have significantly contradicting or differing \nviews to reach a consensus on a way forward, yet without any one group or any \nindividual dominating and imposing their own objectives and the experience of \nothers."',
#  u'Figure 2.',
#  u'A rich picture of the workforce planning scenario \n \nColin Harriden, a Social Care Workforce Planner, speaking about a workshop for \nRaising the profile of Workforce Planning in Social Care said that systemic methods:  \n"Enabled a group of senior HR managers in Social Services to work against their \nrelative disempowerment and devise a strategy to promote HR and workforce \nplanning at all levels.',
#  u'The first planned outcome is an event for directorate/CEO level \nto get workforce planning on the agenda and identify champions."',
#  u'When Colin was involved in the use of soft systems with another team he observed: \n 12\n"The soft systems model enabled a large and diverse group of managers to collaborate  \nin developing common themes and purpose."',
#  u'Colin also made use of Logical Frameworks.',
#  u'He says: \n"Log frame created focused energy - identifying key players assumptions and barriers \nto be addressed.',
#  u'Statement seemed broad but led to specific focus."',
#  u'But when working with another team with LFA he observed the problem of handing \non previous work to a new group: He noted: \n"Learning disability workforce strategy - difficult to use an existing log-frame with a \nnew group.',
#  u'.',
#  u'participants need to own the development of the purpose and other \nelements.',
#  u'Side-step to key tasks and barriers helped to re-engage.',
#  u'Generally - the longer you have the more focus and progress towards achievement."',
#  u'Figure 3.',
#  u'Developing a rich picture  \n \n 13\n \nFigure 4.',
#  u'An early root definition for training strategy \nPositive comments came from most participants, but critical issues remained.',
#  u'For \nexample, Fiona Shield, Changing Working Practice Coordinator noted some good \noutcomes from her work \n \n"I have persevered with the logframe and found it useful.',
#  u'\u2026.',
#  u'we ended up with 3 versions - 1 per health economy.',
#  u"Although the groups were \nsmall each logframe had its own 'flavour', which we felt was very important in terms \nof reflecting local ownership and culture.",
#  u'When I informed the SHA Trust Directors \nof Modernisation about this work they asked if I could produce one framework for the \nwhole patch.',
#  u'I did this by informal thematic analysis \u2026 and kept it to the Purpose and \nOutputs with indicators (attached)."',
#  u'However, Fiona had some pithy comments about the use of systemic methods - most \nspecifically Logical Framework in her case:  \n"I keep asking the Trust CWP leads if they are happy with the Logframe and can\'t \nhonestly say that they really understand or utilise it.',
#  u'BUT I find it a very useful \nworking tool to refer back to periodically.',
#  u'I think the main problem is that it quickly \nbecomes out of date in terms of the specific outputs and indicators.',
#  u'I could keep \n 14\nupdating it, but then it would lose the ownership of the wider team.',
#  u'However the 1 \nside of A4 attached is quite an impressive document to cirulate when people ask what \nI do and what CWP is about!!',
#  u'We also use it within the team of CWP facilitators to \nhelp check the direction of current work."',
#  u'More recently, Fiona has added that, the outcome she was looking for was for the \nwork of the role re-designers to become embedded within the work of the Trusts.',
#  u'But \nhow to evaluate if this has been happening and if so if it was the work of her team that \nhas made it happen?',
#  u'What she can prove is that she had measures in place as part of \nthe project plan.',
#  u'The Logframe was the work plan and seemed to provide a very good \nframework to measure themselves against.',
#  u'Revisiting the Logframe as an evaluation \nexercise and using it as a review tool has given a recent added value for Fiona and her \nteam for all the work that went into producing it.',
#  u'They can see where they\u2019ve come \nfrom.',
#  u'As she says:  \n\u201cWe can step back and say: we had something to do and we got on with it\u201d.',
#  u'Figure 5.',
#  u'Tasks and issues arising from a rich picture exercise \n \n 15\nLynne Lewis, NVQ/Learning Account Manager applied Logical Framework approach \nto her project: Moving Forward Together For People With Learning Disability \nLynne comments on the process as follows:  \n"I have used the process of Logical Frameworks for a project to assist with the Skills \nEscalator approach within Learning Disabilities.',
#  u'The process of logical framework \nhas assisted with a systematic approach to achieving a goal.',
#  u'It breaks down tasks into \nbite sized processes, with clear progression to the ultimate goal.',
#  u'The difference from \nmy own personal point of view with this process compared to the average action plan, \nis the thought process behind the bite sized processes.',
#  u'Thought of what could happen, \nand what effect this has on the overall process.',
#  u'An ordinary action plan will inform \nwho does what by when, but does not inform of the contingency plans.',
#  u'My own style \nof learning was assisted by having the dedicated tutor working through the logical \nframework step by step, with a dedicated group, for a common goal.',
#  u'I found a \nprevious session of logical frameworks with a very large group less effective.',
#  u'Figure 6.',
#  u'An activity plan \n \n 16\nJane Rook, (Podiatry Continuous Professional Development), who was lead for the \nWDD and was project managing the development of an agreed system in Shropshire \nand Staffordshire for re-registration of Podiatrists with the Health Professional \nCouncil observed: \n"There is something about having the actual flip chart paper to work from and \n the post it notes that makes the log frame real and living.',
#  u'I have preferred to have \nthese big and creative bits of paper on the wall to work from and the rich picture to \nwork from in terms of further working out how to tackle the unsaid issues.',
#  u'We are almost at the end of the project and the log frame was a timely reminder as we \nwent along of how to plan to achieve specific targets and to keep me on target.',
#  u'Very encouraging to tick off the boxes as I went along .',
#  u'I did write the document up properly but have used this version only to send out to \nprove that I do have a project plan to work to.',
#  u'I think it was a definite focus for the \nsteering group to work to as well They have appreciated that the wider Authority \nworks to this planning process and felt more corporate as a result.',
#  u'All in all it was probably a lot easier than some of the project plans based on \nMicrosoft and Prince systems.',
#  u'Probably appealed to my need for visual clues for my \nlearning style" \nIn private communication Jane has indicated that she would have liked to have used \nthe methodology with the Steering Group right at the beginning of her planning \nprocess but even half way through it was worth doing and proved valuable.',
#  u'Two \nmajor benefits included:  \n\u2022 it enabled the mixed range of different kinds of managers with a diverse \nunderstanding of project management (Prinz, Microsoft etc.)',
#  u'to share one \napproach and secondly  \n\u2022 it enabled really meaningful conversations with all voices being valued as to \nwhat the project was about and whether or not everyone shared the same \nvision.',
#  u'.',
#  u'17\n \nFigure 7.',
#  u'A Logical Framework under development \n \nAnn, as commissioning officer for the workshops observed:  \n"The dimension that has emerged as so powerful for me in this research is the quality \nof the learning that has been going on in the workshops as groups of colleagues \ndiscussed the elements of their project in order to agree the plan."',
#  u'Author Reflections and Conclusions  \nAs already stated, the authors are not making definitive claims for the WDD \nexperience but, recalling our initial research question: "could systemic tools and \ntechniques effectively develop the various work streams of the WDD?',
#  u'", from the \ncomments of participants, and the experiences of the authors some modest claims, \nseeking further testing, can be suggested: \n1.',
#  u'The use of systemic and participatory techniques was greeted by most of those \non the workshops as a relief and a change from their previous experiences of \nsuch events.',
#  u'18\n2.',
#  u"SSM provided teams with the basis to think widely and divergently about their \nwork context and gave them the 'slack' to think differently \n3.",
#  u'Most of those involved in teams which they worked with regularly, found the \nexperience helpful to the deeper understanding of the tasks which they had \nbeen allocated.',
#  u'4.',
#  u'Those who worked in unfamiliar teams found the brainstorming and sharing \ninvolved helpful in their wider understanding of the work of the SSWDD \n5.',
#  u'LFA was seen as being a readily applicable tool for project planning.',
#  u'If these are the positive reflections, some more negative outcomes were: \n1.',
#  u'Small teams seemed to get more from the process than large \n2.',
#  u'The work of one team was not readily understandable or usable to another \n3.',
#  u'The sustainability of the process is a key point.',
#  u'Without renewal and \ncontinued investment in support - some of the good outcomes of the process \ncould dilute over time.',
#  u'In summary, it appears to the authors that some important foundations have been built \nfor essential collaboration to deliver workforce solutions to the challenging task of \ntrying to achieve integrated services in the Staffordshire and Shropshire areas.',
#  u'Most \ncritically, an awareness of the importance of a methodical approach to planning major \nnew initiatives has been raised.',
#  u'19\n \nReferences \nBaccarini, D. (1999).',
#  u'"The Logical Framework Method for Defining Success."',
#  u'Project \nManagement Journal December: 25-32.',
#  u'Bell, S. (1998).',
#  u'"Managing and Learning with Logical Frameworks: the case of an \nMIS Project in China."',
#  u'Human Systems Management 17(1): 15-28.',
#  u'Bell, S. (2000).',
#  u'"Logical Frameworks, Aristotle and Soft Systems: A note on the \norigins, values and uses of Logical Frameworks."',
#  u'Public Administration and \nDevelopment 20(1): 29-31.',
#  u'Biggs, S. and S. Smith (2003).',
#  u'"A Paradox of Learning in Project Cycle Management \nand the Role of Organizational Culture."',
#  u'World Development 31(10): 1743-\n1757.',
#  u'British Computer Society and Royal Academy of Engineering (2004).',
#  u'Projects: the \nway forward.',
#  u'The Computer Bulletin.',
#  u'July: 20-21.',
#  u'Brookfield, S. (1991).',
#  u'Developing Critical Thinkers: Challenging adults to explore \nalternative ways of thinking and acting.',
#  u'New York, Josey-Bass.',
#  u'Checkland, P. (1994).',
#  u'"Systems Theory and Management Thinking."',
#  u'American \nBehavioral Scientist 38(1): 75-83.',
#  u'Checkland, P. (2001).',
#  u'"The Emergent Properties of SSM in Use: A symposium by \nreflective practitioners."',
#  u'Systemic Practice and Action Research 13(6): 799-\n823.',
#  u'Checkland, P. and S. Holwell (1998).',
#  u'Information, Systems and Information Systems: \nMaking sense of the field.',
#  u'Chichester, Wiley.',
#  u'Checkland, P. B.',
#  u'(1981).',
#  u'Systems thinking, Systems  Practise.',
#  u'Chichester, Wiley.',
#  u'Checkland, P. B. and J. Scholes (1990).',
#  u'Soft Systems Methodology in Action.',
#  u'Chichester, Wiley.',
#  u'Coleman, G. (1987).',
#  u'"Logical Framework Approach to the Monitoring and Evaluation \nof Agricultural and Rural Development projects."',
#  u'Project Appraisal Vol.',
#  u'2(No.',
#  u'4): 251-259.',
#  u'Crawford, G. (2003).',
#  u'"Promoting Democracy from Without - Learning from Within."',
#  u'Democratization 10(1): 77-98.',
#  u'Crawford, P. (2003).',
#  u'"Project Monitoring and Evaluation: a method for enhancing the \nefficiency and effectiveness of aid project implementation."',
#  u'International \nJournal of Project Management 21(5): 363-374.',
#  u'Dale, R. (2003).',
#  u'"The Logical Framework: an easy escape, a straightjacket, or a useful \nplanning tool?"',
#  u'Development in Practice 13(1): 57-70.',
#  u'Davies, C. (2003).',
#  u'The Future Health Workforce.',
#  u'London, Palgrave Macmillan.',
#  u'Deeming, C. (2004).',
#  u'"Decentering the NHS: A case study of resource allocation \ndecisions within a health district."',
#  u'Social Policy and Administration 38(1): 57 \n- 73.',
#  u'Editorial (2004).',
#  u'"Commentary.',
#  u'Nurse Workforce Planning in the UK: policies and \nimpact."',
#  u'Journal of Nursing Management 12: 388 - 392.',
#  u'Flood, R. (2001).',
#  u'"A Brief Review of Peter B. Checkland\'s Contribution to Systemic \nThinking."',
#  u'Systmic Practice and Action Research 13(6): 723-732.',
#  u'Gasper, D. (1997).',
#  u'Logical Frameworks - a critical look.',
#  u'Development Studies \nAssociation, University of East Anglia.',
#  u'20\nGasper, D. (2000).',
#  u'"Evaluating the "Logical Framework Approach": Towards \nlearning -orientated development evaluation."',
#  u'Public Administration and \nDevelopment 20(1): 17-28.',
#  u'Harris, M., B. Cairns, et al.',
#  u'(2004).',
#  u'""So Many Tiers, So Many Agendas, So Many \nPots of Money": The challenge of English regionlaization for voluntary and \ncommunity organizations."',
#  u'Social Policy and Administration 38(5): 525 - 541.',
#  u'Haynes, M. (1995).',
#  u'Soft Systems Methodology.',
#  u'Critical Issues in Systems Theory and \nPractice.',
#  u'K. Ellis.',
#  u'New York, Plenum: 251-257.',
#  u'Hewison, A. and M. Griffiths (2004).',
#  u'"Leadership Development in Health Care: A \nword of caution."',
#  u'Journal of Health, Organisation and Management 18(6): 464 \n- 473.',
#  u'Holwell, S. (2001).',
#  u'"Soft Systems Methodology: Other voices."',
#  u'Systemic Practice and \nAction Research 13(6): 773-798.',
#  u'Huselid, M., B. Becker, et al.',
#  u'(2005).',
#  u'The Workforce Scorecard: Managing human \ncapital to execute strategy.',
#  u'New York, Harvard Business School Press.',
#  u'Issacs, W. (1999).',
#  u'Dialogue and the Art of Thinking Together: A pioneering approach \nto communicating in business and in life.',
#  u'London, Doubleday.',
#  u'Jayaratna, N. (1997).',
#  u'Proceedings of the SSM Research Discussion Group Workshop, \nPreston.',
#  u'Kristina, L. G. (2004).',
#  u'"Leadership Processes for Re-Engineering Changes in the \nHealth Care Industry."',
#  u'Journal of Health, Organisation and Management \n18(6): 435 - 446.',
#  u'Kumar, S. and S. Corbridge (2002).',
#  u'"Programmed to Fail?',
#  u'Development Projects and \nthe Politics of Participation."',
#  u'Journal of  Development Studies 39(2): 73-103.',
#  u'McNulty, T. and E. Ferlie (2002).',
#  u'Reengineering Health Care: The complexties of \norganisational transformation.',
#  u'Oxford, Oxford University Press.',
#  u'Open University (1987).',
#  u'T301 - Complexity Management and Change: a systems \napproach.',
#  u'Open University Systems Group.',
#  u'Milton Keynes., The Open \nUniversity Press.',
#  u'Open University (1997).',
#  u'Management Information Systems T843.',
#  u'Milton Keynes, \nOpen University.',
#  u'Open University (2000).',
#  u'T306 Managing Complexity: a systems approach.',
#  u'Milton \nKeynes, Open University.',
#  u'Open University (2004).',
#  u'T851 the Information Systems Toolkit.',
#  u'Milton Keynes, Open \nUniversity.',
#  u'Probert, S. (1998).',
#  u'"A Critical Analysis of Soft Systems Methodology and its \n(Theoretical and Practical  ) Relationship with Phenomenaology."',
#  u'Systemist \n21: 187-207.',
#  u'Senge, P., R. Ross, et al.',
#  u'(1994).',
#  u'The Fifth Discipline Fieldbook: Strategies and tools \nfor building a learning organisation.',
#  u'London, Nicholas Brealey.',
#  u'Stowell, F. A., P. Holland, et al.',
#  u'(1990).',
#  u'"Applications of SSM in Information System \nDesign: some reflections."',
#  u'Journal of Applied Systems Analysis Vol.',
#  u'17: pp.',
#  u'63-69.',
#  u'Stubbings, L. and J. Scott (200).',
#  u'"NHS Workforce Issues: Implications for future \npractice."',
#  u'Journal of Health, Organisation and Management 18(3): 179 - 194.',
#  u'Wenger, E. (1999).',
#  u'Communities of Practice: Learning, meaning and identity.',
#  u'Cambridge, Cambridge University Press.']

# %%
import pprint
pprint.pprint(sentences)
# Out:
# [u'Open Research Online\nThe Open University\u2019s repository of research publications\nand other research outputs\nApplying Systemic Project Management Approaches\nfor the UK National Health Service\nJournal Article\nHow to cite:\nBell, Simon and Christina, Ann (2006).',
#  u'Applying Systemic Project Management Approaches for the\nUK National Health Service.',
#  u'Systemic Practice and Action Research, 19(1), pp.',
#  u'27\u201343.',
#  u'For guidance on citations see FAQs.',
#  u'c\xa9 [not recorded]\nVersion: [not recorded]\nLink(s) to article on publisher\u2019s website:\nhttp://dx.doi.org/doi:10.1007/s11213-005-9002-4\nCopyright and Moral Rights for the articles on this site are retained by the individual authors and/or other copy-\nright owners.',
#  u'For more information on Open Research Online\u2019s data policy on reuse of materials please consult\nthe policies page.',
#  u'oro.open.ac.uk\n 1\nApplying Systemic Project Management Approaches for the \nUK National Health Service1 \n \nDr. Simon Bell Ann Christina \nOpen Systems Research Group Head of Professional Development for \nSocial Care \nSystems Discipline Kent County Council.',
#  u'Open University Brenchley House, BH-2 Training \nMilton Keynes 123 - 135 Week Street \nMK7 6AA Maidstone ME14 1RF \ns.g.bell@open.ac.uk Ann.christina@kent.gov.uk  \n \n \nAbstract \nThis paper sets out some observations arising from on-going research into the use of \nsystemic methods in the planning of complex projects within the National Health \nService (NHS) in Staffordshire and Shropshire in the UK.',
#  u'This brief paper sets out the main reasons for the application of systemic approaches, \nthe nature of the methodologies put in place and some of the outcomes and reflections \nof those involved in the various workshops.',
#  u'Whilst not attempting to be definitive in our conclusions, the authors believe that the \nresults of the application of systemic methods by Health and Care professionals show \na range of strengths going forward.',
#  u'Keywords: \nSystemic, planning, project management.',
#  u'Accepted for Systemic Practice and Action Research 2006, Vol.',
#  u'19 \n                                              \n1 Published with the kind permission of Staffordshire and Shropshire Workforce Development \nDirectorate.',
#  u'2\nContextual Background to the Study \nThe background to the study described in this paper is the modernisation of the health \nand social care workforces (numerously documented but see: McNulty and Ferlie \n2002).',
#  u'More specifically, this paper arises from the experiences of the application of \nsystemic approaches to workforce re-modelling following the establishment of the \nnew role of Associate Director Workforce Development (ADWD) (Health and Social \nCare Integration) for the Shropshire and Staffordshire Workforce Development \nConfederation.',
#  u'The post was funded by the NHS but the host employer was one of the \nfour Local Authority Social Services Departments within the boundaries of the \nShropshire and Staffordshire Strategic Health Authority.',
#  u'The paper sets out \npractitioner and client notes on the selection and use of systemic methods applied to \nassist care professionals meet their evolving needs to manage complexity in their \nworking environment.',
#  u'In this paper the reflections of the commissioning client and \nthe main consultant/ researcher are included, both in order to provide an accurate \naccount of the training/ induction process for systems methods, and also as a means to \nprovide the reader with a sense of the practical issues which arise from such \nsituations.',
#  u'The care workforce is in a climate of continuous change, invoking wide scale \nrethinking on almost all aspects of its use and development (for a comprehensive \ndiscussion of key issues see: Davies 2003).',
#  u'The NHS workforce for the Staffordshire \nand Shropshire area (the focus of this paper) is 35,000 and the social care workforce is \nestimated to be nearly as great but largely employed outside the Social Services \nDepartments.',
#  u'Rather, it is supplied by hundreds of different private and charitable \nbusiness employers (these organisations face their own, related challenges, see: \nHarris, Cairns et al.',
#  u'2004).',
#  u'The ADWD post was expected to work at the interface \nbetween the NHS and the social care sector on workforce development issues.',
#  u'Shropshire and Staffordshire Workforce Development Confederation was established \nin April 2001 to take forward local strategies in support of the national plan for \nmodernisation of the health and social care workforce.',
#  u'Its formation was part of the \nNHS restructuring of Regional Authorities which devolved budgets and \ncommissioning power to these confederations across the country.',
#  u'In 2004 the \n 3\nWorkforce Development Confederations in England were integrated into each of the \n28 Strategic Health Authorities adding another dimension to the latter\u2019s performance \nmanagement role which had been constantly expanding since they had been brought \ninto being in 2002.',
#  u'In the Shropshire and Staffordshire area this meant that the Confederation was now to \nbecome the Workforce Development Directorate (or WDD) of the Shropshire and \nStaffordshire Strategic Health Authority alongside Directorates for Service \nImprovement, Health Strategy, and Performance and Finance.',
#  u'The WDD was tasked \nwith ensuring the local implementation of national policy.',
#  u'Further, and developing \nfrom this role, there is an expectation that the WDD is also performance managing \nHuman Resource (HR) improvement aspects of the work of the Health Trusts in line \nwith Department of Health (DoH) requirements.',
#  u'This is alongside the continuing \nmulti-million pound commissioning role for university provision of health \nprofessional programmes and funding of secondment to these.',
#  u'Problem issues abound for the WDD to manage.',
#  u'Problems of data shortage on vital \nteams within the NHS are well documented (see, for example: Stubbings and Scott \n200; Editorial 2004), the development of decentralised teams working at local level \nseems patchy at best (Deeming 2004), and leadership training and effectiveness \nremains critical (e.g.',
#  u'see: Hewison and Griffiths 2004; Kristina 2004), yet the goal of \nflexible workforces, responding to need flexible and autonomous ways remains the \nphilosophers stone (For a wider discussion on this see: Huselid, Becker et al.',
#  u'2005) \n \nIn the case of Staffordshire and Shropshire, the WDD had a specific need in the \ndevelopment of capacity in the use of a range of management techniques.',
#  u'The \nadvertisement for the post of ADWD implies as much:  \n\u201cyou will play a key role in modernising service delivery through the effective \nintegration of social care and health workforce development strategies, initiatives and \nprocesses.',
#  u'The task is both enormous and multi-faceted.',
#  u'What we\u2019re working to \nachieve is not only an understanding of functional processes and the skills \ndemonstrated by the current workforce to deliver services, but a specification of the \nskill sets required to deliver evolving, emerging and future service models.\u201d \n(Guardian newspaper, June 2001) \n 4\nThe need for the application of systemic processes and methods in the further \ndevelopment of the WDD remit was also clear:  \n\u201cIn describing you as the Social Care guru in the WDC, we need to make one point \nabsolutely clear: this is not the time or place for professional advocacy.',
#  u'The whole \npoint is to get away from old pitfalls  - demarcation, adversarial budgeting, territorial \nthinking \u2013 and build on the essential elements in the make up of multi-skilled teams\u201d \nThis systemic quality is further emphasised in following sections, including:  \n \n\u201cTo take forward the integration of modernisation of the Health and Social Care \nworkforce through the development of integrated workforce planning and \ndevelopment between the NHS and Social Care; scoping the potential for reducing \ndemarcation, changing working practices and roles and initiating projects to produce \nchange; initiating joint reforms in health and social care education and development at \npre and post qualification levels.\u201d   \n(Guardian newspaper, June 2001) \n \nFollowing her appointment, the remit for multi-skilled teams initiating projects, \navoiding old demarcations and adversarial/ territorial thinking was recognised by Ann \nas demonstrating an implicit need for systemic processes.',
#  u'Such processes impose \nresponsibilities and rigours on the organisation.',
#  u'As Charlotte Roberts and Jennifer \nKemeny have argued:  \n"You can\'t redesign your system .. by dividing it into parts; everyone must look at the \nwhole together.',
#  u"Thus you can't practice systems thinking as an individual - not \nbecause the discipline itself is difficult, but because good results in a complex system \ndepend on bringing in as many perspectives as possible.",
#  u'As you put together a team, \nmake sure all necessary functions are represented, and gain clearance from top \nmanagement to propose cross-functional solutions, regardless of sensitivities and \npolitics" \n(Senge, Ross et al.',
#  u'1994 pages 91 - 92)  \n \n 5\n \nFigure 1.',
#  u'Members of the WDD using Soft Systems Methodology \n \nApproaching the Systemic Intervention \nOn appointment, Ann reflected on the progress being made towards team building \ngoals.',
#  u'In an early reflective email to a colleague she said:  \n\u201cIt is vital to have vision and big picture thinking ability; promoting a whole systems \napproach while breaking down the steps to change into something manageable and \nnot too threatening.\u201d \n(Private email from ADWD to a colleague in the WDD) \n \nIn a separate email Ann developed her thinking as follows: \n"I said that I thought my workplan would mean being a programme manager for a \nrange of projects where I would bring stakeholders together and be a catalyst for them \nto achieve something that they were wanting to do but didn\u2019t know how.',
#  u'Two years \nlater that is exactly what I have been doing."',
#  u'(Private email from ADWD to a colleague in the WDD) \n \nIn order to provide such a catalyst, Ann approached Simon, to develop a structured, \nsystemic intervention in the form of training need support and private mentoring.',
#  u'At \nthis time the needs of the WDD were clearly stated to be focused on six key items in \nthe terms of engagement: \n 6\n1.',
#  u'A series of training events on systemic approaches to project scoping, planning and \nmanagement.',
#  u'2.',
#  u'Actual project work to be used as the basis for all training \n3.',
#  u'A Team based approach to be applied to all training \n4.',
#  u'The workshop process to be completed 1st October 2003.',
#  u'5.',
#  u'That there be a tailored half day for the Executive team.',
#  u'6.',
#  u'That on-going support via email be provided.',
#  u'The nature of the approach to be adopted had been agreed to be systemic, \nparticipatory methods.',
#  u'Ann had gained some first hand experience of systemic/ \nparticipative approaches at a range of workshops run in London and Rugby and was \nconvinced that they could meet the needs of Professionals in Staffordshire and \nShropshire.',
#  u'In her own words:  \n"To be able to advise on the scope for integrated workforce planning and development \nand the methods by which that may be achieved could itself only be achieved through \nwide consultation with stakeholders.',
#  u'Harvesting these stakeholders\u2019 ideas whilst \ngaining an understanding of their opinions, their perspectives and their assumptions \nwould be an important task en route".',
#  u'The main requirement from the WDD was to provide Health and Care Professionals \nwith transferable skills to aid in the planning, management and development of \nprojects across the region.',
#  u'It was judged that systemic methods, focused on problem \nsolving, would be most likely to meet this need.',
#  u'Again, in Ann\'s words: \n"To be able to advise on reforms in working practices and on new roles which may be \nachievable and provide up to date intelligence on key workforce issues in health and \nsocial care I would need to create the kind of mini-environments that would enable \nme to qualitatively research through using \u201cparticipative inquiry\u201d and health and care \npathway and process analysis a shared understanding with those involved across \ndiffering cultures of the current working practices and roles being applied by the NHS \nand Social Care organisations" \n \nIt had further been agreed between Ann and Simon that all training involve real \nprojects in the pipeline.',
#  u'This would help to concentrate participants minds and \n 7\nprovide an acid test for the methods - they would need to be seen to be delivering real \nresults during the learning process.',
#  u'Teams were engaged in the work.',
#  u'Again this was intended to allow cooperating \ncolleagues to learn common methods and provide strength in depth to on-going use of \nthe methods.',
#  u"No one person should be seen as being the team 'expert', all should \ncontribute and participate.",
#  u'Ann notes on this point: \n"The notion of \u201creleasing\u201d ideas about the transformations needed and the way to \nachieve them to bring about the required modernisation from different people in all \nparts of the affected workforce has been very motivating".',
#  u'The original completion date was September 2003.',
#  u'This was subsequently shifted to \nOctober and then later to early 2004.',
#  u'The executive team would also be introduced to the method.',
#  u'This was a crucial plus \nfor the research as it meant that the WDD would gain understanding of the methods \nacross the organisational hierarchy.',
#  u'This is rare in the experience of the authors and \nthe lack of such senior buy-in often means that initiatives lack senior champions later \nin the process.',
#  u'Finally, it was agreed that the process would be supported by email and phone support \nduring the project run-time.',
#  u'This would mean that professionals working on specific, \ncomplex issues could have access to support in the development of their proposals.',
#  u'Methodologies applied \nThe Systems Department at the Open University has been teaching and researching \nwith systemic approaches for over three decades.',
#  u'Although approaches have changed \nand developed over time, one main methodology, applied across undergraduate and \npostgraduate teaching, has been Soft Systems Methodology or SSM.',
#  u'This approach - \nfirst advocated and subsequently developed by Checkland et al (Checkland 1981; \nCheckland and Scholes 1990; Checkland 1994; Checkland 2001) has been included in \nOpen University courses and developed into a distance learning format (Open \nUniversity 1987; Open University 2000).',
#  u'There has been much discussion about the \nuse of SSM (Stowell, Holland et al.',
#  u"1990; Haynes 1995; Jayaratna 1997; Probert \n1998; Flood 2001; Holwell 2001) and it has been applied in a wide variety of contexts \n 8\n- most recently the main author's have turned to the complex field of information \nsystems (Checkland and Holwell 1998).",
#  u'SSM has a range of strengths to advocate its use in the development of project \nplanning and can be seen as an aid to other systemic approaches in encouraging \nimaginative problem solving (see for example: Brookfield 1991; Issacs 1999; Wenger \n1999).',
#  u'From the perspective of the present authors these can be listed as: \n1. a capacity to make use of SSM at a very basic level very quickly - it can be \nadopted rapidly \n2.',
#  u'SSM can be applied in such a way as to provide three outcomes essential for a \nproject: a rich picture of what is, a root definition of what could be and an \nactivity plan or conceptual model of how to get there.',
#  u'3.',
#  u'SSM is best used in a participatory manner by mixed teams of stakeholders.',
#  u'4.',
#  u'SSM is a problem solving approach, it is designed to focus on the kinds of \nsoft, intangible problems which beset organisations like the UK NHS \n5.',
#  u'SSM links well as the front end to more formal methods.',
#  u'This allows user \ngroups to begin their planning with SSM and then move on to more formal \ntechniques.',
#  u'All of these factors keyed in well with the requirements of the WDD as set out in the \nterms of engagement - most specifically for project scoping and early planning.',
#  u'In further developing the project plan, and taking it up to implementation, monitoring \nand evaluation, the Logical Framework Approach or LFA has been applied in a \nvariety of contexts (Coleman 1987; Bell 1998; Baccarini 1999; Kumar and Corbridge \n2002; Biggs and Smith 2003; Crawford 2003; Crawford 2003; Dale 2003) and, as \nwith SSM, has found its way into Open University Systems teaching (Open \nUniversity 1997; Open University 2000; Open University 2004).',
#  u'LFA involves the \ndevelopment of a four by four matrix, containing the main story or the project (the \nnarrative summary), the main assumptions or risks (a key item - often noted as being \nabsent or under-represented in project planning (British Computer Society and Royal \nAcademy of Engineering 2004)) and the means of measuring success in terms of \nperformance, impact, sustainability and strategy \u2013 see Table 1.',
#  u'The LFA can provide a \nsystemic, if highly structured, means to capture the outcomes of SSM.',
#  u'9\nTable 1.',
#  u'The Logical Framework \nNarrative summary \ncolumn \n \nThe Goal of the \npurposeful human \nactivity.',
#  u'Always \nbeyond the project \npurpose.',
#  u'Aspirational \nVerifiable \nindicators \n \nThe goal is \nmeasured by \nqualitative and \nquantitative \nstrategic indicators \nor ST Is \nMeans of \nverification \n \nIndicators can be \nmeasured in by \ndata or by means of \nfocus group/ \nquestionnaire \nAssumptions or \nrisks \n \nThe risks that \nwould mean that \nthe goal was \nunachievable \nThe purpose of the \npurposeful activity: \nincluding details of \nbeneficiaries, \nimplementers, \ntransformation, \nassumption, owners \nand constraints \nThe purpose is \nmeasured by \nqualitative and \nquantitative \nsustainability  \nindicators or SIs \nIndicators can be \nmeasured in by \ndata or by means of \nfocus group/ \nquestionnaire \nThe risks and \nassumptions that \nwould render the \ngoal unrealisable or \nunachievable even \nif this purpose was \nachieved \nThe outputs of the \npurposeful activity:  \nOutput is measured \n\u2013 usually \nquantitatively \u2013 by \nimpact indicators - \nIIs \nIndicators are \nusually measured \nby data or \nquestionnaire \nThe risks and \nassumptions that \nwould render the \npurpose \nunrealisable or \nunachievable even \nif these outputs \nwere achieved \nThe key activities \nfor the purposeful \nactivity \nActivity is \nmeasured \nquantitatively by \nperformance \nindicators \u2013 PIs \nIndicators are \nmeasured by data \nor questionnaire \nThe risks and \nassumptions that \nwould render the \noutputs \nunrealisable or \nunachievable even \nif these activities  \nwere successful  \n \nIn an earlier paper Bell applied this - specifically as a means to explore the outcomes \nof SSM analysis (Bell 2000).',
#  u'Although it is not without numerous critics - and it can \ncertainly be applied in a non-participatory and top-down manner (Gasper 1997; \nGasper 2000), it remains a commonly used method in many difficult and complex \ncontexts.',
#  u'Key to the virtues of LFA are: \n1.',
#  u'It can be applied in context and rapidly \n2.',
#  u'It lends itself to participatory workshops \n3.',
#  u'It can be revised readily \n4. it does not require software or IT solutions.',
#  u'10\n5. it links in to other, even more formal project planning methods if necessary.',
#  u'Again, these five factors all have resonances with the needs of the Directorate.',
#  u'Research Question, Workshops outcomes and participant reflections \nIn May 2003 Ann took a proposal in the form of a discussion paper to the WDD \nExecutive team meeting.',
#  u'They had already approved an experimental day with some \nmembers of the team and Simon Bell to explore the possibilities of the methodologies \nhe could introduce.',
#  u'A key question was, could systemic tools and techniques \neffectively develop the various work streams of the WDD?',
#  u'A recently completed review of the Confederation\u2019s Organisational Structure and \nProcesses had recommended that it needed to build up its project management \napproach.',
#  u"Ann's paper proposed adopting the use of the Logical Framework model for \nproject planning and agreeing other suitable systems for scoping, monitoring, \nreviewing and reporting on all of the project based work being undertaken.",
#  u"On Ann's agenda was the plan to help facilitate these developments for the work \nwhich other members of the Confederation team were responsible for while at the \nsame time helping to ensure that social care and health interface issues were \nprioritised for urgent development using these methods.",
#  u'So, at the instigation of the WDD, a training package for project planning and \ndevelopment was put together which was based upon user-focused variations of SSM \nand LFA.',
#  u'Over a period of eleven months - from April 2003 - May 2004 more than a \ndozen training events took place.',
#  u'Most of the events were either focused on SSM or LFA or, if time allowed - made use \nof both.',
#  u'The user need was paramount and if certain teams needed help with scoping \ntheir specific project, as opposed to planning the detail, then elements of SSM would \nbe applied.',
#  u'It was also notable that, as time progressed, teams began making use of \nkey elements of either methodology, out of sequence, if they thought it would be \nvaluable to them.',
#  u'Following the workshops a random sample of Participants was asked to comment on \nthe value of the various aspects applied.',
#  u'Concerning the overall use of SSM: \n \n 11\nWayne Coombe, Head of Human Resources, Staffordshire Social Care and Health \nmade the following observations:  \n"My experience of Logframe/Soft Systems to date has been very positive \u2026I have \nfound it a useful (yet ultimately simple) technique for pulling together groups of \nindividuals from different organisations (or sub sections of the same organisation).',
#  u'I \nfind that it helps groups who sometimes have significantly contradicting or differing \nviews to reach a consensus on a way forward, yet without any one group or any \nindividual dominating and imposing their own objectives and the experience of \nothers."',
#  u'Figure 2.',
#  u'A rich picture of the workforce planning scenario \n \nColin Harriden, a Social Care Workforce Planner, speaking about a workshop for \nRaising the profile of Workforce Planning in Social Care said that systemic methods:  \n"Enabled a group of senior HR managers in Social Services to work against their \nrelative disempowerment and devise a strategy to promote HR and workforce \nplanning at all levels.',
#  u'The first planned outcome is an event for directorate/CEO level \nto get workforce planning on the agenda and identify champions."',
#  u'When Colin was involved in the use of soft systems with another team he observed: \n 12\n"The soft systems model enabled a large and diverse group of managers to collaborate  \nin developing common themes and purpose."',
#  u'Colin also made use of Logical Frameworks.',
#  u'He says: \n"Log frame created focused energy - identifying key players assumptions and barriers \nto be addressed.',
#  u'Statement seemed broad but led to specific focus."',
#  u'But when working with another team with LFA he observed the problem of handing \non previous work to a new group: He noted: \n"Learning disability workforce strategy - difficult to use an existing log-frame with a \nnew group.',
#  u'.',
#  u'participants need to own the development of the purpose and other \nelements.',
#  u'Side-step to key tasks and barriers helped to re-engage.',
#  u'Generally - the longer you have the more focus and progress towards achievement."',
#  u'Figure 3.',
#  u'Developing a rich picture  \n \n 13\n \nFigure 4.',
#  u'An early root definition for training strategy \nPositive comments came from most participants, but critical issues remained.',
#  u'For \nexample, Fiona Shield, Changing Working Practice Coordinator noted some good \noutcomes from her work \n \n"I have persevered with the logframe and found it useful.',
#  u'\u2026.',
#  u'we ended up with 3 versions - 1 per health economy.',
#  u"Although the groups were \nsmall each logframe had its own 'flavour', which we felt was very important in terms \nof reflecting local ownership and culture.",
#  u'When I informed the SHA Trust Directors \nof Modernisation about this work they asked if I could produce one framework for the \nwhole patch.',
#  u'I did this by informal thematic analysis \u2026 and kept it to the Purpose and \nOutputs with indicators (attached)."',
#  u'However, Fiona had some pithy comments about the use of systemic methods - most \nspecifically Logical Framework in her case:  \n"I keep asking the Trust CWP leads if they are happy with the Logframe and can\'t \nhonestly say that they really understand or utilise it.',
#  u'BUT I find it a very useful \nworking tool to refer back to periodically.',
#  u'I think the main problem is that it quickly \nbecomes out of date in terms of the specific outputs and indicators.',
#  u'I could keep \n 14\nupdating it, but then it would lose the ownership of the wider team.',
#  u'However the 1 \nside of A4 attached is quite an impressive document to cirulate when people ask what \nI do and what CWP is about!!',
#  u'We also use it within the team of CWP facilitators to \nhelp check the direction of current work."',
#  u'More recently, Fiona has added that, the outcome she was looking for was for the \nwork of the role re-designers to become embedded within the work of the Trusts.',
#  u'But \nhow to evaluate if this has been happening and if so if it was the work of her team that \nhas made it happen?',
#  u'What she can prove is that she had measures in place as part of \nthe project plan.',
#  u'The Logframe was the work plan and seemed to provide a very good \nframework to measure themselves against.',
#  u'Revisiting the Logframe as an evaluation \nexercise and using it as a review tool has given a recent added value for Fiona and her \nteam for all the work that went into producing it.',
#  u'They can see where they\u2019ve come \nfrom.',
#  u'As she says:  \n\u201cWe can step back and say: we had something to do and we got on with it\u201d.',
#  u'Figure 5.',
#  u'Tasks and issues arising from a rich picture exercise \n \n 15\nLynne Lewis, NVQ/Learning Account Manager applied Logical Framework approach \nto her project: Moving Forward Together For People With Learning Disability \nLynne comments on the process as follows:  \n"I have used the process of Logical Frameworks for a project to assist with the Skills \nEscalator approach within Learning Disabilities.',
#  u'The process of logical framework \nhas assisted with a systematic approach to achieving a goal.',
#  u'It breaks down tasks into \nbite sized processes, with clear progression to the ultimate goal.',
#  u'The difference from \nmy own personal point of view with this process compared to the average action plan, \nis the thought process behind the bite sized processes.',
#  u'Thought of what could happen, \nand what effect this has on the overall process.',
#  u'An ordinary action plan will inform \nwho does what by when, but does not inform of the contingency plans.',
#  u'My own style \nof learning was assisted by having the dedicated tutor working through the logical \nframework step by step, with a dedicated group, for a common goal.',
#  u'I found a \nprevious session of logical frameworks with a very large group less effective.',
#  u'Figure 6.',
#  u'An activity plan \n \n 16\nJane Rook, (Podiatry Continuous Professional Development), who was lead for the \nWDD and was project managing the development of an agreed system in Shropshire \nand Staffordshire for re-registration of Podiatrists with the Health Professional \nCouncil observed: \n"There is something about having the actual flip chart paper to work from and \n the post it notes that makes the log frame real and living.',
#  u'I have preferred to have \nthese big and creative bits of paper on the wall to work from and the rich picture to \nwork from in terms of further working out how to tackle the unsaid issues.',
#  u'We are almost at the end of the project and the log frame was a timely reminder as we \nwent along of how to plan to achieve specific targets and to keep me on target.',
#  u'Very encouraging to tick off the boxes as I went along .',
#  u'I did write the document up properly but have used this version only to send out to \nprove that I do have a project plan to work to.',
#  u'I think it was a definite focus for the \nsteering group to work to as well They have appreciated that the wider Authority \nworks to this planning process and felt more corporate as a result.',
#  u'All in all it was probably a lot easier than some of the project plans based on \nMicrosoft and Prince systems.',
#  u'Probably appealed to my need for visual clues for my \nlearning style" \nIn private communication Jane has indicated that she would have liked to have used \nthe methodology with the Steering Group right at the beginning of her planning \nprocess but even half way through it was worth doing and proved valuable.',
#  u'Two \nmajor benefits included:  \n\u2022 it enabled the mixed range of different kinds of managers with a diverse \nunderstanding of project management (Prinz, Microsoft etc.)',
#  u'to share one \napproach and secondly  \n\u2022 it enabled really meaningful conversations with all voices being valued as to \nwhat the project was about and whether or not everyone shared the same \nvision.',
#  u'.',
#  u'17\n \nFigure 7.',
#  u'A Logical Framework under development \n \nAnn, as commissioning officer for the workshops observed:  \n"The dimension that has emerged as so powerful for me in this research is the quality \nof the learning that has been going on in the workshops as groups of colleagues \ndiscussed the elements of their project in order to agree the plan."',
#  u'Author Reflections and Conclusions  \nAs already stated, the authors are not making definitive claims for the WDD \nexperience but, recalling our initial research question: "could systemic tools and \ntechniques effectively develop the various work streams of the WDD?',
#  u'", from the \ncomments of participants, and the experiences of the authors some modest claims, \nseeking further testing, can be suggested: \n1.',
#  u'The use of systemic and participatory techniques was greeted by most of those \non the workshops as a relief and a change from their previous experiences of \nsuch events.',
#  u'18\n2.',
#  u"SSM provided teams with the basis to think widely and divergently about their \nwork context and gave them the 'slack' to think differently \n3.",
#  u'Most of those involved in teams which they worked with regularly, found the \nexperience helpful to the deeper understanding of the tasks which they had \nbeen allocated.',
#  u'4.',
#  u'Those who worked in unfamiliar teams found the brainstorming and sharing \ninvolved helpful in their wider understanding of the work of the SSWDD \n5.',
#  u'LFA was seen as being a readily applicable tool for project planning.',
#  u'If these are the positive reflections, some more negative outcomes were: \n1.',
#  u'Small teams seemed to get more from the process than large \n2.',
#  u'The work of one team was not readily understandable or usable to another \n3.',
#  u'The sustainability of the process is a key point.',
#  u'Without renewal and \ncontinued investment in support - some of the good outcomes of the process \ncould dilute over time.',
#  u'In summary, it appears to the authors that some important foundations have been built \nfor essential collaboration to deliver workforce solutions to the challenging task of \ntrying to achieve integrated services in the Staffordshire and Shropshire areas.',
#  u'Most \ncritically, an awareness of the importance of a methodical approach to planning major \nnew initiatives has been raised.',
#  u'19\n \nReferences \nBaccarini, D. (1999).',
#  u'"The Logical Framework Method for Defining Success."',
#  u'Project \nManagement Journal December: 25-32.',
#  u'Bell, S. (1998).',
#  u'"Managing and Learning with Logical Frameworks: the case of an \nMIS Project in China."',
#  u'Human Systems Management 17(1): 15-28.',
#  u'Bell, S. (2000).',
#  u'"Logical Frameworks, Aristotle and Soft Systems: A note on the \norigins, values and uses of Logical Frameworks."',
#  u'Public Administration and \nDevelopment 20(1): 29-31.',
#  u'Biggs, S. and S. Smith (2003).',
#  u'"A Paradox of Learning in Project Cycle Management \nand the Role of Organizational Culture."',
#  u'World Development 31(10): 1743-\n1757.',
#  u'British Computer Society and Royal Academy of Engineering (2004).',
#  u'Projects: the \nway forward.',
#  u'The Computer Bulletin.',
#  u'July: 20-21.',
#  u'Brookfield, S. (1991).',
#  u'Developing Critical Thinkers: Challenging adults to explore \nalternative ways of thinking and acting.',
#  u'New York, Josey-Bass.',
#  u'Checkland, P. (1994).',
#  u'"Systems Theory and Management Thinking."',
#  u'American \nBehavioral Scientist 38(1): 75-83.',
#  u'Checkland, P. (2001).',
#  u'"The Emergent Properties of SSM in Use: A symposium by \nreflective practitioners."',
#  u'Systemic Practice and Action Research 13(6): 799-\n823.',
#  u'Checkland, P. and S. Holwell (1998).',
#  u'Information, Systems and Information Systems: \nMaking sense of the field.',
#  u'Chichester, Wiley.',
#  u'Checkland, P. B.',
#  u'(1981).',
#  u'Systems thinking, Systems  Practise.',
#  u'Chichester, Wiley.',
#  u'Checkland, P. B. and J. Scholes (1990).',
#  u'Soft Systems Methodology in Action.',
#  u'Chichester, Wiley.',
#  u'Coleman, G. (1987).',
#  u'"Logical Framework Approach to the Monitoring and Evaluation \nof Agricultural and Rural Development projects."',
#  u'Project Appraisal Vol.',
#  u'2(No.',
#  u'4): 251-259.',
#  u'Crawford, G. (2003).',
#  u'"Promoting Democracy from Without - Learning from Within."',
#  u'Democratization 10(1): 77-98.',
#  u'Crawford, P. (2003).',
#  u'"Project Monitoring and Evaluation: a method for enhancing the \nefficiency and effectiveness of aid project implementation."',
#  u'International \nJournal of Project Management 21(5): 363-374.',
#  u'Dale, R. (2003).',
#  u'"The Logical Framework: an easy escape, a straightjacket, or a useful \nplanning tool?"',
#  u'Development in Practice 13(1): 57-70.',
#  u'Davies, C. (2003).',
#  u'The Future Health Workforce.',
#  u'London, Palgrave Macmillan.',
#  u'Deeming, C. (2004).',
#  u'"Decentering the NHS: A case study of resource allocation \ndecisions within a health district."',
#  u'Social Policy and Administration 38(1): 57 \n- 73.',
#  u'Editorial (2004).',
#  u'"Commentary.',
#  u'Nurse Workforce Planning in the UK: policies and \nimpact."',
#  u'Journal of Nursing Management 12: 388 - 392.',
#  u'Flood, R. (2001).',
#  u'"A Brief Review of Peter B. Checkland\'s Contribution to Systemic \nThinking."',
#  u'Systmic Practice and Action Research 13(6): 723-732.',
#  u'Gasper, D. (1997).',
#  u'Logical Frameworks - a critical look.',
#  u'Development Studies \nAssociation, University of East Anglia.',
#  u'20\nGasper, D. (2000).',
#  u'"Evaluating the "Logical Framework Approach": Towards \nlearning -orientated development evaluation."',
#  u'Public Administration and \nDevelopment 20(1): 17-28.',
#  u'Harris, M., B. Cairns, et al.',
#  u'(2004).',
#  u'""So Many Tiers, So Many Agendas, So Many \nPots of Money": The challenge of English regionlaization for voluntary and \ncommunity organizations."',
#  u'Social Policy and Administration 38(5): 525 - 541.',
#  u'Haynes, M. (1995).',
#  u'Soft Systems Methodology.',
#  u'Critical Issues in Systems Theory and \nPractice.',
#  u'K. Ellis.',
#  u'New York, Plenum: 251-257.',
#  u'Hewison, A. and M. Griffiths (2004).',
#  u'"Leadership Development in Health Care: A \nword of caution."',
#  u'Journal of Health, Organisation and Management 18(6): 464 \n- 473.',
#  u'Holwell, S. (2001).',
#  u'"Soft Systems Methodology: Other voices."',
#  u'Systemic Practice and \nAction Research 13(6): 773-798.',
#  u'Huselid, M., B. Becker, et al.',
#  u'(2005).',
#  u'The Workforce Scorecard: Managing human \ncapital to execute strategy.',
#  u'New York, Harvard Business School Press.',
#  u'Issacs, W. (1999).',
#  u'Dialogue and the Art of Thinking Together: A pioneering approach \nto communicating in business and in life.',
#  u'London, Doubleday.',
#  u'Jayaratna, N. (1997).',
#  u'Proceedings of the SSM Research Discussion Group Workshop, \nPreston.',
#  u'Kristina, L. G. (2004).',
#  u'"Leadership Processes for Re-Engineering Changes in the \nHealth Care Industry."',
#  u'Journal of Health, Organisation and Management \n18(6): 435 - 446.',
#  u'Kumar, S. and S. Corbridge (2002).',
#  u'"Programmed to Fail?',
#  u'Development Projects and \nthe Politics of Participation."',
#  u'Journal of  Development Studies 39(2): 73-103.',
#  u'McNulty, T. and E. Ferlie (2002).',
#  u'Reengineering Health Care: The complexties of \norganisational transformation.',
#  u'Oxford, Oxford University Press.',
#  u'Open University (1987).',
#  u'T301 - Complexity Management and Change: a systems \napproach.',
#  u'Open University Systems Group.',
#  u'Milton Keynes., The Open \nUniversity Press.',
#  u'Open University (1997).',
#  u'Management Information Systems T843.',
#  u'Milton Keynes, \nOpen University.',
#  u'Open University (2000).',
#  u'T306 Managing Complexity: a systems approach.',
#  u'Milton \nKeynes, Open University.',
#  u'Open University (2004).',
#  u'T851 the Information Systems Toolkit.',
#  u'Milton Keynes, Open \nUniversity.',
#  u'Probert, S. (1998).',
#  u'"A Critical Analysis of Soft Systems Methodology and its \n(Theoretical and Practical  ) Relationship with Phenomenaology."',
#  u'Systemist \n21: 187-207.',
#  u'Senge, P., R. Ross, et al.',
#  u'(1994).',
#  u'The Fifth Discipline Fieldbook: Strategies and tools \nfor building a learning organisation.',
#  u'London, Nicholas Brealey.',
#  u'Stowell, F. A., P. Holland, et al.',
#  u'(1990).',
#  u'"Applications of SSM in Information System \nDesign: some reflections."',
#  u'Journal of Applied Systems Analysis Vol.',
#  u'17: pp.',
#  u'63-69.',
#  u'Stubbings, L. and J. Scott (200).',
#  u'"NHS Workforce Issues: Implications for future \npractice."',
#  u'Journal of Health, Organisation and Management 18(3): 179 - 194.',
#  u'Wenger, E. (1999).',
#  u'Communities of Practice: Learning, meaning and identity.',
#  u'Cambridge, Cambridge University Press.']

# %%
'''
Couldn't we just split(".") ??
'''
wrong_sentences = articleText.split(".")
len(wrong_sentences)
# Out:
# 396

# %%
len(sentences)
# Out:
# 327

# %%
'''
Aparently not, e.g. see this sentence
'''
sentences[5]
# Out:
# u'c\xa9 [not recorded]\nVersion: [not recorded]\nLink(s) to article on publisher\u2019s website:\nhttp://dx.doi.org/doi:10.1007/s11213-005-9002-4\nCopyright and Moral Rights for the articles on this site are retained by the individual authors and/or other copy-\nright owners.'

# %%
sentences[5].split(".")
# Out:
# [u'c\xa9 [not recorded]\nVersion: [not recorded]\nLink(s) to article on publisher\u2019s website:\nhttp://dx',
#  u'doi',
#  u'org/doi:10',
#  u'1007/s11213-005-9002-4\nCopyright and Moral Rights for the articles on this site are retained by the individual authors and/or other copy-\nright owners',
#  u'']

# %% [markdown]
# It incorrectly breaks down to more than one (5) sentences.

# %% [markdown]
# Let's break further to tokens (words):

# %%
tokenized_sentences = [nltk.word_tokenize(sentence) for sentence in sentences]
tokenized_sentences[1:100]
# Out:
# [[u'Applying',
#   u'Systemic',
#   u'Project',
#   u'Management',
#   u'Approaches',
#   u'for',
#   u'the',
#   u'UK',
#   u'National',
#   u'Health',
#   u'Service',
#   u'.'],
#  [u'Systemic',
#   u'Practice',
#   u'and',
#   u'Action',
#   u'Research',
#   u',',
#   u'19',
#   u'(',
#   u'1',
#   u')',
#   u',',
#   u'pp',
#   u'.'],
#  [u'27\u201343', u'.'],
#  [u'For', u'guidance', u'on', u'citations', u'see', u'FAQs', u'.'],
#  [u'c\xa9',
#   u'[',
#   u'not',
#   u'recorded',
#   u']',
#   u'Version',
#   u':',
#   u'[',
#   u'not',
#   u'recorded',
#   u']',
#   u'Link',
#   u'(',
#   u's',
#   u')',
#   u'to',
#   u'article',
#   u'on',
#   u'publisher',
#   u'\u2019',
#   u's',
#   u'website',
#   u':',
#   u'http',
#   u':',
#   u'//dx.doi.org/doi:10.1007/s11213-005-9002-4',
#   u'Copyright',
#   u'and',
#   u'Moral',
#   u'Rights',
#   u'for',
#   u'the',
#   u'articles',
#   u'on',
#   u'this',
#   u'site',
#   u'are',
#   u'retained',
#   u'by',
#   u'the',
#   u'individual',
#   u'authors',
#   u'and/or',
#   u'other',
#   u'copy-',
#   u'right',
#   u'owners',
#   u'.'],
#  [u'For',
#   u'more',
#   u'information',
#   u'on',
#   u'Open',
#   u'Research',
#   u'Online',
#   u'\u2019',
#   u's',
#   u'data',
#   u'policy',
#   u'on',
#   u'reuse',
#   u'of',
#   u'materials',
#   u'please',
#   u'consult',
#   u'the',
#   u'policies',
#   u'page',
#   u'.'],
#  [u'oro.open.ac.uk',
#   u'1',
#   u'Applying',
#   u'Systemic',
#   u'Project',
#   u'Management',
#   u'Approaches',
#   u'for',
#   u'the',
#   u'UK',
#   u'National',
#   u'Health',
#   u'Service1',
#   u'Dr.',
#   u'Simon',
#   u'Bell',
#   u'Ann',
#   u'Christina',
#   u'Open',
#   u'Systems',
#   u'Research',
#   u'Group',
#   u'Head',
#   u'of',
#   u'Professional',
#   u'Development',
#   u'for',
#   u'Social',
#   u'Care',
#   u'Systems',
#   u'Discipline',
#   u'Kent',
#   u'County',
#   u'Council',
#   u'.'],
#  [u'Open',
#   u'University',
#   u'Brenchley',
#   u'House',
#   u',',
#   u'BH-2',
#   u'Training',
#   u'Milton',
#   u'Keynes',
#   u'123',
#   u'-',
#   u'135',
#   u'Week',
#   u'Street',
#   u'MK7',
#   u'6AA',
#   u'Maidstone',
#   u'ME14',
#   u'1RF',
#   u's.g.bell',
#   u'@',
#   u'open.ac.uk',
#   u'Ann.christina',
#   u'@',
#   u'kent.gov.uk',
#   u'Abstract',
#   u'This',
#   u'paper',
#   u'sets',
#   u'out',
#   u'some',
#   u'observations',
#   u'arising',
#   u'from',
#   u'on-going',
#   u'research',
#   u'into',
#   u'the',
#   u'use',
#   u'of',
#   u'systemic',
#   u'methods',
#   u'in',
#   u'the',
#   u'planning',
#   u'of',
#   u'complex',
#   u'projects',
#   u'within',
#   u'the',
#   u'National',
#   u'Health',
#   u'Service',
#   u'(',
#   u'NHS',
#   u')',
#   u'in',
#   u'Staffordshire',
#   u'and',
#   u'Shropshire',
#   u'in',
#   u'the',
#   u'UK',
#   u'.'],
#  [u'This',
#   u'brief',
#   u'paper',
#   u'sets',
#   u'out',
#   u'the',
#   u'main',
#   u'reasons',
#   u'for',
#   u'the',
#   u'application',
#   u'of',
#   u'systemic',
#   u'approaches',
#   u',',
#   u'the',
#   u'nature',
#   u'of',
#   u'the',
#   u'methodologies',
#   u'put',
#   u'in',
#   u'place',
#   u'and',
#   u'some',
#   u'of',
#   u'the',
#   u'outcomes',
#   u'and',
#   u'reflections',
#   u'of',
#   u'those',
#   u'involved',
#   u'in',
#   u'the',
#   u'various',
#   u'workshops',
#   u'.'],
#  [u'Whilst',
#   u'not',
#   u'attempting',
#   u'to',
#   u'be',
#   u'definitive',
#   u'in',
#   u'our',
#   u'conclusions',
#   u',',
#   u'the',
#   u'authors',
#   u'believe',
#   u'that',
#   u'the',
#   u'results',
#   u'of',
#   u'the',
#   u'application',
#   u'of',
#   u'systemic',
#   u'methods',
#   u'by',
#   u'Health',
#   u'and',
#   u'Care',
#   u'professionals',
#   u'show',
#   u'a',
#   u'range',
#   u'of',
#   u'strengths',
#   u'going',
#   u'forward',
#   u'.'],
#  [u'Keywords',
#   u':',
#   u'Systemic',
#   u',',
#   u'planning',
#   u',',
#   u'project',
#   u'management',
#   u'.'],
#  [u'Accepted',
#   u'for',
#   u'Systemic',
#   u'Practice',
#   u'and',
#   u'Action',
#   u'Research',
#   u'2006',
#   u',',
#   u'Vol',
#   u'.'],
#  [u'19',
#   u'1',
#   u'Published',
#   u'with',
#   u'the',
#   u'kind',
#   u'permission',
#   u'of',
#   u'Staffordshire',
#   u'and',
#   u'Shropshire',
#   u'Workforce',
#   u'Development',
#   u'Directorate',
#   u'.'],
#  [u'2',
#   u'Contextual',
#   u'Background',
#   u'to',
#   u'the',
#   u'Study',
#   u'The',
#   u'background',
#   u'to',
#   u'the',
#   u'study',
#   u'described',
#   u'in',
#   u'this',
#   u'paper',
#   u'is',
#   u'the',
#   u'modernisation',
#   u'of',
#   u'the',
#   u'health',
#   u'and',
#   u'social',
#   u'care',
#   u'workforces',
#   u'(',
#   u'numerously',
#   u'documented',
#   u'but',
#   u'see',
#   u':',
#   u'McNulty',
#   u'and',
#   u'Ferlie',
#   u'2002',
#   u')',
#   u'.'],
#  [u'More',
#   u'specifically',
#   u',',
#   u'this',
#   u'paper',
#   u'arises',
#   u'from',
#   u'the',
#   u'experiences',
#   u'of',
#   u'the',
#   u'application',
#   u'of',
#   u'systemic',
#   u'approaches',
#   u'to',
#   u'workforce',
#   u're-modelling',
#   u'following',
#   u'the',
#   u'establishment',
#   u'of',
#   u'the',
#   u'new',
#   u'role',
#   u'of',
#   u'Associate',
#   u'Director',
#   u'Workforce',
#   u'Development',
#   u'(',
#   u'ADWD',
#   u')',
#   u'(',
#   u'Health',
#   u'and',
#   u'Social',
#   u'Care',
#   u'Integration',
#   u')',
#   u'for',
#   u'the',
#   u'Shropshire',
#   u'and',
#   u'Staffordshire',
#   u'Workforce',
#   u'Development',
#   u'Confederation',
#   u'.'],
#  [u'The',
#   u'post',
#   u'was',
#   u'funded',
#   u'by',
#   u'the',
#   u'NHS',
#   u'but',
#   u'the',
#   u'host',
#   u'employer',
#   u'was',
#   u'one',
#   u'of',
#   u'the',
#   u'four',
#   u'Local',
#   u'Authority',
#   u'Social',
#   u'Services',
#   u'Departments',
#   u'within',
#   u'the',
#   u'boundaries',
#   u'of',
#   u'the',
#   u'Shropshire',
#   u'and',
#   u'Staffordshire',
#   u'Strategic',
#   u'Health',
#   u'Authority',
#   u'.'],
#  [u'The',
#   u'paper',
#   u'sets',
#   u'out',
#   u'practitioner',
#   u'and',
#   u'client',
#   u'notes',
#   u'on',
#   u'the',
#   u'selection',
#   u'and',
#   u'use',
#   u'of',
#   u'systemic',
#   u'methods',
#   u'applied',
#   u'to',
#   u'assist',
#   u'care',
#   u'professionals',
#   u'meet',
#   u'their',
#   u'evolving',
#   u'needs',
#   u'to',
#   u'manage',
#   u'complexity',
#   u'in',
#   u'their',
#   u'working',
#   u'environment',
#   u'.'],
#  [u'In',
#   u'this',
#   u'paper',
#   u'the',
#   u'reflections',
#   u'of',
#   u'the',
#   u'commissioning',
#   u'client',
#   u'and',
#   u'the',
#   u'main',
#   u'consultant/',
#   u'researcher',
#   u'are',
#   u'included',
#   u',',
#   u'both',
#   u'in',
#   u'order',
#   u'to',
#   u'provide',
#   u'an',
#   u'accurate',
#   u'account',
#   u'of',
#   u'the',
#   u'training/',
#   u'induction',
#   u'process',
#   u'for',
#   u'systems',
#   u'methods',
#   u',',
#   u'and',
#   u'also',
#   u'as',
#   u'a',
#   u'means',
#   u'to',
#   u'provide',
#   u'the',
#   u'reader',
#   u'with',
#   u'a',
#   u'sense',
#   u'of',
#   u'the',
#   u'practical',
#   u'issues',
#   u'which',
#   u'arise',
#   u'from',
#   u'such',
#   u'situations',
#   u'.'],
#  [u'The',
#   u'care',
#   u'workforce',
#   u'is',
#   u'in',
#   u'a',
#   u'climate',
#   u'of',
#   u'continuous',
#   u'change',
#   u',',
#   u'invoking',
#   u'wide',
#   u'scale',
#   u'rethinking',
#   u'on',
#   u'almost',
#   u'all',
#   u'aspects',
#   u'of',
#   u'its',
#   u'use',
#   u'and',
#   u'development',
#   u'(',
#   u'for',
#   u'a',
#   u'comprehensive',
#   u'discussion',
#   u'of',
#   u'key',
#   u'issues',
#   u'see',
#   u':',
#   u'Davies',
#   u'2003',
#   u')',
#   u'.'],
#  [u'The',
#   u'NHS',
#   u'workforce',
#   u'for',
#   u'the',
#   u'Staffordshire',
#   u'and',
#   u'Shropshire',
#   u'area',
#   u'(',
#   u'the',
#   u'focus',
#   u'of',
#   u'this',
#   u'paper',
#   u')',
#   u'is',
#   u'35,000',
#   u'and',
#   u'the',
#   u'social',
#   u'care',
#   u'workforce',
#   u'is',
#   u'estimated',
#   u'to',
#   u'be',
#   u'nearly',
#   u'as',
#   u'great',
#   u'but',
#   u'largely',
#   u'employed',
#   u'outside',
#   u'the',
#   u'Social',
#   u'Services',
#   u'Departments',
#   u'.'],
#  [u'Rather',
#   u',',
#   u'it',
#   u'is',
#   u'supplied',
#   u'by',
#   u'hundreds',
#   u'of',
#   u'different',
#   u'private',
#   u'and',
#   u'charitable',
#   u'business',
#   u'employers',
#   u'(',
#   u'these',
#   u'organisations',
#   u'face',
#   u'their',
#   u'own',
#   u',',
#   u'related',
#   u'challenges',
#   u',',
#   u'see',
#   u':',
#   u'Harris',
#   u',',
#   u'Cairns',
#   u'et',
#   u'al',
#   u'.'],
#  [u'2004', u')', u'.'],
#  [u'The',
#   u'ADWD',
#   u'post',
#   u'was',
#   u'expected',
#   u'to',
#   u'work',
#   u'at',
#   u'the',
#   u'interface',
#   u'between',
#   u'the',
#   u'NHS',
#   u'and',
#   u'the',
#   u'social',
#   u'care',
#   u'sector',
#   u'on',
#   u'workforce',
#   u'development',
#   u'issues',
#   u'.'],
#  [u'Shropshire',
#   u'and',
#   u'Staffordshire',
#   u'Workforce',
#   u'Development',
#   u'Confederation',
#   u'was',
#   u'established',
#   u'in',
#   u'April',
#   u'2001',
#   u'to',
#   u'take',
#   u'forward',
#   u'local',
#   u'strategies',
#   u'in',
#   u'support',
#   u'of',
#   u'the',
#   u'national',
#   u'plan',
#   u'for',
#   u'modernisation',
#   u'of',
#   u'the',
#   u'health',
#   u'and',
#   u'social',
#   u'care',
#   u'workforce',
#   u'.'],
#  [u'Its',
#   u'formation',
#   u'was',
#   u'part',
#   u'of',
#   u'the',
#   u'NHS',
#   u'restructuring',
#   u'of',
#   u'Regional',
#   u'Authorities',
#   u'which',
#   u'devolved',
#   u'budgets',
#   u'and',
#   u'commissioning',
#   u'power',
#   u'to',
#   u'these',
#   u'confederations',
#   u'across',
#   u'the',
#   u'country',
#   u'.'],
#  [u'In',
#   u'2004',
#   u'the',
#   u'3',
#   u'Workforce',
#   u'Development',
#   u'Confederations',
#   u'in',
#   u'England',
#   u'were',
#   u'integrated',
#   u'into',
#   u'each',
#   u'of',
#   u'the',
#   u'28',
#   u'Strategic',
#   u'Health',
#   u'Authorities',
#   u'adding',
#   u'another',
#   u'dimension',
#   u'to',
#   u'the',
#   u'latter',
#   u'\u2019',
#   u's',
#   u'performance',
#   u'management',
#   u'role',
#   u'which',
#   u'had',
#   u'been',
#   u'constantly',
#   u'expanding',
#   u'since',
#   u'they',
#   u'had',
#   u'been',
#   u'brought',
#   u'into',
#   u'being',
#   u'in',
#   u'2002',
#   u'.'],
#  [u'In',
#   u'the',
#   u'Shropshire',
#   u'and',
#   u'Staffordshire',
#   u'area',
#   u'this',
#   u'meant',
#   u'that',
#   u'the',
#   u'Confederation',
#   u'was',
#   u'now',
#   u'to',
#   u'become',
#   u'the',
#   u'Workforce',
#   u'Development',
#   u'Directorate',
#   u'(',
#   u'or',
#   u'WDD',
#   u')',
#   u'of',
#   u'the',
#   u'Shropshire',
#   u'and',
#   u'Staffordshire',
#   u'Strategic',
#   u'Health',
#   u'Authority',
#   u'alongside',
#   u'Directorates',
#   u'for',
#   u'Service',
#   u'Improvement',
#   u',',
#   u'Health',
#   u'Strategy',
#   u',',
#   u'and',
#   u'Performance',
#   u'and',
#   u'Finance',
#   u'.'],
#  [u'The',
#   u'WDD',
#   u'was',
#   u'tasked',
#   u'with',
#   u'ensuring',
#   u'the',
#   u'local',
#   u'implementation',
#   u'of',
#   u'national',
#   u'policy',
#   u'.'],
#  [u'Further',
#   u',',
#   u'and',
#   u'developing',
#   u'from',
#   u'this',
#   u'role',
#   u',',
#   u'there',
#   u'is',
#   u'an',
#   u'expectation',
#   u'that',
#   u'the',
#   u'WDD',
#   u'is',
#   u'also',
#   u'performance',
#   u'managing',
#   u'Human',
#   u'Resource',
#   u'(',
#   u'HR',
#   u')',
#   u'improvement',
#   u'aspects',
#   u'of',
#   u'the',
#   u'work',
#   u'of',
#   u'the',
#   u'Health',
#   u'Trusts',
#   u'in',
#   u'line',
#   u'with',
#   u'Department',
#   u'of',
#   u'Health',
#   u'(',
#   u'DoH',
#   u')',
#   u'requirements',
#   u'.'],
#  [u'This',
#   u'is',
#   u'alongside',
#   u'the',
#   u'continuing',
#   u'multi-million',
#   u'pound',
#   u'commissioning',
#   u'role',
#   u'for',
#   u'university',
#   u'provision',
#   u'of',
#   u'health',
#   u'professional',
#   u'programmes',
#   u'and',
#   u'funding',
#   u'of',
#   u'secondment',
#   u'to',
#   u'these',
#   u'.'],
#  [u'Problem',
#   u'issues',
#   u'abound',
#   u'for',
#   u'the',
#   u'WDD',
#   u'to',
#   u'manage',
#   u'.'],
#  [u'Problems',
#   u'of',
#   u'data',
#   u'shortage',
#   u'on',
#   u'vital',
#   u'teams',
#   u'within',
#   u'the',
#   u'NHS',
#   u'are',
#   u'well',
#   u'documented',
#   u'(',
#   u'see',
#   u',',
#   u'for',
#   u'example',
#   u':',
#   u'Stubbings',
#   u'and',
#   u'Scott',
#   u'200',
#   u';',
#   u'Editorial',
#   u'2004',
#   u')',
#   u',',
#   u'the',
#   u'development',
#   u'of',
#   u'decentralised',
#   u'teams',
#   u'working',
#   u'at',
#   u'local',
#   u'level',
#   u'seems',
#   u'patchy',
#   u'at',
#   u'best',
#   u'(',
#   u'Deeming',
#   u'2004',
#   u')',
#   u',',
#   u'and',
#   u'leadership',
#   u'training',
#   u'and',
#   u'effectiveness',
#   u'remains',
#   u'critical',
#   u'(',
#   u'e.g',
#   u'.'],
#  [u'see',
#   u':',
#   u'Hewison',
#   u'and',
#   u'Griffiths',
#   u'2004',
#   u';',
#   u'Kristina',
#   u'2004',
#   u')',
#   u',',
#   u'yet',
#   u'the',
#   u'goal',
#   u'of',
#   u'flexible',
#   u'workforces',
#   u',',
#   u'responding',
#   u'to',
#   u'need',
#   u'flexible',
#   u'and',
#   u'autonomous',
#   u'ways',
#   u'remains',
#   u'the',
#   u'philosophers',
#   u'stone',
#   u'(',
#   u'For',
#   u'a',
#   u'wider',
#   u'discussion',
#   u'on',
#   u'this',
#   u'see',
#   u':',
#   u'Huselid',
#   u',',
#   u'Becker',
#   u'et',
#   u'al',
#   u'.'],
#  [u'2005',
#   u')',
#   u'In',
#   u'the',
#   u'case',
#   u'of',
#   u'Staffordshire',
#   u'and',
#   u'Shropshire',
#   u',',
#   u'the',
#   u'WDD',
#   u'had',
#   u'a',
#   u'specific',
#   u'need',
#   u'in',
#   u'the',
#   u'development',
#   u'of',
#   u'capacity',
#   u'in',
#   u'the',
#   u'use',
#   u'of',
#   u'a',
#   u'range',
#   u'of',
#   u'management',
#   u'techniques',
#   u'.'],
#  [u'The',
#   u'advertisement',
#   u'for',
#   u'the',
#   u'post',
#   u'of',
#   u'ADWD',
#   u'implies',
#   u'as',
#   u'much',
#   u':',
#   u'\u201c',
#   u'you',
#   u'will',
#   u'play',
#   u'a',
#   u'key',
#   u'role',
#   u'in',
#   u'modernising',
#   u'service',
#   u'delivery',
#   u'through',
#   u'the',
#   u'effective',
#   u'integration',
#   u'of',
#   u'social',
#   u'care',
#   u'and',
#   u'health',
#   u'workforce',
#   u'development',
#   u'strategies',
#   u',',
#   u'initiatives',
#   u'and',
#   u'processes',
#   u'.'],
#  [u'The',
#   u'task',
#   u'is',
#   u'both',
#   u'enormous',
#   u'and',
#   u'multi-faceted',
#   u'.'],
#  [u'What',
#   u'we',
#   u'\u2019',
#   u're',
#   u'working',
#   u'to',
#   u'achieve',
#   u'is',
#   u'not',
#   u'only',
#   u'an',
#   u'understanding',
#   u'of',
#   u'functional',
#   u'processes',
#   u'and',
#   u'the',
#   u'skills',
#   u'demonstrated',
#   u'by',
#   u'the',
#   u'current',
#   u'workforce',
#   u'to',
#   u'deliver',
#   u'services',
#   u',',
#   u'but',
#   u'a',
#   u'specification',
#   u'of',
#   u'the',
#   u'skill',
#   u'sets',
#   u'required',
#   u'to',
#   u'deliver',
#   u'evolving',
#   u',',
#   u'emerging',
#   u'and',
#   u'future',
#   u'service',
#   u'models.',
#   u'\u201d',
#   u'(',
#   u'Guardian',
#   u'newspaper',
#   u',',
#   u'June',
#   u'2001',
#   u')',
#   u'4',
#   u'The',
#   u'need',
#   u'for',
#   u'the',
#   u'application',
#   u'of',
#   u'systemic',
#   u'processes',
#   u'and',
#   u'methods',
#   u'in',
#   u'the',
#   u'further',
#   u'development',
#   u'of',
#   u'the',
#   u'WDD',
#   u'remit',
#   u'was',
#   u'also',
#   u'clear',
#   u':',
#   u'\u201c',
#   u'In',
#   u'describing',
#   u'you',
#   u'as',
#   u'the',
#   u'Social',
#   u'Care',
#   u'guru',
#   u'in',
#   u'the',
#   u'WDC',
#   u',',
#   u'we',
#   u'need',
#   u'to',
#   u'make',
#   u'one',
#   u'point',
#   u'absolutely',
#   u'clear',
#   u':',
#   u'this',
#   u'is',
#   u'not',
#   u'the',
#   u'time',
#   u'or',
#   u'place',
#   u'for',
#   u'professional',
#   u'advocacy',
#   u'.'],
#  [u'The',
#   u'whole',
#   u'point',
#   u'is',
#   u'to',
#   u'get',
#   u'away',
#   u'from',
#   u'old',
#   u'pitfalls',
#   u'-',
#   u'demarcation',
#   u',',
#   u'adversarial',
#   u'budgeting',
#   u',',
#   u'territorial',
#   u'thinking',
#   u'\u2013',
#   u'and',
#   u'build',
#   u'on',
#   u'the',
#   u'essential',
#   u'elements',
#   u'in',
#   u'the',
#   u'make',
#   u'up',
#   u'of',
#   u'multi-skilled',
#   u'teams',
#   u'\u201d',
#   u'This',
#   u'systemic',
#   u'quality',
#   u'is',
#   u'further',
#   u'emphasised',
#   u'in',
#   u'following',
#   u'sections',
#   u',',
#   u'including',
#   u':',
#   u'\u201c',
#   u'To',
#   u'take',
#   u'forward',
#   u'the',
#   u'integration',
#   u'of',
#   u'modernisation',
#   u'of',
#   u'the',
#   u'Health',
#   u'and',
#   u'Social',
#   u'Care',
#   u'workforce',
#   u'through',
#   u'the',
#   u'development',
#   u'of',
#   u'integrated',
#   u'workforce',
#   u'planning',
#   u'and',
#   u'development',
#   u'between',
#   u'the',
#   u'NHS',
#   u'and',
#   u'Social',
#   u'Care',
#   u';',
#   u'scoping',
#   u'the',
#   u'potential',
#   u'for',
#   u'reducing',
#   u'demarcation',
#   u',',
#   u'changing',
#   u'working',
#   u'practices',
#   u'and',
#   u'roles',
#   u'and',
#   u'initiating',
#   u'projects',
#   u'to',
#   u'produce',
#   u'change',
#   u';',
#   u'initiating',
#   u'joint',
#   u'reforms',
#   u'in',
#   u'health',
#   u'and',
#   u'social',
#   u'care',
#   u'education',
#   u'and',
#   u'development',
#   u'at',
#   u'pre',
#   u'and',
#   u'post',
#   u'qualification',
#   u'levels.',
#   u'\u201d',
#   u'(',
#   u'Guardian',
#   u'newspaper',
#   u',',
#   u'June',
#   u'2001',
#   u')',
#   u'Following',
#   u'her',
#   u'appointment',
#   u',',
#   u'the',
#   u'remit',
#   u'for',
#   u'multi-skilled',
#   u'teams',
#   u'initiating',
#   u'projects',
#   u',',
#   u'avoiding',
#   u'old',
#   u'demarcations',
#   u'and',
#   u'adversarial/',
#   u'territorial',
#   u'thinking',
#   u'was',
#   u'recognised',
#   u'by',
#   u'Ann',
#   u'as',
#   u'demonstrating',
#   u'an',
#   u'implicit',
#   u'need',
#   u'for',
#   u'systemic',
#   u'processes',
#   u'.'],
#  [u'Such',
#   u'processes',
#   u'impose',
#   u'responsibilities',
#   u'and',
#   u'rigours',
#   u'on',
#   u'the',
#   u'organisation',
#   u'.'],
#  [u'As',
#   u'Charlotte',
#   u'Roberts',
#   u'and',
#   u'Jennifer',
#   u'Kemeny',
#   u'have',
#   u'argued',
#   u':',
#   u"''",
#   u'You',
#   u'ca',
#   u"n't",
#   u'redesign',
#   u'your',
#   u'system',
#   u'..',
#   u'by',
#   u'dividing',
#   u'it',
#   u'into',
#   u'parts',
#   u';',
#   u'everyone',
#   u'must',
#   u'look',
#   u'at',
#   u'the',
#   u'whole',
#   u'together',
#   u'.'],
#  [u'Thus',
#   u'you',
#   u'ca',
#   u"n't",
#   u'practice',
#   u'systems',
#   u'thinking',
#   u'as',
#   u'an',
#   u'individual',
#   u'-',
#   u'not',
#   u'because',
#   u'the',
#   u'discipline',
#   u'itself',
#   u'is',
#   u'difficult',
#   u',',
#   u'but',
#   u'because',
#   u'good',
#   u'results',
#   u'in',
#   u'a',
#   u'complex',
#   u'system',
#   u'depend',
#   u'on',
#   u'bringing',
#   u'in',
#   u'as',
#   u'many',
#   u'perspectives',
#   u'as',
#   u'possible',
#   u'.'],
#  [u'As',
#   u'you',
#   u'put',
#   u'together',
#   u'a',
#   u'team',
#   u',',
#   u'make',
#   u'sure',
#   u'all',
#   u'necessary',
#   u'functions',
#   u'are',
#   u'represented',
#   u',',
#   u'and',
#   u'gain',
#   u'clearance',
#   u'from',
#   u'top',
#   u'management',
#   u'to',
#   u'propose',
#   u'cross-functional',
#   u'solutions',
#   u',',
#   u'regardless',
#   u'of',
#   u'sensitivities',
#   u'and',
#   u'politics',
#   u"''",
#   u'(',
#   u'Senge',
#   u',',
#   u'Ross',
#   u'et',
#   u'al',
#   u'.'],
#  [u'1994', u'pages', u'91', u'-', u'92', u')', u'5', u'Figure', u'1', u'.'],
#  [u'Members',
#   u'of',
#   u'the',
#   u'WDD',
#   u'using',
#   u'Soft',
#   u'Systems',
#   u'Methodology',
#   u'Approaching',
#   u'the',
#   u'Systemic',
#   u'Intervention',
#   u'On',
#   u'appointment',
#   u',',
#   u'Ann',
#   u'reflected',
#   u'on',
#   u'the',
#   u'progress',
#   u'being',
#   u'made',
#   u'towards',
#   u'team',
#   u'building',
#   u'goals',
#   u'.'],
#  [u'In',
#   u'an',
#   u'early',
#   u'reflective',
#   u'email',
#   u'to',
#   u'a',
#   u'colleague',
#   u'she',
#   u'said',
#   u':',
#   u'\u201c',
#   u'It',
#   u'is',
#   u'vital',
#   u'to',
#   u'have',
#   u'vision',
#   u'and',
#   u'big',
#   u'picture',
#   u'thinking',
#   u'ability',
#   u';',
#   u'promoting',
#   u'a',
#   u'whole',
#   u'systems',
#   u'approach',
#   u'while',
#   u'breaking',
#   u'down',
#   u'the',
#   u'steps',
#   u'to',
#   u'change',
#   u'into',
#   u'something',
#   u'manageable',
#   u'and',
#   u'not',
#   u'too',
#   u'threatening.',
#   u'\u201d',
#   u'(',
#   u'Private',
#   u'email',
#   u'from',
#   u'ADWD',
#   u'to',
#   u'a',
#   u'colleague',
#   u'in',
#   u'the',
#   u'WDD',
#   u')',
#   u'In',
#   u'a',
#   u'separate',
#   u'email',
#   u'Ann',
#   u'developed',
#   u'her',
#   u'thinking',
#   u'as',
#   u'follows',
#   u':',
#   u"''",
#   u'I',
#   u'said',
#   u'that',
#   u'I',
#   u'thought',
#   u'my',
#   u'workplan',
#   u'would',
#   u'mean',
#   u'being',
#   u'a',
#   u'programme',
#   u'manager',
#   u'for',
#   u'a',
#   u'range',
#   u'of',
#   u'projects',
#   u'where',
#   u'I',
#   u'would',
#   u'bring',
#   u'stakeholders',
#   u'together',
#   u'and',
#   u'be',
#   u'a',
#   u'catalyst',
#   u'for',
#   u'them',
#   u'to',
#   u'achieve',
#   u'something',
#   u'that',
#   u'they',
#   u'were',
#   u'wanting',
#   u'to',
#   u'do',
#   u'but',
#   u'didn',
#   u'\u2019',
#   u't',
#   u'know',
#   u'how',
#   u'.'],
#  [u'Two',
#   u'years',
#   u'later',
#   u'that',
#   u'is',
#   u'exactly',
#   u'what',
#   u'I',
#   u'have',
#   u'been',
#   u'doing',
#   u'.',
#   u"''"],
#  [u'(',
#   u'Private',
#   u'email',
#   u'from',
#   u'ADWD',
#   u'to',
#   u'a',
#   u'colleague',
#   u'in',
#   u'the',
#   u'WDD',
#   u')',
#   u'In',
#   u'order',
#   u'to',
#   u'provide',
#   u'such',
#   u'a',
#   u'catalyst',
#   u',',
#   u'Ann',
#   u'approached',
#   u'Simon',
#   u',',
#   u'to',
#   u'develop',
#   u'a',
#   u'structured',
#   u',',
#   u'systemic',
#   u'intervention',
#   u'in',
#   u'the',
#   u'form',
#   u'of',
#   u'training',
#   u'need',
#   u'support',
#   u'and',
#   u'private',
#   u'mentoring',
#   u'.'],
#  [u'At',
#   u'this',
#   u'time',
#   u'the',
#   u'needs',
#   u'of',
#   u'the',
#   u'WDD',
#   u'were',
#   u'clearly',
#   u'stated',
#   u'to',
#   u'be',
#   u'focused',
#   u'on',
#   u'six',
#   u'key',
#   u'items',
#   u'in',
#   u'the',
#   u'terms',
#   u'of',
#   u'engagement',
#   u':',
#   u'6',
#   u'1',
#   u'.'],
#  [u'A',
#   u'series',
#   u'of',
#   u'training',
#   u'events',
#   u'on',
#   u'systemic',
#   u'approaches',
#   u'to',
#   u'project',
#   u'scoping',
#   u',',
#   u'planning',
#   u'and',
#   u'management',
#   u'.'],
#  [u'2', u'.'],
#  [u'Actual',
#   u'project',
#   u'work',
#   u'to',
#   u'be',
#   u'used',
#   u'as',
#   u'the',
#   u'basis',
#   u'for',
#   u'all',
#   u'training',
#   u'3',
#   u'.'],
#  [u'A',
#   u'Team',
#   u'based',
#   u'approach',
#   u'to',
#   u'be',
#   u'applied',
#   u'to',
#   u'all',
#   u'training',
#   u'4',
#   u'.'],
#  [u'The',
#   u'workshop',
#   u'process',
#   u'to',
#   u'be',
#   u'completed',
#   u'1st',
#   u'October',
#   u'2003',
#   u'.'],
#  [u'5', u'.'],
#  [u'That',
#   u'there',
#   u'be',
#   u'a',
#   u'tailored',
#   u'half',
#   u'day',
#   u'for',
#   u'the',
#   u'Executive',
#   u'team',
#   u'.'],
#  [u'6', u'.'],
#  [u'That',
#   u'on-going',
#   u'support',
#   u'via',
#   u'email',
#   u'be',
#   u'provided',
#   u'.'],
#  [u'The',
#   u'nature',
#   u'of',
#   u'the',
#   u'approach',
#   u'to',
#   u'be',
#   u'adopted',
#   u'had',
#   u'been',
#   u'agreed',
#   u'to',
#   u'be',
#   u'systemic',
#   u',',
#   u'participatory',
#   u'methods',
#   u'.'],
#  [u'Ann',
#   u'had',
#   u'gained',
#   u'some',
#   u'first',
#   u'hand',
#   u'experience',
#   u'of',
#   u'systemic/',
#   u'participative',
#   u'approaches',
#   u'at',
#   u'a',
#   u'range',
#   u'of',
#   u'workshops',
#   u'run',
#   u'in',
#   u'London',
#   u'and',
#   u'Rugby',
#   u'and',
#   u'was',
#   u'convinced',
#   u'that',
#   u'they',
#   u'could',
#   u'meet',
#   u'the',
#   u'needs',
#   u'of',
#   u'Professionals',
#   u'in',
#   u'Staffordshire',
#   u'and',
#   u'Shropshire',
#   u'.'],
#  [u'In',
#   u'her',
#   u'own',
#   u'words',
#   u':',
#   u"''",
#   u'To',
#   u'be',
#   u'able',
#   u'to',
#   u'advise',
#   u'on',
#   u'the',
#   u'scope',
#   u'for',
#   u'integrated',
#   u'workforce',
#   u'planning',
#   u'and',
#   u'development',
#   u'and',
#   u'the',
#   u'methods',
#   u'by',
#   u'which',
#   u'that',
#   u'may',
#   u'be',
#   u'achieved',
#   u'could',
#   u'itself',
#   u'only',
#   u'be',
#   u'achieved',
#   u'through',
#   u'wide',
#   u'consultation',
#   u'with',
#   u'stakeholders',
#   u'.'],
#  [u'Harvesting',
#   u'these',
#   u'stakeholders',
#   u'\u2019',
#   u'ideas',
#   u'whilst',
#   u'gaining',
#   u'an',
#   u'understanding',
#   u'of',
#   u'their',
#   u'opinions',
#   u',',
#   u'their',
#   u'perspectives',
#   u'and',
#   u'their',
#   u'assumptions',
#   u'would',
#   u'be',
#   u'an',
#   u'important',
#   u'task',
#   u'en',
#   u'route',
#   u"''",
#   u'.'],
#  [u'The',
#   u'main',
#   u'requirement',
#   u'from',
#   u'the',
#   u'WDD',
#   u'was',
#   u'to',
#   u'provide',
#   u'Health',
#   u'and',
#   u'Care',
#   u'Professionals',
#   u'with',
#   u'transferable',
#   u'skills',
#   u'to',
#   u'aid',
#   u'in',
#   u'the',
#   u'planning',
#   u',',
#   u'management',
#   u'and',
#   u'development',
#   u'of',
#   u'projects',
#   u'across',
#   u'the',
#   u'region',
#   u'.'],
#  [u'It',
#   u'was',
#   u'judged',
#   u'that',
#   u'systemic',
#   u'methods',
#   u',',
#   u'focused',
#   u'on',
#   u'problem',
#   u'solving',
#   u',',
#   u'would',
#   u'be',
#   u'most',
#   u'likely',
#   u'to',
#   u'meet',
#   u'this',
#   u'need',
#   u'.'],
#  [u'Again',
#   u',',
#   u'in',
#   u'Ann',
#   u"'s",
#   u'words',
#   u':',
#   u"''",
#   u'To',
#   u'be',
#   u'able',
#   u'to',
#   u'advise',
#   u'on',
#   u'reforms',
#   u'in',
#   u'working',
#   u'practices',
#   u'and',
#   u'on',
#   u'new',
#   u'roles',
#   u'which',
#   u'may',
#   u'be',
#   u'achievable',
#   u'and',
#   u'provide',
#   u'up',
#   u'to',
#   u'date',
#   u'intelligence',
#   u'on',
#   u'key',
#   u'workforce',
#   u'issues',
#   u'in',
#   u'health',
#   u'and',
#   u'social',
#   u'care',
#   u'I',
#   u'would',
#   u'need',
#   u'to',
#   u'create',
#   u'the',
#   u'kind',
#   u'of',
#   u'mini-environments',
#   u'that',
#   u'would',
#   u'enable',
#   u'me',
#   u'to',
#   u'qualitatively',
#   u'research',
#   u'through',
#   u'using',
#   u'\u201c',
#   u'participative',
#   u'inquiry',
#   u'\u201d',
#   u'and',
#   u'health',
#   u'and',
#   u'care',
#   u'pathway',
#   u'and',
#   u'process',
#   u'analysis',
#   u'a',
#   u'shared',
#   u'understanding',
#   u'with',
#   u'those',
#   u'involved',
#   u'across',
#   u'differing',
#   u'cultures',
#   u'of',
#   u'the',
#   u'current',
#   u'working',
#   u'practices',
#   u'and',
#   u'roles',
#   u'being',
#   u'applied',
#   u'by',
#   u'the',
#   u'NHS',
#   u'and',
#   u'Social',
#   u'Care',
#   u'organisations',
#   u"''",
#   u'It',
#   u'had',
#   u'further',
#   u'been',
#   u'agreed',
#   u'between',
#   u'Ann',
#   u'and',
#   u'Simon',
#   u'that',
#   u'all',
#   u'training',
#   u'involve',
#   u'real',
#   u'projects',
#   u'in',
#   u'the',
#   u'pipeline',
#   u'.'],
#  [u'This',
#   u'would',
#   u'help',
#   u'to',
#   u'concentrate',
#   u'participants',
#   u'minds',
#   u'and',
#   u'7',
#   u'provide',
#   u'an',
#   u'acid',
#   u'test',
#   u'for',
#   u'the',
#   u'methods',
#   u'-',
#   u'they',
#   u'would',
#   u'need',
#   u'to',
#   u'be',
#   u'seen',
#   u'to',
#   u'be',
#   u'delivering',
#   u'real',
#   u'results',
#   u'during',
#   u'the',
#   u'learning',
#   u'process',
#   u'.'],
#  [u'Teams', u'were', u'engaged', u'in', u'the', u'work', u'.'],
#  [u'Again',
#   u'this',
#   u'was',
#   u'intended',
#   u'to',
#   u'allow',
#   u'cooperating',
#   u'colleagues',
#   u'to',
#   u'learn',
#   u'common',
#   u'methods',
#   u'and',
#   u'provide',
#   u'strength',
#   u'in',
#   u'depth',
#   u'to',
#   u'on-going',
#   u'use',
#   u'of',
#   u'the',
#   u'methods',
#   u'.'],
#  [u'No',
#   u'one',
#   u'person',
#   u'should',
#   u'be',
#   u'seen',
#   u'as',
#   u'being',
#   u'the',
#   u'team',
#   u"'expert",
#   u"'",
#   u',',
#   u'all',
#   u'should',
#   u'contribute',
#   u'and',
#   u'participate',
#   u'.'],
#  [u'Ann',
#   u'notes',
#   u'on',
#   u'this',
#   u'point',
#   u':',
#   u"''",
#   u'The',
#   u'notion',
#   u'of',
#   u'\u201c',
#   u'releasing',
#   u'\u201d',
#   u'ideas',
#   u'about',
#   u'the',
#   u'transformations',
#   u'needed',
#   u'and',
#   u'the',
#   u'way',
#   u'to',
#   u'achieve',
#   u'them',
#   u'to',
#   u'bring',
#   u'about',
#   u'the',
#   u'required',
#   u'modernisation',
#   u'from',
#   u'different',
#   u'people',
#   u'in',
#   u'all',
#   u'parts',
#   u'of',
#   u'the',
#   u'affected',
#   u'workforce',
#   u'has',
#   u'been',
#   u'very',
#   u'motivating',
#   u"''",
#   u'.'],
#  [u'The',
#   u'original',
#   u'completion',
#   u'date',
#   u'was',
#   u'September',
#   u'2003',
#   u'.'],
#  [u'This',
#   u'was',
#   u'subsequently',
#   u'shifted',
#   u'to',
#   u'October',
#   u'and',
#   u'then',
#   u'later',
#   u'to',
#   u'early',
#   u'2004',
#   u'.'],
#  [u'The',
#   u'executive',
#   u'team',
#   u'would',
#   u'also',
#   u'be',
#   u'introduced',
#   u'to',
#   u'the',
#   u'method',
#   u'.'],
#  [u'This',
#   u'was',
#   u'a',
#   u'crucial',
#   u'plus',
#   u'for',
#   u'the',
#   u'research',
#   u'as',
#   u'it',
#   u'meant',
#   u'that',
#   u'the',
#   u'WDD',
#   u'would',
#   u'gain',
#   u'understanding',
#   u'of',
#   u'the',
#   u'methods',
#   u'across',
#   u'the',
#   u'organisational',
#   u'hierarchy',
#   u'.'],
#  [u'This',
#   u'is',
#   u'rare',
#   u'in',
#   u'the',
#   u'experience',
#   u'of',
#   u'the',
#   u'authors',
#   u'and',
#   u'the',
#   u'lack',
#   u'of',
#   u'such',
#   u'senior',
#   u'buy-in',
#   u'often',
#   u'means',
#   u'that',
#   u'initiatives',
#   u'lack',
#   u'senior',
#   u'champions',
#   u'later',
#   u'in',
#   u'the',
#   u'process',
#   u'.'],
#  [u'Finally',
#   u',',
#   u'it',
#   u'was',
#   u'agreed',
#   u'that',
#   u'the',
#   u'process',
#   u'would',
#   u'be',
#   u'supported',
#   u'by',
#   u'email',
#   u'and',
#   u'phone',
#   u'support',
#   u'during',
#   u'the',
#   u'project',
#   u'run-time',
#   u'.'],
#  [u'This',
#   u'would',
#   u'mean',
#   u'that',
#   u'professionals',
#   u'working',
#   u'on',
#   u'specific',
#   u',',
#   u'complex',
#   u'issues',
#   u'could',
#   u'have',
#   u'access',
#   u'to',
#   u'support',
#   u'in',
#   u'the',
#   u'development',
#   u'of',
#   u'their',
#   u'proposals',
#   u'.'],
#  [u'Methodologies',
#   u'applied',
#   u'The',
#   u'Systems',
#   u'Department',
#   u'at',
#   u'the',
#   u'Open',
#   u'University',
#   u'has',
#   u'been',
#   u'teaching',
#   u'and',
#   u'researching',
#   u'with',
#   u'systemic',
#   u'approaches',
#   u'for',
#   u'over',
#   u'three',
#   u'decades',
#   u'.'],
#  [u'Although',
#   u'approaches',
#   u'have',
#   u'changed',
#   u'and',
#   u'developed',
#   u'over',
#   u'time',
#   u',',
#   u'one',
#   u'main',
#   u'methodology',
#   u',',
#   u'applied',
#   u'across',
#   u'undergraduate',
#   u'and',
#   u'postgraduate',
#   u'teaching',
#   u',',
#   u'has',
#   u'been',
#   u'Soft',
#   u'Systems',
#   u'Methodology',
#   u'or',
#   u'SSM',
#   u'.'],
#  [u'This',
#   u'approach',
#   u'-',
#   u'first',
#   u'advocated',
#   u'and',
#   u'subsequently',
#   u'developed',
#   u'by',
#   u'Checkland',
#   u'et',
#   u'al',
#   u'(',
#   u'Checkland',
#   u'1981',
#   u';',
#   u'Checkland',
#   u'and',
#   u'Scholes',
#   u'1990',
#   u';',
#   u'Checkland',
#   u'1994',
#   u';',
#   u'Checkland',
#   u'2001',
#   u')',
#   u'has',
#   u'been',
#   u'included',
#   u'in',
#   u'Open',
#   u'University',
#   u'courses',
#   u'and',
#   u'developed',
#   u'into',
#   u'a',
#   u'distance',
#   u'learning',
#   u'format',
#   u'(',
#   u'Open',
#   u'University',
#   u'1987',
#   u';',
#   u'Open',
#   u'University',
#   u'2000',
#   u')',
#   u'.'],
#  [u'There',
#   u'has',
#   u'been',
#   u'much',
#   u'discussion',
#   u'about',
#   u'the',
#   u'use',
#   u'of',
#   u'SSM',
#   u'(',
#   u'Stowell',
#   u',',
#   u'Holland',
#   u'et',
#   u'al',
#   u'.'],
#  [u'1990',
#   u';',
#   u'Haynes',
#   u'1995',
#   u';',
#   u'Jayaratna',
#   u'1997',
#   u';',
#   u'Probert',
#   u'1998',
#   u';',
#   u'Flood',
#   u'2001',
#   u';',
#   u'Holwell',
#   u'2001',
#   u')',
#   u'and',
#   u'it',
#   u'has',
#   u'been',
#   u'applied',
#   u'in',
#   u'a',
#   u'wide',
#   u'variety',
#   u'of',
#   u'contexts',
#   u'8',
#   u'-',
#   u'most',
#   u'recently',
#   u'the',
#   u'main',
#   u'author',
#   u"'s",
#   u'have',
#   u'turned',
#   u'to',
#   u'the',
#   u'complex',
#   u'field',
#   u'of',
#   u'information',
#   u'systems',
#   u'(',
#   u'Checkland',
#   u'and',
#   u'Holwell',
#   u'1998',
#   u')',
#   u'.'],
#  [u'SSM',
#   u'has',
#   u'a',
#   u'range',
#   u'of',
#   u'strengths',
#   u'to',
#   u'advocate',
#   u'its',
#   u'use',
#   u'in',
#   u'the',
#   u'development',
#   u'of',
#   u'project',
#   u'planning',
#   u'and',
#   u'can',
#   u'be',
#   u'seen',
#   u'as',
#   u'an',
#   u'aid',
#   u'to',
#   u'other',
#   u'systemic',
#   u'approaches',
#   u'in',
#   u'encouraging',
#   u'imaginative',
#   u'problem',
#   u'solving',
#   u'(',
#   u'see',
#   u'for',
#   u'example',
#   u':',
#   u'Brookfield',
#   u'1991',
#   u';',
#   u'Issacs',
#   u'1999',
#   u';',
#   u'Wenger',
#   u'1999',
#   u')',
#   u'.'],
#  [u'From',
#   u'the',
#   u'perspective',
#   u'of',
#   u'the',
#   u'present',
#   u'authors',
#   u'these',
#   u'can',
#   u'be',
#   u'listed',
#   u'as',
#   u':',
#   u'1.',
#   u'a',
#   u'capacity',
#   u'to',
#   u'make',
#   u'use',
#   u'of',
#   u'SSM',
#   u'at',
#   u'a',
#   u'very',
#   u'basic',
#   u'level',
#   u'very',
#   u'quickly',
#   u'-',
#   u'it',
#   u'can',
#   u'be',
#   u'adopted',
#   u'rapidly',
#   u'2',
#   u'.'],
#  [u'SSM',
#   u'can',
#   u'be',
#   u'applied',
#   u'in',
#   u'such',
#   u'a',
#   u'way',
#   u'as',
#   u'to',
#   u'provide',
#   u'three',
#   u'outcomes',
#   u'essential',
#   u'for',
#   u'a',
#   u'project',
#   u':',
#   u'a',
#   u'rich',
#   u'picture',
#   u'of',
#   u'what',
#   u'is',
#   u',',
#   u'a',
#   u'root',
#   u'definition',
#   u'of',
#   u'what',
#   u'could',
#   u'be',
#   u'and',
#   u'an',
#   u'activity',
#   u'plan',
#   u'or',
#   u'conceptual',
#   u'model',
#   u'of',
#   u'how',
#   u'to',
#   u'get',
#   u'there',
#   u'.'],
#  [u'3', u'.'],
#  [u'SSM',
#   u'is',
#   u'best',
#   u'used',
#   u'in',
#   u'a',
#   u'participatory',
#   u'manner',
#   u'by',
#   u'mixed',
#   u'teams',
#   u'of',
#   u'stakeholders',
#   u'.'],
#  [u'4', u'.'],
#  [u'SSM',
#   u'is',
#   u'a',
#   u'problem',
#   u'solving',
#   u'approach',
#   u',',
#   u'it',
#   u'is',
#   u'designed',
#   u'to',
#   u'focus',
#   u'on',
#   u'the',
#   u'kinds',
#   u'of',
#   u'soft',
#   u',',
#   u'intangible',
#   u'problems',
#   u'which',
#   u'beset',
#   u'organisations',
#   u'like',
#   u'the',
#   u'UK',
#   u'NHS',
#   u'5',
#   u'.'],
#  [u'SSM',
#   u'links',
#   u'well',
#   u'as',
#   u'the',
#   u'front',
#   u'end',
#   u'to',
#   u'more',
#   u'formal',
#   u'methods',
#   u'.'],
#  [u'This',
#   u'allows',
#   u'user',
#   u'groups',
#   u'to',
#   u'begin',
#   u'their',
#   u'planning',
#   u'with',
#   u'SSM',
#   u'and',
#   u'then',
#   u'move',
#   u'on',
#   u'to',
#   u'more',
#   u'formal',
#   u'techniques',
#   u'.'],
#  [u'All',
#   u'of',
#   u'these',
#   u'factors',
#   u'keyed',
#   u'in',
#   u'well',
#   u'with',
#   u'the',
#   u'requirements',
#   u'of',
#   u'the',
#   u'WDD',
#   u'as',
#   u'set',
#   u'out',
#   u'in',
#   u'the',
#   u'terms',
#   u'of',
#   u'engagement',
#   u'-',
#   u'most',
#   u'specifically',
#   u'for',
#   u'project',
#   u'scoping',
#   u'and',
#   u'early',
#   u'planning',
#   u'.'],
#  [u'In',
#   u'further',
#   u'developing',
#   u'the',
#   u'project',
#   u'plan',
#   u',',
#   u'and',
#   u'taking',
#   u'it',
#   u'up',
#   u'to',
#   u'implementation',
#   u',',
#   u'monitoring',
#   u'and',
#   u'evaluation',
#   u',',
#   u'the',
#   u'Logical',
#   u'Framework',
#   u'Approach',
#   u'or',
#   u'LFA',
#   u'has',
#   u'been',
#   u'applied',
#   u'in',
#   u'a',
#   u'variety',
#   u'of',
#   u'contexts',
#   u'(',
#   u'Coleman',
#   u'1987',
#   u';',
#   u'Bell',
#   u'1998',
#   u';',
#   u'Baccarini',
#   u'1999',
#   u';',
#   u'Kumar',
#   u'and',
#   u'Corbridge',
#   u'2002',
#   u';',
#   u'Biggs',
#   u'and',
#   u'Smith',
#   u'2003',
#   u';',
#   u'Crawford',
#   u'2003',
#   u';',
#   u'Crawford',
#   u'2003',
#   u';',
#   u'Dale',
#   u'2003',
#   u')',
#   u'and',
#   u',',
#   u'as',
#   u'with',
#   u'SSM',
#   u',',
#   u'has',
#   u'found',
#   u'its',
#   u'way',
#   u'into',
#   u'Open',
#   u'University',
#   u'Systems',
#   u'teaching',
#   u'(',
#   u'Open',
#   u'University',
#   u'1997',
#   u';',
#   u'Open',
#   u'University',
#   u'2000',
#   u';',
#   u'Open',
#   u'University',
#   u'2004',
#   u')',
#   u'.'],
#  [u'LFA',
#   u'involves',
#   u'the',
#   u'development',
#   u'of',
#   u'a',
#   u'four',
#   u'by',
#   u'four',
#   u'matrix',
#   u',',
#   u'containing',
#   u'the',
#   u'main',
#   u'story',
#   u'or',
#   u'the',
#   u'project',
#   u'(',
#   u'the',
#   u'narrative',
#   u'summary',
#   u')',
#   u',',
#   u'the',
#   u'main',
#   u'assumptions',
#   u'or',
#   u'risks',
#   u'(',
#   u'a',
#   u'key',
#   u'item',
#   u'-',
#   u'often',
#   u'noted',
#   u'as',
#   u'being',
#   u'absent',
#   u'or',
#   u'under-represented',
#   u'in',
#   u'project',
#   u'planning',
#   u'(',
#   u'British',
#   u'Computer',
#   u'Society',
#   u'and',
#   u'Royal',
#   u'Academy',
#   u'of',
#   u'Engineering',
#   u'2004',
#   u')',
#   u')',
#   u'and',
#   u'the',
#   u'means',
#   u'of',
#   u'measuring',
#   u'success',
#   u'in',
#   u'terms',
#   u'of',
#   u'performance',
#   u',',
#   u'impact',
#   u',',
#   u'sustainability',
#   u'and',
#   u'strategy',
#   u'\u2013',
#   u'see',
#   u'Table',
#   u'1',
#   u'.'],
#  [u'The',
#   u'LFA',
#   u'can',
#   u'provide',
#   u'a',
#   u'systemic',
#   u',',
#   u'if',
#   u'highly',
#   u'structured',
#   u',',
#   u'means',
#   u'to',
#   u'capture',
#   u'the',
#   u'outcomes',
#   u'of',
#   u'SSM',
#   u'.'],
#  [u'9', u'Table', u'1', u'.'],
#  [u'The',
#   u'Logical',
#   u'Framework',
#   u'Narrative',
#   u'summary',
#   u'column',
#   u'The',
#   u'Goal',
#   u'of',
#   u'the',
#   u'purposeful',
#   u'human',
#   u'activity',
#   u'.'],
#  [u'Always', u'beyond', u'the', u'project', u'purpose', u'.'],
#  [u'Aspirational',
#   u'Verifiable',
#   u'indicators',
#   u'The',
#   u'goal',
#   u'is',
#   u'measured',
#   u'by',
#   u'qualitative',
#   u'and',
#   u'quantitative',
#   u'strategic',
#   u'indicators',
#   u'or',
#   u'ST',
#   u'Is',
#   u'Means',
#   u'of',
#   u'verification',
#   u'Indicators',
#   u'can',
#   u'be',
#   u'measured',
#   u'in',
#   u'by',
#   u'data',
#   u'or',
#   u'by',
#   u'means',
#   u'of',
#   u'focus',
#   u'group/',
#   u'questionnaire',
#   u'Assumptions',
#   u'or',
#   u'risks',
#   u'The',
#   u'risks',
#   u'that',
#   u'would',
#   u'mean',
#   u'that',
#   u'the',
#   u'goal',
#   u'was',
#   u'unachievable',
#   u'The',
#   u'purpose',
#   u'of',
#   u'the',
#   u'purposeful',
#   u'activity',
#   u':',
#   u'including',
#   u'details',
#   u'of',
#   u'beneficiaries',
#   u',',
#   u'implementers',
#   u',',
#   u'transformation',
#   u',',
#   u'assumption',
#   u',',
#   u'owners',
#   u'and',
#   u'constraints',
#   u'The',
#   u'purpose',
#   u'is',
#   u'measured',
#   u'by',
#   u'qualitative',
#   u'and',
#   u'quantitative',
#   u'sustainability',
#   u'indicators',
#   u'or',
#   u'SIs',
#   u'Indicators',
#   u'can',
#   u'be',
#   u'measured',
#   u'in',
#   u'by',
#   u'data',
#   u'or',
#   u'by',
#   u'means',
#   u'of',
#   u'focus',
#   u'group/',
#   u'questionnaire',
#   u'The',
#   u'risks',
#   u'and',
#   u'assumptions',
#   u'that',
#   u'would',
#   u'render',
#   u'the',
#   u'goal',
#   u'unrealisable',
#   u'or',
#   u'unachievable',
#   u'even',
#   u'if',
#   u'this',
#   u'purpose',
#   u'was',
#   u'achieved',
#   u'The',
#   u'outputs',
#   u'of',
#   u'the',
#   u'purposeful',
#   u'activity',
#   u':',
#   u'Output',
#   u'is',
#   u'measured',
#   u'\u2013',
#   u'usually',
#   u'quantitatively',
#   u'\u2013',
#   u'by',
#   u'impact',
#   u'indicators',
#   u'-',
#   u'IIs',
#   u'Indicators',
#   u'are',
#   u'usually',
#   u'measured',
#   u'by',
#   u'data',
#   u'or',
#   u'questionnaire',
#   u'The',
#   u'risks',
#   u'and',
#   u'assumptions',
#   u'that',
#   u'would',
#   u'render',
#   u'the',
#   u'purpose',
#   u'unrealisable',
#   u'or',
#   u'unachievable',
#   u'even',
#   u'if',
#   u'these',
#   u'outputs',
#   u'were',
#   u'achieved',
#   u'The',
#   u'key',
#   u'activities',
#   u'for',
#   u'the',
#   u'purposeful',
#   u'activity',
#   u'Activity',
#   u'is',
#   u'measured',
#   u'quantitatively',
#   u'by',
#   u'performance',
#   u'indicators',
#   u'\u2013',
#   u'PIs',
#   u'Indicators',
#   u'are',
#   u'measured',
#   u'by',
#   u'data',
#   u'or',
#   u'questionnaire',
#   u'The',
#   u'risks',
#   u'and',
#   u'assumptions',
#   u'that',
#   u'would',
#   u'render',
#   u'the',
#   u'outputs',
#   u'unrealisable',
#   u'or',
#   u'unachievable',
#   u'even',
#   u'if',
#   u'these',
#   u'activities',
#   u'were',
#   u'successful',
#   u'In',
#   u'an',
#   u'earlier',
#   u'paper',
#   u'Bell',
#   u'applied',
#   u'this',
#   u'-',
#   u'specifically',
#   u'as',
#   u'a',
#   u'means',
#   u'to',
#   u'explore',
#   u'the',
#   u'outcomes',
#   u'of',
#   u'SSM',
#   u'analysis',
#   u'(',
#   u'Bell',
#   u'2000',
#   u')',
#   u'.'],
#  [u'Although',
#   u'it',
#   u'is',
#   u'not',
#   u'without',
#   u'numerous',
#   u'critics',
#   u'-',
#   u'and',
#   u'it',
#   u'can',
#   u'certainly',
#   u'be',
#   u'applied',
#   u'in',
#   u'a',
#   u'non-participatory',
#   u'and',
#   u'top-down',
#   u'manner',
#   u'(',
#   u'Gasper',
#   u'1997',
#   u';',
#   u'Gasper',
#   u'2000',
#   u')',
#   u',',
#   u'it',
#   u'remains',
#   u'a',
#   u'commonly',
#   u'used',
#   u'method',
#   u'in',
#   u'many',
#   u'difficult',
#   u'and',
#   u'complex',
#   u'contexts',
#   u'.']]

# %% [markdown]
# ## Part of speech tagging (POS tagging):

# %%
pos_tagged_0 = nltk.pos_tag(tokenized_sentences[0])
pprint.pprint(sentences[0])
pprint.pprint(tokenized_sentences[0])
pprint.pprint(pos_tagged_0)
# Out:
# u'Open Research Online\nThe Open University\u2019s repository of research publications\nand other research outputs\nApplying Systemic Project Management Approaches\nfor the UK National Health Service\nJournal Article\nHow to cite:\nBell, Simon and Christina, Ann (2006).'
# [u'Open',
#  u'Research',
#  u'Online',
#  u'The',
#  u'Open',
#  u'University',
#  u'\u2019',
#  u's',
#  u'repository',
#  u'of',
#  u'research',
#  u'publications',
#  u'and',
#  u'other',
#  u'research',
#  u'outputs',
#  u'Applying',
#  u'Systemic',
#  u'Project',
#  u'Management',
#  u'Approaches',
#  u'for',
#  u'the',
#  u'UK',
#  u'National',
#  u'Health',
#  u'Service',
#  u'Journal',
#  u'Article',
#  u'How',
#  u'to',
#  u'cite',
#  u':',
#  u'Bell',
#  u',',
#  u'Simon',
#  u'and',
#  u'Christina',
#  u',',
#  u'Ann',
#  u'(',
#  u'2006',
#  u')',
#  u'.']
# [(u'Open', 'JJ'),
#  (u'Research', 'NNP'),
#  (u'Online', 'NNP'),
#  (u'The', 'DT'),
#  (u'Open', 'NNP'),
#  (u'University', 'NNP'),
#  (u'\u2019', 'NNP'),
#  (u's', 'VBD'),
#  (u'repository', 'NN'),
#  (u'of', 'IN'),
#  (u'research', 'NN'),
#  (u'publications', 'NNS'),
#  (u'and', 'CC'),
#  (u'other', 'JJ'),
#  (u'research', 'NN'),
#  (u'outputs', 'NNS'),
#  (u'Applying', 'NNP'),
#  (u'Systemic', 'NNP'),
#  (u'Project', 'NNP'),
#  (u'Management', 'NNP'),
#  (u'Approaches', 'NNP'),
#  (u'for', 'IN'),
#  (u'the', 'DT'),
#  (u'UK', 'NNP'),
#  (u'National', 'NNP'),
#  (u'Health', 'NNP'),
#  (u'Service', 'NNP'),
#  (u'Journal', 'NNP'),
#  (u'Article', 'NNP'),
#  (u'How', 'NNP'),
#  (u'to', 'TO'),
#  (u'cite', 'VB'),
#  (u':', ':'),
#  (u'Bell', 'NNP'),
#  (u',', ','),
#  (u'Simon', 'NNP'),
#  (u'and', 'CC'),
#  (u'Christina', 'NNP'),
#  (u',', ','),
#  (u'Ann', 'NNP'),
#  (u'(', '('),
#  (u'2006', 'CD'),
#  (u')', ')'),
#  (u'.', '.')]

# %% [markdown]
# What does the label mean next to each token ?
# 1. NN -> noun (plural)
# 2. NNP -> noun (singular)
# 3. VB -> Verb
# 4. CC -> conjuction
# 5. ,,,,
#
#
# A full list of each label can be found here: http://www.comp.leeds.ac.uk/amalgam/tagsets/upenn.html

# %% [markdown]
# ## NER Named Entity Recognition

# %%
parse_tree = nltk.ne_chunk(nltk.tag.pos_tag(sentences[1].split()), binary=True)
named_entities = []

for t in parse_tree.subtrees():
    if t.label() == 'NE':
#         named_entities.append(t)
        named_entities.append(list(t))  # if you want to save a list of tagged words instead of a tree

pprint.pprint(named_entities)
# Out:
# [[(u'Systemic', 'NNP'), (u'Project', 'NNP')],
#  [(u'UK', 'NNP'), (u'National', 'NNP'), (u'Health', 'NNP')]]

# %%
## DBPedia spotlight
## TextRazor 
## for more "semantic" labels

# %%
## DBPedia spotlight:
'''
Get the article abstract
'''
articleAbstract=api.get_core_article_by_id(42,True)['description']
articleAbstract
# Out:
# https://core.ac.uk/api-v2/articles/get/42?fulltext=true&apiKey=btYj73TKGQahoUzL41yHANnJVeClvPIX
# u'This paper sets out some observations arising from on-going research into the use of systemic methods in the planning of complex projects within the National Health Service (NHS) in Staffordshire and Shropshire in the UK. This brief paper sets out the main reasons for the application of systemic approaches, the nature of the methodologies put in place and some of the outcomes and reflections of those involved in the various workshops. Whilst not attempting to be definitive in our conclusions, the authors believe that the results of the application of systemic methods by Health and Care professionals show a range of strengths going forward'

# %%
url = "http://model.dbpedia-spotlight.org/en/annotate?text="+quote_plus(articleAbstract)
response = urlopen(url)
r_text = response.read()
from IPython.core.display import HTML
HTML(r_text)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML+RDFa 1.0//EN" "http://www.w3.org/MarkUp/DTD/xhtml-rdfa-1.dtd">
# <html xmlns="http://www.w3.org/1999/xhtml" xmlns:lexvo="http://lexvo.org/ontology#" xmlns:dbpedia="http://dbpedia.org/resource/" xmlns:dbpo="http://dbpedia.org/ontology/">
# <head>
# <title>DBpedia Spotlight annotation</title>
# </head>
# <body>
# <div>
# This paper sets out some observations arising from on-going research into the use of systemic methods in the planning of complex projects within the <a about="http://dbpedia.org/resource/National_Health_Service" href="http://dbpedia.org/resource/National_Health_Service" title="http://dbpedia.org/resource/National_Health_Service" target="_blank" >National Health Service</a> (<a about="http://dbpedia.org/resource/National_Health_Service" href="http://dbpedia.org/resource/National_Health_Service" title="http://dbpedia.org/resource/National_Health_Service" target="_blank" >NHS</a>) in <a about="http://dbpedia.org/resource/Staffordshire" typeof="http://dbpedia.org/ontology/AdministrativeRegion" href="http://dbpedia.org/resource/Staffordshire" title="http://dbpedia.org/resource/Staffordshire">Staffordshire</a> and <a about="http://dbpedia.org/resource/Shropshire" href="http://dbpedia.org/resource/Shropshire" title="http://dbpedia.org/resource/Shropshire" target="_blank" >Shropshire</a> in the <a about="http://dbpedia.org/resource/United_Kingdom" typeof="http://dbpedia.org/ontology/Country" href="http://dbpedia.org/resource/United_Kingdom" title="http://dbpedia.org/resource/United_Kingdom">UK</a>. This brief paper sets out the main reasons for the application of systemic approaches, the nature of the methodologies put in place and some of the outcomes and reflections of those involved in the various workshops. Whilst not attempting to be definitive in our conclusions, the authors believe that the results of the application of systemic methods by Health and Care professionals show a range of strengths going forward
# </div>
# </body>
# </html>

# %%
'''
The same as above but printing XML nice'''

import lxml.etree as etree

x = etree.fromstring(r_text)
print(etree.tostring(x, pretty_print = True))
# Out:
# <html xmlns="http://www.w3.org/1999/xhtml" xmlns:lexvo="http://lexvo.org/ontology#" xmlns:dbpedia="http://dbpedia.org/resource/" xmlns:dbpo="http://dbpedia.org/ontology/">
# <head>
# <title>DBpedia Spotlight annotation</title>
# </head>
# <body>
# <div>
# This paper sets out some observations arising from on-going research into the use of systemic methods in the planning of complex projects within the <a about="http://dbpedia.org/resource/National_Health_Service" href="http://dbpedia.org/resource/National_Health_Service" title="http://dbpedia.org/resource/National_Health_Service" target="_blank">National Health Service</a> (<a about="http://dbpedia.org/resource/National_Health_Service" href="http://dbpedia.org/resource/National_Health_Service" title="http://dbpedia.org/resource/National_Health_Service" target="_blank">NHS</a>) in <a about="http://dbpedia.org/resource/Staffordshire" typeof="http://dbpedia.org/ontology/AdministrativeRegion" href="http://dbpedia.org/resource/Staffordshire" title="http://dbpedia.org/resource/Staffordshire">Staffordshire</a> and <a about="http://dbpedia.org/resource/Shropshire" href="http://dbpedia.org/resource/Shropshire" title="http://dbpedia.org/resource/Shropshire" target="_blank">Shropshire</a> in the <a about="http://dbpedia.org/resource/United_Kingdom" typeof="http://dbpedia.org/ontology/Country" href="http://dbpedia.org/resource/United_Kingdom" title="http://dbpedia.org/resource/United_Kingdom">UK</a>. This brief paper sets out the main reasons for the application of systemic approaches, the nature of the methodologies put in place and some of the outcomes and reflections of those involved in the various workshops. Whilst not attempting to be definitive in our conclusions, the authors believe that the results of the application of systemic methods by Health and Care professionals show a range of strengths going forward
# </div>
# </body>
# </html>

# %% [markdown]
# ## Text razor
#
# #### Again a NER/analyze text - maps to freebase entities - gives back a confidence score

# %%
# !pip install textrazor
import textrazor
# Out:
# Collecting textrazor
#   Downloading textrazor-1.3.0.tar.gz
# Building wheels for collected packages: textrazor
# done
#   Stored in directory: /Users/mc26486/Library/Caches/pip/wheels/cf/d1/ff/927548addc592735a3991427e3ea4d3b8e3841cdc4cf3dfe13
# Successfully built textrazor
# Installing collected packages: textrazor
# Successfully installed textrazor-1.3.0

# %%
#personal API key - just for this demo - please do not use anywhere else
textrazor.api_key = "eba9d80209aaad9627277d21437d2e0f56ef9c1e6e16332f221af063"

client = textrazor.TextRazor(extractors=["entities", "topics"])
response = client.analyze(articleAbstract)

for entity in response.entities():
    print entity.id, entity.relevance_score, entity.confidence_score, entity.freebase_types
# Out:
# Health 0.3637 1.185 [u'/media_common/quotation_subject', u'/business/industry', u'/organization/organization_sector', u'/media_common/literary_genre', u'/internet/website_category', u'/education/field_of_study', u'/radio/radio_subject', u'/broadcast/genre', u'/media_common/media_genre', u'/exhibitions/exhibition_subject', u'/internet/blog', u'/business/product_category', u'/organization/organization_type', u'/book/book_subject', u'/book/periodical_subject']
# Research 0.6039 1.194 [u'/architecture/building_function', u'/education/school_category', u'/book/periodical_subject', u'/spaceflight/satellite_type', u'/media_common/quotation_subject', u'/book/book_subject', u'/business/industry', u'/organization/organization_sector', u'/architecture/building_complex_function', u'/organization/organization_type', u'/education/field_of_study', u'/award/award_discipline']
# National Health Service 0.351 3.016 []
# Staffordshire 0.1787 3.334 [u'/location/statistical_region', u'/location/location', u'/periodicals/newspaper_circulation_area', u'/location/uk_statistical_location', u'/location/administrative_division', u'/location/dated_location', u'/location/uk_non_metropolitan_county', u'/location/uk_civil_parish']
# National Health Service 0.632 7.567 []
# Shropshire 0.2014 4.447 [u'/location/uk_statistical_location', u'/business/employer', u'/location/dated_location', u'/location/administrative_division', u'/location/uk_non_metropolitan_county', u'/location/location', u'/location/statistical_region', u'/location/uk_unitary_authority']
# Methodology 0.2284 3.809 [u'/book/book_subject']
# United Kingdom 0.1745 3.167 [u'/sports/sport_country', u'/organization/contact_category', u'/food/beer_country_region', u'/government/governmental_jurisdiction', u'/location/uk_statistical_location', u'/business/employer', u'/location/dated_location', u'/organization/organization_scope', u'/royalty/kingdom', u'/organization/organization_member', u'/sports/sports_team_location', u'/media_common/netflix_genre', u'/book/periodical_subject', u'/military/military_combatant', u'/location/location', u'/location/statistical_region', u'/location/administrative_division', u'/biology/breed_origin', u'/symbols/flag_referent', u'/fictional_universe/fictional_setting', u'/tv/tv_location', u'/film/film_location', u'/organization/organization_founder', u'/periodicals/newspaper_circulation_area', u'/location/country', u'/business/business_location', u'/olympics/olympic_participating_country', u'/cvg/computer_game_region', u'/law/court_jurisdiction_area', u'/book/book_subject']

# %% [markdown]
# ## Stemming

# %%
from nltk.stem import PorterStemmer

# %%
stemmer = PorterStemmer()

# %%
stemmer.stem("Management")
# Out:
# u'manag'

# %%
stemmer.stem("Manager")
# Out:
# u'manag'

# %%
stemmer.stem("Managerial")
# Out:
# u'manageri'

# %%
for token in tokenized_sentences[0]:
    pprint.pprint(token+' '+stemmer.stem(token))
# Out:
# u'Open open'
# u'Research research'
# u'Online onlin'
# u'The the'
# u'Open open'
# u'University univers'
# u'\u2019 \u2019'
# u's s'
# u'repository repositori'
# u'of of'
# u'research research'
# u'publications public'
# u'and and'
# u'other other'
# u'research research'
# u'outputs output'
# u'Applying appli'
# u'Systemic system'
# u'Project project'
# u'Management manag'
# u'Approaches approach'
# u'for for'
# u'the the'
# u'UK UK'
# u'National nation'
# u'Health health'
# u'Service servic'
# u'Journal journal'
# u'Article articl'
# u'How how'
# u'to to'
# u'cite cite'
# u': :'
# u'Bell bell'
# u', ,'
# u'Simon simon'
# u'and and'
# u'Christina christina'
# u', ,'
# u'Ann ann'
# u'( ('
# u'2006 2006'
# u') )'
# u'. .'

# %% [markdown]
# What if I don't do English?

# %%
from nltk.stem import SnowballStemmer
SnowballStemmer.languages
# Out:
# (u'danish',
#  u'dutch',
#  u'english',
#  u'finnish',
#  u'french',
#  u'german',
#  u'hungarian',
#  u'italian',
#  u'norwegian',
#  u'porter',
#  u'portuguese',
#  u'romanian',
#  u'russian',
#  u'spanish',
#  u'swedish')

# %% [markdown]
# ## Lemmatization

# %% [markdown]
# Like stemming but not exactly - more like synonym replacement

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
lemmatizer.lemmatize('paper')
# Out:
# 'paper'

# %%
lemmatizer.lemmatize('buses')
# Out:
# u'bus'

# %%
for token in tokenized_sentences[0]:
    pprint.pprint(token+' '+lemmatizer.lemmatize(token))
# Out:
# u'Open Open'
# u'Research Research'
# u'Online Online'
# u'The The'
# u'Open Open'
# u'University University'
# u'\u2019 \u2019'
# u's s'
# u'repository repository'
# u'of of'
# u'research research'
# u'publications publication'
# u'and and'
# u'other other'
# u'research research'
# u'outputs output'
# u'Applying Applying'
# u'Systemic Systemic'
# u'Project Project'
# u'Management Management'
# u'Approaches Approaches'
# u'for for'
# u'the the'
# u'UK UK'
# u'National National'
# u'Health Health'
# u'Service Service'
# u'Journal Journal'
# u'Article Article'
# u'How How'
# u'to to'
# u'cite cite'
# u': :'
# u'Bell Bell'
# u', ,'
# u'Simon Simon'
# u'and and'
# u'Christina Christina'
# u', ,'
# u'Ann Ann'
# u'( ('
# u'2006 2006'
# u') )'
# u'. .'

# %% [markdown]
# Pretty much the same, or maybe not ??

# %%
'''printing all the words that lemma is different than the word'''
for tokenized_sentence in tokenized_sentences:
    for token in tokenized_sentence:
        ltoken = lemmatizer.lemmatize(token)
        stoken=stemmer.stem(token)
        if (ltoken!=token):
            pprint.pprint(token+' '+ltoken)
# Out:
# u'publications publication'
# u'outputs output'
# u'citations citation'
# u'articles article'
# u'authors author'
# u'owners owner'
# u'materials material'
# u'policies policy'
# u'sets set'
# u'observations observation'
# u'methods method'
# u'projects project'
# u'sets set'
# u'reasons reason'
# u'approaches approach'
# u'methodologies methodology'
# u'outcomes outcome'
# u'reflections reflection'
# u'workshops workshop'
# u'conclusions conclusion'
# u'authors author'
# u'results result'
# u'methods method'
# u'professionals professional'
# u'strengths strength'
# u'workforces workforce'
# u'experiences experience'
# u'approaches approach'
# u'was wa'
# u'was wa'
# u'boundaries boundary'
# u'sets set'
# u'notes note'
# u'methods method'
# u'professionals professional'
# u'needs need'
# u'reflections reflection'
# u'systems system'
# u'methods method'
# u'as a'
# u'means mean'
# u'issues issue'
# u'situations situation'
# u'aspects aspect'
# u'its it'
# u'issues issue'
# u'as a'
# u'hundreds hundred'
# u'employers employer'
# u'organisations organisation'
# u'challenges challenge'
# u'was wa'
# u'issues issue'
# u'was wa'
# u'strategies strategy'
# u'was wa'
# u'budgets budget'
# u'confederations confederation'
# u'was wa'
# u'was wa'
# u'aspects aspect'
# u'requirements requirement'
# u'programmes programme'
# u'issues issue'
# u'teams team'
# u'teams team'
# u'workforces workforce'
# u'ways way'
# u'philosophers philosopher'
# u'techniques technique'
# u'as a'
# u'strategies strategy'
# u'initiatives initiative'
# u'processes process'
# u'processes process'
# u'skills skill'
# u'services service'
# u'sets set'
# u'processes process'
# u'methods method'
# u'was wa'
# u'as a'
# u'pitfalls pitfall'
# u'elements element'
# u'teams team'
# u'sections section'
# u'practices practice'
# u'roles role'
# u'projects project'
# u'reforms reform'
# u'teams team'
# u'projects project'
# u'demarcations demarcation'
# u'was wa'
# u'as a'
# u'processes process'
# u'processes process'
# u'responsibilities responsibility'
# u'rigours rigour'
# u'parts part'
# u'systems system'
# u'as a'
# u'results result'
# u'as a'
# u'perspectives perspective'
# u'as a'
# u'functions function'
# u'solutions solution'
# u'sensitivities sensitivity'
# u'pages page'
# u'goals goal'
# u'systems system'
# u'steps step'
# u'as a'
# u'projects project'
# u'stakeholders stakeholder'
# u'years year'
# u'needs need'
# u'items item'
# u'terms term'
# u'events event'
# u'approaches approach'
# u'as a'
# u'methods method'
# u'approaches approach'
# u'workshops workshop'
# u'was wa'
# u'needs need'
# u'words word'
# u'methods method'
# u'stakeholders stakeholder'
# u'stakeholders stakeholder'
# u'ideas idea'
# u'opinions opinion'
# u'perspectives perspective'
# u'assumptions assumption'
# u'was wa'
# u'skills skill'
# u'projects project'
# u'was wa'
# u'methods method'
# u'words word'
# u'reforms reform'
# u'practices practice'
# u'roles role'
# u'issues issue'
# u'cultures culture'
# u'practices practice'
# u'roles role'
# u'organisations organisation'
# u'projects project'
# u'participants participant'
# u'minds mind'
# u'methods method'
# u'results result'
# u'was wa'
# u'colleagues colleague'
# u'methods method'
# u'methods method'
# u'as a'
# u'notes note'
# u'ideas idea'
# u'transformations transformation'
# u'parts part'
# u'has ha'
# u'was wa'
# u'was wa'
# u'was wa'
# u'as a'
# u'methods method'
# u'authors author'
# u'means mean'
# u'initiatives initiative'
# u'champions champion'
# u'was wa'
# u'professionals professional'
# u'issues issue'
# u'proposals proposal'
# u'has ha'
# u'approaches approach'
# u'decades decade'
# u'approaches approach'
# u'has ha'
# u'has ha'
# u'courses course'
# u'has ha'
# u'has ha'
# u'contexts context'
# u'systems system'
# u'has ha'
# u'strengths strength'
# u'its it'
# u'as a'
# u'approaches approach'
# u'authors author'
# u'as a'
# u'as a'
# u'outcomes outcome'
# u'teams team'
# u'stakeholders stakeholder'
# u'kinds kind'
# u'problems problem'
# u'organisations organisation'
# u'links link'
# u'as a'
# u'methods method'
# u'groups group'
# u'techniques technique'
# u'factors factor'
# u'requirements requirement'
# u'as a'
# u'terms term'
# u'has ha'
# u'contexts context'
# u'as a'
# u'has ha'
# u'its it'
# u'assumptions assumption'
# u'risks risk'
# u'as a'
# u'means mean'
# u'terms term'
# u'means mean'
# u'outcomes outcome'
# u'indicators indicator'
# u'indicators indicator'
# u'means mean'
# u'risks risk'
# u'risks risk'
# u'was wa'
# u'details detail'
# u'beneficiaries beneficiary'
# u'owners owner'
# u'constraints constraint'
# u'indicators indicator'
# u'means mean'
# u'risks risk'
# u'assumptions assumption'
# u'was wa'
# u'outputs output'
# u'indicators indicator'
# u'risks risk'
# u'assumptions assumption'
# u'outputs output'
# u'activities activity'
# u'indicators indicator'
# u'risks risk'
# u'assumptions assumption'
# u'outputs output'
# u'activities activity'
# u'as a'
# u'means mean'
# u'outcomes outcome'
# u'critics critic'
# u'contexts context'
# u'virtues virtue'
# u'workshops workshop'
# u'does doe'
# u'solutions solution'
# u'links link'
# u'methods method'
# u'factors factor'
# u'resonances resonance'
# u'needs need'
# u'outcomes outcome'
# u'reflections reflection'
# u'members member'
# u'possibilities possibility'
# u'methodologies methodology'
# u'was wa'
# u'tools tool'
# u'techniques technique'
# u'streams stream'
# u'its it'
# u'systems system'
# u'was wa'
# u'developments development'
# u'members member'
# u'issues issue'
# u'methods method'
# u'was wa'
# u'was wa'
# u'variations variation'
# u'months month'
# u'events event'
# u'events event'
# u'was wa'
# u'teams team'
# u'as a'
# u'elements element'
# u'was wa'
# u'as a'
# u'teams team'
# u'elements element'
# u'workshops workshop'
# u'was wa'
# u'aspects aspect'
# u'observations observation'
# u'has ha'
# u'groups group'
# u'individuals individual'
# u'organisations organisation'
# u'sections section'
# u'helps help'
# u'groups group'
# u'views view'
# u'objectives objective'
# u'methods method'
# u'managers manager'
# u'levels level'
# u'champions champion'
# u'was wa'
# u'systems system'
# u'systems system'
# u'managers manager'
# u'themes theme'
# u'says say'
# u'players player'
# u'assumptions assumption'
# u'barriers barrier'
# u'participants participant'
# u'elements element'
# u'tasks task'
# u'barriers barrier'
# u'comments comment'
# u'participants participant'
# u'issues issue'
# u'outcomes outcome'
# u'versions version'
# u'groups group'
# u'its it'
# u'was wa'
# u'terms term'
# u'indicators indicator'
# u'comments comment'
# u'methods method'
# u'leads lead'
# u'terms term'
# u'outputs output'
# u'indicators indicator'
# u'facilitators facilitator'
# u'has ha'
# u'was wa'
# u'was wa'
# u'has ha'
# u'was wa'
# u'has ha'
# u'measures measure'
# u'as a'
# u'was wa'
# u'as a'
# u'as a'
# u'has ha'
# u'says say'
# u'issues issue'
# u'comments comment'
# u'as a'
# u'has ha'
# u'breaks break'
# u'tasks task'
# u'processes process'
# u'processes process'
# u'has ha'
# u'does doe'
# u'does doe'
# u'plans plan'
# u'was wa'
# u'frameworks framework'
# u'less le'
# u'was wa'
# u'was wa'
# u'notes note'
# u'makes make'
# u'bits bit'
# u'terms term'
# u'issues issue'
# u'was wa'
# u'as a'
# u'targets target'
# u'boxes box'
# u'as a'
# u'was wa'
# u'as a'
# u'works work'
# u'as a'
# u'was wa'
# u'plans plan'
# u'systems system'
# u'clues clue'
# u'has ha'
# u'was wa'
# u'benefits benefit'
# u'kinds kind'
# u'managers manager'
# u'conversations conversation'
# u'voices voice'
# u'as a'
# u'was wa'
# u'as a'
# u'workshops workshop'
# u'has ha'
# u'as a'
# u'has ha'
# u'workshops workshop'
# u'as a'
# u'groups group'
# u'colleagues colleague'
# u'elements element'
# u'authors author'
# u'claims claim'
# u'tools tool'
# u'techniques technique'
# u'streams stream'
# u'comments comment'
# u'participants participant'
# u'experiences experience'
# u'authors author'
# u'claims claim'
# u'techniques technique'
# u'was wa'
# u'workshops workshop'
# u'as a'
# u'experiences experience'
# u'events event'
# u'teams team'
# u'teams team'
# u'tasks task'
# u'teams team'
# u'was wa'
# u'as a'
# u'reflections reflection'
# u'outcomes outcome'
# u'teams team'
# u'was wa'
# u'outcomes outcome'
# u'authors author'
# u'foundations foundation'
# u'solutions solution'
# u'services service'
# u'areas area'
# u'initiatives initiative'
# u'has ha'
# u'origins origin'
# u'values value'
# u'uses us'
# u'adults adult'
# u'ways way'
# u'practitioners practitioner'
# u'projects project'
# u'decisions decision'
# u'policies policy'
# u'organizations organization'
# u'voices voice'
# u'systems system'
# u'systems system'
# u'its it'
# u'tools tool'
# u'reflections reflection'

# %% [markdown]
# So is like stemming, or maybe not

# %%
'''Printing all the words that stemming is different than the lemma'''
for tokenized_sentence in tokenized_sentences:
    for token in tokenized_sentence:
        ltoken = lemmatizer.lemmatize(token)
        stoken=stemmer.stem(token)
        if (ltoken!=stoken):
            pprint.pprint(token+' '+stoken+' '+ltoken)
# Out:
# u'Open open Open'
# u'Research research Research'
# u'Online onlin Online'
# u'The the The'
# u'Open open Open'
# u'University univers University'
# u'repository repositori repository'
# u'publications public publication'
# u'Applying appli Applying'
# u'Systemic system Systemic'
# u'Project project Project'
# u'Management manag Management'
# u'Approaches approach Approaches'
# u'National nation National'
# u'Health health Health'
# u'Service servic Service'
# u'Journal journal Journal'
# u'Article articl Article'
# u'How how How'
# u'Bell bell Bell'
# u'Simon simon Simon'
# u'Christina christina Christina'
# u'Ann ann Ann'
# u'Applying appli Applying'
# u'Systemic system Systemic'
# u'Project project Project'
# u'Management manag Management'
# u'Approaches approach Approaches'
# u'National nation National'
# u'Health health Health'
# u'Service servic Service'
# u'Systemic system Systemic'
# u'Practice practic Practice'
# u'Action action Action'
# u'Research research Research'
# u'For for For'
# u'guidance guidanc guidance'
# u'citations citat citation'
# u'FAQs faq FAQs'
# u'recorded record recorded'
# u'Version version Version'
# u'recorded record recorded'
# u'Link link Link'
# u'article articl article'
# u'publisher publish publisher'
# u'website websit website'
# u'Copyright copyright Copyright'
# u'Moral moral Moral'
# u'Rights right Rights'
# u'articles articl article'
# u'this thi this'
# u'retained retain retained'
# u'individual individu individual'
# u'For for For'
# u'information inform information'
# u'Open open Open'
# u'Research research Research'
# u'Online onlin Online'
# u'policy polici policy'
# u'reuse reus reuse'
# u'materials materi material'
# u'please pleas please'
# u'policies polici policy'
# u'Applying appli Applying'
# u'Systemic system Systemic'
# u'Project project Project'
# u'Management manag Management'
# u'Approaches approach Approaches'
# u'National nation National'
# u'Health health Health'
# u'Service1 service1 Service1'
# u'Dr. dr. Dr.'
# u'Simon simon Simon'
# u'Bell bell Bell'
# u'Ann ann Ann'
# u'Christina christina Christina'
# u'Open open Open'
# u'Systems system Systems'
# u'Research research Research'
# u'Group group Group'
# u'Head head Head'
# u'Professional profession Professional'
# u'Development develop Development'
# u'Social social Social'
# u'Care care Care'
# u'Systems system Systems'
# u'Discipline disciplin Discipline'
# u'Kent kent Kent'
# u'County counti County'
# u'Council council Council'
# u'Open open Open'
# u'University univers University'
# u'Brenchley brenchley Brenchley'
# u'House hous House'
# u'BH-2 bh-2 BH-2'
# u'Training train Training'
# u'Milton milton Milton'
# u'Keynes keyn Keynes'
# u'Week week Week'
# u'Street street Street'
# u'MK7 mk7 MK7'
# u'6AA 6aa 6AA'
# u'Maidstone maidston Maidstone'
# u'ME14 me14 ME14'
# u'1RF 1rf 1RF'
# u'Ann.christina ann.christina Ann.christina'
# u'Abstract abstract Abstract'
# u'This thi This'
# u'observations observ observation'
# u'arising aris arising'
# u'on-going on-go on-going'
# u'systemic system systemic'
# u'planning plan planning'
# u'National nation National'
# u'Health health Health'
# u'Service servic Service'
# u'NHS nh NHS'
# u'Staffordshire staffordshir Staffordshire'
# u'Shropshire shropshir Shropshire'
# u'This thi This'
# u'application applic application'
# u'systemic system systemic'
# u'nature natur nature'
# u'methodologies methodolog methodology'
# u'outcomes outcom outcome'
# u'reflections reflect reflection'
# u'involved involv involved'
# u'various variou various'
# u'Whilst whilst Whilst'
# u'attempting attempt attempting'
# u'definitive definit definitive'
# u'conclusions conclus conclusion'
# u'believe believ believe'
# u'application applic application'
# u'systemic system systemic'
# u'Health health Health'
# u'Care care Care'
# u'professionals profession professional'
# u'range rang range'
# u'going go going'
# u'Keywords keyword Keywords'
# u'Systemic system Systemic'
# u'planning plan planning'
# u'management manag management'
# u'Accepted accept Accepted'
# u'Systemic system Systemic'
# u'Practice practic Practice'
# u'Action action Action'
# u'Research research Research'
# u'Vol vol Vol'
# u'Published publish Published'
# u'permission permiss permission'
# u'Staffordshire staffordshir Staffordshire'
# u'Shropshire shropshir Shropshire'
# u'Workforce workforc Workforce'
# u'Development develop Development'
# u'Directorate director Directorate'
# u'Contextual contextu Contextual'
# u'Background background Background'
# u'Study studi Study'
# u'The the The'
# u'study studi study'
# u'described describ described'
# u'this thi this'
# u'modernisation modernis modernisation'
# u'workforces workforc workforce'
# u'numerously numer numerously'
# u'documented document documented'
# u'McNulty mcnulti McNulty'
# u'Ferlie ferli Ferlie'
# u'More more More'
# u'specifically specif specifically'
# u'this thi this'
# u'arises aris arises'
# u'experiences experi experience'
# u'application applic application'
# u'systemic system systemic'
# u'workforce workforc workforce'
# u're-modelling re-model re-modelling'
# u'following follow following'
# u'establishment establish establishment'
# u'Associate associ Associate'
# u'Director director Director'
# u'Workforce workforc Workforce'
# u'Development develop Development'
# u'ADWD adwd ADWD'
# u'Health health Health'
# u'Social social Social'
# u'Care care Care'
# u'Integration integr Integration'
# u'Shropshire shropshir Shropshire'
# u'Staffordshire staffordshir Staffordshire'
# u'Workforce workforc Workforce'
# u'Development develop Development'
# u'Confederation confeder Confederation'
# u'The the The'
# u'funded fund funded'
# u'NHS nh NHS'
# u'employer employ employer'
# u'Local local Local'
# u'Authority author Authority'
# u'Social social Social'
# u'Services servic Services'
# u'Departments depart Departments'
# u'boundaries boundari boundary'
# u'Shropshire shropshir Shropshire'
# u'Staffordshire staffordshir Staffordshire'
# u'Strategic strateg Strategic'
# u'Health health Health'
# u'Authority author Authority'
# u'The the The'
# u'practitioner practition practitioner'
# u'selection select selection'
# u'systemic system systemic'
# u'applied appli applied'
# u'professionals profession professional'
# u'evolving evolv evolving'
# u'manage manag manage'
# u'complexity complex complexity'
# u'working work working'
# u'environment environ environment'
# u'this thi this'
# u'reflections reflect reflection'
# u'commissioning commiss commissioning'
# u'researcher research researcher'
# u'included includ included'
# u'provide provid provide'
# u'accurate accur accurate'
# u'induction induct induction'
# u'as as a'
# u'provide provid provide'
# u'sense sens sense'
# u'practical practic practical'
# u'issues issu issue'
# u'arise aris arise'
# u'situations situat situation'
# u'The the The'
# u'workforce workforc workforce'
# u'climate climat climate'
# u'continuous continu continuous'
# u'change chang change'
# u'invoking invok invoking'
# u'rethinking rethink rethinking'
# u'development develop development'
# u'comprehensive comprehens comprehensive'
# u'discussion discuss discussion'
# u'issues issu issue'
# u'Davies davi Davies'
# u'The the The'
# u'NHS nh NHS'
# u'workforce workforc workforce'
# u'Staffordshire staffordshir Staffordshire'
# u'Shropshire shropshir Shropshire'
# u'focus focu focus'
# u'this thi this'
# u'workforce workforc workforce'
# u'estimated estim estimated'
# u'nearly nearli nearly'
# u'as as a'
# u'largely larg largely'
# u'employed employ employed'
# u'outside outsid outside'
# u'Social social Social'
# u'Services servic Services'
# u'Departments depart Departments'
# u'Rather rather Rather'
# u'supplied suppli supplied'
# u'hundreds hundr hundred'
# u'different differ different'
# u'private privat private'
# u'charitable charit charitable'
# u'business busi business'
# u'employers employ employer'
# u'organisations organis organisation'
# u'related relat related'
# u'challenges challeng challenge'
# u'Harris harri Harris'
# u'Cairns cairn Cairns'
# u'The the The'
# u'ADWD adwd ADWD'
# u'expected expect expected'
# u'interface interfac interface'
# u'NHS nh NHS'
# u'workforce workforc workforce'
# u'development develop development'
# u'issues issu issue'
# u'Shropshire shropshir Shropshire'
# u'Staffordshire staffordshir Staffordshire'
# u'Workforce workforc Workforce'
# u'Development develop Development'
# u'Confederation confeder Confederation'
# u'established establish established'
# u'April april April'
# u'strategies strategi strategy'
# u'national nation national'
# u'modernisation modernis modernisation'
# u'workforce workforc workforce'
# u'Its it Its'
# u'formation format formation'
# u'NHS nh NHS'
# u'restructuring restructur restructuring'
# u'Regional region Regional'
# u'Authorities author Authorities'
# u'devolved devolv devolved'
# u'commissioning commiss commissioning'
# u'confederations confeder confederation'
# u'country countri country'
# u'Workforce workforc Workforce'
# u'Development develop Development'
# u'Confederations confeder Confederations'
# u'England england England'
# u'integrated integr integrated'
# u'Strategic strateg Strategic'
# u'Health health Health'
# u'Authorities author Authorities'
# u'adding ad adding'
# u'another anoth another'
# u'dimension dimens dimension'
# u'performance perform performance'
# u'management manag management'
# u'constantly constantli constantly'
# u'expanding expand expanding'
# u'since sinc since'
# u'being be being'
# u'Shropshire shropshir Shropshire'
# u'Staffordshire staffordshir Staffordshire'
# u'this thi this'
# u'Confederation confeder Confederation'
# u'become becom become'
# u'Workforce workforc Workforce'
# u'Development develop Development'
# u'Directorate director Directorate'
# u'WDD wdd WDD'
# u'Shropshire shropshir Shropshire'
# u'Staffordshire staffordshir Staffordshire'
# u'Strategic strateg Strategic'
# u'Health health Health'
# u'Authority author Authority'
# u'alongside alongsid alongside'
# u'Directorates director Directorates'
# u'Service servic Service'
# u'Improvement improv Improvement'
# u'Health health Health'
# u'Strategy strategi Strategy'
# u'Performance perform Performance'
# u'Finance financ Finance'
# u'The the The'
# u'WDD wdd WDD'
# u'tasked task tasked'
# u'ensuring ensur ensuring'
# u'implementation implement implementation'
# u'national nation national'
# u'policy polici policy'
# u'Further further Further'
# u'developing develop developing'
# u'this thi this'
# u'expectation expect expectation'
# u'WDD wdd WDD'
# u'performance perform performance'
# u'managing manag managing'
# u'Human human Human'
# u'Resource resourc Resource'
# u'improvement improv improvement'
# u'Health health Health'
# u'Trusts trust Trusts'
# u'Department depart Department'
# u'Health health Health'
# u'DoH doh DoH'
# u'requirements requir requirement'
# u'This thi This'
# u'alongside alongsid alongside'
# u'continuing continu continuing'
# u'commissioning commiss commissioning'
# u'university univers university'
# u'provision provis provision'
# u'professional profession professional'
# u'programmes programm programme'
# u'funding fund funding'
# u'secondment second secondment'
# u'Problem problem Problem'
# u'issues issu issue'
# u'WDD wdd WDD'
# u'manage manag manage'
# u'Problems problem Problems'
# u'shortage shortag shortage'
# u'NHS nh NHS'
# u'documented document documented'
# u'example exampl example'
# u'Stubbings stub Stubbings'
# u'Scott scott Scott'
# u'Editorial editori Editorial'
# u'development develop development'
# u'decentralised decentralis decentralised'
# u'working work working'
# u'seems seem seems'
# u'patchy patchi patchy'
# u'Deeming deem Deeming'
# u'training train training'
# u'effectiveness effect effectiveness'
# u'remains remain remains'
# u'critical critic critical'
# u'Hewison hewison Hewison'
# u'Griffiths griffith Griffiths'
# u'Kristina kristina Kristina'
# u'flexible flexibl flexible'
# u'workforces workforc workforce'
# u'responding respond responding'
# u'flexible flexibl flexible'
# u'autonomous autonom autonomous'
# u'remains remain remains'
# u'philosophers philosoph philosopher'
# u'For for For'
# u'discussion discuss discussion'
# u'this thi this'
# u'Huselid huselid Huselid'
# u'Becker becker Becker'
# u'Staffordshire staffordshir Staffordshire'
# u'Shropshire shropshir Shropshire'
# u'WDD wdd WDD'
# u'specific specif specific'
# u'development develop development'
# u'capacity capac capacity'
# u'range rang range'
# u'management manag management'
# u'techniques techniqu technique'
# u'The the The'
# u'advertisement advertis advertisement'
# u'ADWD adwd ADWD'
# u'implies impli implies'
# u'as as a'
# u'modernising modernis modernising'
# u'service servic service'
# u'delivery deliveri delivery'
# u'effective effect effective'
# u'integration integr integration'
# u'workforce workforc workforce'
# u'development develop development'
# u'strategies strategi strategy'
# u'initiatives initi initiative'
# u'The the The'
# u'enormous enorm enormous'
# u'multi-faceted multi-facet multi-faceted'
# u'What what What'
# u'working work working'
# u'achieve achiev achieve'
# u'only onli only'
# u'understanding understand understanding'
# u'functional function functional'
# u'demonstrated demonstr demonstrated'
# u'workforce workforc workforce'
# u'deliver deliv deliver'
# u'services servic service'
# u'specification specif specification'
# u'required requir required'
# u'deliver deliv deliver'
# u'evolving evolv evolving'
# u'emerging emerg emerging'
# u'future futur future'
# u'service servic service'
# u'Guardian guardian Guardian'
# u'newspaper newspap newspaper'
# u'June june June'
# u'The the The'
# u'application applic application'
# u'systemic system systemic'
# u'development develop development'
# u'WDD wdd WDD'
# u'describing describ describing'
# u'as as a'
# u'Social social Social'
# u'Care care Care'
# u'WDC wdc WDC'
# u'absolutely absolut absolutely'
# u'this thi this'
# u'professional profession professional'
# u'advocacy advocaci advocacy'
# u'The the The'
# u'pitfalls pitfal pitfall'
# u'demarcation demarc demarcation'
# u'adversarial adversari adversarial'
# u'budgeting budget budgeting'
# u'territorial territori territorial'
# u'thinking think thinking'
# u'essential essenti essential'
# u'multi-skilled multi-skil multi-skilled'
# u'This thi This'
# u'systemic system systemic'
# u'quality qualiti quality'
# u'emphasised emphasis emphasised'
# u'following follow following'
# u'including includ including'
# u'integration integr integration'
# u'modernisation modernis modernisation'
# u'Health health Health'
# u'Social social Social'
# u'Care care Care'
# u'workforce workforc workforce'
# u'development develop development'
# u'integrated integr integrated'
# u'workforce workforc workforce'
# u'planning plan planning'
# u'development develop development'
# u'NHS nh NHS'
# u'Social social Social'
# u'Care care Care'
# u'scoping scope scoping'
# u'potential potenti potential'
# u'reducing reduc reducing'
# u'demarcation demarc demarcation'
# u'changing chang changing'
# u'working work working'
# u'practices practic practice'
# u'initiating initi initiating'
# u'produce produc produce'
# u'change chang change'
# u'initiating initi initiating'
# u'education educ education'
# u'development develop development'
# u'qualification qualif qualification'
# u'Guardian guardian Guardian'
# u'newspaper newspap newspaper'
# u'June june June'
# u'Following follow Following'
# u'appointment appoint appointment'
# u'multi-skilled multi-skil multi-skilled'
# u'initiating initi initiating'
# u'avoiding avoid avoiding'
# u'demarcations demarc demarcation'
# u'territorial territori territorial'
# u'thinking think thinking'
# u'recognised recognis recognised'
# u'Ann ann Ann'
# u'as as a'
# u'demonstrating demonstr demonstrating'
# u'systemic system systemic'
# u'Such such Such'
# u'impose impos impose'
# u'responsibilities respons responsibility'
# u'organisation organis organisation'
# u'Charlotte charlott Charlotte'
# u'Roberts robert Roberts'
# u'Jennifer jennif Jennifer'
# u'Kemeny kemeni Kemeny'
# u'argued argu argued'
# u'You you You'
# u'dividing divid dividing'
# u'everyone everyon everyone'
# u'together togeth together'
# u'Thus thu Thus'
# u'practice practic practice'
# u'thinking think thinking'
# u'as as a'
# u'individual individu individual'
# u'because becaus because'
# u'discipline disciplin discipline'
# u'because becaus because'
# u'bringing bring bringing'
# u'as as a'
# u'many mani many'
# u'perspectives perspect perspective'
# u'as as a'
# u'possible possibl possible'
# u'together togeth together'
# u'necessary necessari necessary'
# u'represented repres represented'
# u'clearance clearanc clearance'
# u'management manag management'
# u'propose propos propose'
# u'cross-functional cross-funct cross-functional'
# u'solutions solut solution'
# u'sensitivities sensit sensitivity'
# u'politics polit politics'
# u'Senge seng Senge'
# u'Ross ross Ross'
# u'Figure figur Figure'
# u'Members member Members'
# u'WDD wdd WDD'
# u'using use using'
# u'Soft soft Soft'
# u'Systems system Systems'
# u'Methodology methodolog Methodology'
# u'Approaching approach Approaching'
# u'Systemic system Systemic'
# u'Intervention intervent Intervention'
# u'appointment appoint appointment'
# u'Ann ann Ann'
# u'reflected reflect reflected'
# u'being be being'
# u'towards toward towards'
# u'building build building'
# u'early earli early'
# u'reflective reflect reflective'
# u'colleague colleagu colleague'
# u'picture pictur picture'
# u'thinking think thinking'
# u'ability abil ability'
# u'promoting promot promoting'
# u'breaking break breaking'
# u'change chang change'
# u'something someth something'
# u'manageable manag manageable'
# u'Private privat Private'
# u'ADWD adwd ADWD'
# u'colleague colleagu colleague'
# u'WDD wdd WDD'
# u'separate separ separate'
# u'Ann ann Ann'
# u'developed develop developed'
# u'thinking think thinking'
# u'as as a'
# u'follows follow follows'
# u'being be being'
# u'programme programm programme'
# u'manager manag manager'
# u'range rang range'
# u'stakeholders stakehold stakeholder'
# u'together togeth together'
# u'achieve achiev achieve'
# u'something someth something'
# u'wanting want wanting'
# u'Two two Two'
# u'exactly exactli exactly'
# u'doing do doing'
# u'Private privat Private'
# u'ADWD adwd ADWD'
# u'colleague colleagu colleague'
# u'WDD wdd WDD'
# u'provide provid provide'
# u'Ann ann Ann'
# u'approached approach approached'
# u'Simon simon Simon'
# u'structured structur structured'
# u'systemic system systemic'
# u'intervention intervent intervention'
# u'training train training'
# u'private privat private'
# u'mentoring mentor mentoring'
# u'this thi this'
# u'WDD wdd WDD'
# u'clearly clearli clearly'
# u'stated state stated'
# u'focused focus focused'
# u'engagement engag engagement'
# u'series seri series'
# u'training train training'
# u'systemic system systemic'
# u'scoping scope scoping'
# u'planning plan planning'
# u'management manag management'
# u'Actual actual Actual'
# u'used use used'
# u'as as a'
# u'basis basi basis'
# u'training train training'
# u'Team team Team'
# u'based base based'
# u'applied appli applied'
# u'training train training'
# u'The the The'
# u'completed complet completed'
# u'October octob October'
# u'That that That'
# u'tailored tailor tailored'
# u'Executive execut Executive'
# u'That that That'
# u'on-going on-go on-going'
# u'provided provid provided'
# u'The the The'
# u'nature natur nature'
# u'adopted adopt adopted'
# u'agreed agre agreed'
# u'systemic system systemic'
# u'participatory participatori participatory'
# u'Ann ann Ann'
# u'gained gain gained'
# u'experience experi experience'
# u'participative particip participative'
# u'range rang range'
# u'London london London'
# u'Rugby rugbi Rugby'
# u'convinced convinc convinced'
# u'Professionals profession Professionals'
# u'Staffordshire staffordshir Staffordshire'
# u'Shropshire shropshir Shropshire'
# u'able abl able'
# u'advise advis advise'
# u'integrated integr integrated'
# u'workforce workforc workforce'
# u'planning plan planning'
# u'development develop development'
# u'achieved achiev achieved'
# u'only onli only'
# u'achieved achiev achieved'
# u'consultation consult consultation'
# u'stakeholders stakehold stakeholder'
# u'Harvesting harvest Harvesting'
# u'stakeholders stakehold stakeholder'
# u'gaining gain gaining'
# u'understanding understand understanding'
# u'perspectives perspect perspective'
# u'assumptions assumpt assumption'
# u'important import important'
# u'route rout route'
# u'The the The'
# u'requirement requir requirement'
# u'WDD wdd WDD'
# u'provide provid provide'
# u'Health health Health'
# u'Care care Care'
# u'Professionals profession Professionals'
# u'transferable transfer transferable'
# u'planning plan planning'
# u'management manag management'
# u'development develop development'
# u'judged judg judged'
# u'systemic system systemic'
# u'focused focus focused'
# u'solving solv solving'
# u'likely like likely'
# u'this thi this'
# u'Again again Again'
# u'Ann ann Ann'
# u'able abl able'
# u'advise advis advise'
# u'working work working'
# u'practices practic practice'
# u'achievable achiev achievable'
# u'provide provid provide'
# u'intelligence intellig intelligence'
# u'workforce workforc workforce'
# u'issues issu issue'
# u'create creat create'
# u'mini-environments mini-environ mini-environments'
# u'enable enabl enable'
# u'qualitatively qualit qualitatively'
# u'using use using'
# u'participative particip participative'
# u'inquiry inquiri inquiry'
# u'analysis analysi analysis'
# u'shared share shared'
# u'understanding understand understanding'
# u'involved involv involved'
# u'differing differ differing'
# u'cultures cultur culture'
# u'working work working'
# u'practices practic practice'
# u'being be being'
# u'applied appli applied'
# u'NHS nh NHS'
# u'Social social Social'
# u'Care care Care'
# u'organisations organis organisation'
# u'agreed agre agreed'
# u'Ann ann Ann'
# u'Simon simon Simon'
# u'training train training'
# u'involve involv involve'
# u'pipeline pipelin pipeline'
# u'This thi This'
# u'concentrate concentr concentrate'
# u'participants particip participant'
# u'provide provid provide'
# u'delivering deliv delivering'
# u'during dure during'
# u'learning learn learning'
# u'Teams team Teams'
# u'engaged engag engaged'
# u'Again again Again'
# u'this thi this'
# u'intended intend intended'
# u'cooperating cooper cooperating'
# u'colleagues colleagu colleague'
# u'provide provid provide'
# u'on-going on-go on-going'
# u'as as a'
# u'being be being'
# u'contribute contribut contribute'
# u'participate particip participate'
# u'Ann ann Ann'
# u'this thi this'
# u'The the The'
# u'releasing releas releasing'
# u'transformations transform transformation'
# u'needed need needed'
# u'achieve achiev achieve'
# u'required requir required'
# u'modernisation modernis modernisation'
# u'different differ different'
# u'people peopl people'
# u'affected affect affected'
# u'workforce workforc workforce'
# u'very veri very'
# u'motivating motiv motivating'
# u'The the The'
# u'original origin original'
# u'completion complet completion'
# u'September septemb September'
# u'This thi This'
# u'subsequently subsequ subsequently'
# u'shifted shift shifted'
# u'October octob October'
# u'early earli early'
# u'The the The'
# u'executive execut executive'
# u'introduced introduc introduced'
# u'This thi This'
# u'plus plu plus'
# u'as as a'
# u'WDD wdd WDD'
# u'understanding understand understanding'
# u'organisational organis organisational'
# u'hierarchy hierarchi hierarchy'
# u'This thi This'
# u'experience experi experience'
# u'initiatives initi initiative'
# u'Finally final Finally'
# u'agreed agre agreed'
# u'supported support supported'
# u'during dure during'
# u'run-time run-tim run-time'
# u'This thi This'
# u'professionals profession professional'
# u'working work working'
# u'specific specif specific'
# u'issues issu issue'
# u'development develop development'
# u'proposals propos proposal'
# u'Methodologies methodolog Methodologies'
# u'applied appli applied'
# u'The the The'
# u'Systems system Systems'
# u'Department depart Department'
# u'Open open Open'
# u'University univers University'
# u'teaching teach teaching'
# u'researching research researching'
# u'systemic system systemic'
# u'decades decad decade'
# u'Although although Although'
# u'changed chang changed'
# u'developed develop developed'
# u'methodology methodolog methodology'
# u'applied appli applied'
# u'undergraduate undergradu undergraduate'
# u'postgraduate postgradu postgraduate'
# u'teaching teach teaching'
# u'Soft soft Soft'
# u'Systems system Systems'
# u'Methodology methodolog Methodology'
# u'SSM ssm SSM'
# u'This thi This'
# u'advocated advoc advocated'
# u'subsequently subsequ subsequently'
# u'developed develop developed'
# u'Checkland checkland Checkland'
# u'Checkland checkland Checkland'
# u'Checkland checkland Checkland'
# u'Scholes schole Scholes'
# u'Checkland checkland Checkland'
# u'Checkland checkland Checkland'
# u'included includ included'
# u'Open open Open'
# u'University univers University'
# u'courses cours course'
# u'developed develop developed'
# u'distance distanc distance'
# u'learning learn learning'
# u'Open open Open'
# u'University univers University'
# u'Open open Open'
# u'University univers University'
# u'There there There'
# u'discussion discuss discussion'
# u'SSM ssm SSM'
# u'Stowell stowel Stowell'
# u'Holland holland Holland'
# u'Haynes hayn Haynes'
# u'Jayaratna jayaratna Jayaratna'
# u'Probert probert Probert'
# u'Flood flood Flood'
# u'Holwell holwel Holwell'
# u'applied appli applied'
# u'variety varieti variety'
# u'recently recent recently'
# u'turned turn turned'
# u'information inform information'
# u'Checkland checkland Checkland'
# u'Holwell holwel Holwell'
# u'SSM ssm SSM'
# u'range rang range'
# u'advocate advoc advocate'
# u'development develop development'
# u'planning plan planning'
# u'as as a'
# u'systemic system systemic'
# u'encouraging encourag encouraging'
# u'imaginative imagin imaginative'
# u'solving solv solving'
# u'example exampl example'
# u'Brookfield brookfield Brookfield'
# u'Issacs issac Issacs'
# u'Wenger wenger Wenger'
# u'From from From'
# u'perspective perspect perspective'
# u'listed list listed'
# u'as as a'
# u'capacity capac capacity'
# u'SSM ssm SSM'
# u'very veri very'
# u'very veri very'
# u'quickly quickli quickly'
# u'adopted adopt adopted'
# u'rapidly rapidli rapidly'
# u'SSM ssm SSM'
# u'applied appli applied'
# u'as as a'
# u'provide provid provide'
# u'outcomes outcom outcome'
# u'essential essenti essential'
# u'picture pictur picture'
# u'definition definit definition'
# u'activity activ activity'
# u'conceptual conceptu conceptual'
# u'SSM ssm SSM'
# u'used use used'
# u'participatory participatori participatory'
# u'mixed mix mixed'
# u'stakeholders stakehold stakeholder'
# u'SSM ssm SSM'
# u'solving solv solving'
# u'designed design designed'
# u'focus focu focus'
# u'intangible intang intangible'
# u'organisations organis organisation'
# u'NHS nh NHS'
# u'SSM ssm SSM'
# u'as as a'
# u'This thi This'
# u'allows allow allows'
# u'planning plan planning'
# u'SSM ssm SSM'
# u'techniques techniqu technique'
# u'All all All'
# u'keyed key keyed'
# u'requirements requir requirement'
# u'WDD wdd WDD'
# u'as as a'
# u'engagement engag engagement'
# u'specifically specif specifically'
# u'scoping scope scoping'
# u'early earli early'
# u'planning plan planning'
# u'developing develop developing'
# u'taking take taking'
# u'implementation implement implementation'
# u'monitoring monitor monitoring'
# u'evaluation evalu evaluation'
# u'Logical logic Logical'
# u'Framework framework Framework'
# u'Approach approach Approach'
# u'LFA lfa LFA'
# u'applied appli applied'
# u'variety varieti variety'
# u'Coleman coleman Coleman'
# u'Bell bell Bell'
# u'Baccarini baccarini Baccarini'
# u'Kumar kumar Kumar'
# u'Corbridge corbridg Corbridge'
# u'Biggs bigg Biggs'
# u'Smith smith Smith'
# u'Crawford crawford Crawford'
# u'Crawford crawford Crawford'
# u'Dale dale Dale'
# u'as as a'
# u'SSM ssm SSM'
# u'Open open Open'
# u'University univers University'
# u'Systems system Systems'
# u'teaching teach teaching'
# u'Open open Open'
# u'University univers University'
# u'Open open Open'
# u'University univers University'
# u'Open open Open'
# u'University univers University'
# u'LFA lfa LFA'
# u'involves involv involves'
# u'development develop development'
# u'containing contain containing'
# u'story stori story'
# u'narrative narr narrative'
# u'summary summari summary'
# u'assumptions assumpt assumption'
# u'noted note noted'
# u'as as a'
# u'being be being'
# u'under-represented under-repres under-represented'
# u'planning plan planning'
# u'British british British'
# u'Computer comput Computer'
# u'Society societi Society'
# u'Royal royal Royal'
# u'Academy academi Academy'
# u'Engineering engin Engineering'
# u'measuring measur measuring'
# u'performance perform performance'
# u'sustainability sustain sustainability'
# u'strategy strategi strategy'
# u'Table tabl Table'
# u'The the The'
# u'LFA lfa LFA'
# u'provide provid provide'
# u'systemic system systemic'
# u'highly highli highly'
# u'structured structur structured'
# u'capture captur capture'
# u'outcomes outcom outcome'
# u'SSM ssm SSM'
# u'Table tabl Table'
# u'The the The'
# u'Logical logic Logical'
# u'Framework framework Framework'
# u'Narrative narr Narrative'
# u'summary summari summary'
# u'The the The'
# u'Goal goal Goal'
# u'purposeful purpos purposeful'
# u'activity activ activity'
# u'Always alway Always'
# u'purpose purpos purpose'
# u'Aspirational aspir Aspirational'
# u'Verifiable verifi Verifiable'
# u'indicators indic indicator'
# u'The the The'
# u'measured measur measured'
# u'qualitative qualit qualitative'
# u'quantitative quantit quantitative'
# u'strategic strateg strategic'
# u'indicators indic indicator'
# u'Means mean Means'
# u'verification verif verification'
# u'Indicators indic Indicators'
# u'measured measur measured'
# u'focus focu focus'
# u'questionnaire questionnair questionnaire'
# u'Assumptions assumpt Assumptions'
# u'The the The'
# u'unachievable unachiev unachievable'
# u'The the The'
# u'purpose purpos purpose'
# u'purposeful purpos purposeful'
# u'activity activ activity'
# u'including includ including'
# u'beneficiaries beneficiari beneficiary'
# u'implementers implement implementers'
# u'transformation transform transformation'
# u'assumption assumpt assumption'
# u'The the The'
# u'purpose purpos purpose'
# u'measured measur measured'
# u'qualitative qualit qualitative'
# u'quantitative quantit quantitative'
# u'sustainability sustain sustainability'
# u'indicators indic indicator'
# u'SIs si SIs'
# u'Indicators indic Indicators'
# u'measured measur measured'
# u'focus focu focus'
# u'questionnaire questionnair questionnaire'
# u'The the The'
# u'assumptions assumpt assumption'
# u'unrealisable unrealis unrealisable'
# u'unachievable unachiev unachievable'
# u'this thi this'
# u'purpose purpos purpose'
# u'achieved achiev achieved'
# u'The the The'
# u'purposeful purpos purposeful'
# u'activity activ activity'
# u'Output output Output'
# u'measured measur measured'
# u'usually usual usually'
# u'quantitatively quantit quantitatively'
# u'indicators indic indicator'
# u'IIs ii IIs'
# u'Indicators indic Indicators'
# u'usually usual usually'
# u'measured measur measured'
# u'questionnaire questionnair questionnaire'
# u'The the The'
# u'assumptions assumpt assumption'
# u'purpose purpos purpose'
# u'unrealisable unrealis unrealisable'
# u'unachievable unachiev unachievable'
# u'achieved achiev achieved'
# u'The the The'
# u'activities activ activity'
# u'purposeful purpos purposeful'
# u'activity activ activity'
# u'Activity activ Activity'
# u'measured measur measured'
# u'quantitatively quantit quantitatively'
# u'performance perform performance'
# u'indicators indic indicator'
# u'PIs pi PIs'
# u'Indicators indic Indicators'
# u'measured measur measured'
# u'questionnaire questionnair questionnaire'
# u'The the The'
# u'assumptions assumpt assumption'
# u'unrealisable unrealis unrealisable'
# u'unachievable unachiev unachievable'
# u'activities activ activity'
# u'successful success successful'
# u'Bell bell Bell'
# u'applied appli applied'
# u'this thi this'
# u'specifically specif specifically'
# u'as as a'
# u'explore explor explore'
# u'outcomes outcom outcome'
# u'SSM ssm SSM'
# u'analysis analysi analysis'
# u'Bell bell Bell'
# u'Although although Although'
# u'numerous numer numerous'
# u'certainly certainli certainly'
# u'applied appli applied'
# u'non-participatory non-participatori non-participatory'
# u'Gasper gasper Gasper'
# u'Gasper gasper Gasper'
# u'remains remain remains'
# u'commonly commonli commonly'
# u'used use used'
# u'many mani many'
# u'Key key Key'
# u'virtues virtu virtue'
# u'LFA lfa LFA'
# u'applied appli applied'
# u'rapidly rapidli rapidly'
# u'lends lend lends'
# u'participatory participatori participatory'
# u'revised revis revised'
# u'readily readili readily'
# u'require requir require'
# u'software softwar software'
# u'solutions solut solution'
# u'planning plan planning'
# u'necessary necessari necessary'
# u'Again again Again'
# u'resonances reson resonance'
# u'Directorate director Directorate'
# u'Research research Research'
# u'Question question Question'
# u'Workshops workshop Workshops'
# u'outcomes outcom outcome'
# u'participant particip participant'
# u'reflections reflect reflection'
# u'May may May'
# u'Ann ann Ann'
# u'proposal propos proposal'
# u'discussion discuss discussion'
# u'WDD wdd WDD'
# u'Executive execut Executive'
# u'meeting meet meeting'
# u'They they They'
# u'already alreadi already'
# u'approved approv approved'
# u'experimental experiment experimental'
# u'Simon simon Simon'
# u'Bell bell Bell'
# u'explore explor explore'
# u'possibilities possibl possibility'
# u'methodologies methodolog methodology'
# u'introduce introduc introduce'
# u'systemic system systemic'
# u'techniques techniqu technique'
# u'effectively effect effectively'
# u'various variou various'
# u'WDD wdd WDD'
# u'recently recent recently'
# u'completed complet completed'
# u'Confederation confeder Confederation'
# u'Organisational organis Organisational'
# u'Structure structur Structure'
# u'Processes process Processes'
# u'recommended recommend recommended'
# u'needed need needed'
# u'management manag management'
# u'Ann ann Ann'
# u'proposed propos proposed'
# u'adopting adopt adopting'
# u'Logical logic Logical'
# u'Framework framework Framework'
# u'planning plan planning'
# u'agreeing agre agreeing'
# u'suitable suitabl suitable'
# u'scoping scope scoping'
# u'monitoring monitor monitoring'
# u'reviewing review reviewing'
# u'reporting report reporting'
# u'based base based'
# u'being be being'
# u'Ann ann Ann'
# u'facilitate facilit facilitate'
# u'developments develop development'
# u'Confederation confeder Confederation'
# u'responsible respons responsible'
# u'helping help helping'
# u'ensure ensur ensure'
# u'interface interfac interface'
# u'issues issu issue'
# u'prioritised prioritis prioritised'
# u'development develop development'
# u'using use using'
# u'instigation instig instigation'
# u'WDD wdd WDD'
# u'training train training'
# u'package packag package'
# u'planning plan planning'
# u'development develop development'
# u'together togeth together'
# u'based base based'
# u'user-focused user-focus user-focused'
# u'variations variat variation'
# u'SSM ssm SSM'
# u'LFA lfa LFA'
# u'Over over Over'
# u'April april April'
# u'May may May'
# u'training train training'
# u'Most most Most'
# u'focused focus focused'
# u'SSM ssm SSM'
# u'LFA lfa LFA'
# u'allowed allow allowed'
# u'The the The'
# u'needed need needed'
# u'scoping scope scoping'
# u'specific specif specific'
# u'as as a'
# u'opposed oppos opposed'
# u'planning plan planning'
# u'SSM ssm SSM'
# u'applied appli applied'
# u'notable notabl notable'
# u'as as a'
# u'progressed progress progressed'
# u'making make making'
# u'methodology methodolog methodology'
# u'sequence sequenc sequence'
# u'valuable valuabl valuable'
# u'Following follow Following'
# u'sample sampl sample'
# u'Participants particip Participants'
# u'asked ask asked'
# u'value valu value'
# u'various variou various'
# u'applied appli applied'
# u'Concerning concern Concerning'
# u'overall overal overall'
# u'SSM ssm SSM'
# u'Wayne wayn Wayne'
# u'Coombe coomb Coombe'
# u'Head head Head'
# u'Human human Human'
# u'Resources resourc Resources'
# u'Staffordshire staffordshir Staffordshire'
# u'Social social Social'
# u'Care care Care'
# u'Health health Health'
# u'following follow following'
# u'observations observ observation'
# u'experience experi experience'
# u'Logframe/Soft logframe/soft Logframe/Soft'
# u'Systems system Systems'
# u'very veri very'
# u'positive posit positive'
# u'useful use useful'
# u'ultimately ultim ultimately'
# u'simple simpl simple'
# u'technique techniqu technique'
# u'pulling pull pulling'
# u'together togeth together'
# u'individuals individu individual'
# u'different differ different'
# u'organisations organis organisation'
# u'organisation organis organisation'
# u'sometimes sometim sometimes'
# u'significantly significantli significantly'
# u'contradicting contradict contradicting'
# u'differing differ differing'
# u'consensus consensu consensus'
# u'any ani any'
# u'any ani any'
# u'individual individu individual'
# u'dominating domin dominating'
# u'imposing impos imposing'
# u'objectives object objective'
# u'experience experi experience'
# u'others other others'
# u'Figure figur Figure'
# u'picture pictur picture'
# u'workforce workforc workforce'
# u'planning plan planning'
# u'Colin colin Colin'
# u'Harriden harriden Harriden'
# u'Social social Social'
# u'Care care Care'
# u'Workforce workforc Workforce'
# u'Planner planner Planner'
# u'speaking speak speaking'
# u'Raising rais Raising'
# u'profile profil profile'
# u'Workforce workforc Workforce'
# u'Planning plan Planning'
# u'Social social Social'
# u'Care care Care'
# u'systemic system systemic'
# u'Enabled enabl Enabled'
# u'managers manag manager'
# u'Social social Social'
# u'Services servic Services'
# u'relative rel relative'
# u'disempowerment disempower disempowerment'
# u'devise devis devise'
# u'strategy strategi strategy'
# u'promote promot promote'
# u'workforce workforc workforce'
# u'planning plan planning'
# u'The the The'
# u'planned plan planned'
# u'outcome outcom outcome'
# u'directorate/CEO directorate/ceo directorate/CEO'
# u'workforce workforc workforce'
# u'planning plan planning'
# u'identify identifi identify'
# u'When when When'
# u'Colin colin Colin'
# u'involved involv involved'
# u'another anoth another'
# u'observed observ observed'
# u'The the The'
# u'enabled enabl enabled'
# u'large larg large'
# u'diverse divers diverse'
# u'managers manag manager'
# u'collaborate collabor collaborate'
# u'developing develop developing'
# u'purpose purpos purpose'
# u'Colin colin Colin'
# u'Logical logic Logical'
# u'Frameworks framework Frameworks'
# u'Log log Log'
# u'created creat created'
# u'focused focus focused'
# u'energy energi energy'
# u'identifying identifi identifying'
# u'assumptions assumpt assumption'
# u'addressed address addressed'
# u'Statement statement Statement'
# u'seemed seem seemed'
# u'specific specif specific'
# u'focus focu focus'
# u'But but But'
# u'working work working'
# u'another anoth another'
# u'LFA lfa LFA'
# u'observed observ observed'
# u'handing hand handing'
# u'previous previou previous'
# u'noted note noted'
# u'Learning learn Learning'
# u'disability disabl disability'
# u'workforce workforc workforce'
# u'strategy strategi strategy'
# u'existing exist existing'
# u'log-frame log-fram log-frame'
# u'participants particip participant'
# u'development develop development'
# u'purpose purpos purpose'
# u'Side-step side-step Side-step'
# u'helped help helped'
# u're-engage re-engag re-engage'
# u'Generally gener Generally'
# u'focus focu focus'
# u'towards toward towards'
# u'achievement achiev achievement'
# u'Figure figur Figure'
# u'Developing develop Developing'
# u'picture pictur picture'
# u'Figure figur Figure'
# u'early earli early'
# u'definition definit definition'
# u'training train training'
# u'strategy strategi strategy'
# u'Positive posit Positive'
# u'participants particip participant'
# u'critical critic critical'
# u'issues issu issue'
# u'remained remain remained'
# u'For for For'
# u'example exampl example'
# u'Fiona fiona Fiona'
# u'Shield shield Shield'
# u'Changing chang Changing'
# u'Working work Working'
# u'Practice practic Practice'
# u'Coordinator coordin Coordinator'
# u'noted note noted'
# u'outcomes outcom outcome'
# u'persevered persev persevered'
# u'logframe logfram logframe'
# u'useful use useful'
# u'ended end ended'
# u'economy economi economy'
# u'Although although Although'
# u'logframe logfram logframe'
# u'very veri very'
# u'important import important'
# u'reflecting reflect reflecting'
# u'culture cultur culture'
# u'When when When'
# u'informed inform informed'
# u'SHA sha SHA'
# u'Trust trust Trust'
# u'Directors director Directors'
# u'Modernisation modernis Modernisation'
# u'this thi this'
# u'asked ask asked'
# u'produce produc produce'
# u'this thi this'
# u'informal inform informal'
# u'thematic themat thematic'
# u'analysis analysi analysis'
# u'Purpose purpos Purpose'
# u'Outputs output Outputs'
# u'indicators indic indicator'
# u'attached attach attached'
# u'However howev However'
# u'Fiona fiona Fiona'
# u'pithy pithi pithy'
# u'systemic system systemic'
# u'specifically specif specifically'
# u'Logical logic Logical'
# u'Framework framework Framework'
# u'asking ask asking'
# u'Trust trust Trust'
# u'CWP cwp CWP'
# u'happy happi happy'
# u'Logframe logfram Logframe'
# u'honestly honestli honestly'
# u'really realli really'
# u'utilise utilis utilise'
# u'BUT but BUT'
# u'very veri very'
# u'useful use useful'
# u'working work working'
# u'periodically period periodically'
# u'quickly quickli quickly'
# u'becomes becom becomes'
# u'specific specif specific'
# u'indicators indic indicator'
# u'updating updat updating'
# u'However howev However'
# u'attached attach attached'
# u'quite quit quite'
# u'impressive impress impressive'
# u'cirulate cirul cirulate'
# u'people peopl people'
# u'CWP cwp CWP'
# u'CWP cwp CWP'
# u'facilitators facilit facilitator'
# u'direction direct direction'
# u'More more More'
# u'recently recent recently'
# u'Fiona fiona Fiona'
# u'added ad added'
# u'outcome outcom outcome'
# u'looking look looking'
# u're-designers re-design re-designers'
# u'become becom become'
# u'embedded embed embedded'
# u'Trusts trust Trusts'
# u'But but But'
# u'evaluate evalu evaluate'
# u'this thi this'
# u'happening happen happening'
# u'What what What'
# u'measures measur measure'
# u'as as a'
# u'The the The'
# u'Logframe logfram Logframe'
# u'seemed seem seemed'
# u'provide provid provide'
# u'very veri very'
# u'measure measur measure'
# u'themselves themselv themselves'
# u'Revisiting revisit Revisiting'
# u'Logframe logfram Logframe'
# u'as as a'
# u'evaluation evalu evaluation'
# u'exercise exercis exercise'
# u'using use using'
# u'as as a'
# u'added ad added'
# u'value valu value'
# u'Fiona fiona Fiona'
# u'producing produc producing'
# u'They they They'
# u'something someth something'
# u'Figure figur Figure'
# u'Tasks task Tasks'
# u'issues issu issue'
# u'arising aris arising'
# u'picture pictur picture'
# u'exercise exercis exercise'
# u'Lynne lynn Lynne'
# u'Lewis lewi Lewis'
# u'NVQ/Learning nvq/learn NVQ/Learning'
# u'Account account Account'
# u'Manager manag Manager'
# u'applied appli applied'
# u'Logical logic Logical'
# u'Framework framework Framework'
# u'Moving move Moving'
# u'Forward forward Forward'
# u'Together togeth Together'
# u'For for For'
# u'People peopl People'
# u'With with With'
# u'Learning learn Learning'
# u'Disability disabl Disability'
# u'Lynne lynn Lynne'
# u'as as a'
# u'follows follow follows'
# u'used use used'
# u'Logical logic Logical'
# u'Frameworks framework Frameworks'
# u'Skills skill Skills'
# u'Escalator escal Escalator'
# u'Learning learn Learning'
# u'Disabilities disabl Disabilities'
# u'The the The'
# u'logical logic logical'
# u'assisted assist assisted'
# u'systematic systemat systematic'
# u'achieving achiev achieving'
# u'sized size sized'
# u'progression progress progression'
# u'ultimate ultim ultimate'
# u'The the The'
# u'difference differ difference'
# u'personal person personal'
# u'this thi this'
# u'compared compar compared'
# u'average averag average'
# u'sized size sized'
# u'Thought thought Thought'
# u'this thi this'
# u'overall overal overall'
# u'ordinary ordinari ordinary'
# u'contingency conting contingency'
# u'learning learn learning'
# u'assisted assist assisted'
# u'having have having'
# u'dedicated dedic dedicated'
# u'working work working'
# u'logical logic logical'
# u'dedicated dedic dedicated'
# u'previous previou previous'
# u'logical logic logical'
# u'very veri very'
# u'large larg large'
# u'less less le'
# u'effective effect effective'
# u'Figure figur Figure'
# u'activity activ activity'
# u'Jane jane Jane'
# u'Rook rook Rook'
# u'Podiatry podiatri Podiatry'
# u'Continuous continu Continuous'
# u'Professional profession Professional'
# u'Development develop Development'
# u'WDD wdd WDD'
# u'managing manag managing'
# u'development develop development'
# u'agreed agre agreed'
# u'Shropshire shropshir Shropshire'
# u'Staffordshire staffordshir Staffordshire'
# u're-registration re-registr re-registration'
# u'Podiatrists podiatrist Podiatrists'
# u'Health health Health'
# u'Professional profession Professional'
# u'Council council Council'
# u'observed observ observed'
# u'There there There'
# u'something someth something'
# u'having have having'
# u'living live living'
# u'preferred prefer preferred'
# u'creative creativ creative'
# u'picture pictur picture'
# u'working work working'
# u'tackle tackl tackle'
# u'issues issu issue'
# u'timely time timely'
# u'reminder remind reminder'
# u'as as a'
# u'achieve achiev achieve'
# u'specific specif specific'
# u'Very veri Very'
# u'encouraging encourag encouraging'
# u'as as a'
# u'properly properli properly'
# u'used use used'
# u'this thi this'
# u'only onli only'
# u'definite definit definite'
# u'focus focu focus'
# u'steering steer steering'
# u'as as a'
# u'They they They'
# u'appreciated appreci appreciated'
# u'Authority author Authority'
# u'this thi this'
# u'planning plan planning'
# u'corporate corpor corporate'
# u'as as a'
# u'All all All'
# u'probably probabl probably'
# u'based base based'
# u'Microsoft microsoft Microsoft'
# u'Prince princ Prince'
# u'Probably probabl Probably'
# u'appealed appeal appealed'
# u'learning learn learning'
# u'private privat private'
# u'communication commun communication'
# u'Jane jane Jane'
# u'indicated indic indicated'
# u'liked like liked'
# u'used use used'
# u'methodology methodolog methodology'
# u'Steering steer Steering'
# u'Group group Group'
# u'beginning begin beginning'
# u'planning plan planning'
# u'doing do doing'
# u'proved prove proved'
# u'valuable valuabl valuable'
# u'Two two Two'
# u'included includ included'
# u'enabled enabl enabled'
# u'mixed mix mixed'
# u'range rang range'
# u'different differ different'
# u'managers manag manager'
# u'diverse divers diverse'
# u'understanding understand understanding'
# u'management manag management'
# u'Prinz prinz Prinz'
# u'Microsoft microsoft Microsoft'
# u'secondly secondli secondly'
# u'enabled enabl enabled'
# u'really realli really'
# u'meaningful meaning meaningful'
# u'conversations convers conversation'
# u'voices voic voice'
# u'being be being'
# u'valued valu valued'
# u'as as a'
# u'everyone everyon everyone'
# u'shared share shared'
# u'Figure figur Figure'
# u'Logical logic Logical'
# u'Framework framework Framework'
# u'development develop development'
# u'Ann ann Ann'
# u'as as a'
# u'commissioning commiss commissioning'
# u'officer offic officer'
# u'observed observ observed'
# u'The the The'
# u'dimension dimens dimension'
# u'emerged emerg emerged'
# u'as as a'
# u'powerful power powerful'
# u'this thi this'
# u'quality qualiti quality'
# u'learning learn learning'
# u'going go going'
# u'as as a'
# u'colleagues colleagu colleague'
# u'discussed discuss discussed'
# u'agree agre agree'
# u'Author author Author'
# u'Reflections reflect Reflections'
# u'Conclusions conclus Conclusions'
# u'already alreadi already'
# u'stated state stated'
# u'making make making'
# u'definitive definit definitive'
# u'WDD wdd WDD'
# u'experience experi experience'
# u'recalling recal recalling'
# u'initial initi initial'
# u'systemic system systemic'
# u'techniques techniqu technique'
# u'effectively effect effectively'
# u'various variou various'
# u'WDD wdd WDD'
# u'participants particip participant'
# u'experiences experi experience'
# u'seeking seek seeking'
# u'testing test testing'
# u'suggested suggest suggested'
# u'The the The'
# u'systemic system systemic'
# u'participatory participatori participatory'
# u'techniques techniqu technique'
# u'greeted greet greeted'
# u'as as a'
# u'change chang change'
# u'previous previou previous'
# u'experiences experi experience'
# u'SSM ssm SSM'
# u'provided provid provided'
# u'basis basi basis'
# u'widely wide widely'
# u'divergently diverg divergently'
# u'differently differ differently'
# u'Most most Most'
# u'involved involv involved'
# u'worked work worked'
# u'regularly regularli regularly'
# u'experience experi experience'
# u'helpful help helpful'
# u'understanding understand understanding'
# u'allocated alloc allocated'
# u'Those those Those'
# u'worked work worked'
# u'brainstorming brainstorm brainstorming'
# u'sharing share sharing'
# u'involved involv involved'
# u'helpful help helpful'
# u'understanding understand understanding'
# u'SSWDD sswdd SSWDD'
# u'LFA lfa LFA'
# u'as as a'
# u'being be being'
# u'readily readili readily'
# u'applicable applic applicable'
# u'planning plan planning'
# u'positive posit positive'
# u'reflections reflect reflection'
# u'negative neg negative'
# u'outcomes outcom outcome'
# u'Small small Small'
# u'seemed seem seemed'
# u'large larg large'
# u'The the The'
# u'readily readili readily'
# u'understandable understand understandable'
# u'usable usabl usable'
# u'another anoth another'
# u'The the The'
# u'sustainability sustain sustainability'
# u'Without without Without'
# u'renewal renew renewal'
# u'continued continu continued'
# u'investment invest investment'
# u'outcomes outcom outcome'
# u'dilute dilut dilute'
# u'summary summari summary'
# u'appears appear appears'
# u'important import important'
# u'foundations foundat foundation'
# u'essential essenti essential'
# u'collaboration collabor collaboration'
# u'deliver deliv deliver'
# u'workforce workforc workforce'
# u'solutions solut solution'
# u'challenging challeng challenging'
# u'trying tri trying'
# u'achieve achiev achieve'
# u'integrated integr integrated'
# u'services servic service'
# u'Staffordshire staffordshir Staffordshire'
# u'Shropshire shropshir Shropshire'
# u'Most most Most'
# u'critically critic critically'
# u'awareness awar awareness'
# u'importance import importance'
# u'methodical method methodical'
# u'planning plan planning'
# u'initiatives initi initiative'
# u'raised rais raised'
# u'References refer References'
# u'Baccarini baccarini Baccarini'
# u'The the The'
# u'Logical logic Logical'
# u'Framework framework Framework'
# u'Method method Method'
# u'Defining defin Defining'
# u'Success success Success'
# u'Project project Project'
# u'Management manag Management'
# u'Journal journal Journal'
# u'December decemb December'
# u'Bell bell Bell'
# u'Managing manag Managing'
# u'Learning learn Learning'
# u'Logical logic Logical'
# u'Frameworks framework Frameworks'
# u'MIS mi MIS'
# u'Project project Project'
# u'China china China'
# u'Human human Human'
# u'Systems system Systems'
# u'Management manag Management'
# u'Bell bell Bell'
# u'Logical logic Logical'
# u'Frameworks framework Frameworks'
# u'Aristotle aristotl Aristotle'
# u'Soft soft Soft'
# u'Systems system Systems'
# u'values valu value'
# u'uses use us'
# u'Logical logic Logical'
# u'Frameworks framework Frameworks'
# u'Public public Public'
# u'Administration administr Administration'
# u'Development develop Development'
# u'Biggs bigg Biggs'
# u'Smith smith Smith'
# u'Paradox paradox Paradox'
# u'Learning learn Learning'
# u'Project project Project'
# u'Cycle cycl Cycle'
# u'Management manag Management'
# u'Role role Role'
# u'Organizational organiz Organizational'
# u'Culture cultur Culture'
# u'World world World'
# u'Development develop Development'
# u'British british British'
# u'Computer comput Computer'
# u'Society societi Society'
# u'Royal royal Royal'
# u'Academy academi Academy'
# u'Engineering engin Engineering'
# u'Projects project Projects'
# u'The the The'
# u'Computer comput Computer'
# u'Bulletin bulletin Bulletin'
# u'July juli July'
# u'Brookfield brookfield Brookfield'
# u'Developing develop Developing'
# u'Critical critic Critical'
# u'Thinkers thinker Thinkers'
# u'Challenging challeng Challenging'
# u'explore explor explore'
# u'alternative altern alternative'
# u'thinking think thinking'
# u'acting act acting'
# u'New new New'
# u'York york York'
# u'Josey-Bass josey-bass Josey-Bass'
# u'Checkland checkland Checkland'
# u'Systems system Systems'
# u'Theory theori Theory'
# u'Management manag Management'
# u'Thinking think Thinking'
# u'American american American'
# u'Behavioral behavior Behavioral'
# u'Scientist scientist Scientist'
# u'Checkland checkland Checkland'
# u'The the The'
# u'Emergent emerg Emergent'
# u'Properties properti Properties'
# u'SSM ssm SSM'
# u'Use use Use'
# u'reflective reflect reflective'
# u'practitioners practition practitioner'
# u'Systemic system Systemic'
# u'Practice practic Practice'
# u'Action action Action'
# u'Research research Research'
# u'Checkland checkland Checkland'
# u'Holwell holwel Holwell'
# u'Information inform Information'
# u'Systems system Systems'
# u'Information inform Information'
# u'Systems system Systems'
# u'Making make Making'
# u'sense sens sense'
# u'Chichester chichest Chichester'
# u'Wiley wiley Wiley'
# u'Checkland checkland Checkland'
# u'Systems system Systems'
# u'thinking think thinking'
# u'Systems system Systems'
# u'Practise practis Practise'
# u'Chichester chichest Chichester'
# u'Wiley wiley Wiley'
# u'Checkland checkland Checkland'
# u'Scholes schole Scholes'
# u'Soft soft Soft'
# u'Systems system Systems'
# u'Methodology methodolog Methodology'
# u'Action action Action'
# u'Chichester chichest Chichester'
# u'Wiley wiley Wiley'
# u'Coleman coleman Coleman'
# u'Logical logic Logical'
# u'Framework framework Framework'
# u'Approach approach Approach'
# u'Monitoring monitor Monitoring'
# u'Evaluation evalu Evaluation'
# u'Agricultural agricultur Agricultural'
# u'Rural rural Rural'
# u'Development develop Development'
# u'Project project Project'
# u'Appraisal apprais Appraisal'
# u'Vol vol Vol'
# u'Crawford crawford Crawford'
# u'Promoting promot Promoting'
# u'Democracy democraci Democracy'
# u'Without without Without'
# u'Learning learn Learning'
# u'Within within Within'
# u'Democratization democrat Democratization'
# u'Crawford crawford Crawford'
# u'Project project Project'
# u'Monitoring monitor Monitoring'
# u'Evaluation evalu Evaluation'
# u'enhancing enhanc enhancing'
# u'efficiency effici efficiency'
# u'effectiveness effect effectiveness'
# u'implementation implement implementation'
# u'International intern International'
# u'Journal journal Journal'
# u'Project project Project'
# u'Management manag Management'
# u'Dale dale Dale'
# u'The the The'
# u'Logical logic Logical'
# u'Framework framework Framework'
# u'easy easi easy'
# u'escape escap escape'
# u'useful use useful'
# u'planning plan planning'
# u'Development develop Development'
# u'Practice practic Practice'
# u'Davies davi Davies'
# u'The the The'
# u'Future futur Future'
# u'Health health Health'
# u'Workforce workforc Workforce'
# u'London london London'
# u'Palgrave palgrav Palgrave'
# u'Macmillan macmillan Macmillan'
# u'Deeming deem Deeming'
# u'Decentering decent Decentering'
# u'NHS nh NHS'
# u'study studi study'
# u'resource resourc resource'
# u'allocation alloc allocation'
# u'decisions decis decision'
# u'Social social Social'
# u'Policy polici Policy'
# u'Administration administr Administration'
# u'Editorial editori Editorial'
# u'Commentary commentari Commentary'
# u'Nurse nurs Nurse'
# u'Workforce workforc Workforce'
# u'Planning plan Planning'
# u'policies polici policy'
# u'Journal journal Journal'
# u'Nursing nurs Nursing'
# u'Management manag Management'
# u'Flood flood Flood'
# u'Brief brief Brief'
# u'Review review Review'
# u'Peter peter Peter'
# u'Checkland checkland Checkland'
# u'Contribution contribut Contribution'
# u'Systemic system Systemic'
# u'Thinking think Thinking'
# u'Systmic systmic Systmic'
# u'Practice practic Practice'
# u'Action action Action'
# u'Research research Research'
# u'Gasper gasper Gasper'
# u'Logical logic Logical'
# u'Frameworks framework Frameworks'
# u'critical critic critical'
# u'Development develop Development'
# u'Studies studi Studies'
# u'Association associ Association'
# u'University univers University'
# u'East east East'
# u'Anglia anglia Anglia'
# u'Gasper gasper Gasper'
# u'Evaluating evalu Evaluating'
# u'Logical logic Logical'
# u'Framework framework Framework'
# u'Approach approach Approach'
# u'Towards toward Towards'
# u'learning learn learning'
# u'-orientated -orient -orientated'
# u'development develop development'
# u'evaluation evalu evaluation'
# u'Public public Public'
# u'Administration administr Administration'
# u'Development develop Development'
# u'Harris harri Harris'
# u'Cairns cairn Cairns'
# u'Many mani Many'
# u'Tiers tier Tiers'
# u'Many mani Many'
# u'Agendas agenda Agendas'
# u'Many mani Many'
# u'Pots pot Pots'
# u'Money money Money'
# u'The the The'
# u'challenge challeng challenge'
# u'English english English'
# u'regionlaization regionla regionlaization'
# u'voluntary voluntari voluntary'
# u'community commun community'
# u'organizations organ organization'
# u'Social social Social'
# u'Policy polici Policy'
# u'Administration administr Administration'
# u'Haynes hayn Haynes'
# u'Soft soft Soft'
# u'Systems system Systems'
# u'Methodology methodolog Methodology'
# u'Critical critic Critical'
# u'Issues issu Issues'
# u'Systems system Systems'
# u'Theory theori Theory'
# u'Practice practic Practice'
# u'Ellis elli Ellis'
# u'New new New'
# u'York york York'
# u'Plenum plenum Plenum'
# u'Hewison hewison Hewison'
# u'Griffiths griffith Griffiths'
# u'Leadership leadership Leadership'
# u'Development develop Development'
# u'Health health Health'
# u'Care care Care'
# u'Journal journal Journal'
# u'Health health Health'
# u'Organisation organis Organisation'
# u'Management manag Management'
# u'Holwell holwel Holwell'
# u'Soft soft Soft'
# u'Systems system Systems'
# u'Methodology methodolog Methodology'
# u'Other other Other'
# u'voices voic voice'
# u'Systemic system Systemic'
# u'Practice practic Practice'
# u'Action action Action'
# u'Research research Research'
# u'Huselid huselid Huselid'
# u'Becker becker Becker'
# u'The the The'
# u'Workforce workforc Workforce'
# u'Scorecard scorecard Scorecard'
# u'Managing manag Managing'
# u'capital capit capital'
# u'execute execut execute'
# u'strategy strategi strategy'
# u'New new New'
# u'York york York'
# u'Harvard harvard Harvard'
# u'Business busi Business'
# u'School school School'
# u'Press press Press'
# u'Issacs issac Issacs'
# u'Dialogue dialogu Dialogue'
# u'Art art Art'
# u'Thinking think Thinking'
# u'Together togeth Together'
# u'pioneering pioneer pioneering'
# u'communicating commun communicating'
# u'business busi business'
# u'London london London'
# u'Doubleday doubleday Doubleday'
# u'Jayaratna jayaratna Jayaratna'
# u'Proceedings proceed Proceedings'
# u'SSM ssm SSM'
# u'Research research Research'
# u'Discussion discuss Discussion'
# u'Group group Group'
# u'Workshop workshop Workshop'
# u'Preston preston Preston'
# u'Kristina kristina Kristina'
# u'Leadership leadership Leadership'
# u'Processes process Processes'
# u'Re-Engineering re-engin Re-Engineering'
# u'Changes chang Changes'
# u'Health health Health'
# u'Care care Care'
# u'Industry industri Industry'
# u'Journal journal Journal'
# u'Health health Health'
# u'Organisation organis Organisation'
# u'Management manag Management'
# u'Kumar kumar Kumar'
# u'Corbridge corbridg Corbridge'
# u'Programmed program Programmed'
# u'Fail fail Fail'
# u'Development develop Development'
# u'Projects project Projects'
# u'Politics polit Politics'
# u'Participation particip Participation'
# u'Journal journal Journal'
# u'Development develop Development'
# u'Studies studi Studies'
# u'McNulty mcnulti McNulty'
# u'Ferlie ferli Ferlie'
# u'Reengineering reengin Reengineering'
# u'Health health Health'
# u'Care care Care'
# u'The the The'
# u'complexties complexti complexties'
# u'organisational organis organisational'
# u'transformation transform transformation'
# u'Oxford oxford Oxford'
# u'Oxford oxford Oxford'
# u'University univers University'
# u'Press press Press'
# u'Open open Open'
# u'University univers University'
# u'T301 t301 T301'
# u'Complexity complex Complexity'
# u'Management manag Management'
# u'Change chang Change'
# u'Open open Open'
# u'University univers University'
# u'Systems system Systems'
# u'Group group Group'
# u'Milton milton Milton'
# u'Keynes. keynes. Keynes.'
# u'The the The'
# u'Open open Open'
# u'University univers University'
# u'Press press Press'
# u'Open open Open'
# u'University univers University'
# u'Management manag Management'
# u'Information inform Information'
# u'Systems system Systems'
# u'T843 t843 T843'
# u'Milton milton Milton'
# u'Keynes keyn Keynes'
# u'Open open Open'
# u'University univers University'
# u'Open open Open'
# u'University univers University'
# u'T306 t306 T306'
# u'Managing manag Managing'
# u'Complexity complex Complexity'
# u'Milton milton Milton'
# u'Keynes keyn Keynes'
# u'Open open Open'
# u'University univers University'
# u'Open open Open'
# u'University univers University'
# u'T851 t851 T851'
# u'Information inform Information'
# u'Systems system Systems'
# u'Toolkit toolkit Toolkit'
# u'Milton milton Milton'
# u'Keynes keyn Keynes'
# u'Open open Open'
# u'University univers University'
# u'Probert probert Probert'
# u'Critical critic Critical'
# u'Analysis analysi Analysis'
# u'Soft soft Soft'
# u'Systems system Systems'
# u'Methodology methodolog Methodology'
# u'Theoretical theoret Theoretical'
# u'Practical practic Practical'
# u'Relationship relationship Relationship'
# u'Phenomenaology phenomenaolog Phenomenaology'
# u'Systemist systemist Systemist'
# u'Senge seng Senge'
# u'Ross ross Ross'
# u'The the The'
# u'Fifth fifth Fifth'
# u'Discipline disciplin Discipline'
# u'Fieldbook fieldbook Fieldbook'
# u'Strategies strategi Strategies'
# u'building build building'
# u'learning learn learning'
# u'organisation organis organisation'
# u'London london London'
# u'Nicholas nichola Nicholas'
# u'Brealey brealey Brealey'
# u'Stowell stowel Stowell'
# u'Holland holland Holland'
# u'Applications applic Applications'
# u'SSM ssm SSM'
# u'Information inform Information'
# u'System system System'
# u'Design design Design'
# u'reflections reflect reflection'
# u'Journal journal Journal'
# u'Applied appli Applied'
# u'Systems system Systems'
# u'Analysis analysi Analysis'
# u'Vol vol Vol'
# u'Stubbings stub Stubbings'
# u'Scott scott Scott'
# u'NHS nh NHS'
# u'Workforce workforc Workforce'
# u'Issues issu Issues'
# u'Implications implic Implications'
# u'future futur future'
# u'practice practic practice'
# u'Journal journal Journal'
# u'Health health Health'
# u'Organisation organis Organisation'
# u'Management manag Management'
# u'Wenger wenger Wenger'
# u'Communities commun Communities'
# u'Practice practic Practice'
# u'Learning learn Learning'
# u'meaning mean meaning'
# u'identity ident identity'
# u'Cambridge cambridg Cambridge'
# u'Cambridge cambridg Cambridge'
# u'University univers University'
# u'Press press Press'

# %% [markdown]
# ## Spelling correction

# %% [markdown]
# ##### can be done woth import enchant but omitting for now

# %% [markdown]
# ## Text classification

# %% [markdown]
# # Small text mining exercises

# %% [markdown]
# ## Get some data

# %%
repoId=1
'''
Use page size 50 
-
store as pickle every 200 articles (4 pages)
in the end you will have in the /data folder files like: *
all_articles_on1_1.pkl
all_articles_on1_2.pkl
all_articles_on1_3.pkl
...


*/data is in .gitignore 
'''
import os
import pickle
if not os.path.exists('./data'):
    os.makedirs('./data')
all_articles=[]

for i in range(1,40):
    if not os.path.exists('./data/all_articles_on'+str(repoId)+'_'+str(i/4)+'.pkl'):
        url = api.get_url_of_download_articles_of_repository(repoId,True,i,50)# 40* 50 = 2000 (maximum articles per repo)
        response = urlopen(url)
        resp = response.read()
        result = json.loads(resp.decode('utf-8'))
        all_articles.append(result)
        if (i%4==0):
            pickle.dump(all_articles,open('data/all_articles_on'+str(repoId)+'_'+str(i/4)+'.pkl','wb'),pickle.HIGHEST_PROTOCOL)
            all_articles=[]

# %% [markdown]
# #### Words are important

# %%
### With frequency (tag clouds)
# !pip install simplejson
# !pip install pytagcloud
# !pip install pygame

from pytagcloud import create_tag_image, make_tags
from pytagcloud.lang.counter import get_tag_counts
# Out:
# Collecting simplejson
#   Downloading simplejson-3.11.1.tar.gz (78kB)
#     100% |████████████████████████████████| 81kB 3.7MB/s
# Building wheels for collected packages: simplejson
# done
#   Stored in directory: /Users/mc26486/Library/Caches/pip/wheels/bf/0a/27/5d5e337ed16a175fd483a8c1486b4343ea2632be7ac57bad5d
# Successfully built simplejson
# Installing collected packages: simplejson
# Successfully installed simplejson-3.11.1
# Collecting pytagcloud
#   Downloading pytagcloud-0.3.5.tar.gz (754kB)
#     100% |████████████████████████████████| 757kB 1.4MB/s
# Building wheels for collected packages: pytagcloud
# done
#   Stored in directory: /Users/mc26486/Library/Caches/pip/wheels/68/62/4f/1b5893a43776f017e7f8a444d64b25ca62366ad4a8a72ff94a
# Successfully built pytagcloud
# Installing collected packages: pytagcloud
# Successfully installed pytagcloud-0.3.5
# Collecting pygame
#   Downloading pygame-1.9.3-cp27-cp27m-macosx_10_9_intel.whl (4.8MB)
#     100% |████████████████████████████████| 4.8MB 267kB/s
# Installing collected packages: pygame
# Successfully installed pygame-1.9.3

# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.3.1.tar.gz (169kB)
#     100% |████████████████████████████████| 174kB 2.8MB/s
# Requirement already satisfied: matplotlib in /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python (from wordcloud)
# Requirement already satisfied: numpy>=1.6.1 in /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python (from wordcloud)
# Collecting pillow (from wordcloud)
#   Downloading Pillow-4.2.0-cp27-cp27m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (3.5MB)
#     100% |████████████████████████████████| 3.5MB 338kB/s
# Requirement already satisfied: python-dateutil in /Library/Python/2.7/site-packages (from matplotlib->wordcloud)
# Requirement already satisfied: tornado in /Library/Python/2.7/site-packages (from matplotlib->wordcloud)
# Requirement already satisfied: pyparsing>=1.5.6 in /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python (from matplotlib->wordcloud)
# Collecting nose (from matplotlib->wordcloud)
#   Downloading nose-1.3.7-py2-none-any.whl (154kB)
#     100% |████████████████████████████████| 163kB 4.1MB/s
# Collecting olefile (from pillow->wordcloud)
#   Downloading olefile-0.44.zip (74kB)
#     100% |████████████████████████████████| 81kB 6.8MB/s
# Requirement already satisfied: six>=1.5 in /Library/Python/2.7/site-packages (from python-dateutil->matplotlib->wordcloud)
# Requirement already satisfied: backports.ssl_match_hostname in /Library/Python/2.7/site-packages (from tornado->matplotlib->wordcloud)
# Requirement already satisfied: singledispatch in /Library/Python/2.7/site-packages (from tornado->matplotlib->wordcloud)
# Requirement already satisfied: certifi in /Library/Python/2.7/site-packages (from tornado->matplotlib->wordcloud)
# Requirement already satisfied: backports_abc>=0.4 in /Library/Python/2.7/site-packages (from tornado->matplotlib->wordcloud)
# Building wheels for collected packages: wordcloud, olefile
# done
#   Stored in directory: /Users/mc26486/Library/Caches/pip/wheels/d9/4c/ac/e63c45f2ce09860e9459a410953039c30296e89d9f7234675f
# done
#   Stored in directory: /Users/mc26486/Library/Caches/pip/wheels/20/58/49/cc7bd00345397059149a10b0259ef38b867935ea2ecff99a9b
# Successfully built wordcloud olefile
# Installing collected packages: olefile, pillow, wordcloud, nose
# Successfully installed nose-1.3.7 olefile-0.44 pillow-4.2.0 wordcloud-1.3.1

# %%
# %matplotlib inline
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

#Convert all the required text into a single string here 
#and store them in word_string

#you can specify fonts, stopwords, background color and other options

wordcloud = WordCloud(
                          stopwords=STOPWORDS,
                          background_color='white',
                          width=1200,
                          height=1000
                         ).generate(articleText)


plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
wordcloud

# %%
### With term frequency (tf-idf)
#removed to dev stuff/gensim.ipynb as it is unstable

# %%
## Discovering collaboration networks of a repository

# %%
# examine what is in pickles

# %%
import pickle
try:
    articles = pickle.load(open('data/all_articles_on1_1.pkl','rb'))
except (OSError,IOError) as e:
    print(e)

# %%
articles[0]['data'][0]
# Out:
# {u'authors': [u'Burgin, L. V.', u'Edelsten, L.', u'Aspden, R. M.'],
#  u'contributors': [u'University of Aberdeen, School of Medical Sciences',
#   u'University of Aberdeen, Medicine, Medical Sciences & Nutrition, Division Applied Medicine'],
#  u'datePublished': u'2014-02',
#  u'description': u'Copyright \xa9 2013 IPEM. Published by Elsevier Ltd. All rights reserved.Peer reviewedPostprin',
#  u'doi': u'10.1016/j.medengphy.2013.11.002',
#  u'fullText': u"  \nThe mechanical and material properties of elderly human articular \ncartilage subject to impact and slow loading \n \nRunning title: Impact loading and composition of human cartilage \n \nL.V. Burgin1, L. Edelsten2 and R.M. Aspden* \nMusculoskeletal Research Programme, School of Medicine & Dentistry, University of \nAberdeen, Aberdeen, UK. \n1Current address: Medical Technologies Innovation and Knowledge Centre, X102 Medical \nand Biological Engineering - University of Leeds, Leeds, LS2 9JT. UK. \nL.V.Burgin@leeds.ac.uk \n2Current email address:   Lorna.ramsay@education.gsi.gov.uk \n \n \nCorresponding Author \nProfessor R.M. Aspden \nMusculoskeletal Research Programme \nSchool of Medicine & Dentistry \nUniversity of Aberdeen \nInstitute of Medical Sciences \nForesterhill \nAberdeen AB25 2ZD \nUK \nTel: + (0)1224 437445 \ne-mail: r.aspden@abdn.ac.uk \n  \n 1 \nAbstract \nThe mechanical properties of articular cartilage vary enormously with loading rate, and how \nthese properties derive from the composition and structure of the tissue is still unclear. This \nstudy investigates the mechanical properties of human articular cartilage at rapid rates of \nloading, compares these with measurements at slow rates of loading and explores how they \nrelate to the gross composition of the tissue. Full-depth femoral head cartilage biopsies were \nsubjected to a slow, unconfined compression test followed by an impact at an energy of 78.5 \nmJ and velocity 1.25 m s-1. . The modulus was calculated from the slope of the loading curve \nand the coefficient of restitution from the areas under the loading and unloading curves. \nTissue composition was measured as water, collagen and glycosaminoglycan contents. The \nmaximum dynamic modulus ranged from 25 to 150 MPa. These values compared with 1-3 \nMPa measured during quasi-static loading. The coefficient of restitution was 0.502 (0.066) \n(Mean (Standard deviation)) and showed no site variation. Water loss was not detectable. \nComposition was not strongly associated with modulus; water and collagen contents together \npredicted about 25 % of the variance in modulus.  \n \n \n \nKeywords: articular cartilage; human; femoral head, impact; mechanical properties; \ncomposition; material properties \nSubjects areas: Biomechanics, Biomaterials \n \n \n 2 \n1. Introduction \nArticular cartilage provides a resilient, low-friction bearing surface to bones where they \narticulate in diarthrodial joints. It is a remarkably smooth and tough material and protects the \njoint by distributing applied loads. Mechanical damage caused, for instance, by trauma may \nlead to osteoarthritis (OA) and studies in vivo have suggested that cell damage, oxidative \nstress and apoptosis may play a significant role in this process [1,2]. The chondrocytes are \nprotected by being embedded in an extensive matrix that has a complicated structure. They \ncan regulate their biosynthesis of matrix molecules, and thereby control the composition of \nthe matrix, in order to match the mechanical properties of the tissue to the prevailing loading \nenvironment, but their regenerative capacity is limited. Relationships between the \ncomposition and structure of the tissue and its mechanical properties are still poorly \nunderstood and the advent and rapid expansion of attempts to engineer replacement articular \ncartilage make understanding this relationship increasingly urgent as efforts are made to \nmatch the repair tissue to the natural tissue [3]. Measurements of the  mechanical properties \ndepend strongly on the rate of loading [4] and the nature of the test performed, for example, \nconfined or unconfined. In addition, many studies have used animal, especially bovine, tissue \nbut it is becoming apparent that bovine tissue is not a good model for human tissue, \nmetabolically, structurally or mechanically [5-9]. \n \nWe have hypothesized that cartilage is a biological example of a fibre-composite materia ...
#  u'fulltextIdentifier': u'https://core.ac.uk/download/pdf/19787393.pdf',
#  u'id': u'19787393',
#  u'identifiers': [u'oai:aura.abdn.ac.uk:2164/3144',
#   u'10.1016/j.medengphy.2013.11.002'],
#  u'journals': [{u'identifiers': [u'1350-4533', u'issn:1350-4533'],
#    u'title': None}],
#  u'language': {u'code': u'en', u'id': 9, u'name': u'English'},
#  u'oai': u'oai:aura.abdn.ac.uk:2164/3144',
#  u'relations': [],
#  u'repositories': [{u'citationCount': 0,
#    u'citationDoiCount': 0,
#    u'citationFilesDb': 0,
#    u'citationWithDocCount': 0,
#    u'crawlingLimit': 0,
#    u'databaseDeletedPdfCount': 0,
#    u'databaseDeletedRecordCount': 0,
#    u'databaseIndexCount': 0,
#    u'databasePdfCount': 0,
#    u'databasePdfLinkCount': 0,
#    u'databaseRecordCount': 0,
#    u'databaseTextCount': 0,
#    u'databaseTextNotDeletedCount': 0,
#    u'description': None,
#    u'disabled': False,
#    u'documentDoiCount': 0,
#    u'documentDoiWithFulltextCount': 0,
#    u'hardDriveCitationFiles': 0,
#    u'hardDriveDeletedPdfCount': 0,
#    u'hardDriveDeletedTextCount': 0,
#    u'hardDrivePdfCount': 0,
#    u'hardDrivePdfSize': 0,
#    u'hardDriveTextCount': 0,
#    u'id': u'1',
#    u'indexJournalCount': 0,
#    u'indexRecordCount': 0,
#    u'indexTextCount': 0,
#    u'indexTextCountDB': 0,
#    u'indexTextNotDeletedCount': 0,
#    u'indexedDisabledDB': 0,
#    u'indexedPdfDB': 0,
#    u'journal': None,
#    u'journalMetadataAge': None,
#    u'journalMetadataExtractionDate': None,
#    u'journalMetadataSize': 0,
#    u'lastUpdateTime': None,
#    u'metadataAge': None,
#    u'metadataAlloweInIndexCount': 0,
#    u'metadataDeletedInIndexCount': 0,
#    u'metadataDeletedRecordCount': 0,
#    u'metadataDisabledInIndexCount': 0,
#    u'metadataExtractionDate': None,
#    u'metadataFormat': None,
#    u'metadataInIndexCount': 0,
#    u'metadataLinkCount': 0,
#    u'metadataOnlyIndex': 0,
#    u'metadataRecordCount': 0,
#    u'metadataSize': 0,
#    u'name': u'Aberdeen University Research Archive',
#    u'nrUpdates': 0,
#    u'openDoarId': 0,
#    u'pdfStatus': None,
#    u'physicalName': u'noname',
#    u'repositoryLocation': None,
#    u'software': None,
#    u'source': None,
#    u'uri': None,
#    u'uriJournals': None}],
#  u'subjects': [u'Journal article'],
#  u'title': u'The mechanical and material properties of elderly human articular cartilage subject to impact and slow loading',
#  u'topics': [u'articular cartilage',
#   u'human',
#   u'femoral head',
#   u'impact',
#   u'mechanical properties',
#   u'composition',
#   u'material properties',
#   u'femoral-head cartilage',
#   u'chondrocyte viability',
#   u'in-vitro',
#   u'compressive modulus',
#   u'connective tissues',
#   u'water-loss',
#   u'lower-limb',
#   u'bone',
#   u'stiffness',
#   u'collagen',
#   u'R Medicine',
#   u'R'],
#  u'types': [],
#  u'year': 2014}

# %% [markdown]
# This is the full metadata and fulltext in raw format ready to be analysed of this article:https://core.ac.uk/download/pdf/19787393.pdf

# %%
text = articles[0]['data'][0]['fullText']

# %%
import re
match = re.findall(r'[\w\.-]+@[\w\.-]+', text)

# %%
match
# Out:
# [u'L.V.Burgin@leeds.ac.uk',
#  u'Lorna.ramsay@education.gsi.gov.uk',
#  u'r.aspden@abdn.ac.uk']

# %% [markdown]
# Now do the same for all the aricles of repository 1

# %%
import pickle 
import re
def get_all_emails_of_repository(repoId):
    all_emails = []
    for page_pickle in range(1,10):
        try:
            articles = pickle.load(open('data/all_articles_on'+str(repoId)+'_'+str(page_pickle)+'.pkl','rb'))
            for page in range(0,len(articles)):
                for item in articles[page]['data']:
                    text = item['fullText']
                    article_id=item['id']
                    match = re.findall(r'[\w\.-]+@[\w\.-]+', text)
#                     print(match)
                    all_emails.append([article_id, match])
        except (OSError,IOError) as e:
            print(e)
    return all_emails

# %%
emails_of_1 = get_all_emails_of_repository(1)

# %%
emails_of_1
# Out:
# [[u'19787393',
#   [u'L.V.Burgin@leeds.ac.uk',
#    u'Lorna.ramsay@education.gsi.gov.uk',
#    u'r.aspden@abdn.ac.uk']],
#  [u'19787406', [u'david.mcghee@abdn.ac.uk']],
#  [u'20327925', [u'j.mercer@abdn.ac.uk', u'michelle.murphy@abdn.ac.uk']],
#  [u'20664118', [u'Sarah.Harris@igmm.ed.ac.uk.']],
#  [u'20664131', [u'T.Gillingwater@ed.ac.uk.']],
#  [u'20664054', [u'jiabao.he@abdn.ac.uk']],
#  [u'20664371', []],
#  [u'19888921', [u's.schwarzkopf@gmail.com']],
#  [u'20664053',
#   [u'marie.castellazzi@hutton.ac.uk',
#    u'diana.feliciano@abdn.ac.uk',
#    u'iain.brown@hutton.ac.uk']],
#  [u'20664046', [u'Jill.Francis.1@city.ac.uk']],
#  [u'20664363', [u'jukka.corander@helsinki.fi', u's.k.sheppard@swansea.ac.uk']],
#  [u'19787395', [u'a.price@abdn.ac.uk']],
#  [u'20443919', []],
#  [u'20443926', [u'a.r.akisanya@abdn.ac.uk.']],
#  [u'19506505', [u'j.hussein@abdn.ac.uk']],
#  [u'19888922', [u'c.hesse@abdn.ac.uk']],
#  [u'19888923', [u'y.hopf@abdn.ac.uk']],
#  [u'19506513', [u'clare.allely@glasgow.ac.uk']],
#  [u'19506506', [u'n.r.velaga@iitb.ac.in']],
#  [u'20309545', [u'a.r.akisanya@abdn.ac.uk.']],
#  [u'20664095', [u'x.lambin@abdn.ac.uk']],
#  [u'19506494', [u'm.olson@beatson.gla.ac.uk']],
#  [u'19506487', []],
#  [u'20664037', [u'l.n.kanguru@abdn.ac.uk']],
#  [u'20664044', [u'sally.wyke@glasgow.ac.uk']],
#  [u'20664087', [u'jane.reid@abdn.ac.uk']],
#  [u'20664107',
#   [u'wmoncur@dundee.ac.uk',
#    u'j.masthoff@abdn.ac.uk',
#    u'e.reiter@abdn.ac.uk',
#    u'Yvonne.Freer@luht.scot.nhs.uk']],
#  [u'20443924', [u's.r.gray@abdn.ac.uk']],
#  [u'19506515', [u'gill.hubbard@stir.ac.uk']],
#  [u'19506495', []],
#  [u'19506508',
#   [u'ksaquah@yahoo.com',
#    u'asazak@omu.edu.tr',
#    u'w.houssen@abdn.ac.uk',
#    u'j.tabudravu@abdn.ac.uk',
#    u'h.deng@abdn.ac.uk',
#    u'kkyeremeh@ug.edu.gh',
#    u'm.jaspars@abdn.ac.uk']],
#  [u'19968082', [u'y.hopf@abdn.ac.uk']],
#  [u'19968068', []],
#  [u'20443930', [u'd.mclernon@abdn.ac.uk']],
#  [u'20664036', [u'wime_UoD@me.com']],
#  [u'20664050', [u'a.marks@abdn.ac.uk']],
#  [u'20115546', []],
#  [u'19787398', [u'n.tintarev@abdn.ac.uk', u'r.kutlak@abdn.ac.uk']],
#  [u'20115552', [u'g.l.hold@abdn.ac.uk.']],
#  [u'19787399', [u'n.tintarev@abdn.ac.uk', u'r.kutlak@abdn.ac.uk']],
#  [u'19915630', [u'rodricjenkin@nhs.net', u'rodricjenkin@hotmail.com']],
#  [u'20664028', [u'rjp@doctors.org.uk']],
#  [u'20443922', []],
#  [u'20309535', [u'sanbing.shen@nuigalway.ie', u'c.mccaig@abdn.ac.uk']],
#  [u'19915631', [u'shingkwok@doctors.org.uk']],
#  [u'20115544', []],
#  [u'20309534', [u'craig.morton@abdn.ac.uk']],
#  [u'20443921', [u'm.kashtalyan@abdn.ac.uk']],
#  [u'20664026',
#   [u'nihredit@southampton.ac.uk', u'nihredit@southampton.ac.ukNIHR']],
#  [u'20664103', [u'h.houlden@ucl.ac.uk']],
#  [u'20664110',
#   [u'yanika.borg.11@ucl.ac.uk',
#    u'e.ullner@abdn.ac.uk',
#    u'333@hotmail.com',
#    u'aalsaedi@hotmail.com',
#    u'd.nesbeth@ucl.ac.uk',
#    u'alexey.zaikin@ucl.ac.uk']],
#  [u'20664033', [u'r.lau@ucl.ac.uk']],
#  [u'19787400', [u'a.d.murray@abdn.ac.uk']],
#  [u'19438870', [u'm.jackson@abdn.ac.uk']],
#  [u'20309518', []],
#  [u'19915626', [u'g.i.murray@abdn.ac.uk']],
#  [u'20664075', [u'riccardo.marioni@ed.ac.uk', u'ian.deary@ed.ac.uk']],
#  [u'20664082', [u'yateh@abdn.ac.uk']],
#  [u'20664102', [u'thoffmann@bond.edu.au']],
#  [u'20664378', [u'bjcampbl@liv.ac.uk']],
#  [u'20664032', [u's.hagen@gcal.ac.uk']],
#  [u'20664025', [u'Andrew.carr@ndorms.ox.ac.uk']],
#  [u'19438857', [u'conrad.nieduszynski@nottingham.ac.uk']],
#  [u'20309517', [u'a.m.hall@abdn.ac.uk', u'a.m.hall@abdn.ac.uk']],
#  [u'20664067', []],
#  [u'19915627', [u'marmots@ucla.edu']],
#  [u'20309530', []],
#  [u'20664030', [u'nihredit@southampton.ac.uk', u'nihredit@southampton.ac.uk']],
#  [u'20664100', [u'a.s.anderson@dundee.ac.uk']],
#  [u'19438873', [u'sohinee.bhattacharya@abdn.']],
#  [u'20327928', [u'jonathan.cook@ndorms.ox.ac.uk']],
#  [u'19787403', []],
#  [u'20443938', [u'3antoniomarcosbatista@gmail.com']],
#  [u'19915629', [u'o.varsou@abdn.ac.uk']],
#  [u'20115568', [u'c.gomez@abdn.ac.uk']],
#  [u'20664058', [u'nihredit@southampton.ac.uk', u'nihredit@southampton.ac.uk']],
#  [u'20664128', [u'j.feldmann@abdn.ac.uk']],
#  [u'20115567', [u'm.nakamoto@abdn.ac.uk']],
#  [u'20327927', [u'j.mercer@abdn.ac.uk']],
#  [u'20443937', [u'n.rubido.obrer@abdn.ac.uk']],
#  [u'20309514', [u'h.f.galley@abdn.ac.uk']],
#  [u'20309521', [u'j.lea@abdn.ac.uk']],
#  [u'19438875', [u'c.m.bond@abdn.ac.uk']],
#  [u'19787405', [u'Ivan.Baxter@ars.usda.gov', u'Owen.Hoekenga@ars.usda.gov']],
#  [u'20309520', [u'j.lea@abdn.ac.uk']],
#  [u'20115566', [u'k_scha11@hotmail.de']],
#  [u'20664070', []],
#  [u'20664056', [u'a.m.elliott@abdn.ac.uk']],
#  [u'11303904', [u'tomj@bas.ac.uk']],
#  [u'11303911', [u'kabender@abdn.ac.uk']],
#  [u'11304034', [u'g.m.walsh@abdn.ac.uk']],
#  [u'11304027', [u'y.saka@abdn.ac.uk']],
#  [u'12681421', []],
#  [u'19183820', [u'abdularifkhan@gmail.com']],
#  [u'18268316', []],
#  [u'18498886', [u'Vikki.entwistle@abdn.ac.uk']],
#  [u'19506510', [u'a.nebel@mucosa.de', u'baylac@mnhn.fr']],
#  [u'19506490', []],
#  [u'19968070', [u'francesco.tubiello@fao.org']],
#  [u'20115558', [u'j.anable@abdn.ac.uk']],
#  [u'20664125', [u'alison.smith@jic.']],
#  [u'20664372', []],
#  [u'11303903', [u'g.bacciagaluppi@abdn.ac.uk']],
#  [u'11304040', [u'j.parnell@abdn.']],
#  [u'20327924', [u'Bernhard.Hube@hki-jena.de']],
#  [u'19968071', [u'stephen.ogle@colostate.edu']],
#  [u'19787394',
#   [u'a.stockdale@qub.ac.uk',
#    u'l.philip@abdn.ac.uk',
#    u'Marsaili.macleod@abdn.uk']],
#  [u'19506511', [u'greger.larson@durham.ac.uk.']],
#  [u'17201922', [u'matthew.whitby@bioch.ox.ac.uk']],
#  [u'20664364', [u'jeremy.searle@cornell.edu']],
#  [u'20443927', [u'daniel.powell@soton.ac.uk']],
#  [u'9634238', []],
#  [u'11304032', [u'm.wiercigroch@abdn.ac.uk.']],
#  [u'11303902', [u'g.m.walsh@abdn.ac.uk']],
#  [u'12681423', [u'y.liu@abdn.ac.uk', u'yuh@bournemouth.ac.uk']],
#  [u'18498888', [u'e.j.tait@rgu.ac.uk']],
#  [u'18498915',
#   [u'mpbertone@yahoo.com',
#    u'bmeessen@itg.be',
#    u'gclarysse@unicef.org',
#    u'dhercot@gmail.com',
#    u'agkelley514@yahoo.com',
#    u'odnafak@yahoo.fr',
#    u'Isabelle.Lange@lshtm.ac.uk',
#    u'jpfaffmann@unicef.org',
#    u'valery.ridde@umontreal.ca',
#    u'isidoros2002@yahoo.fr',
#    u's.witter@abdn.ac.uk',
#    u'mpbertone@yahoo.com',
#    u'bmeessen@itg.be',
#    u'gclarysse@unicef.org',
#    u'dhercot@gmail.com',
#    u'agkelley514@yahoo.com',
#    u'odnafak@yahoo.fr',
#    u'Isabelle.Lange@lshtm.ac.uk',
#    u'jpfaffmann@unicef.org',
#    u'valery.ridde@umontreal.ca',
#    u'isidoros2002@yahoo.fr',
#    u's.witter@abdn.ac.uk']],
#  [u'19183815',
#   [u'r01zq11@abdn.ac.uk',
#    u'hs19870604@163.com',
#    u'yuyi119@hotmail.com',
#    u'h.deng@abdn.ac.uk']],
#  [u'19118545', [u'bridie.fitzpatrick@glasgow.ac.uk']],
#  [u'19915612', [u'k.thompson@abdn.ac.uk']],
#  [u'20664096', [u'b.mueller@abdn.ac.uk']],
#  [u'20664130', []],
#  [u'20664356', [u't.xifara@lancaster.ac.uk']],
#  [u'20664370', [u'hugues.chate@cea.fr']],
#  [u'19968072', [u'jimehansen@gmail.com']],
#  [u'11304031',
#   [u'p.cowie@abdn.ac.uk',
#    u'r.ross@abdn.ac.uk',
#    u'alasdair.mackenzie@abdn.ac.uk']],
#  [u'18601300', [u'k.forbes@abdn.ac.uk']],
#  [u'18498916', [u'a.dilley@abdn.ac.uk']],
#  [u'19183823', [u'robert.pickard@newcastle.ac.uk']],
#  [u'19787396', []],
#  [u'19475333', [u'naismith@st-andrews.ac.uk']],
#  [u'19183816',
#   [u'nihredit@southampton.ac.uk',
#    u'nihredit@southampton.ac.ukNIHR',
#    u'john.olson@nhs.net',
#    u'john.olson@nhs.net',
#    u'k.a.goatman@abdn.ac.uk',
#    u'caroline.styles@nhs.net']],
#  [u'19506493', [u'leonhard.schilbach@nf.mpg.de']],
#  [u'20327922', [u'ext.rolland1@rgu.ac.uk']],
#  [u'20664108', [u'xiaoyu.luo@glasgow.ac.uk']],
#  [u'11304030', [u'achille@us.ibm.com']],
#  [u'11923753', [u'd.a.vandera@abdn.ac.uk']],
#  [u'18601301', [u'olavrent@kent.edu']],
#  [u'19183817', [u'c.secombes@abdn.ac.uk']],
#  [u'19183824',
#   [u's.aphale@abdn.ac.uk',
#    u'antoine.ferreira@ensi-bourges.fr',
#    u'reza.moheimani@newcastle.edu.au']],
#  [u'19506507',
#   [u'd.e.beel@abdn.ac.uk',
#    u'n.jekjantuk@abdn.ac.uk',
#    u'gwebster@abdn.ac.uk',
#    u'c.mellish@abdn.ac.uk',
#    u'staylor@abdn.ac.uk',
#    u'c.wallace@abdn.ac.uk']],
#  [u'20664094', [u'A.Sole@shef']],
#  [u'20664114', [u'j.rochford@abdn.ac.uk']],
#  [u'19787397', []],
#  [u'11303985', [u'giorgiocometto@hotmail.com']],
#  [u'12414803', [u'briansbuckley@gmail.com']],
#  [u'19183818', []],
#  [u'19183832', []],
#  [u'17201904', [u'a.cuesta@iqfr.csic.es']],
#  [u'20664093', [u'j.martinovic@abdn.ac.uk']],
#  [u'20664353', [u'sabine.carey@uni-mannheim.de']],
#  [u'12414804', []],
#  [u'17201903', [u'a.cuesta@iqfr.csic.es']],
#  [u'18601303', [u'Al.Brown@abdn.ac.uk']],
#  [u'19506489', [u'michelle.murphy@abdn.ac.uk']],
#  [u'19506509', [u's.r.gray@abdn.ac.uk']],
#  [u'19475336', [u'Jill.Francis.1@city.ac.uk']],
#  [u'20664078', [u'yateh@abdn.ac.uk']],
#  [u'20664085', []],
#  [u'20664092', [u'john.ingram@eci.ox.ac.uk']],
#  [u'11303919', [u'a.r.akisanya@abdn.ac.uk.']],
#  [u'12414805', [u'ychirwa@brti.co.zw']],
#  [u'19888927', [u'radmaneshfar@gmail.com']],
#  [u'19183827', [u't.linley@abdn.ac.uk']],
#  [u'17201902', [u'vikki.entwistle@abdn.ac.uk']],
#  [u'17201938', [u'n.strachan@abdn.ac.uk']],
#  [u'20664077', [u'j.a.godbold@soton.ac.uk']],
#  [u'11304048', [u'kabender@abdnac.uk', u'rochek@mtmary.edu']],
#  [u'11303918', [u'john.ford@abdn.ac.uk']],
#  [u'17201937',
#   [u'tph32@cam.ac.uk', u'fperez-reche@abdn.ac.uk', u'snt1000@cam.ac.uk']],
#  [u'19183842', []],
#  [u'18601305', []],
#  [u'19438855', [u'janet.quinn@ncl.ac.uk', u'l.p.erwig@abdn.ac.uk']],
#  [u'20664090', [u'a.price@abdn.ac.uk']],
#  [u'20443920', [u'tony@abdn.ac.uk']],
#  [u'20115550', [u'P.J.Cooper@liv.ac.uk']],
#  [u'20309533', [u'k.papangelis@abdn.ac.uk']],
#  [u'11303924', []],
#  [u'17201936', []],
#  [u'19475339', [u'david.beard@ndorms.ox.ac.uk']],
#  [u'19438856', [u'conrad.nieduszynski@nottingham.ac.uk']],
#  [u'20309532', [u'G.R.Marsden@its.leeds.ac.uk']],
#  [u'20443948', [u'brian.cuthbertson@sunnybrook.ca']],
#  [u'11304053',
#   [u'nihredit@southampton.ac.uk',
#    u'nihredit@southampton.ac.uk',
#    u'a.grant@abdn.ac.uk',
#    u'reflux@hsru.abdn.ac.uk']],
#  [u'11303909', [u'streweek@mac.com']],
#  [u'11304046',
#   [u'a.schneider@abdn.ac.uk',
#    u'n.sharma@abdn.ac.uk',
#    u'a.mort@abdn.ac.uk',
#    u'c.mellish@abdn.ac.uk',
#    u'e.reiter@abdn.ac.uk',
#    u'p.wilson@abdn.ac.uk']],
#  [u'18498901',
#   [u'BMcPake@qmu.ac.uk',
#    u's.witter@abdn.ac.uk',
#    u'T.R.A.Ensor@leeds.ac.uk',
#    u'SFustukian@qmu.ac.uk',
#    u'd.newlands@abdn.ac.uk',
#    u'T.Martineau@liverpool.ac.uk',
#    u'ychirwa@brti.co.zw',
#    u'BMcPake@qmu.ac.uk',
#    u's.witter@abdn.ac.uk',
#    u'T.R.A.Ensor@leeds.ac.uk',
#    u'SFustukian@qmu.ac.uk',
#    u'd.newlands@abdn.ac.uk',
#    u'T.Martineau@liverpool.ac.uk',
#    u'ychirwa@brti.co.zw']],
#  [u'19787401', [u'tborowik@ibs.bialowieza.pl']],
#  [u'20309531',
#   [u'k.papangelis@abdn.ac.uk',
#    u'n.r.velaga@abdn.ac.uk',
#    u'yaji.sripada@abdn.ac.uk',
#    u'm.beecroft@abdn.ac.uk',
#    u'j.d.nelson@abdn.ac.uk',
#    u'j.anable@abdn.ac.uk',
#    u'j.farrington@abdn.ac.uk']],
#  [u'20664074', [u'innes.sim@rspb.org.uk']],
#  [u'20664377', [u'Albert.Tenesa@ed.ac.uk']],
#  [u'11304045', [u'P.Barrett@abdn.ac.uk']],
#  [u'19787402', []],
#  [u'19915628', [u'mpetelle@ucla.edu']],
#  [u'20664376', [u'michael.lomax@nottingham.ac.uk']],
#  [u'20664369', [u'g.l.oppo@strath.ac.uk']],
#  [u'20664080', [u'william.hunter@univie.ac.at']],
#  [u'20664129', [u'fkuepper@abdn.ac.uk', u'm.feiters@science.ru.nl']],
#  [u'19438872', [u'A.Sneddon@abdn.ac.uk']],
#  [u'17051721', [u'rachael.powell@manchester.ac.uk']],
#  [u'11304037', [u'a.g.kemp@abdn.ac.uk']],
#  [u'11303907', [u'j.gregory@abdn.ac.uk']],
#  [u'11303964', [u'Emiliano.Pereira@uah.es']],
#  [u'11304051', [u'a.grant@abdn.ac.uk']],
#  [u'17201933', [u'r.ebel@abdn.ac.uk']],
#  [u'17201926', []],
#  [u'18498883',
#   [u'd.j.pym@abdn.ac.uk',
#    u'j.swierzbinski@abdn.ac.uk',
#    u'julian.williams@abdn.ac.uk']],
#  [u'18268313', []],
#  [u'20664375', [u'r.hardy@nshd.mrc.ac.uk']],
#  [u'20664072', [u'ibh1@star.le.ac.uk']],
#  [u'11304029', [u'sfm@nhs.net']],
#  [u'11304050', [u'n.tintarev@abdn.ac.uk']],
#  [u'11303920', [u'm.kapitaniak@abdn.ac.uk']],
#  [u'18268314', []],
#  [u'19183811', [u'r.buckland@abdn.ac.uk', u'julian.williams@abdn.ac.uk']],
#  [u'19438867', [u'p.wilson@abdn.ac.uk']],
#  [u'16701380', [u'xiandongliu@gmail.com.']],
#  [u'16466600', [u'c.wang@abdn.ac.uk']],
#  [u'20664374', [u'p.vanwest@abdn.ac.uk']],
#  [u'11303905', [u'chris.burton@ed.ac.uk']],
#  [u'17201897', [u'serranoe@fyl.uva.es']],
#  [u'18268315', []],
#  [u'16701381', [u'R.Reynolds@ed.ac.uk']],
#  [u'19183812', [u'm.e.prior@abdn.ac.uk']],
#  [u'19183848', [u's.bhattacharya@abdn.ac.uk']],
#  [u'20664099', [u'andrew.millar@ed.ac.uk']],
#  [u'20664366', [u'ozyamak@gmail.com']],
#  [u'9634211', [u'guillaume.martel@gmail.com']],
#  [u'9430917', [u'guill_martel@hotmail.com']],
#  [u'9430897', [u'a.c.mclaughlin@abdn.ac.uk']],
#  [u'11303997', [u's.u.dombrowski@abdn.ac.uk']],
#  [u'11303947', [u'al.brown@abdn.ac.uk']],
#  [u'11303954', []],
#  [u'18498906',
#   [u'r.levi@abdn.ac.uk',
#    u'r.levi@abdn.ac.uk',
#    u'r.levi@abdn.ac.uk',
#    u'r.levi@abdn.ac.uk',
#    u'r.levi@abdn.ac.uk',
#    u'r.levi@abdn.ac.uk',
#    u'r.levi@abdn.ac.uk',
#    u'r.levi@abdn.ac.uk',
#    u'r.levi@abdn.ac.uk',
#    u'r.levi@abdn.ac.uk',
#    u'r.levi@abdn.ac.uk',
#    u'r.levi@abdn.ac.uk',
#    u'r.levi@abdn.ac.uk',
#    u'r.levi@abdn.ac.uk',
#    u'r.levi@abdn.ac.uk',
#    u'r.levi@abdn.ac.uk',
#    u'r.levi@abdn.ac.uk',
#    u'r.levi@abdn.ac.uk',
#    u'r.levi@abdn.ac.uk',
#    u'r.levi@abdn.ac.uk',
#    u'r.levi@abdn.ac.uk',
#    u'r.levi@abdn.ac.uk',
#    u'seeliger@math.univ-paris13.fr',
#    u'r.levi@abdn.ac.uk']],
#  [u'18498920', [u'norbert@mmmi.sdu.dk', u'f.guerin@abdn.ac.uk']],
#  [u'20443928', [u'wolff.schlotz@ur.de']],
#  [u'4193280',
#   [u'morisolaade@googlemail.com',
#    u'v.a.paul-ebhohimhen@abdn.ac.uk',
#    u'debbi.marais@abdn.ac.uk',
#    u'morisolaade@gmail.com',
#    u'V.a.paul-ebhohimhen@abdn.ac.uk',
#    u'debbi.marais@abdn.ac.uk']],
#  [u'9430909', [u'j.a.cook@abdn.ac.uk']],
#  [u'9430916', [u'GThomson@uclan.ac.uk']],
#  [u'9629999', []],
#  [u'11303953', []],
#  [u'18498907', [u'lv225@cam.ac.uk']],
#  [u'2797190', [u'm.delibegovic@abdn.ac.uk']],
#  [u'4193281', [u'j.hislop@abdn.ac.uk']],
#  [u'9430915', [u's.fielding@abdn.ac.uk']],
#  [u'9629998', [u'm.jackson@bangor.ac.uk']],
#  [u'11303938', [u'robert.pickard@newcastle.ac.uk']],
#  [u'11303952', [u'Bernhard.Hube@hki-jena.de']],
#  [u'18498908', [u'i.c.van.biezen@fsw.leidenuniv.nl']],
#  [u'19506492', [u'bert.timmermans@uk-koeln.de']],
#  [u'4193275', [u'p.hoddinott@abdn.ac.uk']],
#  [u'9629997', [u'tomaszka@p.lodz.pl']],
#  [u'9597637', [u'tim.barmby@abdn.ac.uk']],
#  [u'9430914', [u'j.francis@abdn.ac.uk']],
#  [u'11303951', []],
#  [u'11304017', [u'michelle.leach@abdn.ac.uk']],
#  [u'11303994', [u'sohinee.bhattacharya@abdn.ac.uk']],
#  [u'11923754', []],
#  [u'17201913', [u'd.m.maccallum@abdn.ac.uk']],
#  [u'17201920',
#   [u'matthew.whitby@bioch.ox.ac.uk', u'matthew.whitby@bioch.ox.ac.uk']],
#  [u'19183830', []],
#  [u'20115562', [u'tl2@sanger.ac.uk']],
#  [u'20664052', [u'diana.feliciano@hutton.ac.uk']],
#  [u'177348',
#   [u'c.ioannidis@bath.ac.uk',
#    u'd.j.pym@abdn.ac.uk',
#    u'julian.williams@abdn.ac.uk']],
#  [u'4193269', [u'j.a.cook@abdn.ac.uk']],
#  [u'4193276', [u'p.hoddinott@abdn.ac.uk']],
#  [u'9634236', [u'n.tintarev@abdn.ac.uk', u'j.masthoff@abdn.ac.uk']],
#  [u'9629989', [u'm.zanda@abdn.ac.uk', u'm.zanda@abdn.ac.uk']],
#  [u'11303986', [u'a.g.kemp@abdn.ac.uk']],
#  [u'11303993', [u'matt.craddock@uni-leipzig.de']],
#  [u'11304016', [u'al.brown@abdn.ac.uk.']],
#  [u'11303979', []],
#  [u'20327921', [u'a.r.akisanya@abdn.ac.uk.']],
#  [u'20115561', [u'lu.cheng@helsinki.']],
#  [u'370449', []],
#  [u'4193241', []],
#  [u'4193227', [u'john.duncan3@nhs.net']],
#  [u'4193234', []],
#  [u'9430912', []],
#  [u'9634235', [u'x.lambin@abdn.ac.uk']],
#  [u'9634242', [u'dermotryan@doctors.org.uk']],
#  [u'11304008', [u'a.jamieson@abdn.ac.uk', u'a.jamieson@abdn.ac.uk']],
#  [u'11303978', []],
#  [u'370448',
#   [u'n.a.miller@abdn.ac.uk',
#    u'j.gregory@abdn.ac.uk',
#    u'scott.semple@ed.ac.uk',
#    u'p.stollery@abdn.ac.uk',
#    u'f.j.gilbert@abdn.ac.uk']],
#  [u'4193235', [u'bisdik@us.ibm.com', u'mbs@ee.ucla.edu']],
#  [u'2797228', [u'l.mitchell@abdn.ac.uk']],
#  [u'11303984', [u'jon.crowcroft@cl.cam.ac.uk']],
#  [u'9634234', [u'chris.burton@ed.ac.uk']],
#  [u'9634241', [u'fabio.siniscalchi@abdn.ac.uk']],
#  [u'20115545', [u's.bhattacharya@abdn.ac.uk']],
#  [u'2797227',
#   [u'claire.fitzsimons@strath.ac.uk',
#    u'graham.baker@strath.ac.uk',
#    u's.r.gray@abdn.ac.uk',
#    u'm.a.nimmo@lboro.ac.uk',
#    u'nanette.mutrie@strath.ac.uk',
#    u'claire.fitzsimons@strath.ac.uk',
#    u'graham.baker@strath.ac.uk',
#    u's.r.gray@abdn.ac.uk',
#    u'M.A.Nimmo@lboro.ac.uk',
#    u'nanette.mutrie@strath.ac.uk']],
#  [u'2797241', [u'oddaksel@imr.no']],
#  [u'4193236', []],
#  [u'4193229', []],
#  [u'4895793', []],
#  [u'9631210', []],
#  [u'9629986', [u'heywood@uwm.edu']],
#  [u'9630469', [u'j.ndow@abdn.ac.uk']],
#  [u'9634240', []],
#  [u'11303983',
#   [u'arjuna@erg.abdn.ac.uk',
#    u'raffaello@erg.abdn.ac.uk',
#    u'gorry@erg.abdn.ac.uk']],
#  [u'11304006',
#   [u'jacques.demouzon@inserm.fr',
#    u'gliorion@icc-al.org.',
#    u'strohmer@kinderwunschzentrum.at.',
#    u'Kris.Bogaerts@med.kuleuven.be.',
#    u'kyurkch@hotmail.com.',
#    u'krezabek@vfn.cz.',
#    u'Karin.erb@ouh.regionsyddanmark.dk',
#    u'mika.gissler@thl.',
#    u'jdemouzon@noos.fr',
#    u'jacques.demouzon@inserm.fr.',
#    u'dominique.royere@biomedecine.fr.',
#    u'basil.tarlatzis@gmail.com.',
#    u'Hilmar@artmedica.is.',
#    u'guilia.scaravelli@iss.it.',
#    u'maris_arajs@inbox.lv.',
#    u'zivile.gudleviciene@gmail.com.',
#    u'dr.lazarevski@mbogorodica.com.mk',
#    u'cb.lambalk@vumc.nl.',
#    u'hazekamp@ivfoslo.nhn.no.',
#    u'Kurzawa@ams.edu.pl.',
#    u'korsak@mcrm.ru.',
#    u'radunn01@gmail.com.',
#    u'tomaz.tomazevic@guest.arnes.si.',
#    u'jhernandezh@telefonica.net.',
#    u'per-olof.karlstrom@karolinska.se.',
#    u'administration.sgrm@bluewin.ch.',
#    u'tgurgan@gurganclinic.com.tr.',
#    u'v.veselovskyy@ivf.com.ua.',
#    u'Richard.baranowski@hfea.gov.uk.']],
#  [u'11303969', [u'j.a.cook@abdn.ac.uk']],
#  [u'18601304', []],
#  [u'19506497', [u'M.Chitnis@surrey.ac.uk']],
#  [u'20664041', [u'j.hussein@abdn.ac.uk']],
#  [u'2797226',
#   [u'j.anable@abdn.ac.uk',
#    u'tim.schwanen@ouce.ox.ac.uk',
#    u'david.banister@ouce.ox.ac.uk']],
#  [u'9629985', [u'jens.karschau@abdn.ac.uk']],
#  [u'9629992',
#   [u'ytanino@alum.mit.edu', u'moisy@fast.u-psud.fr', u'hulin@fast.u-psud.fr']],
#  [u'9430902', [u'craig.morton@abdn.ac.uk']],
#  [u'11303982', [u'd.mclernon@abdn.ac.uk']],
#  [u'11303975', []],
#  [u'11304005', [u'g.bacciagaluppi@abdn.ac.uk']],
#  [u'11303932', [u'linda.sharp@ncri.ie']],
#  [u'19183828', [u'g.m.walsh@abdn.ac.uk']],
#  [u'2797225', [u'p.hoddinott@abdn.ac.uk']],
#  [u'9629991', [u'stephen.leslie@nhs.net']],
#  [u'9630001', [u'tim.barmby@abdn.ac.uk']],
#  [u'11304004',
#   [u'How.ShiMin@nottingham.edu.my', u'c.g.alawattage@abdn.ac.uk']],
#  [u'11304011', [u'n.oren@abdn.ac.uk', u'n.oren@abdn.ac.uk']],
#  [u'17201929', []],
#  [u'19183843', [u'franciska.desplenter@pharm.kuleuven.be']],
#  [u'2797224', [u'c.j.trinder@abdn.ac.uk']],
#  [u'9629983', [u'a.d.donaldson@abdn.ac.uk']],
#  [u'9430900', [u'm.delibegovic@abdn.ac.uk', u'n.mody@abdn.ac.uk']],
#  [u'11303973', []],
#  [u'11304003', [u'iain.mcewan@abdn.ac.uk.', u'rkumar@tcmedc.org.']],
#  [u'11304010',
#   [u'm.sensoy@abdn.ac.uk',
#    u't.j.norman@abdn.ac.uk',
#    u'w.w.vasconcelos@abdn.ac.uk',
#    u'katia@cs.cmu.edu']],
#  [u'11303980', [u'b.christian@abdn.ac.uk']],
#  [u'17201942', []],
#  [u'9629982', [u'j.ndow@abdn.ac.uk']],
#  [u'9634215', []],
#  [u'11304002', [u'chris.burton@ed.ac.uk']],
#  [u'11303972', [u'nick@stroudco.org.uk.', u'jabeecher@cardiffmet.ac.uk.']],
#  [u'19183838', []],
#  [u'2797222', [u'iain.mcewan@abdn.ac.uk']],
#  [u'11303971', []],
#  [u'11303957', [u'helen.dakin@dph.ox.ac.uk']],
#  [u'17201919', [u'matthew.whitby@bioch.ox.ac.uk.']],
#  [u'17201940', [u'k.gillies@abdn.ac.uk.', u'v.a.entwistle@dundee.ac.uk.']],
#  [u'19438866',
#   [u'maruli@cs.ui.ac.id', u'g.ritchie@abdn.ac.uk', u'ht@inf.ed.ac.uk']],
#  [u'2797207', [u'd.lurie@abdn.ac.uk']],
#  [u'2797221', [u'a.g.kemp@abdn.ac.uk']],
#  [u'2797257', [u'Nicola.jones@sickkids.ca']],
#  [u'6104178', []],
#  [u'9430899', []],
#  [u'9430919', [u'Claire.wallace@abdn.ac.uk']],
#  [u'9629980',
#   [u'bessen@math.uni-hannover.de',
#    u'gramain@math.jussieu.fr',
#    u'olsson@math.ku.dk']],
#  [u'11303963', [u'guillaume.rieucau@imr.no']],
#  [u'11303999', [u'gillian.hawthorne@newcastle-pct.nhs.uk']],
#  [u'11303970', [u'j.r.meakin@exeter.ac.uk', u'r.aspden@abdn.ac.uk']],
#  [u'11303956', [u'kirill.batmanov@lifl.fr']],
#  [u'19118541', []],
#  [u'2797206', [u'l.broche@abdn.ac.uk']],
#  [u'2797213',
#   [u'kavita.e.thomas@gmail.com',
#    u'yaji.sripada@abdn.ac.uk',
#    u'm.l.noordzij@utwente.nl']],
#  [u'9631225', []],
#  [u'11303948', [u'Bernhard.Hube@hki-jena.de']],
#  [u'11303962', []],
#  [u'11303998', [u'sohinee.bhattacharya@abdn.']],
#  [u'11303955', [u'p.teismann@abdn.ac.uk', u'journals.permissions@oup.com.']],
#  [u'12681420',
#   [u's.blake.08@aberdeen.ac.uk',
#    u'advaith@abdn.ac.uk',
#    u'h.nguyen@abdn.ac.uk',
#    u'n.sharma@abdn.ac.uk',
#    u'annierobinson@abdn.ac.uk',
#    u'elaine.omahony@bumblebeeconservation.org',
#    u'ben.darvill@bumblebeeconservation.org',
#    u'c.mellish@abdn.ac.uk',
#    u'r.vanderwal@abdn.ac.uk']],
#  [u'17201931', []],
#  [u'84021', [u'mjgreen@abdn.ac.uk', u'k.vdeemter@abdn.ac.uk']],
#  [u'281285', [u'ian.bartholomew@ed.ac.uk']],
#  [u'177421', [u'Arthur.Chung@sabah.gov.my', u'T@RTS']],
#  [u'177337',
#   [u'e.pignotti@abdn.ac.uk',
#    u'p.edwards@abdn.ac.uk',
#    u'n.gotts@macaulay.ac.uk',
#    u'g.polhill@macaulay.ac.uk']],
#  [u'177301', []],
#  [u'2797192', [u'esa.korpi@helsinki.fi', u'lueddens@uni-mainz.de']],
#  [u'2797262', [u'a.c.mclaughlin@abdn.ac.uk']],
#  [u'9634247', [u'p.teismann@abdn.ac.uk']],
#  [u'17201930', []],
#  [u'2797191', [u'mtaljaard@ohri.ca', u'mtaljaard@ohri.ca.']],
#  [u'177232', [u'katia@cs.cmu.edu']],
#  [u'281284',
#   [u'ian.bartholomew@ed.ac.uk',
#    u't.r.cowton@sms.ed.ac.uk',
#    u'peter.nienow@ed.ac.uk',
#    u'andrew.sole@ed.ac.uk',
#    u'd.mair@abdn.ac.uk',
#    u's.j.palmer@leeds.',
#    u'j.l.wadham@bristol.ac.uk']],
#  [u'281283', []],
#  [u'177276', [u'ebenhoeh@abdn.ac.uk']],
#  [u'177339', [u'a.r.akisanya@abdn.ac.uk.']],
#  [u'177346', []],
#  [u'2797239', []],
#  [u'9430908', []],
#  [u'9631208',
#   [u'g.ruessink@geo.uu.nl',
#    u'fsancho@lnec.pt',
#    u'psilva@ua.pt',
#    u'd.a.vandera@abdn.ac.uk',
#    u'jebbe.vanderwerf@deltares.nl']],
#  [u'17201907', [u'matthew.whitby@bioch.ox.ac.uk']],
#  [u'281282',
#   [u'y.saka@abdn.ac.uk',
#    u'a1@Tf',
#    u'D@GD',
#    u'dm@RD',
#    u'g@RD',
#    u'dp@PD',
#    u'8@AgD']],
#  [u'281275',
#   [u'n.nguyen@abdn.ac.uk',
#    u'p.kindness@abdn.ac.uk',
#    u'c.mellish@abdn.ac.uk',
#    u'j.knight@abdn.ac.uk',
#    u'a.mort@abdn.ac.uk',
#    u'e.reiter@abdn.ac.uk']],
#  [u'177291',
#   [u'a.g.kemp@abdn.ac.uk',
#    u'NPV@10',
#    u'I@10',
#    u'NPV@10',
#    u'I@10',
#    u'NPV@10',
#    u'I@10',
#    u'NPV@10',
#    u'I@10',
#    u'NPV@10',
#    u'I@10',
#    u'NPV@10',
#    u'I@10',
#    u'NPV@10',
#    u'I@10',
#    u'NPV@10',
#    u'I@10',
#    u'NPV@10',
#    u'I@10']],
#  [u'177417', [u'chris.kettle@env.ethz.ch']],
#  [u'177361', [u'derrick.bennett@ctsu.ox.ac.uk']],
#  [u'2797182',
#   [u'm.e.prior@abdn.ac.uk',
#    u'j.hamzah@abdn.ac.uk',
#    u'j.francis@abdn.ac.uk',
#    u'c.r.ramsay@abdn.ac.uk',
#    u'm.castillo@abdn.ac.uk',
#    u'Susan.Campbell@uae.ac.uk',
#    u'aazblanco@abdn.ac.uk',
#    u'j.m.burr@abdn.ac.uk',
#    u'm.e.prior@abdn.ac.uk',
#    u'j.hamzah@abdn.ac.uk',
#    u'j.francis@abdn.ac.uk',
#    u'c.r.ramsay@abdn.ac.uk',
#    u'm.castillo@abdn.ac.uk',
#    u'Susan.Campbell@uea.ac.uk',
#    u'aazblanco@abdn.ac.uk',
#    u'j.m.burr@abdn.ac.uk']],
#  [u'2797202', [u's.french@unimelb.edu.au']],
#  [u'2797252', [u'd.vaughan@bas.ac.uk']],
#  [u'4193282',
#   [u'i.reid@auckland.ac.nz',
#    u'a.avenell@abdn.ac.uk',
#    u'i.reid@auckland.ac.nz']],
#  [u'4193232', [u'gabrielle.anderson@soton.ac.uk', u'jr2@ecs.soton.ac.uk']],
#  [u'11303901', [u'chris.burton@ed.ac.uk']],
#  [u'20309538',
#   [u'tim.schwanen@ouce.ox.ac.uk',
#    u'F.W.Geels@sussex.ac.uk.',
#    u'm.watson@sheffield.ac.uk.']],
#  [u'177278', [u'tania.lourenco@abdn.ac.uk']],
#  [u'281281', [u'm.abdelfattah@abdn.ac.uk', u'm.abdelfattah@abdn.ac.uk.']],
#  [u'2797201', [u'mbi167@abdn.ac.ukSchool']],
#  [u'2797251', [u'robert.a.bindschadler@nasa.gov']],
#  [u'9633776', []],
#  [u'9631213', [u'ecrull@nd.edu', u'g.bacciagaluppi@abdn.ac.uk']],
#  [u'177313', [u'g.l.hold@abdn.ac.uk']],
#  [u'177399', [u'T.E.Roberts@bham.ac.uk']],
#  [u'177426', []],
#  [u'177363', [u'g.l.hold@abdn.ac.uk.']],
#  [u'2797166', [u'g.coghill@abdn.ac.uk']],
#  [u'2797173', [u'al.brown@abdn.ac.uk.']],
#  [u'2797200', [u'eld@abdn.ac.uk']],
#  [u'281280', [u'b.platt@abdn.ac.uk']],
#  [u'281273', [u'aeconomou@econ.uth.gr.', u'theod@abdn.ac.uk']],
#  [u'4193277', [u'david.murray@ndorms.ox.ac.uk']],
#  [u'9629995', [u'brian.morgan@ncl.ac.uk', u'janet.quinn@ncl.ac.uk']],
#  [u'9633782', [u'a.mcdonald@abdn.ac.uk', u'LIFELAX.queries@......']],
#  [u'9633775', [u'Brian.Cuthbertson@sunnybrook.ca']],
#  [u'11303942', [u'al.brown@abdn.ac.uk']],
#  [u'18498918', []],
#  [u'20309543', [u'gxpan@njau.edu.cn']],
#  [u'20115560', [u'aw6@sanger.ac.uk', u'l.petrovska@vla.defra.gsi.gov.uk']],
#  [u'177314', [u'justin.presseau@ncl.ac.uk']],
#  [u'177251', [u'g.l.hold@abdn.ac.uk']],
#  [u'4193278', [u'charles.kelly@kcl.ac.uk']],
#  [u'2797165', []],
#  [u'2797235', [u'jgrimshaw@ohri.ca']],
#  [u'9629994', [u'johan@microbiology.se']],
#  [u'9633781', [u'streweek@mac.com']],
#  [u'177315', [u'martin.eccles@ncl.ac.uk']],
#  [u'177365', [u'antje.mertens@hwr']],
#  [u'4193279',
#   [u'pilzk@mcmaster.ca',
#    u'konary@mcmaster.ca',
#    u'q.c.vuong@newcastle.ac.uk',
#    u'bennett@mcmaster.ca',
#    u'sekuler@mcmaster.ca']],
#  [u'9430910', [u'kabender@uwm.edu', u'hmridha@nccu.edu.']],
#  [u'9629979', []],
#  [u'9629993', [u'leho.tedersoo@ut.ee']],
#  [u'177309', [u'j.martinovic@abdn.ac.uk']],
#  [u'177316', [u'j.m.burr@abdn.ac.uk']],
#  [u'370439', []],
#  [u'370453', [u'ramaroson.andriantsitohaina@univ-angers.fr']],
#  [u'4193244',
#   [u'karine@deenp.ufop.br', u'rosane@dep.ufscar.br', u'acmarqui@gmail.com']],
#  [u'9633772', [u'aazblanco@abdn.ac.uk']],
#  [u'9634232', [u'ebenhoeh@abdn.ac.uk']],
#  [u'9634225', []],
#  [u'19915632',
#   [u'j.mcfadden@surrey.ac.uk',
#    u'G@Sbase',
#    u'G@Sbase',
#    u'G@Sbase',
#    u'G@S',
#    u'BuG@Sbase',
#    u'BuG@Sbase..']],
#  [u'19506498',
#   [u'Jacquie.lavin@slimming-world.com', u'Information@Karger.de']],
#  [u'4193245', [u'd.claus@sheffield.ac.uk']],
#  [u'177381', [u'falko.sniehotta@ncl.ac.uk']],
#  [u'177297', [u'g.mowatt@abdn.ac.uk']],
#  [u'370445', []],
#  [u'370452', [u'e.el-omar@abdn.ac.uk']],
#  [u'9634231', [u'kabender@uwm.edu']],
#  [u'370451', [u'richard.kyle@stir.ac.uk']],
#  [u'370444',
#   [u'hhecwsc@hkucc.hku.hk',
#    u'paolo.bertoldi@ec.europa.eu',
#    u'silvia.rezessy@ec.europa.eu',
#    u'j.anable@abdn.ac.uk',
#    u'jochem@kit.edu',
#    u'vlasis@jiqweb.org',
#    u'hhecwsc@hkucc.hku.hk',
#    u'hhecwsc@hkucc.hku.hk',
#    u'hhecwsc@hkucc.hku.hk',
#    u'hhecwsc@hkucc.hku.hk',
#    u'hhecwsc@hkucc.hku.hk',
#    u'hhecwsc@hkucc.hku.hk',
#    u'hhecwsc@hkucc.hku.hk',
#    u'hhecwsc@hkucc.hku.hk',
#    u'hhecwsc@hkucc.hku.hk',
#    u'hhecwsc@hkucc.hku.hk',
#    u'hhecwsc@hkucc.hku.hk',
#    u'hhecwsc@hkucc.hku.hk',
#    u'hhecwsc@hkucc.hku.hk',
#    u'hhecwsc@hkucc.hku.hk',
#    u'hhecwsc@hkucc.hku.hk',
#    u'hhecwsc@hkucc.hku.hk',
#    u'hhecwsc@hkucc.hku.hk',
#    u'hhecwsc@hkucc.hku.hk',
#    u'hhecwsc@hkucc.hku.hk',
#    u'hhecwsc@hkucc.hku.hk',
#    u'hhecwsc@hkucc.hku.hk',
#    u'hhecwsc@hkucc.hku.hk',
#    u'hhecwsc@hkucc.hku.hk',
#    u'hhecwsc@hkucc.hku.hk',
#    u'hhecwsc@hkucc.hku.hk',
#    u'hhecwsc@hkucc.hku.hk',
#    u'hhecwsc@hkucc.hku.hk',
#    u'hhecwsc@hkucc.hku.hk',
#    u'hhecwsc@hkucc.hku.hk',
#    u'hhecwsc@hkucc.hku.hk',
#    u'hhecwsc@hkucc.hku.hk',
#    u'hhecwsc@hkucc.hku.hk',
#    u'hhecwsc@hkucc.hku.hk',
#    u'hhecwsc@hkucc.hku.hk']],
#  [u'177318', [u'j.kiefer@abdn.ac.uk']],
#  [u'177382', [u'n.kolehmainen@abdn.ac.uk']],
#  [u'177402', [u'vlh@computing.dundee.ac.uk', u'gaener.rodger@uhi.ac.uk']],
#  [u'177375', []],
#  [u'4193253',
#   [u'kraenkel@ift.unesp.br',
#    u'k.nakkeeran@abdn.ac.uk',
#    u'kwchow@hkusua.hku.hk']],
#  [u'4193246', [u'p.hannaford@abdn.ac.uk']],
#  [u'2797197', [u'F.Visser@uva.nl']],
#  [u'9634223', []],
#  [u'9634216', [u'AXE898@bham.ac.uk.']],
#  [u'17201928', []],
#  [u'177403', []],
#  [u'281296', [u'a.d.donaldson@abdn.ac.uk']],
#  [u'281289', []],
#  [u'2797209', [u'a.g.kemp@abdn.ac.uk']],
#  [u'19183845', [u'Biehl_S@klinik.uni-wuerzburg.de']],
#  [u'17201927', []],
#  [u'18498902', [u'c.secombes@abdn.ac.uk']],
#  [u'281295', [u'pmhh@vet.dtu.dk']],
#  [u'281288', [u'p.vanwest@abdn.ac.uk']],
#  [u'177334', [u'a.g.kemp@abdn.ac.uk']],
#  [u'9630457', []],
#  [u'9634221',
#   [u'c.wang@abdn.ac.uk',
#    u'paolospe76@gmail.com',
#    u'bob.bingham@stfc.ac.uk',
#    u'titomend@ist.utl.pt']],
#  [u'19183846', [u'hanna@wolkenkind.de']],
#  [u'281287', [u'k.guseva@abdn.ac.uk']],
#  [u'177342', [u'noah.ivers@utoronto.ca']],
#  [u'2797187', [u'p.andrews@ed.ac.uk']],
#  [u'2797194', []],
#  [u'9634249', [u'a.libman@abdn.ac.uk']],
#  [u'11304043', []],
#  [u'177273', [u'i.reid@auckland.ac.nz']],
#  [u'177413', [u'a.r.akisanya@abdn.ac.uk.']],
#  [u'177379',
#   [u'ada.ferrer@iae.csic.es', u'b.m.s.vanpraag@uva.nl', u'theod@abdn.ac.uk']],
#  [u'281279', []],
#  [u'281286',
#   [u'p.edwards@abdn.ac.uk', u'e.pignotti@abdn.ac.uk', u'dcorsar@abdn.ac.uk']],
#  [u'2797193', [u'D.Kelly@abdn.ac.uk']],
#  [u'2797220', [u's.gratz@abdn.ac.uk']],
#  [u'2797263', [u'a.c.mclaughlin@abdn.ac.uk']],
#  [u'4193271', [u'sohinee.bhattacharya@abdn.ac.uk']],
#  [u'9430918', []],
#  [u'9634248', [u'p.teismann@abdn.ac.uk']],
#  [u'17201917', [u'n.alwan@leeds.ac.uk']],
#  [u'177161', [u'brian.cuthbertson@sunnybrook.ca']],
#  [u'177197', [u's.p.devaney@abdn.ac.uk']],
#  [u'9633751', [u'saa@um.edu.my']],
#  [u'177198', [u'tatiana.macfarlane@abdn.ac.uk']],
#  [u'177408', [u'edward.tiekink@gmail.com', u'j.wardell@abdn.ac.uk.']],
#  [u'177302', []],
#  [u'9633750', [u'r.ebel@abdn.ac.uk']],
#  [u'11303946', []],
#  [u'177233', [u'noah.ivers@utoronto.ca']],
#  [u'177423', [u'brian.cuthbertson@sunnybrook.ca']],
#  [u'177156', [u'parsons@sci.brooklyn.cuny.edu']],
#  [u'2797260', [u'm.a.devries@physics.org']],
#  [u'9597638', [u'c.a.brackley@abdn.ac.uk.']],
#  [u'177234', [u'brian.cuthbertson@sunnybrook.ca']],
#  [u'177424', []],
#  [u'177347', [u'nir.oren@kcl.ac.uk']],
#  [u'177241', []],
#  [u'9633777', [u's.k.mccann@abdn.ac.uk']],
#  [u'177242', [u's.u.dombrowski@abdn.ac.uk']],
#  [u'177235', [u'joanne.mckenzie@monash.edu1School']],
#  [u'177158',
#   [u'JSFA@wiley.com',
#    u'c.shand@macaulay.ac.uk.',
#    u'JSFA@wiley.com',
#    u'JSFA@wiley.com',
#    u'JSFA@wiley.com',
#    u'JSFA@wiley.com',
#    u'JSFA@wiley.com',
#    u'JSFA@wiley.com',
#    u'JSFA@wiley.com',
#    u'JSFA@wiley.com',
#    u'JSFA@wiley.com',
#    u'JSFA@wiley.com',
#    u'JSFA@wiley.com',
#    u'JSFA@wiley.com',
#    u'JSFA@wiley.com',
#    u'JSFA@wiley.com',
#    u'JSFA@wiley.com',
#    u'JSFA@wiley.com',
#    u'JSFA@wiley.com',
#    u'JSFA@wiley.com',
#    u'JSFA@wiley.com',
#    u'JSFA@wiley.com',
#    u'JSFA@wiley.com',
#    u'JSFA@wiley.com',
#    u'JSFA@wiley.com',
#    u'JSFA@wiley.com',
#    u'JSFA@wiley.com',
#    u'JSFA@wiley.com',
#    u'JSFA@wiley.com']],
#  [u'177425', [u'scs10@st-andrews.ac.uk']],
#  [u'9633783', [u'j.e.clarkson@cpse.dundee.ac.uk']],
#  [u'9629996', [u'h.morgan@bangor.ac.uk.']],
#  [u'2797229', [u'd.bonetti@cpse.dundee.ac.uk']],
#  [u'2797250', [u'jbts@bas.ac.uk']],
#  [u'177357', [u'r01do7@abdn.ac.uk']],
#  [u'177371', [u'k.kiezebrink@abertay.ac.uk']],
#  [u'177427', []],
#  [u'177244', [u'publications@fertilizer.org']],
#  [u'177287', [u'a.g.kemp@abdn.ac.uk']],
#  [u'177167', [u't.porteous@abdn.ac.uk']],
#  [u'4193228', [u'a.c.mclaughlin@abdn.ac.uk', u'j.w.g.bos@hw.ac.uk']],
#  [u'4895792',
#   [u'pilzk@mcmaster.ca', u'bennett@mcmaster.ca', u'sekuler@mcmaster.ca']],
#  [u'19888926', [u'shimi@bio.kyutech.ac.jp']],
#  [u'177168', []],
#  [u'177202', []],
#  [u'177295', [u'd.lurie@abdn.ac.uk']],
#  [u'177288', [u'a.g.kemp@abdn.ac.uk']],
#  [u'4193250', [u'jakob.nawrath@gmx.de']],
#  [u'9633766', [u'a.moura@abdn.ac.uk', u'ignatova@uni-potsdam.de', u'D@c']],
#  [u'9633759', [u'iain.mcewan@abdn.ac.uk.']],
#  [u'19915624',
#   [u'schmidt@informatik.haw-hamburg.de',
#    u'mw@link-lab.net',
#    u'gorry@erg.abdn.ac.uk']],
#  [u'177373', [u'c.debari@abdn.ac.uk']],
#  [u'177289', [u'a.g.kemp@abdn.ac.uk']],
#  [u'177176', [u'sohinee.bhattacharya@abdn.ac.uk']],
#  [u'177239', [u'n.kolehmainen@abdn.ac.uk']],
#  [u'177210', [u'c.r.ramsay@abdn.ac.uk']],
#  [u'177203', [u'heather.dickinson@ncl.ac.uk', u'susan.hrisos@ncl.ac.uk']],
#  [u'2797199', [u'changhoon.choi@abdn.ac.uk']],
#  [u'4193251', [u'l.ciandrini@abdn.ac.uk']],
#  [u'4193252', [u'b.scharlau@abdn.ac.uk']],
#  [u'177141', [u'k.pouliakas@abdn.ac.uk.', u'theod@abdn.ac.uk.']],
#  [u'177184', [u'i.reid@auckland.ac.nz']],
#  [u'177204', [u'b.abrahamsen@physician.dk']],
#  [u'177374', [u'lindsey.masson@abdn.ac.uk']],
#  [u'177247', [u'malcolm.whiteway@cnrc-nrc.gc.ca']],
#  [u'9629984', [u'guido.verhoeven@med.kuleuven.be']],
#  [u'9633764', []],
#  [u'9633771', []],
#  [u'9634217', [u'phyllis.easton@nhs.net']],
#  [u'177135', [u'b.abrahamsen@physician.dk']],
#  [u'177142',
#   [u'gpanos@abdn.ac.uk', u'theod@abdn.ac.uk', u'theod@abdn.ac.uk.']],
#  [u'177255', []],
#  [u'9629990', [u's.carlisle@clinmed.gla.ac.uk']],
#  [u'9633763', [u'conrad.nieduszynski@nottingham.ac.uk']],
#  [u'177143',
#   [u'gpanos@abdn.ac.uk.',
#    u'gpanos@abdn.ac.uk',
#    u'theod@abdn.ac.uk',
#    u'gpanos@abdn.ac.uk.']],
#  [u'177256', [u'p.hoddinott@abdn.ac.uk']],
#  [u'177369', [u'christian.rodrigues@mis.mpg.de']],
#  [u'13300',
#   [u'c.emele@abdn.ac.uk',
#    u't.j.norman@abdn.ac.uk',
#    u'f.guerin@abdn.ac.uk',
#    u'parsons@sci.brooklyn.cuny.edu']],
#  [u'2797189', [u'o.k.ajibose@abdn.ac.uk']],
#  [u'2797196', [u'afg@iim.csic.es']],
#  [u'9633755', [u'khairyhesham@yahoo.com', u'w.houssen@abdn.ac.uk']],
#  [u'13301',
#   [u'cburnett@abdn.ac.uk', u't.j.norman@abdn.ac.uk', u'katia@cs.cmu.edu']],
#  [u'177144', []],
#  [u'177377', []],
#  [u'4193248', [u's.bhattacharya@abdn.']],
#  [u'2797195', [u'angelguerra@iim.csic.es.']],
#  [u'9629981', [u'r.aspden@abdn.ac.uk']],
#  [u'9633761', [u'l.j.middleton@bham.ac.uk']],
#  [u'177188', []],
#  [u'281294', [u's.mendolia@abdn.ac.uk.']],
#  [u'4193249', [u'a.roberts@abdn.ac.uk', u'a.roberts@abdn.ac.uk']],
#  [u'4193270', []],
#  [u'9633760', [u'persson@mpimp-golm.mpg.de.', u'persson@mpimp-golm.mpg.de']],
#  [u'17201925', []],
#  [u'177223', [u'a.bowman@abdn.ac.uk']],
#  [u'177406', []],
#  [u'177420', [u'sohinee.bhattacharya@abdn.ac.uk.']],
#  [u'2797249', [u'lixin@pric.gov.cn']],
#  [u'9633752', [u'jmm4y@clinmed.gla.ac.uk']],
#  [u'18498912', []],
#  [u'281292', [u'parsons@sci.brooklyn.cuny.edu']],
#  [u'17201923', [u'k.thompson@abdn.ac.uk']],
#  [u'20443942', []],
#  [u'2797177', [u'r.s.pickard@ncl.ac.uk']],
#  [u'177155', [u'w.w.vasconcelos@abdn.ac.uk', u't.j.norman@abdn.ac.uk']],
#  [u'18498914', []],
#  [u'177430', [u's.goodyear@abdn.ac.uk']],
#  [u'177219', [u'f.odds@abdn.ac.uk']],
#  [u'177113',
#   [u'martin.eccles@ncl.ac.uk',
#    u'Susan.hrisos@ncl.ac.uk',
#    u'j.francis@abdn.ac.uk',
#    u'nick.steen@ncl.ac.uk',
#    u'M.Bosch@iq.umcn.nl',
#    u'm.johnston@abdn.ac.uk']],
#  [u'2797176', [u'p.lastra@abdn.ac.uk.']],
#  [u'9634245', []],
#  [u'9634252',
#   [u'chris.burton@ed.ac.uk',
#    u'J.Knoop@nkcv.umcn.nl',
#    u'nikola.popovic@ed.ac.uk',
#    u'michael.sharpe@ed.ac.uk',
#    u'G.Bleijenberg@nkcv.umcn.nl']],
#  [u'9631215', [u'g.bacciagaluppi@abdn.ac.uk', u'ecrull@nd.edu']],
#  [u'20309539', []],
#  [u'177164', [u'j.francis@abdn.ac.uk']],
#  [u'2797175',
#   [u'martin.eccles@ncl.ac.uk',
#    u'Gillian.Hawthorne@newcastle-pct.nhs.uk',
#    u'm.johnston@abdn.ac.uk',
#    u'gwhunter@btinternet.com',
#    u'nick.steen@ncl.ac.uk',
#    u'j.francis@abdn.ac.uk',
#    u'susan.hrisos@ncl.ac.uk',
#    u'Marko.Elovainio@stakes.fi',
#    u'jgrimshaw@ohri.ca']],
#  [u'9634244', [u'adiaz@math.ku.dk', u'assaf@maths.abdn.ac.uk']],
#  [u'11303944',
#   [u'e.nikolaou@abdn.ac.uk',
#    u'ino.agrafioti@imperial.ac.uk',
#    u'm.stumpf@imperial.ac.uk',
#    u'janet.quinn@newcastle.ac.uk',
#    u'i.stansfield@abdn.ac.uk',
#    u'al.brown@abdn.ac.uk']],
#  [u'177115', []],
#  [u'177122',
#   [u'd.bonetti@chs.dundee.ac.uk',
#    u'linda.young@nes.scot.nhs.uk',
#    u'Irene.Black@nes.scot.nhs.uk',
#    u'hcassie@chs.dundee.ac.uk',
#    u'c.r.ramsay@abdn.ac.uk',
#    u'j.e.clarkson@chs.dundee.ac.uk']],
#  [u'177165', [u'k.smith@bath.ac.uk']],
#  [u'2797174',
#   [u'susan.hrisos@ncl.ac.uk',
#    u'martin.eccles@ncl.ac.uk',
#    u'j.francis@abdn.ac.uk',
#    u'M.Bosch@iq.umcn.nl',
#    u'R.Dijkstra@nhg.org',
#    u'm.johnston@abdn.ac.uk',
#    u'R.Grol@iq.umcn.nl',
#    u'e.f.s.kaner@ncl.ac.uk',
#    u'nick.steen@ncl.ac.uk']],
#  [u'9633769', [u'jane.norman@ed.ac.uk']],
#  [u'9634250', [u'natalia@mat.uab.cat', u'assaf@maths.abdn.ac.uk']],
#  [u'9430913', [u'kabender@uwm.edu.', u'theod@abdn.ac.uk.']],
#  [u'19915621', [u'gorry@erg.abdn.ac.uk']],
#  [u'177123',
#   [u's.fielding@abdn.ac.uk',
#    u'p.fayers@abdn.ac.uk',
#    u'c.r.ramsay@abdn.ac.uk']],
#  [u'177229',
#   [u'bill.moorhead@ed.ac.uk',
#    u'e.gountouna@ed.ac.uk',
#    u'djob@staffmail.ed.ac.uk',
#    u'andrew.mcintosh@ed.ac.uk',
#    u'l.romaniuk@sms.ed.ac.uk',
#    u'katherine.lymer@ed.ac.uk',
#    u'hwhalley@staffmail.ed.ac.uk',
#    u'g.waiter@abdn.ac.uk',
#    u'd.brennan@clinmed.gla.ac.uk',
#    u't.ahearn@abdn.ac.uk',
#    u'jc199d@clinmed.gla.ac.uk',
#    u'barrie.condon@udcf.gla.ac.uk',
#    u'd.steele@dundee.ac.uk',
#    u'jmw@skull.dcn.ed.ac.uk',
#    u's.lawrie@ed.ac.uk']],
#  [u'177293', [u'm.mueller@rz.uni-leipzig.de']],
#  [u'177166', [u'l.ternent@abdn.ac.uk']],
#  [u'2797243', [u'jbts@bas.ac.uk']],
#  [u'9430892', [u'wvasconcelos@acm.org', u'ANI@REM']],
#  [u'9430905', [u'd.martin@abdn.ac.uk']],
#  [u'177294', []],
#  [u'177174', [u'kesk@vet.dtu.dk']],
#  [u'9633767', []],
#  [u'9430911', [u'kabender@uwm.edu', u'kabender@uwm.edu.']],
#  [u'177132', []],
#  [u'177118', [u'j.a.cook@abdn.ac.uk']],
#  [u'177428', [u'linda.sharp@ncri.ie']],
#  [u'2797164', [u'denfert@pasteur.fr.']],
#  [u'9634233', [u'richardc@earth.ox.ac.uk']],
#  [u'19968084', [u'al.brown@abdn.']],
#  [u'177400', [u'costantino.manes@polito.it.']],
#  [u'177429',
#   [u'fiona.comrie@foodstandards.gsi.gov.uk',
#    u'lindsey.masson@abdn.ac.uk',
#    u'g.mcneill@abdn.ac.uk']],
#  [u'281270', []],
#  [u'177169',
#   [u'j.presseau@abdn.ac.uk',
#    u'f.sniehotta@abdn.ac.uk',
#    u'j.francis@abdn.ac.uk',
#    u'n.campbell@abdn.ac.uk']],
#  [u'177190', [u't.j.norman@abdn.ac.uk']],
#  [u'177133', [u'brian.cuthbertson@sunnybrook.ca']],
#  [u'177140', [u'c.robertson@abdn.ac.uk']],
#  [u'177119', [u'lg116@york.ac.uk']],
#  [u'2797163', [u'f.odds@abdn.ac.uk.']],
#  [u'2797170', [u'al.brown@abdn.ac.uk']],
#  [u'4193237', [u'bsbuckley@iol.ie']],
#  [u'9630002', [u'y.dewhurst@abdn.ac.uk', u'd.pendergast@griffith.edu.au']],
#  [u'177191',
#   [u'thao.le@abdn.ac.uk', u't.j.norman@abdn.ac.uk', u'wvasconcelos@acm.org']],
#  [u'2797218',
#   [u's.fielding@abdn.ac.uk',
#    u'p.fayers@abdn.ac.uk',
#    u'c.r.ramsay@abdn.ac.uk']],
#  [u'9631237', [u'sophiewitter@blueyonder.co.uk', u'bgarshong@yahoo.com']],
#  [u'11303917', [u'richardc@earth.ox.ac.uk']],
#  [u'177192', [u'ramaroson.andriantsitohaina@univ-angers.fr']],
#  [u'177205', [u'lg116@york.ac.uk']],
#  [u'370437', []],
#  [u'109223', []],
#  [u'177136', [u'j.a.cook@abdn.ac.uk']],
#  [u'11303908', []],
#  [u'177264', []],
#  [u'19506500',
#   [u'anke.hinney@uni-duisburg-essen.de', u'Information@Karger.de']],
#  [u'177138', [u's.hagen@gcal.ac.uk']],
#  [u'177102', []],
#  [u'177392',
#   [u'k.Kiezebrink@abertay.ac.uk',
#    u'i.k.crombie@cpse.dundee.ac.uk',
#    u'm.a.j.irvine@cpse.dundee.ac.uk',
#    u'vivien.swanson@stir.ac.uk',
#    u'kevin.power@nhs.net',
#    u'w.l.wrieden@abdn.ac.uk',
#    u'peter.slane@nhs.net']],
#  [u'4193256', [u'bensondj@maths.abdn.ac.uk']],
#  [u'9631233', [u'c.harrington@abdn.ac.uk']],
#  [u'18498904',
#   [u'r.d.petty@abdn.ac.uk',
#    u'l.samuel@nhs.net',
#    u'g.i.murray@abdn.ac.uk',
#    u'graham.macdonald@nhs.net',
#    u'tokelly@nhs.net',
#    u'malcolm.loudon@arh.grampian.scot.nhs.uk',
#    u'Norman.Binnie@NHS.net',
#    u'emad.aly@nhs.net',
#    u'aileen.mckinley@nhs.net',
#    u'w.wang2@wlv.ac.uk',
#    u'f.j.gilbert@abdn.ac.uk',
#    u'scott.semple@ed.ac.uk',
#    u'e.collie-duguid@abdn.ac.uk',
#    u'r.d.petty@abdn.ac.uk',
#    u'duguid@abdn.ac.uk.',
#    u'r.d.petty@abdn.ac.uk',
#    u'l.samuel@nhs.net',
#    u'g.i.murray@abdn.ac.uk',
#    u'graham.macdonald@nhs.net',
#    u'tokelly@nhs.net',
#    u'malcolm.loudon@arh.grampian.scot.nhs.uk',
#    u'Norman.Binnie@NHS.net',
#    u'emad.aly@nhs.net',
#    u'aileen.mckinley@nhs.net',
#    u'w.wang2@wlv.ac.uk',
#    u'f.j.gilbert@abdn.ac.uk',
#    u'scott.semple@ed.ac.uk',
#    u'e.collie-duguid@abdn.ac.uk']],
#  [u'177209', [u'r.a.hernandez@abdn.ac.uk']],
#  [u'177139', [u's.hagen@gcal.ac.uk']],
#  [u'19438868',
#   [u'a.sneddon@abdn.ac.uk',
#    u'S.Bashir@abdn.ac.uk',
#    u'rayner@vrayner.plus.com',
#    u's.mitchell@abdn.ac.uk',
#    u'honny@kitox.re.kr',
#    u'A.Morris@abdn.ac.uk',
#    u'k.wahle@abdn.ac.uk',
#    u'L.Williams@abdn.ac.uk.']],
#  [u'177111', [u'g.mowatt@abdn.ac.uk']],
#  [u'177274', [u'm.mueller@rz.uni-leipzig.de']],
#  [u'4193265', [u'tim.wilt@med.va.gov', u'j.k.gupta@bham.ac.uk']],
#  [u'4193272', [u'rgbi@bas.ac.uk']],
#  [u'9631224',
#   [u'c.lagido@abdn.ac.uk',
#    u'j.pettitt@abdn.ac.uk',
#    u'a.w.flett@abdn.ac.uk',
#    u'l.a.glover@abdn.ac.uk']],
#  [u'9631231', [u'proksch@uni-duesseldorf.de']],
#  [u'4193266', [u'tim.wilt@med.va.gov']],
#  [u'177042',
#   [u'susan.hrisos@ncl.ac.uk',
#    u'martin.eccles@ncl.ac.uk',
#    u'm.johnston@abdn.ac.uk',
#    u'j.francis@abdn.ac.uk',
#    u'e.f.s.kaner@ncl.ac.uk',
#    u'nick.steen@ncl.ac.uk',
#    u'jgrimshaw@ohri.ca',
#    u'susan.hrisos@ncl.ac.uk',
#    u'martin.eccles@ncl.ac.uk',
#    u'e.f.s.kaner@ncl.ac.uk',
#    u'nick.steen@ncl.ac.uk',
#    u'm.johnston@abdn.ac.uk',
#    u'j.francis@abdn.ac.uk',
#    u'jgrimshaw@ohri.ca',
#    u'susan.hrisos@ncl.ac.uk']],
#  [u'9631223', []],
#  [u'19787407', [u'kadosh@uthscsa.edu']],
#  [u'177240',
#   [u'j.francis@abdn.ac.uk',
#    u'Martin.Eccles@newcastle.ac.uk',
#    u'm.johnston@abdn.ac.uk',
#    u'p.m.whitty@ncl.ac.uk',
#    u'jgrimshaw@ohri.ca',
#    u'E.F.S.Kaner@newcastle.ac.uk',
#    u'liz.smith@mbs.ac.uk',
#    u'anne_walker@yahoo.co.uk']],
#  [u'177050', [u'r.a.hernandez@abdn.ac.uk']],
#  [u'177043',
#   [u'susan.hrisos@ncl.ac.uk',
#    u'martin.eccles@ncl.ac.uk',
#    u'm.johnston@abdn.ac.uk',
#    u'j.francis@abdn.ac.uk',
#    u'e.f.s.kaner@ncl.ac.uk',
#    u'nick.steen@ncl.ac.uk',
#    u'jgrimshaw@ohri.ca']],
#  [u'177120', []],
#  [u'177086', [u'j.a.cook@abdn.ac.uk']],
#  [u'9633778',
#   [u'anne.langston@ed.ac.uk',
#    u'm.johnston@abdn.ac.uk',
#    u'j.francis@abdn.ac.uk',
#    u'c.robertson@abdn.ac.uk',
#    u'm.k.campbell@abdn.ac.uk',
#    u'v.a.entwistle@dundee.ac.uk',
#    u'theresa.marteau@kcl.ac.uk',
#    u'g.maclennan@abdn.ac.uk',
#    u'john.weinman@kcl.ac.uk',
#    u'narpd@btconnect.com',
#    u'zosia@abdn.ac.uk',
#    u'aalj23@ukgateway.net',
#    u'stuart.ralston@ed.ac.uk']],
#  [u'18498922', [u'pam42@cam.ac.uk']],
#  [u'20115549', [u'lcc@sanger.ac.uk', u'vgonzal@ccg.unam.mx']],
#  [u'177114', [u'don.wilson@otago.ac.nz']],
#  [u'177087', []],
#  [u'177044', []],
#  [u'2797238', [u'bensondj@maths.abdn.ac.uk']],
#  [u'177108', []],
#  [u'177305', [u'changhoon.choi@abdn.ac.uk', u'd.lurie@abdn.ac.uk']],
#  [u'177109', [u'drallahdin@hotmail.co.uk']],
#  [u'177116', [u'v.a.paul-ebhohimhen@abdn.ac.uk']],
#  [u'177130', [u'r.a.hernandez@abdn.ac.uk']],
#  [u'177306', []],
#  [u'177173', []],
#  [u'2797180', [u'j.ndow@abdn.ac.uk']],
#  [u'177237',
#   [u'j.allan@abdn.ac.uk', u'm.johnston@abdn.ac.uk', u'n.campbell@abdn.ac.uk']],
#  [u'177131', [u'x.jia@abdn.ac.uk']],
#  [u'177097',
#   [u'j.francis@abdn.ac.uk',
#    u'Martin.Eccles@newcastle.ac.uk',
#    u'm.johnston@abdn.ac.uk',
#    u'p.m.whitty@ncl.ac.uk',
#    u'jgrimshaw@ohri.ca',
#    u'E.F.S.Kaner@newcastle.ac.uk',
#    u'liz.smith@mbs.ac.uk',
#    u'anne_walker@yahoo.co.uk']],
#  [u'177047', [u'buchheit@ba.ttu.edu', u'n.feltovich@abdn.ac.uk']],
#  [u'19915623',
#   [u'tsvwg@ietf.org',
#    u'gerrit@erg.abdn.ac.uk',
#    u'gorry@erg.abdn.ac.uk',
#    u'ietf-ipr@ietf.org.']],
#  [u'177125',
#   [u'j.cameron@dundee.ac.uk', u'j.z.taylor@dundee.ac.uk', u'Acg2@st-']],
#  [u'177048', [u'p.a.schofield@abdn.ac.uk']],
#  [u'177252',
#   [u's.fielding@abdn.ac.uk',
#    u'g.maclennan@abdn.ac.uk',
#    u'j.a.cook@abdn.ac.uk',
#    u'c.r.ramsay@abdn.ac.uk']],
#  [u'177330',
#   [u'thorsten.bestvater.tb@bayermaterialscience.com',
#    u'p.louis@rowett.ac.uk',
#    u'galinski@uni-bonn.de']],
#  [u'177380', [u'm.mueller@rz.uni-leipzig.de']],
#  [u'177063', [u'jduffy@pitt.edu', u'n.feltovich@abdn.ac.uk']],
#  [u'177099',
#   [u'noemilois@aol.com',
#    u'j.m.burr@abdn.ac.uk',
#    u'j.norrie@abdn.ac.uk',
#    u'l.vale@abdn.ac.uk',
#    u'j.a.cook@abdn.ac.uk',
#    u'a.mcdonald@abdn.ac.uk',
#    u'not@valid.com']],
#  [u'11304012', []],
#  [u'177331',
#   [u'd.sleeman@abdn.ac.uk',
#    u'surajajit@yahoo.com',
#    u'davidfowler0@googlemail.com',
#    u'david.knott@rolls-royce.com']],
#  [u'177261', [u'nir.oren@kcl.ac.uk']],
#  [u'19506499', [u'S.Whybrow@Rowett.ac.uk']],
#  [u'19915619', [u'lars.eggert@nokia.com', u'gorry@erg.abdn.ac.uk']],
#  [u'177128',
#   [u's.michie@ucl.ac.uk',
#    u'm.johnston@abdn.ac.uk',
#    u'j.francis@abdn.ac.uk',
#    u'wendy.hardeman@phpc.cam.ac.uk',
#    u'martin.eccles@ncl.ac.uk']],
#  [u'177368', [u'linda.sharp@ncri.ie']],
#  [u'9631229', []],
#  [u'177073',
#   [u'anne.langston@ed.ac.uk',
#    u'm.johnston@abdn.ac.uk',
#    u'j.francis@abdn.ac.uk',
#    u'c.robertson@abdn.ac.uk',
#    u'm.k.campbell@abdn.ac.uk',
#    u'v.a.entwistle@dundee.ac.uk',
#    u'theresa.marteau@kcl.ac.uk',
#    u'g.maclennan@abdn.ac.uk',
#    u'john.weinman@kcl.ac.uk',
#    u'narpd@btconnect.com',
#    u'zosia@abdn.ac.uk',
#    u'aalj23@ukgateway.net',
#    u'stuart.ralston@ed.ac.uk']],
#  [u'177059',
#   [u'richardrecord@hotmail.com',
#    u'abdumohiddin@doctors.org.uk',
#    u'insights@ids.ac.uk',
#    u'sophiewitter@blueyonder.co.uk',
#    u'stephen.jan@lshtm.ac.uk',
#    u'tara.kielmann@qmu.ac.uk',
#    u'id21@ids.ac.uk',
#    u'rmanongi@yahoo.co.uk']],
#  [u'177066',
#   [u'w.graham@abdn.ac.uk',
#    u'sahmed@jhsph.edu',
#    u'cstanton@jhsph.edu',
#    u'abouzahrc@who.int',
#    u'Oona.Campbell@lshtm.ac.uk']],
#  [u'177129', [u'g.mcneill@abdn.ac.uk']],
#  [u'177333', []],
#  [u'9631228', [u'm.p.frenneaux@bham.ac.uk']],
#  [u'177137', [u'g.mowatt@abdn.ac.uk.']],
#  [u'177074',
#   [u'jan.lecouturier@newcastle.ac.uk',
#    u'c.h.bamford@ncl.ac.uk',
#    u'julian.hughes@northumbria-healthcare.nhs.uk',
#    u'j.francis@abdn.ac.uk',
#    u'r.c.foy@ncl.ac.uk',
#    u'm.johnston@abdn.ac.uk',
#    u'martin.eccles@ncl.ac.uk']],
#  [u'177187', []],
#  [u'4193262', [u'christina.bell@abdn.ac.uk']],
#  [u'9631227', [u'm.jackson@bangor.ac.uk']],
#  [u'177040', [u'n.feltovich@abdn.ac.uk']],
#  [u'177160', [u'd.pendergast@uq.edu.au', u'y.dewhurst@abdn.ac.uk']],
#  [u'177076',
#   [u'joanne.mckenzie@med.monash.edu.au',
#    u'simon.french@med.monash.edu.au',
#    u'denise.oconnor@med.monash.edu.au',
#    u'jgrimshaw@ohri.ca',
#    u'duncan.mortimer@buseco.monash.edu.au',
#    u's.michie@ucl.ac.uk',
#    u'j.francis@abdn.ac.uk',
#    u'neil.spike@med.monash.edu.au',
#    u'peter.schattner@med.monash.edu.au',
#    u'peter.kent@med.monash.edu.au',
#    u'rachelle.buchbinder@med.monash.edu.au',
#    u'sally.green@med.monash.edu.au']],
#  [u'177083',
#   [u's.fielding@abdn.ac.uk',
#    u'g.maclennan@abdn.ac.uk',
#    u'j.a.cook@abdn.ac.uk',
#    u'c.r.ramsay@abdn.ac.uk']],
#  [u'177230', [u'rorden@gwm.sc.edu']],
#  [u'177110', []],
#  [u'177026', []],
#  [u'2797179', [u'j.ndow@abdn.ac.uk']],
#  [u'2797186', []],
#  [u'4193264',
#   [u'tkavita@abdn.ac.uk',
#    u'lferres@ccs.carleton.ca',
#    u'yaji.sripada@abdn.ac.uk']],
#  [u'13291', []],
#  [u'177091', [u'a.poobalan@abdn.ac.uk']],
#  [u'176997', [u'kabender@uwm.edu', u'theod@abdn.ac.uk']],
#  [u'177077', [u'j.ndow@abdn.ac.uk']],
#  [u'177041',
#   [u'martin.eccles@ncl.ac.uk',
#    u'm.johnston@abdn.ac.uk',
#    u'susan.hrisos@ncl.ac.uk',
#    u'j.francis@abdn.ac.uk',
#    u'jgrimshaw@ohri.ca',
#    u'nick.steen@ncl.ac.uk',
#    u'e.f.s.kaner@ncl.ac.uk']],
#  [u'177281',
#   [u'a.clegg@soton.ac.uk',
#    u'david.scott@oxfordoutcomes.com',
#    u'e.loveman@soton.ac.uk',
#    u'j.colquitt@soton.',
#    u'p.royle@abdn.ac.uk',
#    u'J.S.Bryant@soton.ac.uk']],
#  [u'19118543', []],
#  [u'2797247', [u'rgbi@bas.ac.uk']],
#  [u'176955', [u'theod@abdn.ac.uk.']],
#  [u'177028',
#   [u'jgrimshaw@ohri.ca',
#    u'merrick.zwarenstein@ices.on.ca',
#    u'jtetroe@cihr-',
#    u'Gaston.Godin@fsi.ulaval.ca',
#    u'igraham@cihr-irsc.gc.ca',
#    u'louise.lemyre@uottawa.ca',
#    u'martin.eccles@ncl.ac.uk',
#    u'm.johnston@abdn.ac.uk',
#    u'j.francis@abdn.ac.uk',
#    u'jan@ices.on.ca',
#    u'korourke@ohri.ca',
#    u'France.Legare@mfa.ulaval.ca',
#    u'justin.presseau@alumni.uottawa.ca']],
#  [u'176998', []],
#  [u'177078', [u'j.hussein@abdn.ac.uk']],
#  [u'13292', []],
#  [u'176956', [u'theod@abdn.ac.uk.']],
#  [u'177269',
#   [u'noren@csd.abdn.ac.uk',
#    u'tnorman@csd.abdn.ac.uk',
#    u'apreece@csd.abdn.ac.uk']],
#  [u'176999', [u'rkoretz@dhs.co.la.ca.us']],
#  [u'177029',
#   [u'r.c.foy@ncl.ac.uk',
#    u'j.francis@abdn.ac.uk',
# ...
#    u'd.bonetti@chs.dundee.ac.uk',
#    u'Anne_walker@yahoo.co.uk']],
#  [u'177057', [u'billy.bosu@hru-ghs.org']],
#  [u'177064', [u'sophiewitter@blueyonder.co.uk']],
#  [u'176984', []],
#  [u'176977', []],
#  [u'2797162', [u'al.brown@abdn.ac.uk.']],
#  [u'19968093', [u'jennifer.boyd@abdn', u'h.r.J.daniels@bath.ac.uk']],
#  [u'177262', [u'apreece@csd.abdn.ac.uk']],
#  [u'176985', [u'Robert.Watson@Durham.ac.uk']],
#  [u'176992', [u'sm37@york.ac.uk']],
#  [u'177008', [u'j.m.burr@abdn.ac.uk', u'c.fraser@abdn.ac.uk']],
#  [u'176978', [u'theod@abdn.ac.uk', u'a.zangelidis@abdn.ac.uk']],
#  [u'177383', []],
#  [u'177023',
#   [u'p.andrews@ed.ac.uk',
#    u'a.avenell@abdn.ac.uk',
#    u'David.Noble@arh.grampian.scot.nhs.uk',
#    u'm.k.campbell@abdn.ac.uk',
#    u'c.battison@ed.ac.uk',
#    u'bernie.croal@nhs.net',
#    u'bill.simpson@nhs.net',
#    u'j.norrie@abdn.ac.uk',
#    u'l.vale@abdn.ac.uk',
#    u'j.cook@abdn.ac.uk',
#    u'r.deverteuil@abdn.ac.uk',
#    u'anne.milne@abdn.ac.uk',
#    u'p.andrews@ed.ac.uk']],
#  [u'177030',
#   [u'j.francis@abdn.ac.uk',
#    u'jgrimshaw@ohri.ca',
#    u'merrick.zwarenstein@ices.on.ca',
#    u'martin.eccles@ncl.ac.uk',
#    u'susan.shiller@ices.on.ca',
#    u'Gaston.Godin@fsi.ulaval.ca',
#    u'm.johnston@abdn.ac.uk',
#    u'k_orourke@rogers.com',
#    u'justin.presseau@alumni.uottawa.ca',
#    u'jtetroe@cihr-irsc.gc.ca']],
#  [u'177009', [u'jen.cleland@abdn.ac.uk']],
#  [u'177067',
#   [u'sophiewitter@blueyonder.co.uk',
#    u'tonykusi@gmail.com',
#    u'maikins@jsaconsultants.com']],
#  [u'177257',
#   [u'jgrimshaw@ohri.ca',
#    u'merrick.zwarenstein@ices.on.ca',
#    u'jtetroe@cihr-',
#    u'Gaston.Godin@fsi.ulaval.ca',
#    u'igraham@cihr-irsc.gc.ca',
#    u'louise.lemyre@uottawa.ca',
#    u'martin.eccles@ncl.ac.uk',
#    u'm.johnston@abdn.ac.uk',
#    u'j.francis@abdn.ac.uk',
#    u'jan@ices.on.ca',
#    u'korourke@ohri.ca',
#    u'France.Legare@mfa.ulaval.ca',
#    u'justin.presseau@alumni.uottawa.ca']],
#  [u'177031',
#   [u'dlf@brighton.ac.uk',
#    u'Ian.Roberts@lshtm.ac.uk',
#    u'diana.elbourne@lshtm.ac.uk',
#    u'Haleema.shakur@lshtm.ac.uk',
#    u'Rosemary.Knight@lshtm.ac.uk',
#    u'j.garcia@ioe.ac.uk',
#    u'cms1000@cam.ac.uk',
#    u'V.A.Entwistle@dundee.ac.uk',
#    u'a.mcdonald@abdn.ac.uk',
#    u'a.grant@abdn.ac.uk',
#    u'm.k.campbell@abdn.ac.uk']],
#  [u'370435',
#   [u'aviswanath@nhs.net',
#    u'a.avenell@abdn.ac.uk',
#    u'sam.philip@arh.grampian.scot.nhs.uk',
#    u'S.acharya@nhs.net',
#    u'g.maclennan@abdn.ac.uk',
#    u'kdalziel@nhs.net',
#    u'olivia.pereira@nhs.net',
#    u'S.Copland@arh.grampian.scot.nhs.uk',
#    u'J.S.bevan@arh.grampian.scot.nhs.uk',
#    u'P.Abraham@arh.grampian.scot.nhs.uk']],
#  [u'177017', []],
#  [u'177024', [u'p.fayers@abdn.ac.uk']],
#  [u'19438859', [u'g.ritchie@abdn.ac.uk']],
#  [u'177195', [u'b.hayes@abdn.ac.uk.']],
#  [u'177025', [u'john.eagles@gpct.grampian.scot.nhs.uk']],
#  [u'177075', [u'laurelhatt@yahoo.com']],
#  [u'176995', []],
#  [u'177018',
#   [u'b.h.cuthbertson@abdn.ac.uk',
#    u'j.z.rattray@dundee.ac.uk',
#    u'm.johnston@abdn.ac.uk',
#    u'jaww@doctors.org.uk',
#    u'eddie.wilson@tuht.scot.nhs.uk',
#    u'c.r.r.a.hernandez@abdn.ac.uk',
#    u'c.r.ramsay@abdn.ac.uk',
#    u'alastair.hull@tpct.scot.nhs.uk',
#    u'j.norrie@abdn.ac.uk',
#    u'm.k.campbell@abdn.ac.uk']],
#  [u'177189', [u'conrad@oridb.org']],
#  [u'177090', [u'aazblanco@aol.com.']],
#  [u'177103', [u'r.a.hernandez@abdn.ac.uk']],
#  [u'177386', [u'm.mueller@rz.uni-leipzig.de.']],
#  [u'176960', [u'theod@abdn.ac.uk.']],
#  [u'177019', [u'b.h.cuthbertson@abdn.ac.uk']],
#  [u'176996', [u'j.a.cook@abdn.ac.uk']],
#  [u'13290', []],
#  [u'176954',
#   [u'f.douglas@abdn.ac.uk',
#    u'n.torrance@abdn.ac.uk',
#    u'van.teijlingen@abdn.ac.uk',
#    u'serena.meloni@health.scot.nhs.uk',
#    u'Ann.Kerr@health.scot.nhs.uk']],
#  [u'176961',
#   [u'a.langston@abdn.ac.uk',
#    u'm.johnston@abdn.ac.uk',
#    u'c.robertson@abdn.ac.uk',
#    u'm.k.campbell@abdn.ac.uk',
#    u'v.a.entwistle@dundee.ac.uk',
#    u'theresa.marteau@kcl.ac.uk',
#    u'narpd@btconnect.com',
#    u'stuart.ralston@ed.ac.uk']],
#  [u'176947', [u'theod@abdn.ac.uk', u'a.zangelidis@abdn.ac.uk']],
#  [u'177034', [u'j.bruce@abdn.ac.uk.']],
#  [u'177231', [u'duong.nguyen@bt.com']],
#  [u'2797248', [u'r.bingham@bris.ac.uk']],
#  [u'17201909', [u'ornacf@helix.nih.gov']],
#  [u'176962',
#   [u'r.dijkstra@kwazo.umcn.nl',
#    u'm.wensing@kwazo.umcn.nl',
#    u'ret@hsru.abdn.ac.uk',
#    u'r.akkermans@ives.umcn.nl',
#    u'j.braspenning@kwazo.umcn.nl',
#    u'jgrimshaw@ohri.ca',
#    u'r.grol@kwazo.umcn.nl']],
#  [u'176948', []],
#  [u'177268',
#   [u'f.douglas@abdn.ac.uk',
#    u'n.torrance@abdn.ac.uk',
#    u'van.teijlingen@abdn.ac.uk',
#    u'serena.meloni@health.scot.nhs.uk',
#    u'Ann.Kerr@health.scot.nhs.uk']],
#  [u'176949', [u'r.campbell@abdn.ac.uk.']],
#  [u'176963',
#   [u'c.fraser@abdn.ac.uk', u'a.c.murray@abdn.ac.uk', u'j.m.burr@abdn.ac.uk']],
#  [u'176964', [u'martin.eccles@ncl.ac.uk']],
#  [u'176971',
#   [u'i.shemilt@uea.ac.uk',
#    u'm.mugford@uea.ac.uk',
#    u'md18@york.ac.uk',
#    u'eric.eisenstein@duke.edu',
#    u'jacque.mallender@matrixrcl.co.uk',
#    u'd.mcdaid@lse.ac.uk',
#    u'l.vale@abdn.ac.uk',
#    u'damian.walker@lshtm.ac.uk',
#    u'research@c-cemg.org']],
#  [u'19506486', [u'perinm@ccf.org.']],
#  [u'176965',
#   [u'a.mcdonald@abdn.ac.uk',
#    u'Rosemary.Knight@lshtm.ac.uk',
#    u'm.k.campbell@abdn.ac.uk',
#    u'V.A.Entwistle@dundee.ac.uk',
#    u'a.grant@abdn.ac.uk',
#    u'j.a.cook@abdn.ac.uk',
#    u'diana.elbourne@lshtm.ac.uk',
#    u'd.l.francis@brighton.ac.uk',
#    u'j.garcia@ioe.ac.uk',
#    u'Ian.Roberts@lshtm.ac.uk',
#    u'cms1000@cam.ac.uk']],
#  [u'176966',
#   [u'cms1000@cam.ac.uk',
#    u'diana.elbourne@lshtm.ac.uk',
#    u'j.garcia@ioe.ac.uk',
#    u'm.k.campbell@abdn.ac.uk',
#    u'V.A.Entwistle@dundee.ac.uk',
#    u'd.l.francis@brighton.ac.uk',
#    u'a.grant@abdn.ac.uk',
#    u'Rosemary.Knight@lshtm.ac.uk',
#    u'a.mcdonald@abdn.ac.uk',
#    u'Ian.Roberts@lshtm.ac.uk']],
#  [u'177250', [u'ts@ltt.uni-erlangen.de', u'dnk@kapella.gpi.ru']],
#  [u'2797158', [u'm.netea@aig.umcn.nl.']],
#  [u'177012', [u'p.a.schofield@sheffield.ac.uk']],
#  [u'176983',
#   [u'martin.eccles@ncl.ac.uk',
#    u'susan.hrisos@ncl.ac.uk',
#    u'j.francis@abdn.ac.uk',
#    u'e.f.s.kaner@ncl.ac.uk',
#    u'heather.dickinson@ncl.ac.uk',
#    u'fiona.beyer@ncl.ac.uk',
#    u'm.johnston@abdn.ac.uk']],
#  [u'177013', [u'p.a.schofield@sheffield.ac.uk']],
#  [u'176990',
#   [u'c.glazener@abdn.ac.uk',
#    u'c.glazener@abdn.ac.uk',
#    u'peter.herbison@otago.ac.nz',
#    u'c.macarthur@bham.ac.uk',
#    u'R.J.Lancashire@bham.ac.uk',
#    u'magnusmcgee@hotmail.com',
#    u'a.grant@abdn.ac.uk',
#    u'don.wilson@stonebow.otago.ac.nz']],
#  [u'177260', [u'francesco.dellaccio@kcl.ac.uk']],
#  [u'177070', [u'josephine_borghi@yahoo.co.uk']],
#  [u'177014', [u'p.a.schofield@sheffield.ac.uk']],
#  [u'176935', [u'tim.barmby@abdn.ac.uk', u'peter.dolton@rhul.ac.uk']],
#  [u'177193', []],
#  [u'177263', [u'jmasthoff@csd.abdn.ac.uk']],
#  [u'177390',
#   [u'd.leiper@doctors.org.uk',
#    u'a.m.elliott@abdn.ac.uk',
#    u'p.hannaford@abdn.ac.uk']],
#  [u'176943', []],
#  [u'176993', [u'sue.ross@calgaryhealthregion.ca']],
#  [u'176979', []],
#  [u'176944', [u'tim.barmby@abdn.ac.uk', u'b.eberth@abdn.ac.uk']],
#  [u'177391',
#   [u'a.m.elliott@abdn.ac.uk',
#    u'p.hannaford@abdn.ac.uk',
#    u'blairsmith@abdn.ac.uk',
#    u'sally.wyke@stir.ac.uk',
#    u'kate@msoc.mrc.gla.ac.uk']],
#  [u'177215', [u'a.d.donaldson@abdn.ac.uk']],
#  [u'176952', [u'jennifer.hall@nhs.net', u'van.teijlingen@abdn.ac.uk']],
#  [u'177145', []],
#  [u'176988', [u'd.bonetti@chs.dundee.ac.uk']],
#  [u'176953',
#   [u'D.Heaney@abdn.ac.uk',
#    u'corri.black@abdn.ac.uk',
#    u'Donnell@clinmed.gla.ac.uk',
#    u'c.stark@abdn.ac.uk',
#    u'van.teijlingen@abdn.ac.uk']],
#  [u'176989', []],
#  [u'177033', [u'j.bruce@abdn.ac.uk']],
#  [u'176946',
#   [u'tim.barmby@abdn.ac.uk', u'b.eberth@abdn.ac.uk', u'a.ma@abdn.ac.uk']],
#  [u'20443929', [u'p.louis@rowett.ac.uk']],
#  [u'2797212',
#   [u'trutot@gmail.com',
#    u'mt326@cornell.edu',
#    u'kg@ncgr.org',
#    u'mark@compbiogen.com',
#    u'p.vanwest@abdn.ac.uk',
#    u'kamoun.1@osu.edu']],
#  [u'11303943',
#   [u'denfert@pasteur.fr', u'journals.permissions@oupjournals.org.']],
#  [u'177236',
#   [u'tarja.sorsa-leslie@helsinki.fi',
#    u'hmason@sghms.ac.uk',
#    u'billharris@golfershome.co.uk',
#    u'p.a.fowler@abdn.ac.uk']],
#  [u'177356', [u'NL@G']],
#  [u'176930', []],
#  [u'177053',
#   [u'l.dambruoso@abdn.ac.uk',
#    u'Mercy.Abbey@hru-ghs.org',
#    u'j.hussein@abdn.ac.uk']],
#  [u'11304015', []],
#  [u'176931', []],
#  [u'177175', [u'p.d.eckersall@vet.gla.ac.uk']],
#  [u'176932', []],
#  [u'176899', [u'pec140@abdn.ac.uk']],
#  [u'177367', [u'lurie@abdn.ac.uk']],
#  [u'177065', [u'MArmar-Klemesu@noguchi.mimcom.net', u'immpact@abdn.ac.uk']],
#  [u'177015', [u'p.a.schofield@sheffield.ac.uk']],
#  [u'177179', [u'irahwan@acm.org', u'tnorman@csd.abdn.ac.uk']],
#  [u'176950', [u'men206@abdn.ac.uk', u'van.teijlingen@abdn.ac.uk']],
#  [u'176951', [u'elp17@le.ac.uk', u'van.teijlingen@abdn.ac.uk']],
#  [u'176904', [u'a.zangelidis@abdn.ac.uk']],
#  [u'281268', [u'jpc@middlebury.edu.', u'erika.seki@abdn.ac.uk']],
#  [u'176909', []],
#  [u'176896', [u'erika.seki@abdn.ac.uk']],
#  [u'176897', [u'h.battu@abdn.ac.uk.']],
#  [u'11304014', [u'janet.quinn@ncl.ac.uk.']],
#  [u'176898', []],
#  [u'281271', [u'j.skakle@abdn.ac.uk']],
#  [u'11304013', []],
#  [u'176928', []],
#  [u'177206',
#   [u'j.gregory@abdn.ac.uk',
#    u'a.stewart@abdn.ac.uk',
#    u'p.undrill@abdn.ac.uk',
#    u'd.m.reid@abdn.ac.uk',
#    u'r.aspden@abdn.ac.uk']],
#  [u'176900',
#   [u'e.phimister@abdn.ac.uk',
#    u'theod@abdn.ac.uk',
#    u'richard.upward@nottingham.ac.uk',
#    u'e.phimister@abdn.ac.uk.']],
#  [u'176901',
#   [u'h.battu@abdn.ac.uk', u'p.t.seaman@dundee.ac.uk', u'yvesz@iui.se']],
#  [u'177265', [u'Judith.Masthoff@brighton.ac.uk']],
#  [u'176910', [u'tim.barmby@abdn.ac.uk']],
#  [u'17201914', [u'cg@st-andrews.ac.uk']],
#  [u'176915', []],
#  [u'177222', [u'g.s.bewick@abdn.ac.uk.']],
#  [u'177354', [u'cg@st-andrews.ac.uk']],
#  [u'17201912', [u'cg@st-andrews.ac.uk']],
#  [u'9629978', []],
#  [u'177177', []],
#  [u'17201918', [u'j.skakle@abdn.ac.uk']],
#  [u'177351', [u'cg@st-andrews.ac.uk']],
#  [u'177352', [u'cg@st-andrews.ac.uk']],
#  [u'176927', []],
#  [u'17195323', []],
#  [u'19506485', []],
#  [u'20664039',
#   [u'nihredit@southampton.ac.uk',
#    u'nihredit@southampton.ac.ukNIHR',
#    u'ALIFE@Work']],
#  [u'20664031',
#   [u'nihredit@southampton.ac.uk',
#    u'nihredit@southampton.ac.ukNIHR',
#    u'david.murray@ndorms.ox.ac.uk',
#    u'KAT@abdn.ac.uk',
#    u'KAT@abdn.ac.uk157']],
#  [u'19118544', [u'Helen.minnis@glasgow.ac.uk']],
#  [u'17051719',
#   [u'nihredit@southampton.ac.uk',
#    u'nihredit@southampton.ac.uk',
#    u'p.hannaford@abdn.ac.uk',
#    u'p.royle@abdn.ac.uk',
#    u'p.royle@abdn.ac.uk',
#    u'John.ford@abdn.ac.uk',
#    u'ecummins@mcmdc.com',
#    u'clive.mulatero@leedsth.nhs.uk',
#    u'p.royle@abdn.ac.uk',
#    u'j.m.burr@abdn.ac.uk']],
#  [u'11303990', [u'k.a.kazimierczak@abdn.ac.uk']],
#  [u'19915625',
#   [u'nihredit@southampton.ac.uk',
#    u'nihredit@southampton.ac.uk',
#    u'p.sharma@abdn.ac.uk',
#    u'g.mowatt@abdn.ac.uk']],
#  [u'11303995', [u'helen.minnis@glasgow.ac.uk']],
#  [u'11303959', [u'wbarr@ucalgary.ca', u'p.loovers@abdn.ac.uk']],
#  [u'2797208', []],
#  [u'177107', [u'b.e.harrington@durham.ac.uk']],
#  [u'177117',
#   [u'prof.p.fraser@abdn.ac.uk',
#    u'martin.hoesli@unige.ch',
#    u'lmcalevey@business.otago.ac.nz',
#    u'prof.p.fraser@abdn.ac.uk',
#    u'martin.hoesli@unige.ch',
#    u'lmcalevey@business.otago.ac.nz']],
#  [u'177020', [u'r.deverteuil@abdn.ac.uk']],
#  [u'177081', [u'j.d.walley@leeds.ac.uk']],
#  [u'176942', []],
#  [u'176905', [u'h.dickey@abdn.ac.uk']],
#  [u'176907', [u'a.zangelidis@abdn.ac.uk']],
#  [u'176895', []],
#  [u'19438864', []],
#  [u'29151161', [u'c.adam@abdn.ac.uk']],
#  [u'29151111', [u'w.huang@abdn.ac.uk']],
#  [u'29151084', [u'gordon.brown@abdn.ac.uk']],
#  [u'29151197', []],
#  [u'29151091', [u'michael.daly@stir.ac.uk']],
#  [u'29151224', [u'a.c.mclaughlin@abdn.ac.uk.']],
#  [u'30276092', []],
#  [u'30276105',
#   [u'thomas.peron@usp.br',
#    u'pengji@pik-potsdam.de',
#    u'francisco@icmc.usp.br']],
#  [u'30276028',
#   [u'm.awad@dotenergyconsulting.com',
#    u'osama.khair@sd.zain.com',
#    u'hassan.hamdoun@abdn.ac.uk',
#    u'h.hamdoun@dotenergyconsulting.com']],
#  [u'29465884', [u'eficeec@efi.int', u'eficeec@efi.int']],
#  [u'29408721', []],
#  [u'29408714',
#   [u'juozas.baltusnikas@lsu.lt',
#    u'audrius.kilikevicius@lsu.lt',
#    u'tomas.venckunas@lsu.lt',
#    u'fokinandrej@yahoo.com',
#    u'a.lionikas@abdn.ac.uk',
#    u'a.ratkevicius@abdn.ac.uk']],
#  [u'30435648', [u'dimitrios.pavlidis@imperial.ac.uk']],
#  [u'30435655', [u'al.brown@abdn.ac.uk']],
#  [u'30435698', [u'a.poobalan@abdn.ac.uk']],
#  [u'30435732',
#   [u'ken.ong@mrc-epid.cam.ac.uk', u'john.perry@mrc-epid.cam.ac.uk']],
#  [u'30474088', [u's.p.hoppler@abdn.ac.uk']],
#  [u'30474038', [u'astap@matis.is', u'j.feldmann@abdn.ac.uk']],
#  [u'30474052',
#   [u'stephen.mccall@dph.ox.ac.uk',
#    u'gillian.flett@nhs.net',
#    u'emmanuel.okpo@nhs.net',
#    u'sohinee.bhattacharya@abdn.ac.uk',
#    u'sohinee.bhattacharya@abdn.ac.uk']],
#  [u'30790889',
#   [u'figgw@helix.nih.gov',
#    u'n.vargesson@abdn.ac.uk',
#    u'nvargesson@gmail.com']],
#  [u'30435662', [u'r02sl13@abdn.ac.uk']],
#  [u'30435725', [u'graham.lord@kcl.ac.uk']],
#  [u'30435802', [u'sinead.noirin.murphy@gmail.com', u'strandings@zsl.org.']],
#  [u'30435888', [u'k.starr@abdn.ac.uk']],
#  [u'30435895', [u'p.haggarty@abdn.ac.uk']],
#  [u'30435908', [u'dingyuqiang@vip.163.com', u'lzhang0808@tongji.edu.cn']],
#  [u'30435915', [u'r02gk11@abdn.ac.uk']],
#  [u'30435922', [u'j.sternberg@abdn.ac.uk']],
#  [u'30435965', [u'huangzg@lzu.edu.cn', u'andYing-Cheng.Lai@asu.edu']],
#  [u'30435972', [u'rbialik@igf.edu.pl']],
#  [u'42130737', [u'jackisch@kit.edu']],
#  [u'42130681', [u'pete.smith@abdn.ac.uk']],
#  [u'42130807', [u'sartorelli@if.usp.br']],
#  [u'42130674',
#   [u'permissions@acm.org.',
#    u'Assessment@Entity',
#    u'Assessment@Entity',
#    u'Assessment@Entity']],
#  [u'42130787', [u'a.e.vardy@dundee.ac.uk']],
#  [u'42130617', [u'jkrys@psych.pan.pl', u'kuba@krys.pl']],
#  [u'42130794', [u'editing@geosociety.org.']],
#  [u'42130624',
#   [u'y.liu8@rgu.ac.uk.',
#    u'jpaez@espol.edu.ec',
#    u'e.pavlovskaia@abdn.ac.uk',
#    u'm.wiercigroch@abdn.ac.uk']],
#  [u'42130477', []],
#  [u'42130484', []],
#  [u'42130491', [u'mgronwald@abdn.ac.uk.']],
#  [u'42130504', [u'm.menshykova@abdn.ac.uk']],
#  [u'42130554',
#   [u'nihredit@southampton.ac.uk',
#    u'nihredit@southampton.ac.uk',
#    u'm.brazzelli@abdn.ac.uk']],
#  [u'77050512', [u'r03mc13@abdn.ac.uk']],
#  [u'77050485', [u'fperez-reche@abdn.ac.uk']],
#  [u'77050442', [u'a.o.pasternak@amc.uva.nl']],
#  [u'77050745', [u'xjin@abdn.ac.uk.']],
#  [u'77050738', []],
#  [u'77051015',
#   [u'mcmarche@syr.edu',
#    u'yffily.brandeis@gmail.com',
#    u'shenkes@abdn.ac.uk',
#    u'apatch@syr.edu',
#    u'dyllanes@syr.edu']],
#  [u'77051825', [u'b.guthrie@dundee.ac.uk', u'robertson@strath.ac.uk']],
#  [u'77051832', [u'd.jackson@rowett.ac.uk']],
#  [u'77051882', [u'Angus.Macleod@abdn.ac.uk']],
#  [u'77051938', [u'Luis.Botana@usc.es']],
#  [u'77052152', [u'Luis.Botana@usc.es']],
#  [u'77052188', [u'Rebrow@ceh.ac.uk']],
#  [u'77052195', [u'stephen.leslie@nhs.net', u'consortiasales@bmjgroup.com']],
#  [u'77052258', [u'rosalindadam@abdn.']],
#  [u'77052272', [u'John.West@ed.ac.uk']],
#  [u'77052405', [u'sunxiaoqiang@yahoo.com']],
#  [u'77052448', [u'gruer.health@gmail.com']],
#  [u'77050618', [u'mairead.black@abdn.ac.uk']],
#  [u'77050632', [u'm.spagnolo@abdn.ac.uk']],
#  [u'77051945', [u'zhao73@foxmail.com', u'J.Speakman@abdn.ac.uk']],
#  [u'77051952',
#   [u'endocrinology@endocrine.org',
#    u'endocrinology@endocrine.org',
#    u'endocrinology@endocrine.org',
#    u'endocrinology@endocrine.org',
#    u'tyler.stevenson@abdn.ac.uk']],
#  [u'77052018', [u'ginazoo@outlook.com']],
#  [u'77052025', [u'jill.hall@ed.ac.uk']],
#  [u'77052138', [u'b.w.tatler@abdn.ac.uk']],
#  [u'77052378',
#   [u'kiarosz@gmail.com',
#    u'antoniomarcosbatista@gmail.com',
#    u'murilo.baptista@abdn.ac.uk',
#    u'protachevicz@gmail.com']],
#  [u'77052455', [u'bobduncan@abdn.ac.uk', u'mark.whittington@abdn.ac.uk']],
#  [u'77052518', []],
#  [u'77052575', []],
#  [u'77052568', [u'tiphainejdd@gmail.com']],
#  [u'77052582',
#   [u'b.williamson@abdn.ac.uk',
#    u'b.e.scott@abdn.ac.uk',
#    u's.fraser@abdn.ac.uk',
#    u'P.Blondel@bath.ac.uk',
#    u'psb@noc.ac.uk',
#    u'j.waggitt@bangor.ac.uk']],
#  [u'77614635', [u'p@efsa.europa.eu']],
#  ...]

# %% [markdown]
# Lets flatten the list

# %%
def flatten_list(unevenList):
    flat_list=[]
    for sublist in unevenList:
        aid=sublist[0]
        emails = sublist[1]
        for item in emails:
            flat_list.append([aid,item])
    return flat_list

# %%
email_of_1_flat = flatten_list(emails_of_1)
len(email_of_1_flat)
# Out:
# 2936

# %%
email_of_1_flat[1:10]
# Out:
# [[u'19787393', u'Lorna.ramsay@education.gsi.gov.uk'],
#  [u'19787393', u'r.aspden@abdn.ac.uk'],
#  [u'19787406', u'david.mcghee@abdn.ac.uk'],
#  [u'20327925', u'j.mercer@abdn.ac.uk'],
#  [u'20327925', u'michelle.murphy@abdn.ac.uk'],
#  [u'20664118', u'Sarah.Harris@igmm.ed.ac.uk.'],
#  [u'20664131', u'T.Gillingwater@ed.ac.uk.'],
#  [u'20664054', u'jiabao.he@abdn.ac.uk'],
#  [u'19888921', u's.schwarzkopf@gmail.com']]

# %%
#how many authors from aberdeen's articles are from aberdeen?
abdn_ctn=0
for i in email_of_1_flat:
    if i[1].endswith("abdn.ac.uk"):
        abdn_ctn +=1
print(abdn_ctn,len(email_of_1_flat))
# Out:
# (1132, 2936)

# %% [markdown]
# ### so about 50% of authors in articles in the Aberdeen repository are not from Aberdeen

# %%
import pandas as pd

# %% [markdown]
# Let's import a catalogue of all world domain of academic instituiotns and match it to authors

# %%
world_domains = pd.read_json('world_universities_and_domains.json')
world_domains.head()
# Out:
#   alpha_two_code        country          domain  \
# 0             US  United States  calbaptist.edu
# 1             US  United States   stevenson.edu
# 2             US  United States         mbl.edu
# 3             US  United States   maryville.edu
# 4             US  United States         aii.edu
#
#                             name                    web_page
# 0  California Baptist University  http://www.calbaptist.edu/
# 1           Stevenson University   http://www.stevenson.edu/
# 2   Marine Biological Laboratory         http://www.mbl.edu/
# 3           Maryville University   http://www.maryville.edu/
# 4             The Art Institutes         http://www.aii.edu/

# %%
#Create the frame with the emails

# %%
emails_df = pd.DataFrame.from_records(email_of_1_flat)
emails_df.head()
# Out:
#           0                                  1
# 0  19787393             L.V.Burgin@leeds.ac.uk
# 1  19787393  Lorna.ramsay@education.gsi.gov.uk
# 2  19787393                r.aspden@abdn.ac.uk
# 3  19787406            david.mcghee@abdn.ac.uk
# 4  20327925                j.mercer@abdn.ac.uk

# %% [markdown]
# We need to extract domain from each email:

# %%
def extract_domain(email):
    return email.split("@")[1]

# %%
#let's test:
extract_domain("mackenzie@abdn.ac.uk")
# Out:
# 'abdn.ac.uk'

# %%
#now run it on all the frame
emails_df['domain']=emails_df.apply(lambda row: extract_domain(row[1]),axis=1)
emails_df.head()
# Out:
#           0                                  1                domain
# 0  19787393             L.V.Burgin@leeds.ac.uk           leeds.ac.uk
# 1  19787393  Lorna.ramsay@education.gsi.gov.uk  education.gsi.gov.uk
# 2  19787393                r.aspden@abdn.ac.uk            abdn.ac.uk
# 3  19787406            david.mcghee@abdn.ac.uk            abdn.ac.uk
# 4  20327925                j.mercer@abdn.ac.uk            abdn.ac.uk

# %% [markdown]
# Now for the extracted domain match it (join operation) with the known affiliation of this domain using our first frame

# %%
merged_domains = pd.merge(emails_df,world_domains , left_on='domain',right_on="domain")
merged_domains.head(10)
# Out:
#           0                          1       domain alpha_two_code  \
# 0  19787393     L.V.Burgin@leeds.ac.uk  leeds.ac.uk             GB
# 1  18498901    T.R.A.Ensor@leeds.ac.uk  leeds.ac.uk             GB
# 2  18498901    T.R.A.Ensor@leeds.ac.uk  leeds.ac.uk             GB
# 3  17201917        n.alwan@leeds.ac.uk  leeds.ac.uk             GB
# 4    177081     j.d.walley@leeds.ac.uk  leeds.ac.uk             GB
# 5  30435804     r.m.wilkie@leeds.ac.uk  leeds.ac.uk             GB
# 6  77052240       d.miller@leeds.ac.uk  leeds.ac.uk             GB
# 7  77614526        pscplab@leeds.ac.uk  leeds.ac.uk             GB
# 8  77614646  s.r.kingsbury@leeds.ac.uk  leeds.ac.uk             GB
# 9  30435935      d.g.jayne@leeds.ac.uk  leeds.ac.uk             GB
#
#           country                 name                 web_page
# 0  United Kingdom  University of Leeds  http://www.leeds.ac.uk/
# 1  United Kingdom  University of Leeds  http://www.leeds.ac.uk/
# 2  United Kingdom  University of Leeds  http://www.leeds.ac.uk/
# 3  United Kingdom  University of Leeds  http://www.leeds.ac.uk/
# 4  United Kingdom  University of Leeds  http://www.leeds.ac.uk/
# 5  United Kingdom  University of Leeds  http://www.leeds.ac.uk/
# 6  United Kingdom  University of Leeds  http://www.leeds.ac.uk/
# 7  United Kingdom  University of Leeds  http://www.leeds.ac.uk/
# 8  United Kingdom  University of Leeds  http://www.leeds.ac.uk/
# 9  United Kingdom  University of Leeds  http://www.leeds.ac.uk/

# %%
merged_domains.columns = ['core_id', 'mail', 'domain','alpha_two_code', 'country', "name", "web"]

# %%
unique_domains = merged_domains.domain.unique()
unique_domains
domain_id_dict = {}
for domain in unique_domains:
    ids = merged_domains[merged_domains.domain==domain].core_id
    collaboration = merged_domains[merged_domains.core_id.isin(ids)].domain
    domain_id_dict[domain]=collaboration.values
# Out:
# {u'abdn.ac.uk': array([u'leeds.ac.uk', u'leeds.ac.uk', u'leeds.ac.uk', ...,
#         u'columbia.edu', u'uit.no', u'mit.edu'], dtype=object),
#  u'aber.ac.uk': array([u'aber.ac.uk', u'aber.ac.uk'], dtype=object),
#  u'abertay.ac.uk': array([u'abdn.ac.uk', u'stir.ac.uk', u'abertay.ac.uk', u'abertay.ac.uk'], dtype=object),
#  u'adelaide.edu.au': array([u'adelaide.edu.au'], dtype=object),
#  u'asu.edu': array([u'lzu.edu.cn', u'lzu.edu.cn', u'asu.edu', u'asu.edu', u'asu.edu',
#         u'asu.edu', u'asu.edu', u'asu.edu'], dtype=object),
#  u'auckland.ac.nz': array([u'abdn.ac.uk', u'auckland.ac.nz', u'auckland.ac.nz',
#         u'auckland.ac.nz', u'auckland.ac.nz', u'auckland.ac.nz'], dtype=object),
#  u'bangor.ac.uk': array([u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'bangor.ac.uk', u'bangor.ac.uk', u'bangor.ac.uk',
#         u'bangor.ac.uk', u'bangor.ac.uk', u'bath.ac.uk', u'hw.ac.uk'], dtype=object),
#  u'bath.ac.uk': array([u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'bangor.ac.uk', u'bath.ac.uk', u'bath.ac.uk',
#         u'bath.ac.uk', u'bath.ac.uk', u'bath.ac.uk', u'bath.ac.uk',
#         u'bath.ac.uk'], dtype=object),
#  u'bham.ac.uk': array([u'leeds.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'stir.ac.uk', u'nottingham.ac.uk', u'bham.ac.uk',
#         u'bham.ac.uk', u'bham.ac.uk', u'bham.ac.uk', u'bham.ac.uk',
#         u'bham.ac.uk', u'bham.ac.uk', u'bham.ac.uk', u'bham.ac.uk',
#         u'bham.ac.uk', u'otago.ac.nz', u'warwick.ac.uk', u'warwick.ac.uk'], dtype=object),
#  u'bnu.edu.cn': array([u'bnu.edu.cn', u'bnu.edu.cn'], dtype=object),
#  u'bond.edu.au': array([u'bond.edu.au'], dtype=object),
#  u'bournemouth.ac.uk': array([u'abdn.ac.uk', u'bournemouth.ac.uk'], dtype=object),
#  u'bris.ac.uk': array([u'bris.ac.uk'], dtype=object),
#  u'brunel.ac.uk': array([u'brunel.ac.uk'], dtype=object),
#  u'buffalo.edu': array([u'abdn.ac.uk', u'ncl.ac.uk', u'buffalo.edu'], dtype=object),
#  u'cam.ac.uk': array([u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'dundee.ac.uk', u'dundee.ac.uk', u'dundee.ac.uk',
#         u'lshtm.ac.uk', u'lshtm.ac.uk', u'lshtm.ac.uk', u'lshtm.ac.uk',
#         u'lshtm.ac.uk', u'lshtm.ac.uk', u'lshtm.ac.uk', u'lshtm.ac.uk',
#         u'lshtm.ac.uk', u'lshtm.ac.uk', u'cam.ac.uk', u'cam.ac.uk',
#         u'cam.ac.uk', u'cam.ac.uk', u'cam.ac.uk', u'cam.ac.uk',
#         u'cam.ac.uk', u'cam.ac.uk', u'cam.ac.uk', u'cam.ac.uk',
#         u'cam.ac.uk', u'cam.ac.uk', u'ioe.ac.uk', u'ioe.ac.uk', u'ioe.ac.uk'], dtype=object),
#  u'cardiff.ac.uk': array([u'cardiff.ac.uk', u'cardiff.ac.uk', u'cardiff.ac.uk'], dtype=object),
#  u'chester.ac.uk': array([u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'chester.ac.uk', u'chester.ac.uk'], dtype=object),
#  u'city.ac.uk': array([u'abdn.ac.uk', u'city.ac.uk', u'city.ac.uk', u'city.ac.uk'], dtype=object),
#  u'colostate.edu': array([u'colostate.edu'], dtype=object),
#  u'columbia.edu': array([u'abdn.ac.uk', u'columbia.edu', u'columbia.edu'], dtype=object),
#  u'cornell.edu': array([u'abdn.ac.uk', u'cornell.edu', u'cornell.edu', u'osu.edu'], dtype=object),
#  u'dal.ca': array([u'dal.ca'], dtype=object),
#  u'duke.edu': array([u'abdn.ac.uk', u'lshtm.ac.uk', u'uea.ac.uk', u'uea.ac.uk',
#         u'york.ac.uk', u'duke.edu', u'lse.ac.uk'], dtype=object),
#  u'dundee.ac.uk': array([u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'dundee.ac.uk', u'dundee.ac.uk', u'dundee.ac.uk',
#         u'dundee.ac.uk', u'dundee.ac.uk', u'dundee.ac.uk', u'dundee.ac.uk',
#         u'dundee.ac.uk', u'dundee.ac.uk', u'dundee.ac.uk', u'dundee.ac.uk',
#         u'dundee.ac.uk', u'dundee.ac.uk', u'dundee.ac.uk', u'dundee.ac.uk',
#         u'dundee.ac.uk', u'dundee.ac.uk', u'dundee.ac.uk', u'dundee.ac.uk',
#         u'ed.ac.uk', u'ed.ac.uk', u'ed.ac.uk', u'ed.ac.uk', u'ed.ac.uk',
#         u'ed.ac.uk', u'ed.ac.uk', u'ed.ac.uk', u'ed.ac.uk', u'ed.ac.uk',
#         u'lshtm.ac.uk', u'lshtm.ac.uk', u'lshtm.ac.uk', u'lshtm.ac.uk',
#         u'lshtm.ac.uk', u'lshtm.ac.uk', u'lshtm.ac.uk', u'lshtm.ac.uk',
#         u'lshtm.ac.uk', u'lshtm.ac.uk', u'cam.ac.uk', u'cam.ac.uk',
#         u'cam.ac.uk', u'strath.ac.uk', u'kcl.ac.uk', u'kcl.ac.uk',
#         u'kcl.ac.uk', u'kcl.ac.uk', u'kcl.ac.uk', u'ioe.ac.uk',
#         u'ioe.ac.uk', u'ioe.ac.uk'], dtype=object),
#  u'ed.ac.uk': array([u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'dundee.ac.uk',
#         u'dundee.ac.uk', u'dundee.ac.uk', u'dundee.ac.uk', u'ed.ac.uk',
#         u'ed.ac.uk', u'ed.ac.uk', u'ed.ac.uk', u'ed.ac.uk', u'ed.ac.uk',
#         u'ed.ac.uk', u'ed.ac.uk', u'ed.ac.uk', u'ed.ac.uk', u'ed.ac.uk',
#         u'ed.ac.uk', u'ed.ac.uk', u'ed.ac.uk', u'ed.ac.uk', u'ed.ac.uk',
#         u'ed.ac.uk', u'ed.ac.uk', u'ed.ac.uk', u'ed.ac.uk', u'ed.ac.uk',
#         u'ed.ac.uk', u'ed.ac.uk', u'ed.ac.uk', u'ed.ac.uk', u'ed.ac.uk',
#         u'ed.ac.uk', u'ed.ac.uk', u'ed.ac.uk', u'ed.ac.uk', u'ed.ac.uk',
#         u'ed.ac.uk', u'ed.ac.uk', u'ed.ac.uk', u'ed.ac.uk', u'ed.ac.uk',
#         u'ed.ac.uk', u'ed.ac.uk', u'ed.ac.uk', u'ed.ac.uk', u'ed.ac.uk',
#         u'ed.ac.uk', u'ed.ac.uk', u'ed.ac.uk', u'ed.ac.uk', u'ed.ac.uk',
#         u'ed.ac.uk', u'ed.ac.uk', u'ed.ac.uk', u'ed.ac.uk', u'ed.ac.uk',
#         u'ed.ac.uk', u'kcl.ac.uk', u'kcl.ac.uk', u'kcl.ac.uk', u'kcl.ac.uk',
#         u'kcl.ac.uk', u'wlv.ac.uk', u'wlv.ac.uk'], dtype=object),
#  u'espol.edu.ec': array([u'abdn.ac.uk', u'abdn.ac.uk', u'espol.edu.ec'], dtype=object),
#  u'essex.ac.uk': array([u'essex.ac.uk'], dtype=object),
#  u'gcal.ac.uk': array([u'gcal.ac.uk', u'gcal.ac.uk', u'gcal.ac.uk'], dtype=object),
#  u'guc.edu.eg': array([u'guc.edu.eg'], dtype=object),
#  u'hallym.ac.kr': array([u'hallym.ac.kr'], dtype=object),
#  u'helsinki.fi': array([u'abdn.ac.uk', u'helsinki.fi', u'helsinki.fi', u'helsinki.fi',
#         u'helsinki.fi', u'uni-mainz.de', u'sghms.ac.uk'], dtype=object),
#  u'hull.ac.uk': array([u'hull.ac.uk'], dtype=object),
#  u'hw.ac.uk': array([u'abdn.ac.uk', u'abdn.ac.uk', u'bangor.ac.uk', u'hw.ac.uk',
#         u'hw.ac.uk', u'hw.ac.uk', u'hw.ac.uk'], dtype=object),
#  u'iitb.ac.in': array([u'iitb.ac.in'], dtype=object),
#  u'iiti.ac.in': array([u'iiti.ac.in'], dtype=object),
#  u'ioe.ac.uk': array([u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'dundee.ac.uk', u'dundee.ac.uk',
#         u'dundee.ac.uk', u'lshtm.ac.uk', u'lshtm.ac.uk', u'lshtm.ac.uk',
#         u'lshtm.ac.uk', u'lshtm.ac.uk', u'lshtm.ac.uk', u'lshtm.ac.uk',
#         u'lshtm.ac.uk', u'lshtm.ac.uk', u'lshtm.ac.uk', u'cam.ac.uk',
#         u'cam.ac.uk', u'cam.ac.uk', u'ioe.ac.uk', u'ioe.ac.uk', u'ioe.ac.uk'], dtype=object),
#  u'jlu.edu.cn': array([u'abdn.ac.uk', u'abdn.ac.uk', u'jlu.edu.cn', u'jlu.edu.cn'], dtype=object),
#  u'jnu.edu.cn': array([u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'jnu.edu.cn', u'jnu.edu.cn'], dtype=object),
#  u'kau.edu.sa': array([u'kau.edu.sa'], dtype=object),
#  u'kcl.ac.uk': array([u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'dundee.ac.uk', u'dundee.ac.uk', u'dundee.ac.uk',
#         u'ed.ac.uk', u'ed.ac.uk', u'ed.ac.uk', u'ed.ac.uk', u'ed.ac.uk',
#         u'kcl.ac.uk', u'kcl.ac.uk', u'kcl.ac.uk', u'kcl.ac.uk',
#         u'kcl.ac.uk', u'kcl.ac.uk', u'kcl.ac.uk', u'kcl.ac.uk',
#         u'kcl.ac.uk', u'kcl.ac.uk', u'kcl.ac.uk', u'kcl.ac.uk', u'kcl.ac.uk'], dtype=object),
#  u'keele.ac.uk': array([u'keele.ac.uk'], dtype=object),
#  u'keene.edu': array([u'keene.edu'], dtype=object),
#  u'kent.edu': array([u'kent.edu'], dtype=object),
#  u'ki.se': array([u'ki.se', u'ki.se', u'ki.se', u'ki.se'], dtype=object),
#  u'kth.se': array([u'kth.se'], dtype=object),
#  u'lboro.ac.uk': array([u'abdn.ac.uk', u'abdn.ac.uk', u'strath.ac.uk', u'strath.ac.uk',
#         u'strath.ac.uk', u'strath.ac.uk', u'strath.ac.uk', u'strath.ac.uk',
#         u'lboro.ac.uk', u'lboro.ac.uk', u'lboro.ac.uk'], dtype=object),
#  u'le.ac.uk': array([u'abdn.ac.uk', u'le.ac.uk'], dtype=object),
#  u'leeds.ac.uk': array([u'leeds.ac.uk', u'leeds.ac.uk', u'leeds.ac.uk', u'leeds.ac.uk',
#         u'leeds.ac.uk', u'leeds.ac.uk', u'leeds.ac.uk', u'leeds.ac.uk',
#         u'leeds.ac.uk', u'leeds.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'stir.ac.uk', u'nottingham.ac.uk', u'bham.ac.uk', u'bham.ac.uk',
#         u'warwick.ac.uk', u'warwick.ac.uk'], dtype=object),
#  u'liv.ac.uk': array([u'abdn.ac.uk', u'liv.ac.uk', u'liv.ac.uk', u'liv.ac.uk'], dtype=object),
#  u'lse.ac.uk': array([u'abdn.ac.uk', u'lshtm.ac.uk', u'uea.ac.uk', u'uea.ac.uk',
#         u'york.ac.uk', u'duke.edu', u'lse.ac.uk', u'lse.ac.uk'], dtype=object),
#  u'lshtm.ac.uk': array([u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'dundee.ac.uk', u'dundee.ac.uk',
#         u'dundee.ac.uk', u'lshtm.ac.uk', u'lshtm.ac.uk', u'lshtm.ac.uk',
#         u'lshtm.ac.uk', u'lshtm.ac.uk', u'lshtm.ac.uk', u'lshtm.ac.uk',
#         u'lshtm.ac.uk', u'lshtm.ac.uk', u'lshtm.ac.uk', u'lshtm.ac.uk',
#         u'lshtm.ac.uk', u'lshtm.ac.uk', u'lshtm.ac.uk', u'lshtm.ac.uk',
#         u'lshtm.ac.uk', u'lshtm.ac.uk', u'umontreal.ca', u'umontreal.ca',
#         u'cam.ac.uk', u'cam.ac.uk', u'cam.ac.uk', u'uea.ac.uk',
#         u'uea.ac.uk', u'york.ac.uk', u'ioe.ac.uk', u'ioe.ac.uk',
#         u'ioe.ac.uk', u'duke.edu', u'lse.ac.uk'], dtype=object),
#  u'lzu.edu.cn': array([u'lzu.edu.cn', u'lzu.edu.cn', u'lzu.edu.cn', u'asu.edu', u'asu.edu'], dtype=object),
#  u'mans.edu.eg': array([u'mans.edu.eg'], dtype=object),
#  u'mcmaster.ca': array([u'mcmaster.ca', u'mcmaster.ca', u'mcmaster.ca', u'mcmaster.ca',
#         u'mcmaster.ca', u'mcmaster.ca', u'mcmaster.ca', u'mcmaster.ca',
#         u'mcmaster.ca'], dtype=object),
#  u'missouri.edu': array([u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'missouri.edu'], dtype=object),
#  u'mit.edu': array([u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'mit.edu'], dtype=object),
#  u'mmu.ac.uk': array([u'abdn.ac.uk', u'mmu.ac.uk'], dtype=object),
#  u'napier.ac.uk': array([u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'rgu.ac.uk',
#         u'napier.ac.uk'], dtype=object),
#  u'ncl.ac.uk': array([u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'ucl.ac.uk',
#         u'ncl.ac.uk', u'ncl.ac.uk', u'ncl.ac.uk', u'ncl.ac.uk',
#         u'ncl.ac.uk', u'ncl.ac.uk', u'ncl.ac.uk', u'ncl.ac.uk',
#         u'ncl.ac.uk', u'ncl.ac.uk', u'ncl.ac.uk', u'ncl.ac.uk',
#         u'ncl.ac.uk', u'ncl.ac.uk', u'ncl.ac.uk', u'ncl.ac.uk',
#         u'ncl.ac.uk', u'ncl.ac.uk', u'ncl.ac.uk', u'ncl.ac.uk',
#         u'ncl.ac.uk', u'ncl.ac.uk', u'ncl.ac.uk', u'ncl.ac.uk',
#         u'ncl.ac.uk', u'ncl.ac.uk', u'ncl.ac.uk', u'ncl.ac.uk',
#         u'ncl.ac.uk', u'ncl.ac.uk', u'ncl.ac.uk', u'ncl.ac.uk',
#         u'ncl.ac.uk', u'ncl.ac.uk', u'ncl.ac.uk', u'ncl.ac.uk',
#         u'ncl.ac.uk', u'ncl.ac.uk', u'ncl.ac.uk', u'ncl.ac.uk',
#         u'ncl.ac.uk', u'ncl.ac.uk', u'ncl.ac.uk', u'ncl.ac.uk',
#         u'ncl.ac.uk', u'ncl.ac.uk', u'ncl.ac.uk', u'ncl.ac.uk',
#         u'ncl.ac.uk', u'ncl.ac.uk', u'ncl.ac.uk', u'ncl.ac.uk',
#         u'ncl.ac.uk', u'ncl.ac.uk', u'ncl.ac.uk', u'ncl.ac.uk',
#         u'ncl.ac.uk', u'ncl.ac.uk', u'ncl.ac.uk', u'ncl.ac.uk',
#         u'ncl.ac.uk', u'ncl.ac.uk', u'ncl.ac.uk', u'ncl.ac.uk',
#         u'ncl.ac.uk', u'ncl.ac.uk', u'uea.ac.uk', u'uottawa.ca',
#         u'uottawa.ca', u'buffalo.edu'], dtype=object),
#  u'nd.edu': array([u'abdn.ac.uk', u'abdn.ac.uk', u'nd.edu', u'nd.edu'], dtype=object),
#  u'newcastle.edu.au': array([u'abdn.ac.uk', u'newcastle.edu.au'], dtype=object),
#  u'njau.edu.cn': array([u'njau.edu.cn'], dtype=object),
#  u'nottingham.ac.uk': array([u'leeds.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'stir.ac.uk', u'nottingham.ac.uk', u'nottingham.ac.uk',
#         u'nottingham.ac.uk', u'nottingham.ac.uk', u'nottingham.ac.uk',
#         u'nottingham.ac.uk', u'nottingham.ac.uk', u'nottingham.ac.uk',
#         u'bham.ac.uk', u'bham.ac.uk', u'warwick.ac.uk', u'warwick.ac.uk'], dtype=object),
#  u'nottingham.edu.my': array([u'abdn.ac.uk', u'nottingham.edu.my'], dtype=object),
#  u'ntnu.no': array([u'ntnu.no'], dtype=object),
#  u'omu.edu.tr': array([u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'omu.edu.tr', u'omu.edu.tr', u'ug.edu.gh'], dtype=object),
#  u'osu.edu': array([u'abdn.ac.uk', u'cornell.edu', u'osu.edu'], dtype=object),
#  u'otago.ac.nz': array([u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'bham.ac.uk',
#         u'bham.ac.uk', u'otago.ac.nz', u'otago.ac.nz', u'otago.ac.nz'], dtype=object),
#  u'p.lodz.pl': array([u'p.lodz.pl'], dtype=object),
#  u'pi.ac.ae': array([u'pi.ac.ae'], dtype=object),
#  u'pitt.edu': array([u'abdn.ac.uk', u'pitt.edu'], dtype=object),
#  u'plymouth.ac.uk': array([u'plymouth.ac.uk', u'plymouth.ac.uk'], dtype=object),
#  u'pucrs.br': array([u'abdn.ac.uk', u'pucrs.br'], dtype=object),
#  u'purdue.edu': array([u'purdue.edu'], dtype=object),
#  u'qub.ac.uk': array([u'abdn.ac.uk', u'qub.ac.uk', u'qub.ac.uk'], dtype=object),
#  u'queensu.ca': array([u'queensu.ca'], dtype=object),
#  u'rgu.ac.uk': array([u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'rgu.ac.uk', u'rgu.ac.uk', u'rgu.ac.uk', u'rgu.ac.uk',
#         u'rgu.ac.uk', u'rgu.ac.uk', u'napier.ac.uk'], dtype=object),
#  u'rug.nl': array([u'rug.nl'], dtype=object),
#  u'salford.ac.uk': array([u'salford.ac.uk'], dtype=object),
#  u'sghms.ac.uk': array([u'abdn.ac.uk', u'helsinki.fi', u'sghms.ac.uk'], dtype=object),
#  u'slu.se': array([u'slu.se'], dtype=object),
#  u'soton.ac.uk': array([u'abdn.ac.uk', u'soton.ac.uk', u'soton.ac.uk', u'soton.ac.uk',
#         u'soton.ac.uk', u'soton.ac.uk', u'soton.ac.uk', u'soton.ac.uk',
#         u'soton.ac.uk'], dtype=object),
#  u'stir.ac.uk': array([u'leeds.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'stir.ac.uk', u'stir.ac.uk',
#         u'stir.ac.uk', u'stir.ac.uk', u'stir.ac.uk', u'stir.ac.uk',
#         u'stir.ac.uk', u'stir.ac.uk', u'stir.ac.uk', u'nottingham.ac.uk',
#         u'bham.ac.uk', u'bham.ac.uk', u'abertay.ac.uk', u'warwick.ac.uk',
#         u'warwick.ac.uk'], dtype=object),
#  u'strath.ac.uk': array([u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'dundee.ac.uk', u'strath.ac.uk',
#         u'strath.ac.uk', u'strath.ac.uk', u'strath.ac.uk', u'strath.ac.uk',
#         u'strath.ac.uk', u'strath.ac.uk', u'strath.ac.uk', u'strath.ac.uk',
#         u'lboro.ac.uk', u'lboro.ac.uk'], dtype=object),
#  u'surrey.ac.uk': array([u'surrey.ac.uk', u'surrey.ac.uk'], dtype=object),
#  u'syr.edu': array([u'abdn.ac.uk', u'abdn.ac.uk', u'syr.edu', u'syr.edu', u'syr.edu',
#         u'syr.edu', u'syr.edu', u'syr.edu'], dtype=object),
#  u'tabrizu.ac.ir': array([u'abdn.ac.uk', u'abdn.ac.uk', u'tabrizu.ac.ir', u'uni-bayreuth.de'], dtype=object),
#  u'tongji.edu.cn': array([u'tongji.edu.cn'], dtype=object),
#  u'tum.de': array([u'tum.de'], dtype=object),
#  u'ua.pt': array([u'abdn.ac.uk', u'ua.pt'], dtype=object),
#  u'uah.es': array([u'uah.es'], dtype=object),
#  u'ucalgary.ca': array([u'abdn.ac.uk', u'ucalgary.ca'], dtype=object),
#  u'ucd.ie': array([u'ucd.ie'], dtype=object),
#  u'uchile.cl': array([u'uchile.cl'], dtype=object),
#  u'ucl.ac.uk': array([u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'ucl.ac.uk', u'ucl.ac.uk', u'ucl.ac.uk', u'ucl.ac.uk',
#         u'ucl.ac.uk', u'ucl.ac.uk', u'ucl.ac.uk', u'ucl.ac.uk',
#         u'ucl.ac.uk', u'ucl.ac.uk', u'ucl.ac.uk', u'ucl.ac.uk',
#         u'ucl.ac.uk', u'ucl.ac.uk', u'ncl.ac.uk'], dtype=object),
#  u'ucla.edu': array([u'ucla.edu', u'ucla.edu'], dtype=object),
#  u'uclan.ac.uk': array([u'uclan.ac.uk', u'uclan.ac.uk'], dtype=object),
#  u'ucmerced.edu': array([u'ucmerced.edu'], dtype=object),
#  u'uct.ac.za': array([u'uct.ac.za'], dtype=object),
#  u'uea.ac.uk': array([u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'lshtm.ac.uk', u'ncl.ac.uk', u'uea.ac.uk', u'uea.ac.uk',
#         u'uea.ac.uk', u'uea.ac.uk', u'uea.ac.uk', u'uea.ac.uk',
#         u'york.ac.uk', u'duke.edu', u'lse.ac.uk'], dtype=object),
#  u'ufc.br': array([u'abdn.ac.uk', u'univie.ac.at', u'ufc.br'], dtype=object),
#  u'ug.edu.gh': array([u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'omu.edu.tr', u'ug.edu.gh', u'ug.edu.gh'], dtype=object),
#  u'uib.no': array([u'uib.no'], dtype=object),
#  u'uiowa.edu': array([u'uiowa.edu'], dtype=object),
#  u'uit.no': array([u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'uit.no'], dtype=object),
#  u'ujn.edu.cn': array([u'ujn.edu.cn'], dtype=object),
#  u'um.edu.my': array([u'um.edu.my'], dtype=object),
#  u'umanitoba.ca': array([u'umanitoba.ca'], dtype=object),
#  u'umd.edu': array([u'umd.edu'], dtype=object),
#  u'umontreal.ca': array([u'abdn.ac.uk', u'abdn.ac.uk', u'lshtm.ac.uk', u'lshtm.ac.uk',
#         u'umontreal.ca', u'umontreal.ca'], dtype=object),
#  u'uni-bayreuth.de': array([u'abdn.ac.uk', u'abdn.ac.uk', u'tabrizu.ac.ir', u'uni-bayreuth.de'], dtype=object),
#  u'uni-bonn.de': array([u'uni-bonn.de', u'uni-bonn.de'], dtype=object),
#  u'uni-bremen.de': array([u'uni-bremen.de', u'uni-bremen.de'], dtype=object),
#  u'uni-duesseldorf.de': array([u'uni-duesseldorf.de'], dtype=object),
#  u'uni-duisburg-essen.de': array([u'uni-duisburg-essen.de'], dtype=object),
#  u'uni-leipzig.de': array([u'uni-leipzig.de', u'uni-leipzig.de'], dtype=object),
#  u'uni-mainz.de': array([u'helsinki.fi', u'uni-mainz.de'], dtype=object),
#  u'uni-mannheim.de': array([u'uni-mannheim.de'], dtype=object),
#  u'uni-potsdam.de': array([u'abdn.ac.uk', u'uni-potsdam.de'], dtype=object),
#  u'unige.ch': array([u'abdn.ac.uk', u'abdn.ac.uk', u'unige.ch', u'unige.ch'], dtype=object),
#  u'unikl.edu.my': array([u'unikl.edu.my'], dtype=object),
#  u'unimelb.edu.au': array([u'unimelb.edu.au'], dtype=object),
#  u'unisa.edu.au': array([u'unisa.edu.au'], dtype=object),
#  u'unitn.it': array([u'abdn.ac.uk', u'unitn.it', u'unitn.it'], dtype=object),
#  u'univ-angers.fr': array([u'univ-angers.fr', u'univ-angers.fr'], dtype=object),
#  u'univ-lyon1.fr': array([u'univ-lyon1.fr'], dtype=object),
#  u'univ-montp2.fr': array([u'univ-montp2.fr'], dtype=object),
#  u'univie.ac.at': array([u'abdn.ac.uk', u'univie.ac.at', u'univie.ac.at', u'univie.ac.at',
#         u'ufc.br'], dtype=object),
#  u'uottawa.ca': array([u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'ncl.ac.uk', u'ncl.ac.uk', u'uottawa.ca', u'uottawa.ca',
#         u'uottawa.ca'], dtype=object),
#  u'upm.edu.my': array([u'upm.edu.my'], dtype=object),
#  u'uq.edu.au': array([u'abdn.ac.uk', u'uq.edu.au'], dtype=object),
#  u'usc.es': array([u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'usc.es', u'usc.es',
#         u'usc.es', u'usc.es', u'usc.es', u'usc.es', u'usp.ac.fj',
#         u'usp.ac.fj', u'usp.ac.fj', u'usp.ac.fj'], dtype=object),
#  u'usp.ac.fj': array([u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'usc.es', u'usc.es',
#         u'usc.es', u'usc.es', u'usp.ac.fj', u'usp.ac.fj', u'usp.ac.fj',
#         u'usp.ac.fj'], dtype=object),
#  u'usp.br': array([u'usp.br'], dtype=object),
#  u'ut.ee': array([u'ut.ee'], dtype=object),
#  u'uth.gr': array([u'uth.gr'], dtype=object),
#  u'utoronto.ca': array([u'utoronto.ca', u'utoronto.ca', u'utoronto.ca', u'utoronto.ca',
#         u'utoronto.ca', u'utoronto.ca', u'utoronto.ca', u'utoronto.ca'], dtype=object),
#  u'utwente.nl': array([u'abdn.ac.uk', u'utwente.nl', u'utwente.nl', u'utwente.nl',
#         u'utwente.nl'], dtype=object),
#  u'uu.nl': array([u'uu.nl'], dtype=object),
#  u'uva.es': array([u'uva.es'], dtype=object),
#  u'uva.nl': array([u'abdn.ac.uk', u'uva.nl', u'uva.nl'], dtype=object),
#  u'uvm.edu': array([u'uvm.edu'], dtype=object),
#  u'uw.edu': array([u'uw.edu'], dtype=object),
#  u'uwa.edu.au': array([u'uwa.edu.au'], dtype=object),
#  u'uwm.edu': array([u'abdn.ac.uk', u'uwm.edu', u'uwm.edu', u'uwm.edu', u'uwm.edu',
#         u'uwm.edu'], dtype=object),
#  u'uws.edu.au': array([u'abdn.ac.uk', u'uws.edu.au'], dtype=object),
#  u'vit.ac.in': array([u'vit.ac.in'], dtype=object),
#  u'warwick.ac.uk': array([u'leeds.ac.uk', u'abdn.ac.uk', u'stir.ac.uk', u'nottingham.ac.uk',
#         u'bham.ac.uk', u'bham.ac.uk', u'warwick.ac.uk', u'warwick.ac.uk',
#         u'warwick.ac.uk', u'warwick.ac.uk'], dtype=object),
#  u'weizmann.ac.il': array([u'weizmann.ac.il'], dtype=object),
#  u'wisc.edu': array([u'wisc.edu', u'wisc.edu'], dtype=object),
#  u'wlv.ac.uk': array([u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk',
#         u'abdn.ac.uk', u'ed.ac.uk', u'ed.ac.uk', u'wlv.ac.uk', u'wlv.ac.uk'], dtype=object),
#  u'york.ac.uk': array([u'abdn.ac.uk', u'abdn.ac.uk', u'abdn.ac.uk', u'lshtm.ac.uk',
#         u'uea.ac.uk', u'uea.ac.uk', u'york.ac.uk', u'york.ac.uk',
#         u'york.ac.uk', u'york.ac.uk', u'york.ac.uk', u'york.ac.uk',
#         u'york.ac.uk', u'duke.edu', u'lse.ac.uk'], dtype=object)}

# %% [markdown]
# And now let's group by to find biggest instituions collaborating with Aberdeen:

# %%
# merged_domains.groupby(['domain']).agg(['count']).reset_index('count').sort_values(['count'], ascending=False)
count_frame = merged_domains.groupby(['domain']).count().sort_values([1],ascending=False)#.reset_index('count').sort_values(['count'], ascending=False)
count_frame.head(10)
# Out:
#                  0     1  alpha_two_code  country  name  web_page
# domain
# abdn.ac.uk    1111  1111            1111     1111  1111      1111
# ncl.ac.uk       66    66              66       66    66        66
# ed.ac.uk        52    52              52       52    52        52
# dundee.ac.uk    19    19              19       19    19        19
# lshtm.ac.uk     17    17              17       17    17        17
# ucl.ac.uk       14    14              14       14    14        14
# kcl.ac.uk       13    13              13       13    13        13
# cam.ac.uk       12    12              12       12    12        12
# bham.ac.uk      10    10              10       10    10        10
# leeds.ac.uk     10    10              10       10    10        10

# %%
# count_frame = count_frame.ix[:,0:1]
# count_frame['ddomain'] = count_frame.index
# count_frame.head(10)
print(count_frame.index)
# Out:
# Index([u'abdn.ac.uk', u'ncl.ac.uk', u'ed.ac.uk', u'dundee.ac.uk',
#        u'lshtm.ac.uk', u'ucl.ac.uk', u'kcl.ac.uk', u'cam.ac.uk', u'bham.ac.uk',
#        u'leeds.ac.uk',
#        ...
#        u'tongji.edu.cn', u'le.ac.uk', u'adelaide.edu.au', u'uchile.cl',
#        u'ucd.ie', u'ucalgary.ca', u'uah.es', u'ua.pt', u'tum.de',
#        u'queensu.ca'],
#       dtype='object', name=u'domain', length=153)

# %% [markdown]
# ## External author-collaborators over time

# %%
import pickle 
import re
def get_all_emails_with_time_of_repository(repoId):
    all_emails = []
    for page_pickle in range(1,10):
        try:
            articles = pickle.load(open('data/all_articles_on'+str(repoId)+'_'+str(page_pickle)+'.pkl','rb'))
            for page in range(0,len(articles)):
                for item in articles[page]['data']:
                    text = item['fullText']
                    article_id=item['id']
                    year=item['year']
                    match = re.findall(r'[\w\.-]+@[\w\.-]+', text)
#                     print(match)
                    all_emails.append([article_id, year,match])
        except (OSError,IOError) as e:
            print(e)
    return all_emails

# %%
def flatten_list(unevenList):
    flat_list=[]
    for sublist in unevenList:
        aid=sublist[0]
        y=sublist[1]
        emails = sublist[2]
        for item in emails:
            flat_list.append([aid,y,item])
    return flat_list

# %%
aberdeen_emails_with_years= get_all_emails_with_time_of_repository(1)

# %%
aberdeen_emails_with_years_flatten=flatten_list(aberdeen_emails_with_years)

# %%
aberdeen_df = pd.DataFrame.from_records(aberdeen_emails_with_years_flatten)
aberdeen_df.head()
# Out:
#           0     1                                  2
# 0  19787393  2014             L.V.Burgin@leeds.ac.uk
# 1  19787393  2014  Lorna.ramsay@education.gsi.gov.uk
# 2  19787393  2014                r.aspden@abdn.ac.uk
# 3  19787406  2014            david.mcghee@abdn.ac.uk
# 4  20327925  2014                j.mercer@abdn.ac.uk

# %%
aberdeen_df['domain']=aberdeen_df.apply(lambda row: extract_domain(row[2]),axis=1)
aberdeen_df.head()
# Out:
#           0     1                                  2                domain
# 0  19787393  2014             L.V.Burgin@leeds.ac.uk           leeds.ac.uk
# 1  19787393  2014  Lorna.ramsay@education.gsi.gov.uk  education.gsi.gov.uk
# 2  19787393  2014                r.aspden@abdn.ac.uk            abdn.ac.uk
# 3  19787406  2014            david.mcghee@abdn.ac.uk            abdn.ac.uk
# 4  20327925  2014                j.mercer@abdn.ac.uk            abdn.ac.uk

# %%
aberdeen_df.columns = ["articleId","year","author_email","author_domain"]
aberdeen_df['external']=aberdeen_df['author_domain']!='abdn.ac.uk'

aberdeen_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2936 entries, 0 to 2935
# Data columns (total 5 columns):
# articleId        2936 non-null object
# year             2936 non-null int64
# author_email     2936 non-null object
# author_domain    2936 non-null object
# external         2936 non-null bool
# dtypes: bool(1), int64(1), object(3)
# memory usage: 94.7+ KB

# %%
# ab_gr_df = aberdeen_df.groupby(["year"]).count().sort(["year"],ascending=False)#.reset_index('count').sort_values(['count'], ascending=False)
ab_gr_df = aberdeen_df.groupby(["year","external"]).count()
ab_gr_df
# Out:
#                articleId  author_email  author_domain
# year external
# 2001 True              2             2              2
# 2002 False             1             1              1
#      True              2             2              2
# 2003 True              2             2              2
# 2004 False            15            15             15
#      True              8             8              8
# 2005 False            10            10             10
#      True             18            18             18
# 2006 False            46            46             46
#      True             72            72             72
# 2007 False            87            87             87
#      True            140           140            140
# 2008 False            68            68             68
#      True            115           115            115
# 2009 False            60            60             60
#      True            119           119            119
# 2010 False            37            37             37
#      True             89            89             89
# 2011 False            72            72             72
#      True            167           167            167
# 2012 False           100           100            100
#      True            112           112            112
# 2013 False            91            91             91
#      True            120           120            120
# 2014 False            49            49             49
#      True             64            64             64
# 2015 False           195           195            195
#      True            365           365            365
# 2016 False           244           244            244
#      True            382           382            382
# 2017 False            36            36             36
#      True             48            48             48

# %%
ab_gr_df['articleId']
# Out:
# year  external
# 2001  True          2
# 2002  False         1
#       True          2
# 2003  True          2
# 2004  False        15
#       True          8
# 2005  False        10
#       True         18
# 2006  False        46
#       True         72
# 2007  False        87
#       True        140
# 2008  False        68
#       True        115
# 2009  False        60
#       True        119
# 2010  False        37
#       True         89
# 2011  False        72
#       True        167
# 2012  False       100
#       True        112
# 2013  False        91
#       True        120
# 2014  False        49
#       True         64
# 2015  False       195
#       True        365
# 2016  False       244
#       True        382
# 2017  False        36
#       True         48
# Name: articleId, dtype: int64

# %%
## Collaborators across universities

# %%
emails_of_repository=dict()
cached_repos=[1,86,39,136,48]
for i in cached_repos:
    emails_of_repository[i]=get_all_emails_of_repository(i)

# %%
emails_of_repository
# Out:
# []

# %%
## Combining important terms with external collaboration networks
### What are the topics that gets the most external authors ?

# %%
import itertools
import matplotlib.patches as patches
import matplotlib.pyplot as plt
import numpy as np
import sys

domain_list= list(unique_domains)
fig, ax = plt.subplots()

npoints = len(domain_list)

# Calculate the xy coords for each point on the circle
s = 2 * np.pi / npoints
verts = np.zeros((npoints, 2))
for i in np.arange(npoints):
    angle = s * i
    x = npoints * np.cos(angle)
    y = npoints * np.sin(angle)
    verts[i] = [x, y]

# Plot the Bezier curves
numbers = [i for i in xrange(npoints)]
bezier_path = np.arange(0, 1.01, 0.01)
for a,b in itertools.product(domain_list, repeat=2):
    if a == b:
        continue
       
    if a in domain_id_dict[b]:
        x1y1 = x1, y1 = verts[domain_list.index(a)]
        x2y2 = x2, y2 = verts[domain_list.index(a)]

        xbyb = xb, yb = [0, 0]

        # Compute and store the Bezier curve points
        x = (1 - bezier_path)** 2 * x1 + 2 * (1 - bezier_path) * bezier_path * xb + bezier_path** 2 * x2
        y = (1 - bezier_path)** 2 * y1 + 2 * (1 - bezier_path) * bezier_path * yb + bezier_path** 2 * y2

        ax.plot(x, y, 'k-')

x, y = verts.T
ax.scatter(x, y, marker='o', s=5, c='r')

ax.set_xlim(-npoints - 5, npoints + 6)
ax.set_ylim(-npoints - 5, npoints + 6)
ax.set(aspect=1)
# Out:
# [None]

# %%
node_color=['rgba(0,51,181, 0.85)' for d in domain_id_dict]
line_color=['#FFFFFF'  for d in domain_id_dict]
edge_colors=['#d4daff','#84a9dd', '#5588c8', '#6d8acf']

# %%
Xn=[layt[k][0] for k in range(len(domain_id_dict))]
Yn=[layt[k][1] for k in range(len(domain_id_dict))]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-137-bff75d671f49> in <module>()
# ----> 1 Xn=[layt[k][0] for k in range(len(domain_id_dict))]
#       2 Yn=[layt[k][1] for k in range(len(domain_id_dict))]
#
# NameError: name 'layt' is not defined
